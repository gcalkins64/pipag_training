# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.12/dist-packages (2.6.1)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.10.0+cu128)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.3)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Requirement already satisfied: torchmetrics>0.7.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (1.8.2)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (26.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (0.15.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.24.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1.0->pytorch_lightning) (1.3.4)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/pipag_training.git
# Out:
# fatal: destination path 'pipag_training' already exists and is not an empty directory.

# %%
# %cd pipag_training
# !cd /content/pipag_training && git pull
# !git pull
sys.path.append('/content/pipag_training')
# Out:
# /content/pipag_training
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 444.57 KiB | 1.52 MiB/s, done.
# From https://github.com/gcalkins64/pipag_training
#    5eb2b70..fb63a72  main       -> origin/main
# Updating 5eb2b70..fb63a72
# Fast-forward
#  JP_gmvae_aerocapture_SWEEP copy.ipynb | 38456 ++++++++------------------------
#  JP_gmvae_aerocapture_SWEEP.ipynb      | 31481 +++++---------------------
#  2 files changed, 13779 insertions(+), 56158 deletions(-)

# %%
# !ls
# Out:
#  compare_classification_accuracy.py	  models.py
#  compare_variance_gmvae.py		  move_figures_to_LB.py
#  generate_gif_from_pngs.py		 'old notebooks'
#  generate_training_json.py		  __pycache__
#  gmvae_common.py			  README.md
#  JP_gmvae_aerocapture_BASE_copy.ipynb	  svd.py
#  JP_gmvae_aerocapture_BASE.ipynb	  test_git_imports.ipynb
#  JP_gmvae_aerocapture_energy.ipynb	  vae_aerocapture_vel.py
# 'JP_gmvae_aerocapture_SWEEP copy.ipynb'   VAE_Capture.ipynb
#  JP_gmvae_aerocapture_SWEEP.ipynb	  VAE_sweep_arch.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1305: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
# n_train = 1024
# n_val = 128
# n_test = 128
# For testing small batches of data
n_train = 800
n_val = 100
n_test = 100
# THREE LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = 24
hd1 = 24
hd2 = 18
hd3 = 12
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = None
# hidden_dims = [hd1, hd2]

# latent_dims = [6]
# n_clustersS = [9]
latent_dims = [3,4,5,6,7,8,9]
n_clustersS = [3,4,5,6,7,8,9]
skip_combos = []
lr = 1e-3
n_epochs = 15_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

plot_interval = 500
dpi = 300

D = 1  #num_modalities
# downsampleNum = 64
downsampleNum = 36 # Revision

loadFlag = False  # True to load in old case, False to run a new case

# data = '1_near_escape_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_fnpag_1999_inds_energy_scaled_downsampled_'
# tag = 'near_escape'

# data = '1_near_crash_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_crash_fnpag_2000_inds_energy_scaled_downsampled_'
# tag = 'near_crash'

# data = 'UOP_inc_lit_disps_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_inc_lit_disps_4999_inds_energy_scaled_downsampled_'
# tag = 'near_escape_OLD'

# data = 'UOP_near_crash_steeper_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_near_crash_steeper_4997_inds_energy_scaled_downsampled_'
# tag = 'near_crash_OLD'

# data = '1_near_escape_new_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_new_2000_inds_energy_scaled_downsampled_'
# tag = 'near_escape_new'

# data = 'rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_'
# inds = 'rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_'
# tag = 'rev_gu_mixture'
# dataName = 'velocity_fpa'

# data = 'rev_gumixture_1000_data_energy_scaled_downsampled_'
# inds = 'rev_gumixture_1000_inds_energy_scaled_downsampled_'
# tag = 'rev_gu_mixture_energy'
# dataName = 'energy'

data = 'rev_gumixture_dp15_more_downwards_1000_data_energy_scaled_downsampled_'
inds = 'rev_gumixture_dp15_more_downwards_1000_inds_energy_scaled_downsampled_'
tag = 'rev_gu_mixture_energy_biased_down'
dataName = 'energy'

# %%
# !ls /content/drive/MyDrive/rev_pipag_data/
# Out:
# gmvae_rev_gu_mixture_20260216_184454_L5_C3
# gmvae_rev_gu_mixture_20260216_185127_L6_C3
# gmvae_rev_gu_mixture_20260216_190125_L5_C4
# gmvae_rev_gu_mixture_20260216_190656_L6_C4
# gmvae_rev_gu_mixture_20260216_191906_L5_C5
# gmvae_rev_gu_mixture_20260216_192236_L6_C5
# gmvae_rev_gu_mixture_20260216_193657_L5_C6
# gmvae_rev_gu_mixture_20260216_193840_L6_C6
# gmvae_rev_gu_mixture_20260216_201930_L7_C3
# gmvae_rev_gu_mixture_20260216_201945_L8_C3
# gmvae_rev_gu_mixture_20260216_203450_L7_C4
# gmvae_rev_gu_mixture_20260216_203532_L8_C4
# gmvae_rev_gu_mixture_20260216_205019_L7_C5
# gmvae_rev_gu_mixture_20260216_205122_L8_C5
# gmvae_rev_gu_mixture_20260216_210557_L7_C6
# gmvae_rev_gu_mixture_20260216_210713_L8_C6
# gmvae_rev_gu_mixture_20260216_221130_L5_C7
# gmvae_rev_gu_mixture_20260216_221251_L5_C3_24_18_12
# gmvae_rev_gu_mixture_20260216_221358_L5_C7
# gmvae_rev_gu_mixture_20260216_222846_L5_C4_24_18_12
# gmvae_rev_gu_mixture_20260216_223026_L5_C8
# gmvae_rev_gu_mixture_20260216_224438_L5_C5_24_18_12
# gmvae_rev_gu_mixture_20260216_224634_L6_C7
# gmvae_rev_gu_mixture_20260216_231212_L5_C6_24_18_12
# gmvae_rev_gu_mixture_20260216_231213_L6_C8
# gmvae_rev_gu_mixture_20260216_232708_L7_C7
# gmvae_rev_gu_mixture_20260216_232738_L6_C3_24_18_12
# gmvae_rev_gu_mixture_20260216_234208_L7_C8
# gmvae_rev_gu_mixture_20260216_234341_L6_C4_24_18_12
# gmvae_rev_gu_mixture_20260216_235712_L8_C7
# gmvae_rev_gu_mixture_20260216_235933_L6_C5_24_18_12
# gmvae_rev_gu_mixture_20260217_001230_L8_C8
# gmvae_rev_gu_mixture_20260217_001541_L6_C6_24_18_12
# gmvae_rev_gu_mixture_20260217_003159_L7_C3_24_18_12
# gmvae_rev_gu_mixture_20260217_004818_L7_C4_24_18_12
# gmvae_rev_gu_mixture_20260217_010413_L7_C5_24_18_12
# gmvae_rev_gu_mixture_20260217_034212_L5_C3
# gmvae_rev_gu_mixture_20260217_034216_L6_C3
# gmvae_rev_gu_mixture_20260217_035654_L6_C4
# gmvae_rev_gu_mixture_20260217_035749_L5_C4
# gmvae_rev_gu_mixture_20260217_041343_L5_C5
# gmvae_rev_gu_mixture_20260217_042650_L6_C6
# gmvae_rev_gu_mixture_20260217_042947_L5_C6
# gmvae_rev_gu_mixture_energy_20260217_181312_L5_C5
# gmvae_rev_gu_mixture_energy_20260217_181348_L5_C3
# gmvae_rev_gu_mixture_energy_20260217_182833_L5_C4
# gmvae_rev_gu_mixture_energy_20260217_182842_L5_C6
# gmvae_rev_gu_mixture_energy_20260217_184319_L6_C3
# gmvae_rev_gu_mixture_energy_20260217_184424_L6_C5
# gmvae_rev_gu_mixture_energy_20260217_185813_L6_C4
# gmvae_rev_gu_mixture_energy_20260217_190003_L6_C6
# gmvae_rev_gu_mixture_energy_20260217_191317_L7_C3
# gmvae_rev_gu_mixture_energy_20260217_191558_L7_C5
# gmvae_rev_gu_mixture_energy_20260217_192829_L7_C4
# gmvae_rev_gu_mixture_energy_20260217_193201_L7_C6
# gmvae_rev_gu_mixture_energy_20260218_000315_L5_C7
# gmvae_rev_gu_mixture_energy_20260218_000322_L8_C3
# gmvae_rev_gu_mixture_energy_20260218_001906_L8_C4
# gmvae_rev_gu_mixture_energy_20260218_002010_L5_C8
# gmvae_rev_gu_mixture_energy_20260218_003512_L8_C5
# gmvae_rev_gu_mixture_energy_20260218_003725_L6_C7
# gmvae_rev_gu_mixture_energy_20260218_005116_L8_C6
# gmvae_rev_gu_mixture_energy_20260218_011222_L6_C8
# gmvae_rev_gu_mixture_energy_20260218_011225_L8_C7
# gmvae_rev_gu_mixture_energy_20260218_012805_L8_C8
# gmvae_rev_gu_mixture_energy_20260218_012918_L7_C7
# gmvae_rev_gu_mixture_energy_20260218_014406_L9_C7
# gmvae_rev_gu_mixture_energy_20260218_014631_L7_C8
# gmvae_rev_gu_mixture_energy_20260218_015955_L9_C8
# gmvae_rev_gu_mixture_energy_20260218_211300_L9_C3
# gmvae_rev_gu_mixture_energy_20260218_211315_L9_C5
# gmvae_rev_gu_mixture_energy_20260218_212759_L9_C4
# gmvae_rev_gu_mixture_energy_20260218_212935_L9_C6
# gmvae_rev_gu_mixture_energy_biased_down_20260221_234903_L7_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260221_234920_L3_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_001119_L3_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_001514_L7_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_003345_L3_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_004152_L7_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_005654_L3_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_010903_L7_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_012030_L3_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_044731_L7_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_044827_L3_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_051155_L3_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_051250_L7_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_053457_L4_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_053647_L7_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_055734_L4_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_060048_L8_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_065508_L8_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_065517_L4_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_071818_L8_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_072116_L4_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_074139_L8_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_074639_L4_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_080533_L8_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_081213_L4_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_024308_L8_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_024328_L4_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_030455_L8_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_030531_L5_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_032658_L9_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_034937_L9_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_034940_L5_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_041207_L5_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_201426_L9_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_201512_L5_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_203727_L5_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_204218_L9_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_210002_L5_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_211041_L9_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_212252_L6_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_213859_L9_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_230824_L6_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_230826_L9_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_233138_L6_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_233722_L3_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260223_235531_L6_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260224_000019_L3_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_001941_L6_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260224_002347_L3_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_004338_L6_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260224_004618_L3_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_010834_L3_C7_24_18_12
# rev_gumixture_1000_data_energy_scaled_downsampled_.json
# rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_.json
# rev_gumixture_1000_inds_energy_scaled_downsampled_.json
# rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_.json
# rev_gumixture_dp15_more_downwards_1000_data_energy_scaled_downsampled_.json
# rev_gumixture_dp15_more_downwards_1000_inds_energy_scaled_downsampled_.json

# %% [markdown]
# # LOOP GMVAE TRAINING

# %%
for latent_dim in latent_dims:
   for n_clusters in n_clustersS:
      if [latent_dim, n_clusters] in skip_combos:
        continue
      else:
          K = n_clusters
          Z = latent_dim

          from datetime import datetime
          timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

          if loadFlag:  # Load in old data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", 'gmvae_em_aerocapture_energy_20250429_155508_5_4')
          else:  # generate new data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters)+"_"+str(hd1)+"_"+str(hd2)+"_"+str(hd3))
          os.makedirs(dirname, exist_ok=True)
          print("Filepath directory: " + dirname)

          if loadFlag:  # load old data
              postfix = '_42_1024_128_128_32_16_5_4_0.001000_128_0.001000_0.000010_1000.000000_'
          else:  # Generate new suffix
              if hd3 is not None:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
              else:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
          print("Filepath postfix: " + postfix)

          data_dir = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{data}.json")

          with open(os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{inds}.json"), 'r') as f:
              sample_list_load = json.load(f)
          sample_list = [int(sample) for sample in sample_list_load['sample_list']]
          print(sample_list)

          data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                          train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                          num_workers=0, dataName=dataName)

          data_module.setup("fit", sample_list = sample_list)

          train_loader = data_module.train_dataloader()
          val_loader = data_module.val_dataloader()
          test_loader = data_module.test_dataloader()
          data_dim = len(train_loader.dataset[0][0])
          text_labels = ['capture', 'escape', 'impact']
          label_colors = ['C2', 'C3', 'C4']

          num_train_batches = len(train_loader)

          ts_plot = np.linspace(0,450,36)
          seabornSettings()
          fig, ax = plt.subplots(figsize=(4, 4))
          for j in range(n_train):
              ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.75)

          eline = mlines.Line2D([], [], color='C2', label='Escape')
          cline = mlines.Line2D([], [], color='C3', label='Capture')
          iline = mlines.Line2D([], [], color='C4', label='Impact')
          plt.legend(handles=[eline, cline, iline])
          plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
          plt.xlabel("Time [s]")
          plt.ylabel("Nondimensionalized Energy")
          plt.title("Training Data")
          plt.tight_layout()
          fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_val):
              ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()])
          plt.title("Validation Data")
          fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_test):
              ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()])
          plt.title("Test Data")
          fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)
          # initialize latent GMM model parameters
          params = {}
          pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
          params['pi_c'] = torch.ones(K) / K
          params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
          params['logsigmasq_c'] = torch.zeros((K, Z))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]

          # initialize neural networks
          encoder_list = []
          decoder_list = []
          trainable_parameters = []
          trainable_parameters.append(pi_variables)

          for _ in range(D):
              encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
              decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
              encoder_list.append(encoder)
              decoder_list.append(decoder)
              trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

          optimizer = optim.Adam(trainable_parameters, lr=lr)

          # training

          import time
          ts = time.time()
          tic = time.perf_counter()

          train_loss = torch.zeros(n_epochs)
          train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_loss = torch.zeros(n_epochs)
          pi_history = torch.zeros((n_epochs, K))
          train_mse_history = torch.zeros(n_epochs)
          val_mse_history = torch.zeros(n_epochs)
          min_val_loss = torch.inf
          seabornSettings()

          for epoch in range(n_epochs):
              ti = time.time()
              for encoder in encoder_list:
                  encoder.train()
              for decoder in decoder_list:
                  decoder.train()

              train_elbo = 0
              train_mse = 0
              train_elbo_term = np.zeros(4)
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

              for (batch_idx, batch) in enumerate(train_loader):
                  batch_x, _ = batch
                  x_list = [batch_x]  # assume D=2 and each modality has data_dim
                  optimizer.zero_grad()
                  pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
                  params['pi_c'] = pi_c

                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma

                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                  train_elbo += elbo.item()
                  train_elbo_term += elbo_terms
                  train_mse += sse.item()
                  loss = - elbo / batch_x.shape[0]
                  loss.backward()
                  optimizer.step()

              for encoder in encoder_list:
                  encoder.eval()
              for decoder in decoder_list:
                  decoder.eval()

              if epoch % plot_interval == 0 or epoch == n_epochs:
                  # Plot the first two dimensions of the latents
                  with torch.no_grad():
                      means = []
                      samples = []
                      labels = []
                      for batch in train_loader:
                          batch_x, batch_label = batch
                          x_list = [batch_x]
                          mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                          sigma = torch.exp(0.5 * logsigmasq)
                          eps = Normal(0, 1).sample(mean.shape)
                          z = mean + eps * sigma
                          means.append(mean)
                          samples.append(z)
                          labels.append(batch_label)

                  means = torch.vstack(means).cpu()
                  samples = torch.vstack(samples).cpu()
                  labels = torch.hstack(labels).cpu()

                  savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

                  savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


                  # plot samples from generative model
                  n_gen = n_train
                  cluster_probs = params['pi_c'].cpu().detach().numpy() #
                  fig, ax = plt.subplots(figsize=(4.5, 4))
                  for j in range(n_gen):
                      c = np.random.choice(K, p=cluster_probs)
                      mu_c = params['mu_c'][c].clone().detach()
                      sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
                      z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
                      mu_x = decoder.forward(z)[0]
                      ax.plot(mu_x.cpu().detach().numpy())
                  fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
                  plt.close()


              val_elbo = 0
              val_mse = 0
              val_elbo_term = np.zeros(4)
              with torch.no_grad():
                  for (batch_idx, batch) in enumerate(val_loader):
                      batch_x, _ = batch
                      x_list = [batch_x]
                      mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                      sigma = torch.exp(0.5 * logsigmasq)
                      eps = Normal(0, 1).sample(mu.shape)
                      z = mu + eps * sigma
                      with torch.no_grad():
                          gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
                      elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                      val_elbo += elbo.item()
                      val_mse += sse.item()
                      val_elbo_term += elbo_items

              train_elbo /= len(train_loader.dataset)
              train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
              val_elbo /= len(val_loader.dataset)
              val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
              train_mse /= len(train_loader.dataset)
              val_mse /= len(val_loader.dataset)

              tf = time.time()
              toc = time.perf_counter()
              print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

              train_loss[epoch] = - train_elbo
              val_loss[epoch] = - val_elbo
              train_elbo_terms[epoch,:] = - train_elbo_term
              val_elbo_terms[epoch,:] = - val_elbo_term
              pi_history[epoch] = params['pi_c']
              train_mse_history[epoch] = train_mse
              val_mse_history[epoch] = val_mse

              if - val_elbo < min_val_loss:
                  min_val_loss = - val_elbo
                  torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
                  torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
                  torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
                  torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
                  torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

              if epoch % plot_interval == 0 or epoch == n_epochs:
                # Plot the training and validation loss vs. epoch number
                plt.figure(figsize=(4.5, 4))
                # const = min(min(train_loss), min(val_loss))
                train_loss_adjusted = train_loss
                val_loss_adjusted = val_loss
                plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
                # print(train_loss_adjusted.cpu()[:epoch])
                plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
                plt.yscale('symlog')
                plt.xlabel("number of epochs")
                plt.ylabel("loss")
                plt.title("Negative Loss")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot each term of the training loss and validation loss
                plt.figure(figsize=(4.5, 4))
                labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
                for ii in range(4):
                    train_loss_adjusted = train_elbo_terms[:epoch, ii]
                    val_loss_adjusted = val_elbo_terms[:epoch, ii]
                    plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
                    plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
                plt.xlabel("number of epochs")
                plt.yscale('symlog')
                plt.ylabel("loss")
                plt.title("Negative Loss Terms")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the training and validation mse vs. epoch number
                plt.figure(figsize=(4.5, 4))
                plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
                plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the history of pi
                plt.figure(figsize=(4.5, 4))
                for i in range(K):
                    plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()


          te = time.time()
          import datetime
          duration = datetime.timedelta(seconds=te - ts)
          print("Training took ", duration)

          # Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
          torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))

          if loadFlag:
            path = dirname
            epoch = n_epochs - 1
          params = {}
          encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
          decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")

          # Use if you need to load in the data
          if loadFlag:
            suffix = postfix
            encoder.load_state_dict(torch.load(os.path.join(path, f'encoder_{suffix}.pt'),map_location=torch.device('cpu')))
            decoder.load_state_dict(torch.load(os.path.join(path, f'decoder_{suffix}.pt'),map_location=torch.device('cpu')))
            logsigmasq = torch.load(os.path.join(path, f'gmm_params_logsigmasq_{suffix}.pt'),map_location=torch.device('cpu'))
            mu = torch.load(os.path.join(path, f'gmm_params_mu_{suffix}.pt'),map_location=torch.device('cpu'))
            pi = torch.load(os.path.join(path, f'gmm_params_pi_{suffix}.pt'),map_location=torch.device('cpu'))

          encoder_list = [encoder]
          decoder_list = [decoder]

          device = next(encoder.parameters()).device
          # Load in training history metrics
          pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]
          data_colors = label_colors

          # Plot training history
          # Plot the training and validation loss vs. epoch number
          plt.figure(figsize=(4, 4))
          const = min(min(train_loss), min(val_loss))
          # const = min(10, const)
          train_loss_adjusted = train_loss
          val_loss_adjusted = val_loss
          plt.plot(train_loss_adjusted.cpu(), label='Training')
          plt.plot(val_loss_adjusted.cpu(), label='Validation')
          plt.xlabel("Number of Epochs")
          plt.ylabel("Negative Loss")
          # plt.title("Negative Loss")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
          for ii in range(4):
              # print(train_elbo_terms.cpu()[ii, :epoch])
              # print(len(train_elbo_terms.cpu()[ii, :epoch]))
              train_loss_adjusted = train_elbo_terms[:, ii]
              val_loss_adjusted = val_elbo_terms[:, ii]
              plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
              plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Negative Loss Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot the sum of each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          # print(train_elbo_terms.cpu()[ii, :epoch])
          # print(len(train_elbo_terms.cpu()[ii, :epoch]))
          train_loss_adjusted = train_elbo_terms.sum(axis=1)
          val_loss_adjusted = val_elbo_terms.sum(axis=1)
          plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
          plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Sum of ELBO Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the training and validation mse vs. epoch number
          plt.figure(figsize=(4.5, 4))
          plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
          plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
          plt.xlabel("number of epochs")
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the history of pi
          plt.figure(figsize=(4, 4))
          for i in range(K):
              plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
          plt.xlabel("Number of Epochs")
          plt.ylabel("Predicted Cluster Probability")
          plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
          plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Load best model saved
          params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
          params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
          params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
          encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
          decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

          encoder.eval()
          decoder.eval()

          # run one last EM step and plot training data in latent space
          for encoder in encoder_list:
              encoder.eval()

          with torch.no_grad():
              means = []
              samples = []
              labels = []
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
              for batch in train_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma
                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  means.append(mu)
                  samples.append(z)
                  labels.append(batch_label)

          means = torch.vstack(means).cpu()
          samples = torch.vstack(samples).cpu()
          labels = torch.hstack(labels).cpu()


          savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
          plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
          plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot test data in latent space
          with torch.no_grad():
              test_means = []
              test_labels = []
              for batch in test_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mean, _ = encoder_step(x_list, encoder_list, decoder_list)
                  test_means.append(mean)
                  test_labels.append(batch_label)

          test_means = torch.vstack(test_means).cpu()
          test_labels = torch.hstack(test_labels).cpu()


          savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
          plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot decoding results from cluster means # todo: expand this function for multi-modal data
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for i in range(K):
              # with torch.no_grad:
              x_mean = decoder.forward(params['mu_c'][i])[0]
              ax.plot(x_mean.cpu().detach().numpy(), label=r"decoded $\mu$"+str(i+1))
          ax.legend()
          plt.title("Decoded Means")
          fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
          # plt.close()

          # plot samples from generative model
          n_gen = n_train
          cluster_probs = params['pi_c'].cpu().detach().numpy()
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_gen):
              c = np.random.choice(K, p=cluster_probs)
              # print(c)
              mu_c = params['mu_c'][c].cpu().clone().detach()
              sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
              z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
              # print(z)
              mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
              sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
              sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
              ax.plot(sample_x.cpu().detach().numpy())
          plt.title("Generated Samples")
          fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
          plt.close()

          # np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
              # train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
              # pi_history=pi_history.cpu().detach().numpy(),
              # cluster_probs=params['pi_c'].cpu().detach().numpy(),
              # cluster_means=params['mu_c'].cpu().detach().numpy(),
              # cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


          print("Training data size", n_train)
          print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
          print("Cluster 1 probability:", cluster_probs.min().item())

          # ---- CLEANUP ----
          del encoder
          del decoder
          del encoder_list
          del decoder_list
          del optimizer
          del train_loader
          del val_loader
          del test_loader
          del data_module
          del means
          del samples
          del labels
          del train_loss
          del val_loss
          del train_elbo_terms
          del val_elbo_terms
          del train_mse_history
          del val_mse_history
          del pi_history
          del params

          import gc
          gc.collect()
          torch.cuda.empty_cache()
# Out:
# Filepath directory: /content/drive/MyDrive/rev_pipag_data/gmvae_rev_gu_mixture_energy_biased_down_20260224_013007_L6_C9_30_20_10
# Filepath postfix: _42_800_100_100_30_20_10_6_9_0.001000_128_0.001000_0.000010_15000.000000_
# [543, 139, 827, 571, 171, 15, 199, 163, 416, 589, 492, 661, 556, 570, 177, 667, 354, 510, 778, 430, 319, 967, 860, 329, 633, 29, 404, 836, 847, 388, 885, 229, 69, 921, 132, 839, 96, 835, 227, 181, 968, 351, 925, 24, 336, 123, 759, 189, 455, 626, 862, 469, 110, 219, 285, 445, 738, 723, 179, 77, 353, 84, 424, 948, 963, 266, 735, 576, 83, 724, 259, 387, 959, 551, 733, 658, 260, 516, 806, 651, 11, 522, 343, 40, 493, 692, 919, 995, 558, 352, 359, 368, 251, 893, 479, 777, 102, 90, 870, 310, 538, 745, 891, 150, 380, 324, 505, 144, 375, 66, 656, 631, 216, 306, 987, 371, 673, 5, 190, 804, 487, 757, 153, 884, 78, 555, 438, 758, 21, 597, 706, 303, 254, 47, 373, 87, 224, 1, 523, 754, 247, 390, 992, 986, 764, 947, 665, 527, 271, 322, 39, 586, 760, 148, 280, 678, 539, 26, 779, 335, 299, 439, 748, 140, 741, 494, 415, 30, 8, 914, 278, 514, 409, 498, 853, 822, 64, 52, 640, 103, 225, 557, 82, 742, 160, 363, 286, 880, 545, 924, 604, 376, 344, 502, 194, 563, 568, 526, 300, 927, 944, 496, 296, 23, 710, 378, 312, 323, 210, 517, 790, 625, 718, 890, 704, 566, 737, 432, 331, 550, 874, 372, 111, 427, 67, 230, 497, 488, 611, 408, 956, 128, 788, 783, 814, 34, 273, 459, 58, 993, 75, 426, 185, 466, 42, 751, 175, 482, 607, 531, 463, 172, 826, 863, 73, 781, 242, 241, 707, 326, 320, 582, 698, 346, 134, 327, 664, 700, 187, 183, 205, 410, 269, 696, 13, 898, 195, 917, 297, 464, 540, 248, 989, 41, 355, 95, 138, 164, 868, 699, 174, 629, 393, 107, 546, 904, 386, 622, 182, 867, 470, 690, 796, 521, 518, 660, 37, 930, 795, 889, 869, 499, 501, 437, 772, 151, 734, 902, 206, 731, 792, 905, 873, 512, 752, 365, 855, 528, 419, 773, 395, 184, 909, 829, 202, 131, 819, 657, 200, 274, 119, 485, 749, 101, 776, 596, 542, 418, 208, 56, 845, 209, 519, 221, 89, 789, 674, 805, 933, 669, 616, 381, 234, 328, 984, 304, 94, 142, 980, 358, 79, 524, 237, 121, 832, 43, 588, 676, 332, 800, 246, 133, 483, 965, 135, 53, 728, 431, 446, 928, 276, 173, 530, 609, 16, 309, 621, 389, 864, 726, 287, 261, 979, 547, 413, 105, 666, 294, 567, 275, 983, 383, 716, 315, 892, 577, 946, 552, 367, 683, 19, 985, 283, 220, 307, 876, 603, 239, 769, 701, 414, 215, 708, 338, 915, 774, 99, 955, 149, 711, 212, 337, 952, 113, 397, 982, 314, 693, 746, 385, 341, 852, 49, 178, 793, 771, 695, 828, 529, 672, 218, 481, 396, 20, 236, 452, 349, 214, 325, 975, 912, 536, 143, 932, 866, 270, 458, 775, 460, 770, 922, 645, 197, 856, 462, 807, 207, 255, 412, 203, 361, 612, 392, 86, 899, 405, 920, 28, 9, 926, 508, 14, 55, 249, 619, 3, 115, 594, 560, 808, 998, 117, 936, 291, 691, 490, 333, 233, 590, 937, 146, 243, 977, 450, 879, 677, 841, 374, 763, 451, 801, 532, 399, 688, 457, 950, 961, 653, 694, 895, 562, 797, 471, 442, 98, 268, 646, 785, 668, 434, 896, 714, 59, 940, 787, 476, 681, 311, 250, 957, 971, 990, 655, 169, 624, 671, 284, 475, 515, 71, 972, 823, 705, 72, 93, 507, 454, 578, 473, 191, 391, 960, 549, 684, 402, 581, 301, 421, 401, 0, 91, 755, 417, 340, 872, 644, 908, 159, 491, 837, 725, 384, 7, 461, 882, 730, 489, 258, 97, 815, 652, 465, 76, 593, 106, 595, 632, 180, 580, 305, 468, 65, 583, 824, 316, 689, 978, 293, 613, 330, 18, 288, 894, 659, 743, 598, 166, 736, 643, 916, 118, 675, 802, 157, 145, 537, 54, 756, 865, 818, 638, 45, 298, 591, 35, 168, 302, 31, 433, 996, 697, 51, 830, 112, 799, 970, 939, 641, 816, 345, 141, 575, 720, 838, 766, 686, 585, 423, 559, 147, 292, 57, 859, 425, 991, 687, 61, 232, 321, 941, 2, 584, 500, 561, 478, 608, 949, 544, 125, 534, 263, 721, 379, 122, 377, 525, 812, 903, 636, 615, 883, 610, 253, 918, 27, 136, 753, 362, 614, 938, 295, 553, 364, 124, 628, 506, 861, 226, 176, 886, 877, 654, 887, 116, 170, 192, 634, 834, 317, 712, 999, 257, 279, 520, 313, 719, 152, 277, 444, 436, 809, 129, 264, 334, 477, 605, 662, 394, 929, 265, 541, 486, 441, 350, 126, 627, 36, 851, 339, 104, 443, 74, 875, 821, 981, 403, 988, 953, 901, 784, 848, 966, 60, 100, 188, 411, 88, 740, 747, 974, 685, 348, 680, 198, 606, 435, 767, 484, 997, 618, 308, 25, 858, 620, 897, 165, 572, 878, 92, 154, 648, 642, 535, 913, 942, 356, 256, 84 ...
# Loading File...
# ...File Loaded
# Sample List: [543, 139, 827, 571, 171, 15, 199, 163, 416, 589, 492, 661, 556, 570, 177, 667, 354, 510, 778, 430, 319, 967, 860, 329, 633, 29, 404, 836, 847, 388, 885, 229, 69, 921, 132, 839, 96, 835, 227, 181, 968, 351, 925, 24, 336, 123, 759, 189, 455, 626, 862, 469, 110, 219, 285, 445, 738, 723, 179, 77, 353, 84, 424, 948, 963, 266, 735, 576, 83, 724, 259, 387, 959, 551, 733, 658, 260, 516, 806, 651, 11, 522, 343, 40, 493, 692, 919, 995, 558, 352, 359, 368, 251, 893, 479, 777, 102, 90, 870, 310, 538, 745, 891, 150, 380, 324, 505, 144, 375, 66, 656, 631, 216, 306, 987, 371, 673, 5, 190, 804, 487, 757, 153, 884, 78, 555, 438, 758, 21, 597, 706, 303, 254, 47, 373, 87, 224, 1, 523, 754, 247, 390, 992, 986, 764, 947, 665, 527, 271, 322, 39, 586, 760, 148, 280, 678, 539, 26, 779, 335, 299, 439, 748, 140, 741, 494, 415, 30, 8, 914, 278, 514, 409, 498, 853, 822, 64, 52, 640, 103, 225, 557, 82, 742, 160, 363, 286, 880, 545, 924, 604, 376, 344, 502, 194, 563, 568, 526, 300, 927, 944, 496, 296, 23, 710, 378, 312, 323, 210, 517, 790, 625, 718, 890, 704, 566, 737, 432, 331, 550, 874, 372, 111, 427, 67, 230, 497, 488, 611, 408, 956, 128, 788, 783, 814, 34, 273, 459, 58, 993, 75, 426, 185, 466, 42, 751, 175, 482, 607, 531, 463, 172, 826, 863, 73, 781, 242, 241, 707, 326, 320, 582, 698, 346, 134, 327, 664, 700, 187, 183, 205, 410, 269, 696, 13, 898, 195, 917, 297, 464, 540, 248, 989, 41, 355, 95, 138, 164, 868, 699, 174, 629, 393, 107, 546, 904, 386, 622, 182, 867, 470, 690, 796, 521, 518, 660, 37, 930, 795, 889, 869, 499, 501, 437, 772, 151, 734, 902, 206, 731, 792, 905, 873, 512, 752, 365, 855, 528, 419, 773, 395, 184, 909, 829, 202, 131, 819, 657, 200, 274, 119, 485, 749, 101, 776, 596, 542, 418, 208, 56, 845, 209, 519, 221, 89, 789, 674, 805, 933, 669, 616, 381, 234, 328, 984, 304, 94, 142, 980, 358, 79, 524, 237, 121, 832, 43, 588, 676, 332, 800, 246, 133, 483, 965, 135, 53, 728, 431, 446, 928, 276, 173, 530, 609, 16, 309, 621, 389, 864, 726, 287, 261, 979, 547, 413, 105, 666, 294, 567, 275, 983, 383, 716, 315, 892, 577, 946, 552, 367, 683, 19, 985, 283, 220, 307, 876, 603, 239, 769, 701, 414, 215, 708, 338, 915, 774, 99, 955, 149, 711, 212, 337, 952, 113, 397, 982, 314, 693, 746, 385, 341, 852, 49, 178, 793, 771, 695, 828, 529, 672, 218, 481, 396, 20, 236, 452, 349, 214, 325, 975, 912, 536, 143, 932, 866, 270, 458, 775, 460, 770, 922, 645, 197, 856, 462, 807, 207, 255, 412, 203, 361, 612, 392, 86, 899, 405, 920, 28, 9, 926, 508, 14, 55, 249, 619, 3, 115, 594, 560, 808, 998, 117, 936, 291, 691, 490, 333, 233, 590, 937, 146, 243, 977, 450, 879, 677, 841, 374, 763, 451, 801, 532, 399, 688, 457, 950, 961, 653, 694, 895, 562, 797, 471, 442, 98, 268, 646, 785, 668, 434, 896, 714, 59, 940, 787, 476, 681, 311, 250, 957, 971, 990, 655, 169, 624, 671, 284, 475, 515, 71, 972, 823, 705, 72, 93, 507, 454, 578, 473, 191, 391, 960, 549, 684, 402, 581, 301, 421, 401, 0, 91, 755, 417, 340, 872, 644, 908, 159, 491, 837, 725, 384, 7, 461, 882, 730, 489, 258, 97, 815, 652, 465, 76, 593, 106, 595, 632, 180, 580, 305, 468, 65, 583, 824, 316, 689, 978, 293, 613, 330, 18, 288, 894, 659, 743, 598, 166, 736, 643, 916, 118, 675, 802, 157, 145, 537, 54, 756, 865, 818, 638, 45, 298, 591, 35, 168, 302, 31, 433, 996, 697, 51, 830, 112, 799, 970, 939, 641, 816, 345, 141, 575, 720, 838, 766, 686, 585, 423, 559, 147, 292, 57, 859, 425, 991, 687, 61, 232, 321, 941, 2, 584, 500, 561, 478, 608, 949, 544, 125, 534, 263, 721, 379, 122, 377, 525, 812, 903, 636, 615, 883, 610, 253, 918, 27, 136, 753, 362, 614, 938, 295, 553, 364, 124, 628, 506, 861, 226, 176, 886, 877, 654, 887, 116, 170, 192, 634, 834, 317, 712, 999, 257, 279, 520, 313, 719, 152, 277, 444, 436, 809, 129, 264, 334, 477, 605, 662, 394, 929, 265, 541, 486, 441, 350, 126, 627, 36, 851, 339, 104, 443, 74, 875, 821, 981, 403, 988, 953, 901, 784, 848, 966, 60, 100, 188, 411, 88, 740, 747, 974, 685, 348, 680, 198, 606, 435, 767, 484, 997, 618, 308, 25, 858, 620, 897, 165, 572, 878, 92, 154, 648, 642, 535, 913, 942, ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipython-input-1656036900.py:67: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)
# /content/pipag_training/gmvae_common.py:265: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   elbo_terms[0] = Normal(mu_, torch.exp(0.5 * logsigmasq_)).log_prob(x_list[d]).sum()
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 4593 Train ELBO: -86.7836 Val ELBO: -147.1507, Epoch Time (s): 0.11, Total Time (hrs): 0.1324
# ====> Epoch: 4594 Train ELBO: -86.5764 Val ELBO: -153.1535, Epoch Time (s): 0.12, Total Time (hrs): 0.1325
# ====> Epoch: 4595 Train ELBO: -83.1366 Val ELBO: -152.4485, Epoch Time (s): 0.10, Total Time (hrs): 0.1325
# ====> Epoch: 4596 Train ELBO: -81.0545 Val ELBO: -155.3692, Epoch Time (s): 0.11, Total Time (hrs): 0.1325
# ====> Epoch: 4597 Train ELBO: -84.0816 Val ELBO: -164.4079, Epoch Time (s): 0.13, Total Time (hrs): 0.1325
# ====> Epoch: 4598 Train ELBO: -90.7155 Val ELBO: -169.2100, Epoch Time (s): 0.13, Total Time (hrs): 0.1326
# ====> Epoch: 4599 Train ELBO: -89.9414 Val ELBO: -148.3699, Epoch Time (s): 0.11, Total Time (hrs): 0.1326
# ====> Epoch: 4600 Train ELBO: -85.7160 Val ELBO: -146.1181, Epoch Time (s): 0.13, Total Time (hrs): 0.1327
# ====> Epoch: 4601 Train ELBO: -77.0648 Val ELBO: -157.8220, Epoch Time (s): 0.12, Total Time (hrs): 0.1327
# ====> Epoch: 4602 Train ELBO: -79.8816 Val ELBO: -156.3902, Epoch Time (s): 0.14, Total Time (hrs): 0.1327
# ====> Epoch: 4603 Train ELBO: -76.1517 Val ELBO: -148.0446, Epoch Time (s): 0.12, Total Time (hrs): 0.1328
# ====> Epoch: 4604 Train ELBO: -77.3997 Val ELBO: -138.4497, Epoch Time (s): 0.08, Total Time (hrs): 0.1328
# ====> Epoch: 4605 Train ELBO: -71.3870 Val ELBO: -144.8445, Epoch Time (s): 0.09, Total Time (hrs): 0.1328
# ====> Epoch: 4606 Train ELBO: -73.9026 Val ELBO: -146.9039, Epoch Time (s): 0.08, Total Time (hrs): 0.1328
# ====> Epoch: 4607 Train ELBO: -74.7295 Val ELBO: -142.7850, Epoch Time (s): 0.08, Total Time (hrs): 0.1328
# ====> Epoch: 4608 Train ELBO: -71.6870 Val ELBO: -148.3744, Epoch Time (s): 0.09, Total Time (hrs): 0.1329
# ====> Epoch: 4609 Train ELBO: -71.0040 Val ELBO: -152.9442, Epoch Time (s): 0.07, Total Time (hrs): 0.1329
# ====> Epoch: 4610 Train ELBO: -95.5972 Val ELBO: -254.0124, Epoch Time (s): 0.08, Total Time (hrs): 0.1329
# ====> Epoch: 4611 Train ELBO: -120.4381 Val ELBO: -184.1792, Epoch Time (s): 0.08, Total Time (hrs): 0.1329
# ====> Epoch: 4612 Train ELBO: -95.9859 Val ELBO: -177.8743, Epoch Time (s): 0.08, Total Time (hrs): 0.1330
# ====> Epoch: 4613 Train ELBO: -82.0829 Val ELBO: -170.6562, Epoch Time (s): 0.08, Total Time (hrs): 0.1330
# ====> Epoch: 4614 Train ELBO: -79.0989 Val ELBO: -143.4618, Epoch Time (s): 0.08, Total Time (hrs): 0.1330
# ====> Epoch: 4615 Train ELBO: -98.8124 Val ELBO: -166.1538, Epoch Time (s): 0.09, Total Time (hrs): 0.1330
# ====> Epoch: 4616 Train ELBO: -88.5257 Val ELBO: -194.9418, Epoch Time (s): 0.07, Total Time (hrs): 0.1331
# ====> Epoch: 4617 Train ELBO: -94.3189 Val ELBO: -157.8364, Epoch Time (s): 0.08, Total Time (hrs): 0.1331
# ====> Epoch: 4618 Train ELBO: -88.1956 Val ELBO: -214.9753, Epoch Time (s): 0.08, Total Time (hrs): 0.1331
# ====> Epoch: 4619 Train ELBO: -106.9465 Val ELBO: -166.4759, Epoch Time (s): 0.08, Total Time (hrs): 0.1331
# ====> Epoch: 4620 Train ELBO: -90.2334 Val ELBO: -164.4380, Epoch Time (s): 0.08, Total Time (hrs): 0.1331
# ====> Epoch: 4621 Train ELBO: -84.7194 Val ELBO: -146.7494, Epoch Time (s): 0.07, Total Time (hrs): 0.1332
# ====> Epoch: 4622 Train ELBO: -77.7383 Val ELBO: -161.2495, Epoch Time (s): 0.07, Total Time (hrs): 0.1332
# ====> Epoch: 4623 Train ELBO: -76.3764 Val ELBO: -158.9760, Epoch Time (s): 0.08, Total Time (hrs): 0.1332
# ====> Epoch: 4624 Train ELBO: -70.5651 Val ELBO: -142.9949, Epoch Time (s): 0.08, Total Time (hrs): 0.1332
# ====> Epoch: 4625 Train ELBO: -72.8212 Val ELBO: -138.8059, Epoch Time (s): 0.07, Total Time (hrs): 0.1332
# ====> Epoch: 4626 Train ELBO: -73.2866 Val ELBO: -151.3244, Epoch Time (s): 0.08, Total Time (hrs): 0.1333
# ====> Epoch: 4627 Train ELBO: -75.8670 Val ELBO: -163.3698, Epoch Time (s): 0.07, Total Time (hrs): 0.1333
# ====> Epoch: 4628 Train ELBO: -79.2306 Val ELBO: -183.2997, Epoch Time (s): 0.09, Total Time (hrs): 0.1333
# ====> Epoch: 4629 Train ELBO: -79.0989 Val ELBO: -149.9110, Epoch Time (s): 0.08, Total Time (hrs): 0.1333
# ====> Epoch: 4630 Train ELBO: -79.5207 Val ELBO: -160.1967, Epoch Time (s): 0.07, Total Time (hrs): 0.1334
# ====> Epoch: 4631 Train ELBO: -83.4864 Val ELBO: -157.7438, Epoch Time (s): 0.07, Total Time (hrs): 0.1334
# ====> Epoch: 4632 Train ELBO: -90.1833 Val ELBO: -177.4595, Epoch Time (s): 0.09, Total Time (hrs): 0.1334
# ====> Epoch: 4633 Train ELBO: -84.7227 Val ELBO: -164.7248, Epoch Time (s): 0.07, Total Time (hrs): 0.1334
# ====> Epoch: 4634 Train ELBO: -91.0427 Val ELBO: -186.2113, Epoch Time (s): 0.07, Total Time (hrs): 0.1334
# ====> Epoch: 4635 Train ELBO: -95.4264 Val ELBO: -212.2272, Epoch Time (s): 0.08, Total Time (hrs): 0.1335
# ====> Epoch: 4636 Train ELBO: -101.6045 Val ELBO: -163.1606, Epoch Time (s): 0.07, Total Time (hrs): 0.1335
# ====> Epoch: 4637 Train ELBO: -88.3138 Val ELBO: -151.4071, Epoch Time (s): 0.07, Total Time (hrs): 0.1335
# ====> Epoch: 4638 Train ELBO: -76.4945 Val ELBO: -152.9104, Epoch Time (s): 0.08, Total Time (hrs): 0.1335
# ====> Epoch: 4639 Train ELBO: -73.3084 Val ELBO: -163.9006, Epoch Time (s): 0.07, Total Time (hrs): 0.1336
# ====> Epoch: 4640 Train ELBO: -75.1744 Val ELBO: -151.6373, Epoch Time (s): 0.07, Total Time (hrs): 0.1336
# ====> Epoch: 4641 Train ELBO: -73.6880 Val ELBO: -152.0217, Epoch Time (s): 0.10, Total Time (hrs): 0.1336
# ====> Epoch: 4642 Train ELBO: -74.3438 Val ELBO: -157.5502, Epoch Time (s): 0.08, Total Time (hrs): 0.1336
# ====> Epoch: 4643 Train ELBO: -82.9528 Val ELBO: -168.6121, Epoch Time (s): 0.08, Total Time (hrs): 0.1336
# ====> Epoch: 4644 Train ELBO: -81.1476 Val ELBO: -180.2377, Epoch Time (s): 0.09, Total Time (hrs): 0.1337
# ====> Epoch: 4645 Train ELBO: -82.9536 Val ELBO: -172.0526, Epoch Time (s): 0.07, Total Time (hrs): 0.1337
# ====> Epoch: 4646 Train ELBO: -81.6435 Val ELBO: -157.6677, Epoch Time (s): 0.07, Total Time (hrs): 0.1337
# ====> Epoch: 4647 Train ELBO: -77.9890 Val ELBO: -168.2433, Epoch Time (s): 0.08, Total Time (hrs): 0.1337
# ====> Epoch: 4648 Train ELBO: -92.4847 Val ELBO: -182.3633, Epoch Time (s): 0.08, Total Time (hrs): 0.1338
# ====> Epoch: 4649 Train ELBO: -99.4088 Val ELBO: -173.5496, Epoch Time (s): 0.07, Total Time (hrs): 0.1338
# ====> Epoch: 4650 Train ELBO: -89.1242 Val ELBO: -166.8884, Epoch Time (s): 0.08, Total Time (hrs): 0.1338
# ====> Epoch: 4651 Train ELBO: -84.1654 Val ELBO: -157.4280, Epoch Time (s): 0.07, Total Time (hrs): 0.1338
# ====> Epoch: 4652 Train ELBO: -71.6184 Val ELBO: -153.4384, Epoch Time (s): 0.07, Total Time (hrs): 0.1338
# ====> Epoch: 4653 Train ELBO: -75.9949 Val ELBO: -158.5490, Epoch Time (s): 0.08, Total Time (hrs): 0.1339
# ====> Epoch: 4654 Train ELBO: -78.7244 Val ELBO: -174.5099, Epoch Time (s): 0.07, Total Time (hrs): 0.1339
# ====> Epoch: 4655 Train ELBO: -83.5158 Val ELBO: -154.0247, Epoch Time (s): 0.09, Total Time (hrs): 0.1339
# ====> Epoch: 4656 Train ELBO: -80.5926 Val ELBO: -155.2583, Epoch Time (s): 0.09, Total Time (hrs): 0.1339
# ====> Epoch: 4657 Train ELBO: -96.4023 Val ELBO: -204.5541, Epoch Time (s): 0.08, Total Time (hrs): 0.1339
# ====> Epoch: 4658 Train ELBO: -102.3213 Val ELBO: -243.0894, Epoch Time (s): 0.07, Total Time (hrs): 0.1340
# ====> Epoch: 4659 Train ELBO: -129.4871 Val ELBO: -196.4392, Epoch Time (s): 0.08, Total Time (hrs): 0.1340
# ====> Epoch: 4660 Train ELBO: -103.6076 Val ELBO: -169.1480, Epoch Time (s): 0.08, Total Time (hrs): 0.1340
# ====> Epoch: 4661 Train ELBO: -87.6430 Val ELBO: -191.9443, Epoch Time (s): 0.07, Total Time (hrs): 0.1340
# ====> Epoch: 4662 Train ELBO: -106.0481 Val ELBO: -160.9580, Epoch Time (s): 0.08, Total Time (hrs): 0.1341
# ====> Epoch: 4663 Train ELBO: -89.7857 Val ELBO: -193.0425, Epoch Time (s): 0.07, Total Time (hrs): 0.1341
# ====> Epoch: 4664 Train ELBO: -84.4692 Val ELBO: -153.8079, Epoch Time (s): 0.07, Total Time (hrs): 0.1341
# ====> Epoch: 4665 Train ELBO: -74.2824 Val ELBO: -155.5082, Epoch Time (s): 0.08, Total Time (hrs): 0.1341
# ====> Epoch: 4666 Train ELBO: -71.8532 Val ELBO: -185.8424, Epoch Time (s): 0.07, Total Time (hrs): 0.1341
# ====> Epoch: 4667 Train ELBO: -85.8636 Val ELBO: -157.4187, Epoch Time (s): 0.07, Total Time (hrs): 0.1342
# ====> Epoch: 4668 Train ELBO: -82.6563 Val ELBO: -190.0577, Epoch Time (s): 0.10, Total Time (hrs): 0.1342
# ====> Epoch: 4669 Train ELBO: -121.2862 Val ELBO: -243.5657, Epoch Time (s): 0.08, Total Time (hrs): 0.1342
# ====> Epoch: 4670 Train ELBO: -123.7411 Val ELBO: -195.7647, Epoch Time (s): 0.08, Total Time (hrs): 0.1342
# ====> Epoch: 4671 Train ELBO: -124.3437 Val ELBO: -287.5436, Epoch Time (s): 0.08, Total Time (hrs): 0.1343
# ====> Epoch: 4672 Train ELBO: -140.1224 Val ELBO: -201.8709, Epoch Time (s): 0.07, Total Time (hrs): 0.1343
# ====> Epoch: 4673 Train ELBO: -138.6799 Val ELBO: -246.1381, Epoch Time (s): 0.07, Total Time (hrs): 0.1343
# ====> Epoch: 4674 Train ELBO: -125.7401 Val ELBO: -197.3618, Epoch Time (s): 0.08, Total Time (hrs): 0.1343
# ====> Epoch: 4675 Train ELBO: -122.3372 Val ELBO: -177.4598, Epoch Time (s): 0.08, Total Time (hrs): 0.1343
# ====> Epoch: 4676 Train ELBO: -107.2429 Val ELBO: -226.5035, Epoch Time (s): 0.07, Total Time (hrs): 0.1344
# ====> Epoch: 4677 Train ELBO: -115.2541 Val ELBO: -193.5309, Epoch Time (s): 0.08, Total Time (hrs): 0.1344
# ====> Epoch: 4678 Train ELBO: -109.6202 Val ELBO: -180.3339, Epoch Time (s): 0.07, Total Time (hrs): 0.1344
# ====> Epoch: 4679 Train ELBO: -102.3048 Val ELBO: -171.1875, Epoch Time (s): 0.08, Total Time (hrs): 0.1344
# ====> Epoch: 4680 Train ELBO: -91.0117 Val ELBO: -158.7178, Epoch Time (s): 0.13, Total Time (hrs): 0.1345
# ====> Epoch: 4681 Train ELBO: -77.9721 Val ELBO: -158.2245, Epoch Time (s): 0.08, Total Time (hrs): 0.1345
# ====> Epoch: 4682 Train ELBO: -70.4063 Val ELBO: -156.9209, Epoch Time (s): 0.08, Total Time (hrs): 0.1345
# ====> Epoch: 4683 Train ELBO: -76.3531 Val ELBO: -151.3530, Epoch Time (s): 0.09, Total Time (hrs): 0.1345
# ====> Epoch: 4684 Train ELBO: -76.0492 Val ELBO: -160.6961, Epoch Time (s): 0.08, Total Time (hrs): 0.1346
# ====> Epoch: 4685 Train ELBO: -79.5554 Val ELBO: -156.8180, Epoch Time (s): 0.08, Total Time (hrs): 0.1346
# ====> Epoch: 4686 Train ELBO: -78.2860 Val ELBO: -156.4791, Epoch Time (s): 0.08, Total Time (hrs): 0.1346
# ====> Epoch: 4687 Train ELBO: -80.7534 Val ELBO: -158.6847, Epoch Time (s): 0.08, Total Time (hrs): 0.1346
# ====> Epoch: 4688 Train ELBO: -85.2597 Val ELBO: -151.6871, Epoch Time (s): 0.08, Total Time (hrs): 0.1346
# ====> Epoch: 4689 Train ELBO: -91.8218 Val ELBO: -216.8828, Epoch Time (s): 0.08, Total Time (hrs): 0.1347
# ====> Epoch: 4690 Train ELBO: -102.5598 Val ELBO: -171.1472, Epoch Time (s): 0.07, Total Time (hrs): 0.1347
# ====> Epoch: 4691 Train ELBO: -85.5117 Val ELBO: -145.3292, Epoch Time (s): 0.07, Total Time (hrs): 0.1347
# ====> Epoch: 4692 Train ELBO: -86.7151 Val ELBO: -146.8883, Epoch Time (s): 0.08, Total Time (hrs): 0.1347
# ====> Epoch: 4693 Train ELBO: -86.0268 Val ELBO: -158.8923, Epoch Time (s): 0.09, Total Time (hrs): 0.1348
# ====> Epoch: 4694 Train ELBO: -74.1687 Val ELBO: -159.5966, Epoch Time (s): 0.08, Total Time (hrs): 0.1348
# ====> Epoch: 4695 Train ELBO: -81.0697 Val ELBO: -147.7092, Epoch Time (s): 0.09, Total Time (hrs): 0.1348
# ====> Epoch: 4696 Train ELBO: -89.6360 Val ELBO: -205.9997, Epoch Time (s): 0.08, Total Time (hrs): 0.1348
# ====> Epoch: 4697 Train ELBO: -96.4047 Val ELBO: -164.3933, Epoch Time (s): 0.08, Total Time (hrs): 0.1348
# ====> Epoch: 4698 Train ELBO: -82.9321 Val ELBO: -159.1325, Epoch Time (s): 0.08, Total Time (hrs): 0.1349
# ====> Epoch: 4699 Train ELBO: -79.2616 Val ELBO: -162.1002, Epoch Time (s): 0.07, Total Time (hrs): 0.1349
# ====> Epoch: 4700 Train ELBO: -88.8163 Val ELBO: -176.4708, Epoch Time (s): 0.08, Total Time (hrs): 0.1349
# ====> Epoch: 4701 Train ELBO: -88.6050 Val ELBO: -163.7682, Epoch Time (s): 0.08, Total Time (hrs): 0.1349
# ====> Epoch: 4702 Train ELBO: -88.0370 Val ELBO: -187.7033, Epoch Time (s): 0.07, Total Time (hrs): 0.1350
# ====> Epoch: 4703 Train ELBO: -108.0614 Val ELBO: -188.7594, Epoch Time (s): 0.07, Total Time (hrs): 0.1350
# ====> Epoch: 4704 Train ELBO: -106.9759 Val ELBO: -161.2997, Epoch Time (s): 0.09, Total Time (hrs): 0.1350
# ====> Epoch: 4705 Train ELBO: -99.2910 Val ELBO: -208.4222, Epoch Time (s): 0.08, Total Time (hrs): 0.1350
# ====> Epoch: 4706 Train ELBO: -105.8602 Val ELBO: -182.9661, Epoch Time (s): 0.09, Total Time (hrs): 0.1350
# ====> Epoch: 4707 Train ELBO: -105.4126 Val ELBO: -146.2816, Epoch Time (s): 0.08, Total Time (hrs): 0.1351
# ====> Epoch: 4708 Train ELBO: -86.7461 Val ELBO: -173.2569, Epoch Time (s): 0.07, Total Time (hrs): 0.1351
# ====> Epoch: 4709 Train ELBO: -91.5097 Val ELBO: -160.4839, Epoch Time (s): 0.08, Total Time (hrs): 0.1351
# ====> Epoch: 4710 Train ELBO: -81.4787 Val ELBO: -189.8495, Epoch Time (s): 0.09, Total Time (hrs): 0.1351
# ====> Epoch: 4711 Train ELBO: -90.3727 Val ELBO: -187.6381, Epoch Time (s): 0.07, Total Time (hrs): 0.1352
# ====> Epoch: 4712 Train ELBO: -83.6502 Val ELBO: -159.8546, Epoch Time (s): 0.07, Total Time (hrs): 0.1352
# ====> Epoch: 4713 Train ELBO: -72.8131 Val ELBO: -163.1251, Epoch Time (s): 0.08, Total Time (hrs): 0.1352
# ====> Epoch: 4714 Train ELBO: -72.9978 Val ELBO: -157.3977, Epoch Time (s): 0.07, Total Time (hrs): 0.1352
# ====> Epoch: 4715 Train ELBO: -74.6535 Val ELBO: -156.7764, Epoch Time (s): 0.07, Total Time (hrs): 0.1352
# ====> Epoch: 4716 Train ELBO: -78.6195 Val ELBO: -155.3243, Epoch Time (s): 0.09, Total Time (hrs): 0.1353
# ====> Epoch: 4717 Train ELBO: -82.9280 Val ELBO: -163.1582, Epoch Time (s): 0.07, Total Time (hrs): 0.1353
# ====> Epoch: 4718 Train ELBO: -81.2385 Val ELBO: -162.5392, Epoch Time (s): 0.07, Total Time (hrs): 0.1353
# ====> Epoch: 4719 Train ELBO: -76.6971 Val ELBO: -160.9749, Epoch Time (s): 0.10, Total Time (hrs): 0.1353
# ====> Epoch: 4720 Train ELBO: -78.6723 Val ELBO: -169.0252, Epoch Time (s): 0.08, Total Time (hrs): 0.1354
# ====> Epoch: 4721 Train ELBO: -73.5929 Val ELBO: -135.1260, Epoch Time (s): 0.07, Total Time (hrs): 0.1354
# ====> Epoch: 4722 Train ELBO: -68.7738 Val ELBO: -145.0788, Epoch Time (s): 0.08, Total Time (hrs): 0.1354
# ====> Epoch: 4723 Train ELBO: -78.0811 Val ELBO: -166.8077, Epoch Time (s): 0.08, Total Time (hrs): 0.1354
# ====> Epoch: 4724 Train ELBO: -77.5140 Val ELBO: -155.4551, Epoch Time (s): 0.07, Total Time (hrs): 0.1354
# ====> Epoch: 4725 Train ELBO: -83.4859 Val ELBO: -160.6675, Epoch Time (s): 0.08, Total Time (hrs): 0.1355
# ====> Epoch: 4726 Train ELBO: -80.8919 Val ELBO: -185.4930, Epoch Time (s): 0.07, Total Time (hrs): 0.1355
# ====> Epoch: 4727 Train ELBO: -89.9325 Val ELBO: -168.3850, Epoch Time (s): 0.07, Total Time (hrs): 0.1355
# ====> Epoch: 4728 Train ELBO: -82.2548 Val ELBO: -160.5403, Epoch Time (s): 0.08, Total Time (hrs): 0.1355
# ====> Epoch: 4729 Train ELBO: -75.8373 Val ELBO: -171.6972, Epoch Time (s): 0.13, Total Time (hrs): 0.1356
# ====> Epoch: 4730 Train ELBO: -121.9865 Val ELBO: -197.1789, Epoch Time (s): 0.12, Total Time (hrs): 0.1356
# ====> Epoch: 4731 Train ELBO: -126.5023 Val ELBO: -208.3139, Epoch Time (s): 0.12, Total Time (hrs): 0.1356
# ====> Epoch: 4732 Train ELBO: -118.0283 Val ELBO: -197.8738, Epoch Time (s): 0.13, Total Time (hrs): 0.1357
# ====> Epoch: 4733 Train ELBO: -92.7508 Val ELBO: -166.7560, Epoch Time (s): 0.11, Total Time (hrs): 0.1357
# ====> Epoch: 4734 Train ELBO: -81.3897 Val ELBO: -162.2156, Epoch Time (s): 0.11, Total Time (hrs): 0.1357
# ====> Epoch: 4735 Train ELBO: -79.7846 Val ELBO: -146.3779, Epoch Time (s): 0.12, Total Time (hrs): 0.1358
# ====> Epoch: 4736 Train ELBO: -76.1511 Val ELBO: -163.8341, Epoch Time (s): 0.10, Total Time (hrs): 0.1358
# ====> Epoch: 4737 Train ELBO: -81.0213 Val ELBO: -169.8409, Epoch Time (s): 0.11, Total Time (hrs): 0.1358
# ====> Epoch: 4738 Train ELBO: -92.1900 Val ELBO: -161.3977, Epoch Time (s): 0.11, Total Time (hrs): 0.1358
# ====> Epoch: 4739 Train ELBO: -83.8499 Val ELBO: -152.1050, Epoch Time (s): 0.11, Total Time (hrs): 0.1359
# ====> Epoch: 4740 Train ELBO: -106.9929 Val ELBO: -172.4455, Epoch Time (s): 0.13, Total Time (hrs): 0.1359
# ====> Epoch: 4741 Train ELBO: -105.5943 Val ELBO: -195.9697, Epoch Time (s): 0.13, Total Time (hrs): 0.1359
# ====> Epoch: 4742 Train ELBO: -94.1227 Val ELBO: -187.3637, Epoch Time (s): 0.16, Total Time (hrs): 0.1360
# ====> Epoch: 4743 Train ELBO: -90.7469 Val ELBO: -142.6691, Epoch Time (s): 0.11, Total Time (hrs): 0.1360
# ====> Epoch: 4744 Train ELBO: -82.6513 Val ELBO: -160.0315, Epoch Time (s): 0.12, Total Time (hrs): 0.1361
# ====> Epoch: 4745 Train ELBO: -77.8123 Val ELBO: -166.4392, Epoch Time (s): 0.11, Total Time (hrs): 0.1361
# ====> Epoch: 4746 Train ELBO: -84.9382 Val ELBO: -188.5584, Epoch Time (s): 0.12, Total Time (hrs): 0.1361
# ====> Epoch: 4747 Train ELBO: -92.2107 Val ELBO: -164.8223, Epoch Time (s): 0.10, Total Time (hrs): 0.1361
# ====> Epoch: 4748 Train ELBO: -103.6344 Val ELBO: -202.4787, Epoch Time (s): 0.11, Total Time (hrs): 0.1362
# ====> Epoch: 4749 Train ELBO: -148.5006 Val ELBO: -195.7243, Epoch Time (s): 0.11, Total Time (hrs): 0.1362
# ====> Epoch: 4750 Train ELBO: -112.4603 Val ELBO: -173.3016, Epoch Time (s): 0.12, Total Time (hrs): 0.1362
# ====> Epoch: 4751 Train ELBO: -89.3577 Val ELBO: -180.8142, Epoch Time (s): 0.10, Total Time (hrs): 0.1363
# ====> Epoch: 4752 Train ELBO: -119.6765 Val ELBO: -211.8944, Epoch Time (s): 0.10, Total Time (hrs): 0.1363
# ====> Epoch: 4753 Train ELBO: -108.6986 Val ELBO: -192.5051, Epoch Time (s): 0.11, Total Time (hrs): 0.1363
# ====> Epoch: 4754 Train ELBO: -93.5244 Val ELBO: -170.3370, Epoch Time (s): 0.10, Total Time (hrs): 0.1364
# ====> Epoch: 4755 Train ELBO: -81.1710 Val ELBO: -158.1948, Epoch Time (s): 0.13, Total Time (hrs): 0.1364
# ====> Epoch: 4756 Train ELBO: -78.0784 Val ELBO: -162.7746, Epoch Time (s): 0.11, Total Time (hrs): 0.1364
# ====> Epoch: 4757 Train ELBO: -75.0963 Val ELBO: -149.2521, Epoch Time (s): 0.12, Total Time (hrs): 0.1365
# ====> Epoch: 4758 Train ELBO: -75.9380 Val ELBO: -159.1216, Epoch Time (s): 0.12, Total Time (hrs): 0.1365
# ====> Epoch: 4759 Train ELBO: -78.7833 Val ELBO: -145.7351, Epoch Time (s): 0.14, Total Time (hrs): 0.1365
# ====> Epoch: 4760 Train ELBO: -79.8702 Val ELBO: -178.5943, Epoch Time (s): 0.13, Total Time (hrs): 0.1366
# ====> Epoch: 4761 Train ELBO: -80.6453 Val ELBO: -144.2998, Epoch Time (s): 0.10, Total Time (hrs): 0.1366
# ====> Epoch: 4762 Train ELBO: -76.5267 Val ELBO: -159.5987, Epoch Time (s): 0.07, Total Time (hrs): 0.1366
# ====> Epoch: 4763 Train ELBO: -86.6330 Val ELBO: -157.6299, Epoch Time (s): 0.07, Total Time (hrs): 0.1366
# ====> Epoch: 4764 Train ELBO: -86.0700 Val ELBO: -187.5003, Epoch Time (s): 0.08, Total Time (hrs): 0.1367
# ====> Epoch: 4765 Train ELBO: -99.2374 Val ELBO: -256.4990, Epoch Time (s): 0.07, Total Time (hrs): 0.1367
# ====> Epoch: 4766 Train ELBO: -108.1604 Val ELBO: -178.2433, Epoch Time (s): 0.07, Total Time (hrs): 0.1367
# ====> Epoch: 4767 Train ELBO: -89.1552 Val ELBO: -157.6953, Epoch Time (s): 0.08, Total Time (hrs): 0.1367
# ====> Epoch: 4768 Train ELBO: -76.4818 Val ELBO: -149.9936, Epoch Time (s): 0.08, Total Time (hrs): 0.1367
# ====> Epoch: 4769 Train ELBO: -81.2968 Val ELBO: -171.6503, Epoch Time (s): 0.07, Total Time (hrs): 0.1368
# ====> Epoch: 4770 Train ELBO: -86.0030 Val ELBO: -171.6875, Epoch Time (s): 0.08, Total Time (hrs): 0.1368
# ====> Epoch: 4771 Train ELBO: -94.9663 Val ELBO: -162.3139, Epoch Time (s): 0.08, Total Time (hrs): 0.1368
# ====> Epoch: 4772 Train ELBO: -123.7743 Val ELBO: -196.7088, Epoch Time (s): 0.09, Total Time (hrs): 0.1368
# ====> Epoch: 4773 Train ELBO: -118.1485 Val ELBO: -192.0789, Epoch Time (s): 0.08, Total Time (hrs): 0.1369
# ====> Epoch: 4774 Train ELBO: -118.5312 Val ELBO: -197.7230, Epoch Time (s): 0.07, Total Time (hrs): 0.1369
# ====> Epoch: 4775 Train ELBO: -181.0728 Val ELBO: -261.3128, Epoch Time (s): 0.07, Total Time (hrs): 0.1369
# ====> Epoch: 4776 Train ELBO: -132.5515 Val ELBO: -196.6360, Epoch Time (s): 0.08, Total Time (hrs): 0.1369
# ====> Epoch: 4777 Train ELBO: -122.7146 Val ELBO: -220.6899, Epoch Time (s): 0.07, Total Time (hrs): 0.1369
# ====> Epoch: 4778 Train ELBO: -121.0838 Val ELBO: -174.5319, Epoch Time (s): 0.07, Total Time (hrs): 0.1370
# ====> Epoch: 4779 Train ELBO: -104.9550 Val ELBO: -177.5414, Epoch Time (s): 0.08, Total Time (hrs): 0.1370
# ====> Epoch: 4780 Train ELBO: -100.9936 Val ELBO: -166.3832, Epoch Time (s): 0.08, Total Time (hrs): 0.1370
# ====> Epoch: 4781 Train ELBO: -92.4910 Val ELBO: -155.5459, Epoch Time (s): 0.07, Total Time (hrs): 0.1370
# ====> Epoch: 4782 Train ELBO: -84.8835 Val ELBO: -150.2598, Epoch Time (s): 0.08, Total Time (hrs): 0.1370
# ====> Epoch: 4783 Train ELBO: -85.4564 Val ELBO: -210.1632, Epoch Time (s): 0.07, Total Time (hrs): 0.1371
# ====> Epoch: 4784 Train ELBO: -106.4170 Val ELBO: -200.9843, Epoch Time (s): 0.07, Total Time (hrs): 0.1371
# ====> Epoch: 4785 Train ELBO: -95.0916 Val ELBO: -175.5197, Epoch Time (s): 0.10, Total Time (hrs): 0.1371
# ====> Epoch: 4786 Train ELBO: -87.4245 Val ELBO: -170.1224, Epoch Time (s): 0.07, Total Time (hrs): 0.1371
# ====> Epoch: 4787 Train ELBO: -93.1723 Val ELBO: -166.1203, Epoch Time (s): 0.07, Total Time (hrs): 0.1372
# ====> Epoch: 4788 Train ELBO: -93.7720 Val ELBO: -152.3179, Epoch Time (s): 0.08, Total Time (hrs): 0.1372
# ====> Epoch: 4789 Train ELBO: -93.1623 Val ELBO: -165.6508, Epoch Time (s): 0.07, Total Time (hrs): 0.1372
# ====> Epoch: 4790 Train ELBO: -88.2041 Val ELBO: -172.1497, Epoch Time (s): 0.07, Total Time (hrs): 0.1372
# ====> Epoch: 4791 Train ELBO: -82.3762 Val ELBO: -158.1071, Epoch Time (s): 0.08, Total Time (hrs): 0.1372
# ====> Epoch: 4792 Train ELBO: -74.3660 Val ELBO: -146.5521, Epoch Time (s): 0.07, Total Time (hrs): 0.1373
# ====> Epoch: 4793 Train ELBO: -70.5599 Val ELBO: -154.3372, Epoch Time (s): 0.08, Total Time (hrs): 0.1373
# ====> Epoch: 4794 Train ELBO: -69.7077 Val ELBO: -157.2035, Epoch Time (s): 0.08, Total Time (hrs): 0.1373
# ====> Epoch: 4795 Train ELBO: -67.5831 Val ELBO: -136.4604, Epoch Time (s): 0.07, Total Time (hrs): 0.1373
# ====> Epoch: 4796 Train ELBO: -65.0788 Val ELBO: -146.4188, Epoch Time (s): 0.07, Total Time (hrs): 0.1373
# ====> Epoch: 4797 Train ELBO: -65.9323 Val ELBO: -143.2455, Epoch Time (s): 0.08, Total Time (hrs): 0.1374
# ====> Epoch: 4798 Train ELBO: -71.5383 Val ELBO: -165.3423, Epoch Time (s): 0.08, Total Time (hrs): 0.1374
# ====> Epoch: 4799 Train ELBO: -79.0635 Val ELBO: -178.6039, Epoch Time (s): 0.09, Total Time (hrs): 0.1374
# ====> Epoch: 4800 Train ELBO: -86.1716 Val ELBO: -154.5396, Epoch Time (s): 0.08, Total Time (hrs): 0.1374
# ====> Epoch: 4801 Train ELBO: -76.8288 Val ELBO: -194.4857, Epoch Time (s): 0.07, Total Time (hrs): 0.1375
# ====> Epoch: 4802 Train ELBO: -123.7998 Val ELBO: -211.9409, Epoch Time (s): 0.08, Total Time (hrs): 0.1375
# ====> Epoch: 4803 Train ELBO: -104.3174 Val ELBO: -188.0799, Epoch Time (s): 0.08, Total Time (hrs): 0.1375
# ====> Epoch: 4804 Train ELBO: -94.9015 Val ELBO: -147.7711, Epoch Time (s): 0.08, Total Time (hrs): 0.1375
# ====> Epoch: 4805 Train ELBO: -80.3416 Val ELBO: -150.1592, Epoch Time (s): 0.07, Total Time (hrs): 0.1375
# ====> Epoch: 4806 Train ELBO: -73.6107 Val ELBO: -151.9522, Epoch Time (s): 0.08, Total Time (hrs): 0.1376
# ====> Epoch: 4807 Train ELBO: -77.9509 Val ELBO: -149.1408, Epoch Time (s): 0.07, Total Time (hrs): 0.1376
# ====> Epoch: 4808 Train ELBO: -80.4615 Val ELBO: -172.0907, Epoch Time (s): 0.07, Total Time (hrs): 0.1376
# ====> Epoch: 4809 Train ELBO: -78.9498 Val ELBO: -153.4907, Epoch Time (s): 0.08, Total Time (hrs): 0.1376
# ====> Epoch: 4810 Train ELBO: -69.5138 Val ELBO: -155.9242, Epoch Time (s): 0.07, Total Time (hrs): 0.1376
# ====> Epoch: 4811 Train ELBO: -71.1545 Val ELBO: -136.5214, Epoch Time (s): 0.07, Total Time (hrs): 0.1377
# ====> Epoch: 4812 Train ELBO: -67.6786 Val ELBO: -163.3174, Epoch Time (s): 0.10, Total Time (hrs): 0.1377
# ====> Epoch: 4813 Train ELBO: -77.8818 Val ELBO: -152.7732, Epoch Time (s): 0.07, Total Time (hrs): 0.1377
# ====> Epoch: 4814 Train ELBO: -68.3596 Val ELBO: -143.2158, Epoch Time (s): 0.07, Total Time (hrs): 0.1377
# ====> Epoch: 4815 Train ELBO: -76.5007 Val ELBO: -161.8896, Epoch Time (s): 0.08, Total Time (hrs): 0.1378
# ====> Epoch: 4816 Train ELBO: -70.8757 Val ELBO: -143.6838, Epoch Time (s): 0.07, Total Time (hrs): 0.1378
# ====> Epoch: 4817 Train ELBO: -70.1094 Val ELBO: -159.8778, Epoch Time (s): 0.07, Total Time (hrs): 0.1378
# ====> Epoch: 4818 Train ELBO: -72.7185 Val ELBO: -173.1131, Epoch Time (s): 0.08, Total Time (hrs): 0.1378
# ====> Epoch: 4819 Train ELBO: -83.1574 Val ELBO: -194.2539, Epoch Time (s): 0.08, Total Time (hrs): 0.1378
# ====> Epoch: 4820 Train ELBO: -88.1639 Val ELBO: -173.2323, Epoch Time (s): 0.07, Total Time (hrs): 0.1379
# ====> Epoch: 4821 Train ELBO: -94.2758 Val ELBO: -169.9321, Epoch Time (s): 0.08, Total Time (hrs): 0.1379
# ====> Epoch: 4822 Train ELBO: -100.2367 Val ELBO: -178.8668, Epoch Time (s): 0.08, Total Time (hrs): 0.1379
# ====> Epoch: 4823 Train ELBO: -81.8847 Val ELBO: -180.2244, Epoch Time (s): 0.07, Total Time (hrs): 0.1379
# ====> Epoch: 4824 Train ELBO: -113.0386 Val ELBO: -210.8653, Epoch Time (s): 0.08, Total Time (hrs): 0.1380
# ====> Epoch: 4825 Train ELBO: -122.3496 Val ELBO: -177.1350, Epoch Time (s): 0.09, Total Time (hrs): 0.1380
# ====> Epoch: 4826 Train ELBO: -108.5932 Val ELBO: -257.4346, Epoch Time (s): 0.07, Total Time (hrs): 0.1380
# ====> Epoch: 4827 Train ELBO: -127.7522 Val ELBO: -262.6170, Epoch Time (s): 0.08, Total Time (hrs): 0.1380
# ====> Epoch: 4828 Train ELBO: -135.1080 Val ELBO: -218.3870, Epoch Time (s): 0.07, Total Time (hrs): 0.1380
# ====> Epoch: 4829 Train ELBO: -131.5397 Val ELBO: -215.4896, Epoch Time (s): 0.07, Total Time (hrs): 0.1381
# ====> Epoch: 4830 Train ELBO: -106.3245 Val ELBO: -196.7682, Epoch Time (s): 0.08, Total Time (hrs): 0.1381
# ====> Epoch: 4831 Train ELBO: -102.0955 Val ELBO: -212.5210, Epoch Time (s): 0.07, Total Time (hrs): 0.1381
# ====> Epoch: 4832 Train ELBO: -115.9994 Val ELBO: -161.2595, Epoch Time (s): 0.08, Total Time (hrs): 0.1381
# ====> Epoch: 4833 Train ELBO: -103.5646 Val ELBO: -168.6820, Epoch Time (s): 0.08, Total Time (hrs): 0.1381
# ====> Epoch: 4834 Train ELBO: -81.9156 Val ELBO: -182.2963, Epoch Time (s): 0.07, Total Time (hrs): 0.1382
# ====> Epoch: 4835 Train ELBO: -96.6194 Val ELBO: -207.5135, Epoch Time (s): 0.08, Total Time (hrs): 0.1382
# ====> Epoch: 4836 Train ELBO: -102.4067 Val ELBO: -161.3174, Epoch Time (s): 0.08, Total Time (hrs): 0.1382
# ====> Epoch: 4837 Train ELBO: -94.2444 Val ELBO: -182.6112, Epoch Time (s): 0.07, Total Time (hrs): 0.1382
# ====> Epoch: 4838 Train ELBO: -93.0693 Val ELBO: -149.6733, Epoch Time (s): 0.09, Total Time (hrs): 0.1383
# ====> Epoch: 4839 Train ELBO: -78.8431 Val ELBO: -152.8903, Epoch Time (s): 0.08, Total Time (hrs): 0.1383
# ====> Epoch: 4840 Train ELBO: -73.4695 Val ELBO: -144.5060, Epoch Time (s): 0.07, Total Time (hrs): 0.1383
# ====> Epoch: 4841 Train ELBO: -72.6127 Val ELBO: -155.6123, Epoch Time (s): 0.08, Total Time (hrs): 0.1383
# ====> Epoch: 4842 Train ELBO: -73.3142 Val ELBO: -153.6349, Epoch Time (s): 0.08, Total Time (hrs): 0.1383
# ====> Epoch: 4843 Train ELBO: -71.0880 Val ELBO: -163.7689, Epoch Time (s): 0.08, Total Time (hrs): 0.1384
# ====> Epoch: 4844 Train ELBO: -76.9539 Val ELBO: -146.9717, Epoch Time (s): 0.08, Total Time (hrs): 0.1384
# ====> Epoch: 4845 Train ELBO: -82.6933 Val ELBO: -166.8838, Epoch Time (s): 0.08, Total Time (hrs): 0.1384
# ====> Epoch: 4846 Train ELBO: -76.0982 Val ELBO: -164.0353, Epoch Time (s): 0.07, Total Time (hrs): 0.1384
# ====> Epoch: 4847 Train ELBO: -72.3437 Val ELBO: -135.3966, Epoch Time (s): 0.07, Total Time (hrs): 0.1385
# ====> Epoch: 4848 Train ELBO: -73.6025 Val ELBO: -144.5769, Epoch Time (s): 0.09, Total Time (hrs): 0.1385
# ====> Epoch: 4849 Train ELBO: -72.3834 Val ELBO: -149.8317, Epoch Time (s): 0.07, Total Time (hrs): 0.1385
# ====> Epoch: 4850 Train ELBO: -66.7769 Val ELBO: -138.6411, Epoch Time (s): 0.07, Total Time (hrs): 0.1385
# ====> Epoch: 4851 Train ELBO: -63.0791 Val ELBO: -146.5816, Epoch Time (s): 0.08, Total Time (hrs): 0.1385
# ====> Epoch: 4852 Train ELBO: -64.1775 Val ELBO: -138.2198, Epoch Time (s): 0.08, Total Time (hrs): 0.1386
# ====> Epoch: 4853 Train ELBO: -62.9278 Val ELBO: -141.8107, Epoch Time (s): 0.07, Total Time (hrs): 0.1386
# ====> Epoch: 4854 Train ELBO: -68.0534 Val ELBO: -156.3849, Epoch Time (s): 0.08, Total Time (hrs): 0.1386
# ====> Epoch: 4855 Train ELBO: -67.4030 Val ELBO: -142.1898, Epoch Time (s): 0.07, Total Time (hrs): 0.1386
# ====> Epoch: 4856 Train ELBO: -63.7195 Val ELBO: -139.8892, Epoch Time (s): 0.08, Total Time (hrs): 0.1386
# ====> Epoch: 4857 Train ELBO: -66.5594 Val ELBO: -153.1749, Epoch Time (s): 0.08, Total Time (hrs): 0.1387
# ====> Epoch: 4858 Train ELBO: -65.6795 Val ELBO: -145.9299, Epoch Time (s): 0.07, Total Time (hrs): 0.1387
# ====> Epoch: 4859 Train ELBO: -64.2020 Val ELBO: -135.1651, Epoch Time (s): 0.07, Total Time (hrs): 0.1387
# ====> Epoch: 4860 Train ELBO: -68.5638 Val ELBO: -157.2892, Epoch Time (s): 0.08, Total Time (hrs): 0.1387
# ====> Epoch: 4861 Train ELBO: -73.3643 Val ELBO: -142.7477, Epoch Time (s): 0.07, Total Time (hrs): 0.1387
# ====> Epoch: 4862 Train ELBO: -68.5923 Val ELBO: -142.0663, Epoch Time (s): 0.07, Total Time (hrs): 0.1388
# ====> Epoch: 4863 Train ELBO: -64.4649 Val ELBO: -164.3487, Epoch Time (s): 0.08, Total Time (hrs): 0.1388
# ====> Epoch: 4864 Train ELBO: -75.5354 Val ELBO: -161.3827, Epoch Time (s): 0.07, Total Time (hrs): 0.1388
# ====> Epoch: 4865 Train ELBO: -77.5436 Val ELBO: -168.6815, Epoch Time (s): 0.09, Total Time (hrs): 0.1388
# ====> Epoch: 4866 Train ELBO: -72.5049 Val ELBO: -153.8876, Epoch Time (s): 0.08, Total Time (hrs): 0.1389
# ====> Epoch: 4867 Train ELBO: -71.6288 Val ELBO: -146.4382, Epoch Time (s): 0.07, Total Time (hrs): 0.1389
# ====> Epoch: 4868 Train ELBO: -76.2387 Val ELBO: -152.8832, Epoch Time (s): 0.07, Total Time (hrs): 0.1389
# ====> Epoch: 4869 Train ELBO: -76.0951 Val ELBO: -147.1427, Epoch Time (s): 0.08, Total Time (hrs): 0.1389
# ====> Epoch: 4870 Train ELBO: -73.5474 Val ELBO: -158.9427, Epoch Time (s): 0.07, Total Time (hrs): 0.1389
# ====> Epoch: 4871 Train ELBO: -72.6095 Val ELBO: -169.2751, Epoch Time (s): 0.08, Total Time (hrs): 0.1390
# ====> Epoch: 4872 Train ELBO: -80.7530 Val ELBO: -141.7318, Epoch Time (s): 0.08, Total Time (hrs): 0.1390
# ====> Epoch: 4873 Train ELBO: -71.2986 Val ELBO: -151.0439, Epoch Time (s): 0.07, Total Time (hrs): 0.1390
# ====> Epoch: 4874 Train ELBO: -72.8920 Val ELBO: -153.5564, Epoch Time (s): 0.07, Total Time (hrs): 0.1390
# ====> Epoch: 4875 Train ELBO: -67.4034 Val ELBO: -143.9043, Epoch Time (s): 0.08, Total Time (hrs): 0.1390
# ====> Epoch: 4876 Train ELBO: -68.6451 Val ELBO: -149.5537, Epoch Time (s): 0.08, Total Time (hrs): 0.1391
# ====> Epoch: 4877 Train ELBO: -78.1036 Val ELBO: -177.3993, Epoch Time (s): 0.08, Total Time (hrs): 0.1391
# ====> Epoch: 4878 Train ELBO: -86.2623 Val ELBO: -156.6879, Epoch Time (s): 0.08, Total Time (hrs): 0.1391
# ====> Epoch: 4879 Train ELBO: -85.6240 Val ELBO: -172.5318, Epoch Time (s): 0.08, Total Time (hrs): 0.1391
# ====> Epoch: 4880 Train ELBO: -100.9003 Val ELBO: -176.1358, Epoch Time (s): 0.07, Total Time (hrs): 0.1392
# ====> Epoch: 4881 Train ELBO: -86.1534 Val ELBO: -158.0144, Epoch Time (s): 0.08, Total Time (hrs): 0.1392
# ====> Epoch: 4882 Train ELBO: -89.2933 Val ELBO: -154.1137, Epoch Time (s): 0.07, Total Time (hrs): 0.1392
# ====> Epoch: 4883 Train ELBO: -88.5049 Val ELBO: -187.8427, Epoch Time (s): 0.08, Total Time (hrs): 0.1392
# ====> Epoch: 4884 Train ELBO: -91.7812 Val ELBO: -165.3159, Epoch Time (s): 0.09, Total Time (hrs): 0.1392
# ====> Epoch: 4885 Train ELBO: -83.0811 Val ELBO: -184.9845, Epoch Time (s): 0.08, Total Time (hrs): 0.1393
# ====> Epoch: 4886 Train ELBO: -82.9401 Val ELBO: -190.2220, Epoch Time (s): 0.07, Total Time (hrs): 0.1393
# ====> Epoch: 4887 Train ELBO: -88.2047 Val ELBO: -169.7813, Epoch Time (s): 0.08, Total Time (hrs): 0.1393
# ====> Epoch: 4888 Train ELBO: -83.6688 Val ELBO: -198.6508, Epoch Time (s): 0.07, Total Time (hrs): 0.1393
# ====> Epoch: 4889 Train ELBO: -93.1987 Val ELBO: -157.8366, Epoch Time (s): 0.07, Total Time (hrs): 0.1394
# ====> Epoch: 4890 Train ELBO: -88.7682 Val ELBO: -192.8562, Epoch Time (s): 0.12, Total Time (hrs): 0.1394
# ====> Epoch: 4891 Train ELBO: -104.4022 Val ELBO: -174.2344, Epoch Time (s): 0.13, Total Time (hrs): 0.1394
# ====> Epoch: 4892 Train ELBO: -94.3227 Val ELBO: -227.8050, Epoch Time (s): 0.11, Total Time (hrs): 0.1395
# ====> Epoch: 4893 Train ELBO: -155.8072 Val ELBO: -275.6313, Epoch Time (s): 0.11, Total Time (hrs): 0.1395
# ====> Epoch: 4894 Train ELBO: -164.9417 Val ELBO: -373.8918, Epoch Time (s): 0.11, Total Time (hrs): 0.1395
# ====> Epoch: 4895 Train ELBO: -223.4102 Val ELBO: -362.5632, Epoch Time (s): 0.10, Total Time (hrs): 0.1395
# ====> Epoch: 4896 Train ELBO: -241.4194 Val ELBO: -257.6846, Epoch Time (s): 0.11, Total Time (hrs): 0.1396
# ====> Epoch: 4897 Train ELBO: -228.7220 Val ELBO: -325.3645, Epoch Time (s): 0.12, Total Time (hrs): 0.1396
# ====> Epoch: 4898 Train ELBO: -284.6700 Val ELBO: -274.5625, Epoch Time (s): 0.11, Total Time (hrs): 0.1396
# ====> Epoch: 4899 Train ELBO: -195.5123 Val ELBO: -221.8515, Epoch Time (s): 0.10, Total Time (hrs): 0.1397
# ====> Epoch: 4900 Train ELBO: -147.7946 Val ELBO: -201.3580, Epoch Time (s): 0.10, Total Time (hrs): 0.1397
# ====> Epoch: 4901 Train ELBO: -109.7600 Val ELBO: -261.9223, Epoch Time (s): 0.13, Total Time (hrs): 0.1397
# ====> Epoch: 4902 Train ELBO: -131.6446 Val ELBO: -212.9509, Epoch Time (s): 0.11, Total Time (hrs): 0.1398
# ====> Epoch: 4903 Train ELBO: -120.7744 Val ELBO: -294.8827, Epoch Time (s): 0.13, Total Time (hrs): 0.1398
# ====> Epoch: 4904 Train ELBO: -160.1226 Val ELBO: -207.0559, Epoch Time (s): 0.11, Total Time (hrs): 0.1398
# ====> Epoch: 4905 Train ELBO: -129.3714 Val ELBO: -184.7981, Epoch Time (s): 0.12, Total Time (hrs): 0.1399
# ====> Epoch: 4906 Train ELBO: -113.7861 Val ELBO: -168.8478, Epoch Time (s): 0.11, Total Time (hrs): 0.1399
# ====> Epoch: 4907 Train ELBO: -89.3460 Val ELBO: -159.6474, Epoch Time (s): 0.11, Total Time (hrs): 0.1399
# ====> Epoch: 4908 Train ELBO: -73.9638 Val ELBO: -144.4327, Epoch Time (s): 0.11, Total Time (hrs): 0.1399
# ====> Epoch: 4909 Train ELBO: -74.9256 Val ELBO: -161.9480, Epoch Time (s): 0.11, Total Time (hrs): 0.1400
# ====> Epoch: 4910 Train ELBO: -77.6212 Val ELBO: -166.8237, Epoch Time (s): 0.12, Total Time (hrs): 0.1400
# ====> Epoch: 4911 Train ELBO: -75.5818 Val ELBO: -161.8853, Epoch Time (s): 0.12, Total Time (hrs): 0.1400
# ====> Epoch: 4912 Train ELBO: -76.7202 Val ELBO: -163.7289, Epoch Time (s): 0.10, Total Time (hrs): 0.1401
# ====> Epoch: 4913 Train ELBO: -80.8007 Val ELBO: -160.7681, Epoch Time (s): 0.11, Total Time (hrs): 0.1401
# ====> Epoch: 4914 Train ELBO: -83.0375 Val ELBO: -189.6460, Epoch Time (s): 0.11, Total Time (hrs): 0.1401
# ====> Epoch: 4915 Train ELBO: -97.5149 Val ELBO: -211.9943, Epoch Time (s): 0.10, Total Time (hrs): 0.1402
# ====> Epoch: 4916 Train ELBO: -109.3898 Val ELBO: -200.7733, Epoch Time (s): 0.11, Total Time (hrs): 0.1402
# ====> Epoch: 4917 Train ELBO: -99.0794 Val ELBO: -182.1463, Epoch Time (s): 0.12, Total Time (hrs): 0.1402
# ====> Epoch: 4918 Train ELBO: -85.4983 Val ELBO: -174.9671, Epoch Time (s): 0.10, Total Time (hrs): 0.1403
# ====> Epoch: 4919 Train ELBO: -83.8479 Val ELBO: -173.2271, Epoch Time (s): 0.13, Total Time (hrs): 0.1403
# ====> Epoch: 4920 Train ELBO: -89.4746 Val ELBO: -185.0952, Epoch Time (s): 0.13, Total Time (hrs): 0.1403
# ====> Epoch: 4921 Train ELBO: -88.4309 Val ELBO: -175.6707, Epoch Time (s): 0.14, Total Time (hrs): 0.1404
# ====> Epoch: 4922 Train ELBO: -90.5213 Val ELBO: -154.2645, Epoch Time (s): 0.14, Total Time (hrs): 0.1404
# ====> Epoch: 4923 Train ELBO: -81.0691 Val ELBO: -146.5133, Epoch Time (s): 0.09, Total Time (hrs): 0.1404
# ====> Epoch: 4924 Train ELBO: -76.4830 Val ELBO: -153.7356, Epoch Time (s): 0.07, Total Time (hrs): 0.1405
# ====> Epoch: 4925 Train ELBO: -71.8266 Val ELBO: -158.3106, Epoch Time (s): 0.07, Total Time (hrs): 0.1405
# ====> Epoch: 4926 Train ELBO: -70.4925 Val ELBO: -152.6861, Epoch Time (s): 0.08, Total Time (hrs): 0.1405
# ====> Epoch: 4927 Train ELBO: -68.8703 Val ELBO: -146.0300, Epoch Time (s): 0.07, Total Time (hrs): 0.1405
# ====> Epoch: 4928 Train ELBO: -69.5526 Val ELBO: -148.2782, Epoch Time (s): 0.07, Total Time (hrs): 0.1405
# ====> Epoch: 4929 Train ELBO: -70.1067 Val ELBO: -131.8037, Epoch Time (s): 0.09, Total Time (hrs): 0.1406
# ====> Epoch: 4930 Train ELBO: -64.3087 Val ELBO: -143.6087, Epoch Time (s): 0.07, Total Time (hrs): 0.1406
# ====> Epoch: 4931 Train ELBO: -66.2525 Val ELBO: -152.9046, Epoch Time (s): 0.07, Total Time (hrs): 0.1406
# ====> Epoch: 4932 Train ELBO: -61.8952 Val ELBO: -139.0694, Epoch Time (s): 0.10, Total Time (hrs): 0.1406
# ====> Epoch: 4933 Train ELBO: -64.7604 Val ELBO: -146.0219, Epoch Time (s): 0.07, Total Time (hrs): 0.1406
# ====> Epoch: 4934 Train ELBO: -66.4715 Val ELBO: -154.3015, Epoch Time (s): 0.07, Total Time (hrs): 0.1407
# ====> Epoch: 4935 Train ELBO: -69.1621 Val ELBO: -167.6170, Epoch Time (s): 0.08, Total Time (hrs): 0.1407
# ====> Epoch: 4936 Train ELBO: -77.7178 Val ELBO: -163.4569, Epoch Time (s): 0.07, Total Time (hrs): 0.1407
# ====> Epoch: 4937 Train ELBO: -79.5690 Val ELBO: -180.6944, Epoch Time (s): 0.07, Total Time (hrs): 0.1407
# ====> Epoch: 4938 Train ELBO: -95.3229 Val ELBO: -148.3930, Epoch Time (s): 0.08, Total Time (hrs): 0.1408
# ====> Epoch: 4939 Train ELBO: -82.3234 Val ELBO: -148.3102, Epoch Time (s): 0.07, Total Time (hrs): 0.1408
# ====> Epoch: 4940 Train ELBO: -77.3333 Val ELBO: -158.1373, Epoch Time (s): 0.07, Total Time (hrs): 0.1408
# ====> Epoch: 4941 Train ELBO: -83.7858 Val ELBO: -164.0776, Epoch Time (s): 0.08, Total Time (hrs): 0.1408
# ====> Epoch: 4942 Train ELBO: -83.0394 Val ELBO: -176.7550, Epoch Time (s): 0.07, Total Time (hrs): 0.1408
# ====> Epoch: 4943 Train ELBO: -81.2322 Val ELBO: -156.6894, Epoch Time (s): 0.07, Total Time (hrs): 0.1409
# ====> Epoch: 4944 Train ELBO: -118.0625 Val ELBO: -221.3270, Epoch Time (s): 0.08, Total Time (hrs): 0.1409
# ====> Epoch: 4945 Train ELBO: -160.5755 Val ELBO: -255.5599, Epoch Time (s): 0.10, Total Time (hrs): 0.1409
# ====> Epoch: 4946 Train ELBO: -140.5921 Val ELBO: -197.1757, Epoch Time (s): 0.08, Total Time (hrs): 0.1409
# ====> Epoch: 4947 Train ELBO: -130.0362 Val ELBO: -270.3654, Epoch Time (s): 0.09, Total Time (hrs): 0.1409
# ====> Epoch: 4948 Train ELBO: -138.2660 Val ELBO: -173.2196, Epoch Time (s): 0.07, Total Time (hrs): 0.1410
# ====> Epoch: 4949 Train ELBO: -110.4002 Val ELBO: -151.5627, Epoch Time (s): 0.08, Total Time (hrs): 0.1410
# ====> Epoch: 4950 Train ELBO: -91.6658 Val ELBO: -174.7485, Epoch Time (s): 0.09, Total Time (hrs): 0.1410
# ====> Epoch: 4951 Train ELBO: -92.0931 Val ELBO: -188.2861, Epoch Time (s): 0.07, Total Time (hrs): 0.1410
# ====> Epoch: 4952 Train ELBO: -84.3938 Val ELBO: -178.3619, Epoch Time (s): 0.07, Total Time (hrs): 0.1411
# ====> Epoch: 4953 Train ELBO: -96.7292 Val ELBO: -207.5785, Epoch Time (s): 0.08, Total Time (hrs): 0.1411
# ====> Epoch: 4954 Train ELBO: -110.5228 Val ELBO: -174.7785, Epoch Time (s): 0.08, Total Time (hrs): 0.1411
# ====> Epoch: 4955 Train ELBO: -125.2627 Val ELBO: -185.6107, Epoch Time (s): 0.08, Total Time (hrs): 0.1411
# ====> Epoch: 4956 Train ELBO: -121.2521 Val ELBO: -186.0586, Epoch Time (s): 0.08, Total Time (hrs): 0.1411
# ...
# ====> Epoch: 9361 Train ELBO: -72.0365 Val ELBO: -122.9051, Epoch Time (s): 0.08, Total Time (hrs): 0.2632
# ====> Epoch: 9362 Train ELBO: -24.0117 Val ELBO: -93.7124, Epoch Time (s): 0.07, Total Time (hrs): 0.2633
# ====> Epoch: 9363 Train ELBO: 4.9433 Val ELBO: -63.1125, Epoch Time (s): 0.07, Total Time (hrs): 0.2633
# ====> Epoch: 9364 Train ELBO: 18.7869 Val ELBO: -27.2385, Epoch Time (s): 0.08, Total Time (hrs): 0.2633
# ====> Epoch: 9365 Train ELBO: 33.9380 Val ELBO: -31.9151, Epoch Time (s): 0.07, Total Time (hrs): 0.2633
# ====> Epoch: 9366 Train ELBO: 38.5133 Val ELBO: -26.7534, Epoch Time (s): 0.07, Total Time (hrs): 0.2633
# ====> Epoch: 9367 Train ELBO: 37.3179 Val ELBO: -19.7571, Epoch Time (s): 0.08, Total Time (hrs): 0.2634
# ====> Epoch: 9368 Train ELBO: 42.6854 Val ELBO: -33.5264, Epoch Time (s): 0.08, Total Time (hrs): 0.2634
# ====> Epoch: 9369 Train ELBO: 45.0302 Val ELBO: -26.5756, Epoch Time (s): 0.07, Total Time (hrs): 0.2634
# ====> Epoch: 9370 Train ELBO: 45.1259 Val ELBO: -24.5087, Epoch Time (s): 0.08, Total Time (hrs): 0.2634
# ====> Epoch: 9371 Train ELBO: 47.4946 Val ELBO: -11.3836, Epoch Time (s): 0.08, Total Time (hrs): 0.2634
# ====> Epoch: 9372 Train ELBO: 47.1778 Val ELBO: -11.3134, Epoch Time (s): 0.11, Total Time (hrs): 0.2635
# ====> Epoch: 9373 Train ELBO: 50.5498 Val ELBO: -19.7013, Epoch Time (s): 0.08, Total Time (hrs): 0.2635
# ====> Epoch: 9374 Train ELBO: 48.5823 Val ELBO: -19.3105, Epoch Time (s): 0.07, Total Time (hrs): 0.2635
# ====> Epoch: 9375 Train ELBO: 37.7336 Val ELBO: -35.2278, Epoch Time (s): 0.08, Total Time (hrs): 0.2636
# ====> Epoch: 9376 Train ELBO: 32.6439 Val ELBO: -48.9540, Epoch Time (s): 0.07, Total Time (hrs): 0.2636
# ====> Epoch: 9377 Train ELBO: 29.0600 Val ELBO: -17.6091, Epoch Time (s): 0.08, Total Time (hrs): 0.2636
# ====> Epoch: 9378 Train ELBO: 42.8703 Val ELBO: -17.9534, Epoch Time (s): 0.08, Total Time (hrs): 0.2636
# ====> Epoch: 9379 Train ELBO: 43.5392 Val ELBO: -46.8916, Epoch Time (s): 0.07, Total Time (hrs): 0.2636
# ====> Epoch: 9380 Train ELBO: 22.3495 Val ELBO: -29.9198, Epoch Time (s): 0.07, Total Time (hrs): 0.2637
# ====> Epoch: 9381 Train ELBO: 37.4820 Val ELBO: -17.4067, Epoch Time (s): 0.08, Total Time (hrs): 0.2637
# ====> Epoch: 9382 Train ELBO: 36.9652 Val ELBO: -44.9982, Epoch Time (s): 0.07, Total Time (hrs): 0.2637
# ====> Epoch: 9383 Train ELBO: 25.5034 Val ELBO: -35.1806, Epoch Time (s): 0.07, Total Time (hrs): 0.2637
# ====> Epoch: 9384 Train ELBO: 27.9135 Val ELBO: -58.1143, Epoch Time (s): 0.09, Total Time (hrs): 0.2638
# ====> Epoch: 9385 Train ELBO: 28.5694 Val ELBO: -28.9707, Epoch Time (s): 0.08, Total Time (hrs): 0.2638
# ====> Epoch: 9386 Train ELBO: 34.7430 Val ELBO: -33.7628, Epoch Time (s): 0.07, Total Time (hrs): 0.2638
# ====> Epoch: 9387 Train ELBO: 31.4327 Val ELBO: -30.9125, Epoch Time (s): 0.08, Total Time (hrs): 0.2638
# ====> Epoch: 9388 Train ELBO: 35.1931 Val ELBO: -22.1518, Epoch Time (s): 0.07, Total Time (hrs): 0.2638
# ====> Epoch: 9389 Train ELBO: 35.2805 Val ELBO: -33.3288, Epoch Time (s): 0.07, Total Time (hrs): 0.2639
# ====> Epoch: 9390 Train ELBO: 42.7601 Val ELBO: -36.6131, Epoch Time (s): 0.08, Total Time (hrs): 0.2639
# ====> Epoch: 9391 Train ELBO: 41.2297 Val ELBO: -42.8389, Epoch Time (s): 0.07, Total Time (hrs): 0.2639
# ====> Epoch: 9392 Train ELBO: 41.6600 Val ELBO: -15.3901, Epoch Time (s): 0.07, Total Time (hrs): 0.2639
# ====> Epoch: 9393 Train ELBO: 45.7271 Val ELBO: -24.6920, Epoch Time (s): 0.08, Total Time (hrs): 0.2639
# ====> Epoch: 9394 Train ELBO: 42.5121 Val ELBO: -18.3184, Epoch Time (s): 0.08, Total Time (hrs): 0.2640
# ====> Epoch: 9395 Train ELBO: 44.8774 Val ELBO: -22.5139, Epoch Time (s): 0.07, Total Time (hrs): 0.2640
# ====> Epoch: 9396 Train ELBO: 44.7287 Val ELBO: -7.1524, Epoch Time (s): 0.09, Total Time (hrs): 0.2640
# ====> Epoch: 9397 Train ELBO: 45.4435 Val ELBO: -25.6972, Epoch Time (s): 0.08, Total Time (hrs): 0.2640
# ====> Epoch: 9398 Train ELBO: 35.9423 Val ELBO: -24.9870, Epoch Time (s): 0.08, Total Time (hrs): 0.2641
# ====> Epoch: 9399 Train ELBO: 41.1844 Val ELBO: -27.3966, Epoch Time (s): 0.08, Total Time (hrs): 0.2641
# ====> Epoch: 9400 Train ELBO: 42.8527 Val ELBO: -22.5561, Epoch Time (s): 0.07, Total Time (hrs): 0.2641
# ====> Epoch: 9401 Train ELBO: 41.4361 Val ELBO: -25.7628, Epoch Time (s): 0.07, Total Time (hrs): 0.2641
# ====> Epoch: 9402 Train ELBO: 37.7295 Val ELBO: -39.4501, Epoch Time (s): 0.07, Total Time (hrs): 0.2641
# ====> Epoch: 9403 Train ELBO: 39.1110 Val ELBO: -29.0615, Epoch Time (s): 0.07, Total Time (hrs): 0.2642
# ====> Epoch: 9404 Train ELBO: 39.8400 Val ELBO: -32.5315, Epoch Time (s): 0.07, Total Time (hrs): 0.2642
# ====> Epoch: 9405 Train ELBO: 29.9726 Val ELBO: -30.3248, Epoch Time (s): 0.08, Total Time (hrs): 0.2642
# ====> Epoch: 9406 Train ELBO: 23.6823 Val ELBO: -40.0964, Epoch Time (s): 0.08, Total Time (hrs): 0.2642
# ====> Epoch: 9407 Train ELBO: 20.1370 Val ELBO: -49.3061, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 9408 Train ELBO: 30.2986 Val ELBO: -43.2352, Epoch Time (s): 0.08, Total Time (hrs): 0.2643
# ====> Epoch: 9409 Train ELBO: 28.7620 Val ELBO: -26.6631, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 9410 Train ELBO: 30.5151 Val ELBO: -40.8266, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 9411 Train ELBO: 36.0479 Val ELBO: -28.7501, Epoch Time (s): 0.10, Total Time (hrs): 0.2643
# ====> Epoch: 9412 Train ELBO: 44.4878 Val ELBO: -26.7786, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 9413 Train ELBO: 48.3561 Val ELBO: -13.7824, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 9414 Train ELBO: 47.8004 Val ELBO: -15.5401, Epoch Time (s): 0.08, Total Time (hrs): 0.2644
# ====> Epoch: 9415 Train ELBO: 48.8156 Val ELBO: -22.4638, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 9416 Train ELBO: 45.8600 Val ELBO: -11.2574, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 9417 Train ELBO: 47.8207 Val ELBO: -15.8625, Epoch Time (s): 0.08, Total Time (hrs): 0.2645
# ====> Epoch: 9418 Train ELBO: 49.2505 Val ELBO: -10.3732, Epoch Time (s): 0.07, Total Time (hrs): 0.2645
# ====> Epoch: 9419 Train ELBO: 53.5081 Val ELBO: -16.1319, Epoch Time (s): 0.07, Total Time (hrs): 0.2645
# ====> Epoch: 9420 Train ELBO: 49.5137 Val ELBO: -20.0336, Epoch Time (s): 0.08, Total Time (hrs): 0.2645
# ====> Epoch: 9421 Train ELBO: 48.7044 Val ELBO: -2.9203, Epoch Time (s): 0.07, Total Time (hrs): 0.2646
# ====> Epoch: 9422 Train ELBO: 51.6765 Val ELBO: -8.0873, Epoch Time (s): 0.08, Total Time (hrs): 0.2646
# ====> Epoch: 9423 Train ELBO: 53.4015 Val ELBO: -5.5320, Epoch Time (s): 0.08, Total Time (hrs): 0.2646
# ====> Epoch: 9424 Train ELBO: 54.1976 Val ELBO: -8.4579, Epoch Time (s): 0.09, Total Time (hrs): 0.2646
# ====> Epoch: 9425 Train ELBO: 48.9826 Val ELBO: -13.7095, Epoch Time (s): 0.07, Total Time (hrs): 0.2647
# ====> Epoch: 9426 Train ELBO: 45.7419 Val ELBO: -25.7732, Epoch Time (s): 0.08, Total Time (hrs): 0.2647
# ====> Epoch: 9427 Train ELBO: 43.9699 Val ELBO: -24.0675, Epoch Time (s): 0.07, Total Time (hrs): 0.2647
# ====> Epoch: 9428 Train ELBO: 48.4794 Val ELBO: -22.6710, Epoch Time (s): 0.07, Total Time (hrs): 0.2647
# ====> Epoch: 9429 Train ELBO: 49.0664 Val ELBO: -16.1334, Epoch Time (s): 0.07, Total Time (hrs): 0.2647
# ====> Epoch: 9430 Train ELBO: 51.3869 Val ELBO: -5.3558, Epoch Time (s): 0.07, Total Time (hrs): 0.2648
# ====> Epoch: 9431 Train ELBO: 52.2515 Val ELBO: -17.7561, Epoch Time (s): 0.07, Total Time (hrs): 0.2648
# ====> Epoch: 9432 Train ELBO: 49.8534 Val ELBO: -11.5467, Epoch Time (s): 0.08, Total Time (hrs): 0.2648
# ====> Epoch: 9433 Train ELBO: 48.8501 Val ELBO: -20.6252, Epoch Time (s): 0.07, Total Time (hrs): 0.2648
# ====> Epoch: 9434 Train ELBO: 47.1312 Val ELBO: -23.3002, Epoch Time (s): 0.07, Total Time (hrs): 0.2648
# ====> Epoch: 9435 Train ELBO: 47.1546 Val ELBO: -20.1126, Epoch Time (s): 0.07, Total Time (hrs): 0.2649
# ====> Epoch: 9436 Train ELBO: 44.3010 Val ELBO: -31.2039, Epoch Time (s): 0.07, Total Time (hrs): 0.2649
# ====> Epoch: 9437 Train ELBO: 43.7084 Val ELBO: -21.5429, Epoch Time (s): 0.07, Total Time (hrs): 0.2649
# ====> Epoch: 9438 Train ELBO: 47.8959 Val ELBO: -19.1282, Epoch Time (s): 0.09, Total Time (hrs): 0.2649
# ====> Epoch: 9439 Train ELBO: 43.9681 Val ELBO: -44.6952, Epoch Time (s): 0.07, Total Time (hrs): 0.2649
# ====> Epoch: 9440 Train ELBO: 2.2066 Val ELBO: -66.7072, Epoch Time (s): 0.07, Total Time (hrs): 0.2650
# ====> Epoch: 9441 Train ELBO: 21.7730 Val ELBO: -30.0860, Epoch Time (s): 0.08, Total Time (hrs): 0.2650
# ====> Epoch: 9442 Train ELBO: 20.2727 Val ELBO: -28.4334, Epoch Time (s): 0.07, Total Time (hrs): 0.2650
# ====> Epoch: 9443 Train ELBO: 12.3772 Val ELBO: -87.5125, Epoch Time (s): 0.07, Total Time (hrs): 0.2650
# ====> Epoch: 9444 Train ELBO: 15.2002 Val ELBO: -21.8041, Epoch Time (s): 0.08, Total Time (hrs): 0.2650
# ====> Epoch: 9445 Train ELBO: 33.3544 Val ELBO: -16.5891, Epoch Time (s): 0.07, Total Time (hrs): 0.2651
# ====> Epoch: 9446 Train ELBO: 38.4523 Val ELBO: -23.5839, Epoch Time (s): 0.07, Total Time (hrs): 0.2651
# ====> Epoch: 9447 Train ELBO: 45.3933 Val ELBO: -22.4259, Epoch Time (s): 0.08, Total Time (hrs): 0.2651
# ====> Epoch: 9448 Train ELBO: 45.0662 Val ELBO: -23.4212, Epoch Time (s): 0.08, Total Time (hrs): 0.2651
# ====> Epoch: 9449 Train ELBO: 43.3978 Val ELBO: -11.5790, Epoch Time (s): 0.07, Total Time (hrs): 0.2652
# ====> Epoch: 9450 Train ELBO: 34.5684 Val ELBO: -33.6379, Epoch Time (s): 0.08, Total Time (hrs): 0.2652
# ====> Epoch: 9451 Train ELBO: 30.9181 Val ELBO: -36.8565, Epoch Time (s): 0.07, Total Time (hrs): 0.2652
# ====> Epoch: 9452 Train ELBO: 33.4836 Val ELBO: -16.5716, Epoch Time (s): 0.09, Total Time (hrs): 0.2652
# ====> Epoch: 9453 Train ELBO: 41.1354 Val ELBO: -22.7940, Epoch Time (s): 0.08, Total Time (hrs): 0.2652
# ====> Epoch: 9454 Train ELBO: 39.0660 Val ELBO: -21.9208, Epoch Time (s): 0.07, Total Time (hrs): 0.2653
# ====> Epoch: 9455 Train ELBO: 34.4191 Val ELBO: -39.6138, Epoch Time (s): 0.07, Total Time (hrs): 0.2653
# ====> Epoch: 9456 Train ELBO: 29.7607 Val ELBO: -21.2326, Epoch Time (s): 0.08, Total Time (hrs): 0.2653
# ====> Epoch: 9457 Train ELBO: 30.6683 Val ELBO: -22.7383, Epoch Time (s): 0.09, Total Time (hrs): 0.2653
# ====> Epoch: 9458 Train ELBO: 41.5105 Val ELBO: -39.4229, Epoch Time (s): 0.13, Total Time (hrs): 0.2654
# ====> Epoch: 9459 Train ELBO: 41.9915 Val ELBO: -24.2904, Epoch Time (s): 0.11, Total Time (hrs): 0.2654
# ====> Epoch: 9460 Train ELBO: 46.6748 Val ELBO: -14.7713, Epoch Time (s): 0.11, Total Time (hrs): 0.2654
# ====> Epoch: 9461 Train ELBO: 49.2614 Val ELBO: -10.8310, Epoch Time (s): 0.11, Total Time (hrs): 0.2655
# ====> Epoch: 9462 Train ELBO: 49.9484 Val ELBO: -9.7398, Epoch Time (s): 0.11, Total Time (hrs): 0.2655
# ====> Epoch: 9463 Train ELBO: 47.2731 Val ELBO: -22.4348, Epoch Time (s): 0.11, Total Time (hrs): 0.2655
# ====> Epoch: 9464 Train ELBO: 44.8995 Val ELBO: -20.8612, Epoch Time (s): 0.12, Total Time (hrs): 0.2655
# ====> Epoch: 9465 Train ELBO: 44.6024 Val ELBO: -23.8783, Epoch Time (s): 0.10, Total Time (hrs): 0.2656
# ====> Epoch: 9466 Train ELBO: 48.1241 Val ELBO: -9.4638, Epoch Time (s): 0.10, Total Time (hrs): 0.2656
# ====> Epoch: 9467 Train ELBO: 49.5209 Val ELBO: -22.3343, Epoch Time (s): 0.11, Total Time (hrs): 0.2656
# ====> Epoch: 9468 Train ELBO: 40.0019 Val ELBO: -15.9388, Epoch Time (s): 0.10, Total Time (hrs): 0.2657
# ====> Epoch: 9469 Train ELBO: 43.6755 Val ELBO: -11.2546, Epoch Time (s): 0.12, Total Time (hrs): 0.2657
# ====> Epoch: 9470 Train ELBO: 44.6521 Val ELBO: -25.7364, Epoch Time (s): 0.11, Total Time (hrs): 0.2657
# ====> Epoch: 9471 Train ELBO: 43.0860 Val ELBO: -15.8948, Epoch Time (s): 0.11, Total Time (hrs): 0.2658
# ====> Epoch: 9472 Train ELBO: 44.0172 Val ELBO: -12.6163, Epoch Time (s): 0.11, Total Time (hrs): 0.2658
# ====> Epoch: 9473 Train ELBO: 47.8634 Val ELBO: -12.9002, Epoch Time (s): 0.13, Total Time (hrs): 0.2658
# ====> Epoch: 9474 Train ELBO: 51.2761 Val ELBO: -10.8486, Epoch Time (s): 0.11, Total Time (hrs): 0.2659
# ====> Epoch: 9475 Train ELBO: 47.0314 Val ELBO: -24.8831, Epoch Time (s): 0.11, Total Time (hrs): 0.2659
# ====> Epoch: 9476 Train ELBO: 45.8970 Val ELBO: -24.1434, Epoch Time (s): 0.11, Total Time (hrs): 0.2659
# ====> Epoch: 9477 Train ELBO: 47.0667 Val ELBO: -12.4940, Epoch Time (s): 0.10, Total Time (hrs): 0.2659
# ====> Epoch: 9478 Train ELBO: 46.6668 Val ELBO: -13.9390, Epoch Time (s): 0.11, Total Time (hrs): 0.2660
# ====> Epoch: 9479 Train ELBO: 43.5305 Val ELBO: -15.8492, Epoch Time (s): 0.11, Total Time (hrs): 0.2660
# ====> Epoch: 9480 Train ELBO: 45.2318 Val ELBO: -29.4579, Epoch Time (s): 0.10, Total Time (hrs): 0.2660
# ====> Epoch: 9481 Train ELBO: 46.9436 Val ELBO: -21.2179, Epoch Time (s): 0.10, Total Time (hrs): 0.2661
# ====> Epoch: 9482 Train ELBO: 43.7844 Val ELBO: -20.4794, Epoch Time (s): 0.10, Total Time (hrs): 0.2661
# ====> Epoch: 9483 Train ELBO: 34.5585 Val ELBO: -16.2815, Epoch Time (s): 0.11, Total Time (hrs): 0.2661
# ====> Epoch: 9484 Train ELBO: 42.9514 Val ELBO: -17.6527, Epoch Time (s): 0.12, Total Time (hrs): 0.2662
# ====> Epoch: 9485 Train ELBO: 38.6191 Val ELBO: -17.3852, Epoch Time (s): 0.12, Total Time (hrs): 0.2662
# ====> Epoch: 9486 Train ELBO: 42.4163 Val ELBO: -33.5331, Epoch Time (s): 0.11, Total Time (hrs): 0.2662
# ====> Epoch: 9487 Train ELBO: 38.1428 Val ELBO: -74.0275, Epoch Time (s): 0.14, Total Time (hrs): 0.2663
# ====> Epoch: 9488 Train ELBO: 18.6841 Val ELBO: -59.8073, Epoch Time (s): 0.12, Total Time (hrs): 0.2663
# ====> Epoch: 9489 Train ELBO: 13.9426 Val ELBO: -44.1328, Epoch Time (s): 0.13, Total Time (hrs): 0.2663
# ====> Epoch: 9490 Train ELBO: 13.4306 Val ELBO: -56.3574, Epoch Time (s): 0.09, Total Time (hrs): 0.2664
# ====> Epoch: 9491 Train ELBO: 11.4167 Val ELBO: -77.0256, Epoch Time (s): 0.07, Total Time (hrs): 0.2664
# ====> Epoch: 9492 Train ELBO: 16.4880 Val ELBO: -41.7606, Epoch Time (s): 0.09, Total Time (hrs): 0.2664
# ====> Epoch: 9493 Train ELBO: 26.4529 Val ELBO: -18.1395, Epoch Time (s): 0.07, Total Time (hrs): 0.2664
# ====> Epoch: 9494 Train ELBO: 47.1122 Val ELBO: -11.5009, Epoch Time (s): 0.07, Total Time (hrs): 0.2664
# ====> Epoch: 9495 Train ELBO: 45.3437 Val ELBO: -31.8607, Epoch Time (s): 0.08, Total Time (hrs): 0.2665
# ====> Epoch: 9496 Train ELBO: 38.2266 Val ELBO: -20.4648, Epoch Time (s): 0.07, Total Time (hrs): 0.2665
# ====> Epoch: 9497 Train ELBO: 44.0144 Val ELBO: -19.3668, Epoch Time (s): 0.07, Total Time (hrs): 0.2665
# ====> Epoch: 9498 Train ELBO: 40.1162 Val ELBO: -17.1729, Epoch Time (s): 0.08, Total Time (hrs): 0.2665
# ====> Epoch: 9499 Train ELBO: 49.3366 Val ELBO: -33.8858, Epoch Time (s): 0.07, Total Time (hrs): 0.2665
# 3
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# ====> Epoch: 9500 Train ELBO: 46.7270 Val ELBO: -9.4358, Epoch Time (s): 3.06, Total Time (hrs): 0.2674
# ====> Epoch: 9501 Train ELBO: 47.0049 Val ELBO: -14.9006, Epoch Time (s): 0.07, Total Time (hrs): 0.2681
# ====> Epoch: 9502 Train ELBO: 32.1444 Val ELBO: -36.0774, Epoch Time (s): 0.09, Total Time (hrs): 0.2681
# ====> Epoch: 9503 Train ELBO: 24.5576 Val ELBO: -18.7854, Epoch Time (s): 0.07, Total Time (hrs): 0.2681
# ====> Epoch: 9504 Train ELBO: 34.4046 Val ELBO: -44.5124, Epoch Time (s): 0.08, Total Time (hrs): 0.2682
# ====> Epoch: 9505 Train ELBO: 34.8156 Val ELBO: -15.6358, Epoch Time (s): 0.07, Total Time (hrs): 0.2682
# ====> Epoch: 9506 Train ELBO: 44.9581 Val ELBO: -32.0008, Epoch Time (s): 0.07, Total Time (hrs): 0.2682
# ====> Epoch: 9507 Train ELBO: 38.1226 Val ELBO: -19.4135, Epoch Time (s): 0.08, Total Time (hrs): 0.2682
# ====> Epoch: 9508 Train ELBO: 44.3983 Val ELBO: -25.9279, Epoch Time (s): 0.07, Total Time (hrs): 0.2682
# ====> Epoch: 9509 Train ELBO: 37.1463 Val ELBO: -18.6565, Epoch Time (s): 0.07, Total Time (hrs): 0.2683
# ====> Epoch: 9510 Train ELBO: 38.4478 Val ELBO: -13.3284, Epoch Time (s): 0.08, Total Time (hrs): 0.2683
# ====> Epoch: 9511 Train ELBO: 44.4691 Val ELBO: -18.6978, Epoch Time (s): 0.07, Total Time (hrs): 0.2683
# ====> Epoch: 9512 Train ELBO: 46.4724 Val ELBO: -17.2856, Epoch Time (s): 0.07, Total Time (hrs): 0.2683
