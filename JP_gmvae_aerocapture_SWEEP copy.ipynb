# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.10.0+cu128)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.3)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (26.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.24.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1.0->pytorch_lightning) (1.3.4)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 22.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 69.3 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.3 pytorch_lightning-2.6.1 torchmetrics-1.8.2

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/pipag_training.git
# Out:
# Cloning into 'pipag_training'...
# remote: Enumerating objects: 364, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 364 (delta 14), reused 7 (delta 7), pack-reused 337 (from 1)
# Receiving objects: 100% (364/364), 15.06 MiB | 13.96 MiB/s, done.
# Resolving deltas: 100% (197/197), done.

# %%
# %cd pipag_training
# !cd /content/pipag_training && git pull
# !git pull
sys.path.append('/content/pipag_training')
# Out:
# /content/pipag_training
# Already up to date.

# %%
# !ls
# Out:
#  compare_classification_accuracy.py	  models.py
#  compare_variance_gmvae.py		  move_figures_to_LB.py
#  generate_gif_from_pngs.py		 'old notebooks'
#  generate_training_json.py		  README.md
#  gmvae_common.py			  svd.py
#  JP_gmvae_aerocapture_BASE_copy.ipynb	  test_git_imports.ipynb
#  JP_gmvae_aerocapture_BASE.ipynb	  vae_aerocapture_vel.py
#  JP_gmvae_aerocapture_energy.ipynb	  VAE_Capture.ipynb
# 'JP_gmvae_aerocapture_SWEEP copy.ipynb'   VAE_sweep_arch.ipynb
#  JP_gmvae_aerocapture_SWEEP.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1305: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
# n_train = 1024
# n_val = 128
# n_test = 128
# For testing small batches of data
n_train = 800
n_val = 100
n_test = 100
# THREE LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = 24
hd1 = 30
hd2 = 20
hd3 = 10
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = None
# hidden_dims = [hd1, hd2]

latent_dims = [6]
n_clustersS = [4,5,6,7,8,9]
skip_combos = []
lr = 1e-3
n_epochs = 15_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

plot_interval = 500
dpi = 300

D = 1  #num_modalities
# downsampleNum = 64
downsampleNum = 36 # Revision

loadFlag = False  # True to load in old case, False to run a new case

# data = '1_near_escape_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_fnpag_1999_inds_energy_scaled_downsampled_'
# tag = 'near_escape'

# data = '1_near_crash_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_crash_fnpag_2000_inds_energy_scaled_downsampled_'
# tag = 'near_crash'

# data = 'UOP_inc_lit_disps_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_inc_lit_disps_4999_inds_energy_scaled_downsampled_'
# tag = 'near_escape_OLD'

# data = 'UOP_near_crash_steeper_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_near_crash_steeper_4997_inds_energy_scaled_downsampled_'
# tag = 'near_crash_OLD'

# data = '1_near_escape_new_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_new_2000_inds_energy_scaled_downsampled_'
# tag = 'near_escape_new'

# data = 'rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_'
# inds = 'rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_'
# tag = 'rev_gu_mixture'
# dataName = 'velocity_fpa'

# data = 'rev_gumixture_1000_data_energy_scaled_downsampled_'
# inds = 'rev_gumixture_1000_inds_energy_scaled_downsampled_'
# tag = 'rev_gu_mixture_energy'
# dataName = 'energy'

data = 'rev_gumixture_dp15_more_downwards_1000_data_energy_scaled_downsampled_'
inds = 'rev_gumixture_dp15_more_downwards_1000_inds_energy_scaled_downsampled_'
tag = 'rev_gu_mixture_energy_biased_down'
dataName = 'energy'

# %%
# !ls /content/drive/MyDrive/rev_pipag_data/
# Out:
# gmvae_rev_gu_mixture_20260216_184454_L5_C3
# gmvae_rev_gu_mixture_20260216_185127_L6_C3
# gmvae_rev_gu_mixture_20260216_190125_L5_C4
# gmvae_rev_gu_mixture_20260216_190656_L6_C4
# gmvae_rev_gu_mixture_20260216_191906_L5_C5
# gmvae_rev_gu_mixture_20260216_192236_L6_C5
# gmvae_rev_gu_mixture_20260216_193657_L5_C6
# gmvae_rev_gu_mixture_20260216_193840_L6_C6
# gmvae_rev_gu_mixture_20260216_201930_L7_C3
# gmvae_rev_gu_mixture_20260216_201945_L8_C3
# gmvae_rev_gu_mixture_20260216_203450_L7_C4
# gmvae_rev_gu_mixture_20260216_203532_L8_C4
# gmvae_rev_gu_mixture_20260216_205019_L7_C5
# gmvae_rev_gu_mixture_20260216_205122_L8_C5
# gmvae_rev_gu_mixture_20260216_210557_L7_C6
# gmvae_rev_gu_mixture_20260216_210713_L8_C6
# gmvae_rev_gu_mixture_20260216_221130_L5_C7
# gmvae_rev_gu_mixture_20260216_221251_L5_C3_24_18_12
# gmvae_rev_gu_mixture_20260216_221358_L5_C7
# gmvae_rev_gu_mixture_20260216_222846_L5_C4_24_18_12
# gmvae_rev_gu_mixture_20260216_223026_L5_C8
# gmvae_rev_gu_mixture_20260216_224438_L5_C5_24_18_12
# gmvae_rev_gu_mixture_20260216_224634_L6_C7
# gmvae_rev_gu_mixture_20260216_231212_L5_C6_24_18_12
# gmvae_rev_gu_mixture_20260216_231213_L6_C8
# gmvae_rev_gu_mixture_20260216_232708_L7_C7
# gmvae_rev_gu_mixture_20260216_232738_L6_C3_24_18_12
# gmvae_rev_gu_mixture_20260216_234208_L7_C8
# gmvae_rev_gu_mixture_20260216_234341_L6_C4_24_18_12
# gmvae_rev_gu_mixture_20260216_235712_L8_C7
# gmvae_rev_gu_mixture_20260216_235933_L6_C5_24_18_12
# gmvae_rev_gu_mixture_20260217_001230_L8_C8
# gmvae_rev_gu_mixture_20260217_001541_L6_C6_24_18_12
# gmvae_rev_gu_mixture_20260217_003159_L7_C3_24_18_12
# gmvae_rev_gu_mixture_20260217_004818_L7_C4_24_18_12
# gmvae_rev_gu_mixture_20260217_010413_L7_C5_24_18_12
# gmvae_rev_gu_mixture_20260217_034212_L5_C3
# gmvae_rev_gu_mixture_20260217_034216_L6_C3
# gmvae_rev_gu_mixture_20260217_035654_L6_C4
# gmvae_rev_gu_mixture_20260217_035749_L5_C4
# gmvae_rev_gu_mixture_20260217_041343_L5_C5
# gmvae_rev_gu_mixture_20260217_042650_L6_C6
# gmvae_rev_gu_mixture_20260217_042947_L5_C6
# gmvae_rev_gu_mixture_energy_20260217_181312_L5_C5
# gmvae_rev_gu_mixture_energy_20260217_181348_L5_C3
# gmvae_rev_gu_mixture_energy_20260217_182833_L5_C4
# gmvae_rev_gu_mixture_energy_20260217_182842_L5_C6
# gmvae_rev_gu_mixture_energy_20260217_184319_L6_C3
# gmvae_rev_gu_mixture_energy_20260217_184424_L6_C5
# gmvae_rev_gu_mixture_energy_20260217_185813_L6_C4
# gmvae_rev_gu_mixture_energy_20260217_190003_L6_C6
# gmvae_rev_gu_mixture_energy_20260217_191317_L7_C3
# gmvae_rev_gu_mixture_energy_20260217_191558_L7_C5
# gmvae_rev_gu_mixture_energy_20260217_192829_L7_C4
# gmvae_rev_gu_mixture_energy_20260217_193201_L7_C6
# gmvae_rev_gu_mixture_energy_20260218_000315_L5_C7
# gmvae_rev_gu_mixture_energy_20260218_000322_L8_C3
# gmvae_rev_gu_mixture_energy_20260218_001906_L8_C4
# gmvae_rev_gu_mixture_energy_20260218_002010_L5_C8
# gmvae_rev_gu_mixture_energy_20260218_003512_L8_C5
# gmvae_rev_gu_mixture_energy_20260218_003725_L6_C7
# gmvae_rev_gu_mixture_energy_20260218_005116_L8_C6
# gmvae_rev_gu_mixture_energy_20260218_011222_L6_C8
# gmvae_rev_gu_mixture_energy_20260218_011225_L8_C7
# gmvae_rev_gu_mixture_energy_20260218_012805_L8_C8
# gmvae_rev_gu_mixture_energy_20260218_012918_L7_C7
# gmvae_rev_gu_mixture_energy_20260218_014406_L9_C7
# gmvae_rev_gu_mixture_energy_20260218_014631_L7_C8
# gmvae_rev_gu_mixture_energy_20260218_015955_L9_C8
# gmvae_rev_gu_mixture_energy_20260218_211300_L9_C3
# gmvae_rev_gu_mixture_energy_20260218_211315_L9_C5
# gmvae_rev_gu_mixture_energy_20260218_212759_L9_C4
# gmvae_rev_gu_mixture_energy_20260218_212935_L9_C6
# gmvae_rev_gu_mixture_energy_biased_down_20260221_234903_L7_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260221_234920_L3_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_001119_L3_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_001514_L7_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_003345_L3_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_004152_L7_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_005654_L3_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_010903_L7_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_012030_L3_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_013629_L7_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_034811_L3_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_044731_L7_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_044827_L3_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_051155_L3_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_051250_L7_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_053457_L4_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_053647_L7_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_055734_L4_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_060048_L8_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_062041_L4_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_062416_L8_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_065508_L8_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_065517_L4_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_071818_L8_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_072116_L4_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_074139_L8_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_074639_L4_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_080533_L8_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_081213_L4_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_083137_L8_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_083801_L4_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_024308_L8_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_024328_L4_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_030455_L8_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_030531_L5_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_032658_L9_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_032722_L5_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_034937_L9_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_034940_L5_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_041207_L5_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_041430_L9_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_201426_L9_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_201512_L5_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_203727_L5_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_204218_L9_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_210002_L5_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_211041_L9_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_212252_L6_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_213859_L9_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_214540_L6_C4_30_20_10
# rev_gumixture_1000_data_energy_scaled_downsampled_.json
# rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_.json
# rev_gumixture_1000_inds_energy_scaled_downsampled_.json
# rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_.json
# rev_gumixture_dp15_more_downwards_1000_data_energy_scaled_downsampled_.json
# rev_gumixture_dp15_more_downwards_1000_inds_energy_scaled_downsampled_.json

# %% [markdown]
# # LOOP GMVAE TRAINING

# %%
for latent_dim in latent_dims:
   for n_clusters in n_clustersS:
      if [latent_dim, n_clusters] in skip_combos:
        continue
      else:
          K = n_clusters
          Z = latent_dim

          from datetime import datetime
          timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

          if loadFlag:  # Load in old data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", 'gmvae_em_aerocapture_energy_20250429_155508_5_4')
          else:  # generate new data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters)+"_"+str(hd1)+"_"+str(hd2)+"_"+str(hd3))
          os.makedirs(dirname, exist_ok=True)
          print("Filepath directory: " + dirname)

          if loadFlag:  # load old data
              postfix = '_42_1024_128_128_32_16_5_4_0.001000_128_0.001000_0.000010_1000.000000_'
          else:  # Generate new suffix
              if hd3 is not None:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
              else:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
          print("Filepath postfix: " + postfix)

          data_dir = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{data}.json")

          with open(os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{inds}.json"), 'r') as f:
              sample_list_load = json.load(f)
          sample_list = [int(sample) for sample in sample_list_load['sample_list']]
          print(sample_list)

          data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                          train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                          num_workers=0, dataName=dataName)

          data_module.setup("fit", sample_list = sample_list)

          train_loader = data_module.train_dataloader()
          val_loader = data_module.val_dataloader()
          test_loader = data_module.test_dataloader()
          data_dim = len(train_loader.dataset[0][0])
          text_labels = ['capture', 'escape', 'impact']
          label_colors = ['C2', 'C3', 'C4']

          num_train_batches = len(train_loader)

          ts_plot = np.linspace(0,450,36)
          seabornSettings()
          fig, ax = plt.subplots(figsize=(4, 4))
          for j in range(n_train):
              ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.75)

          eline = mlines.Line2D([], [], color='C2', label='Escape')
          cline = mlines.Line2D([], [], color='C3', label='Capture')
          iline = mlines.Line2D([], [], color='C4', label='Impact')
          plt.legend(handles=[eline, cline, iline])
          plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
          plt.xlabel("Time [s]")
          plt.ylabel("Nondimensionalized Energy")
          plt.title("Training Data")
          plt.tight_layout()
          fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_val):
              ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()])
          plt.title("Validation Data")
          fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_test):
              ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()])
          plt.title("Test Data")
          fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)
          # initialize latent GMM model parameters
          params = {}
          pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
          params['pi_c'] = torch.ones(K) / K
          params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
          params['logsigmasq_c'] = torch.zeros((K, Z))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]

          # initialize neural networks
          encoder_list = []
          decoder_list = []
          trainable_parameters = []
          trainable_parameters.append(pi_variables)

          for _ in range(D):
              encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
              decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
              encoder_list.append(encoder)
              decoder_list.append(decoder)
              trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

          optimizer = optim.Adam(trainable_parameters, lr=lr)

          # training

          import time
          ts = time.time()
          tic = time.perf_counter()

          train_loss = torch.zeros(n_epochs)
          train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_loss = torch.zeros(n_epochs)
          pi_history = torch.zeros((n_epochs, K))
          train_mse_history = torch.zeros(n_epochs)
          val_mse_history = torch.zeros(n_epochs)
          min_val_loss = torch.inf
          seabornSettings()

          for epoch in range(n_epochs):
              ti = time.time()
              for encoder in encoder_list:
                  encoder.train()
              for decoder in decoder_list:
                  decoder.train()

              train_elbo = 0
              train_mse = 0
              train_elbo_term = np.zeros(4)
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

              for (batch_idx, batch) in enumerate(train_loader):
                  batch_x, _ = batch
                  x_list = [batch_x]  # assume D=2 and each modality has data_dim
                  optimizer.zero_grad()
                  pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
                  params['pi_c'] = pi_c

                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma

                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                  train_elbo += elbo.item()
                  train_elbo_term += elbo_terms
                  train_mse += sse.item()
                  loss = - elbo / batch_x.shape[0]
                  loss.backward()
                  optimizer.step()

              for encoder in encoder_list:
                  encoder.eval()
              for decoder in decoder_list:
                  decoder.eval()

              if epoch % plot_interval == 0 or epoch == n_epochs:
                  # Plot the first two dimensions of the latents
                  with torch.no_grad():
                      means = []
                      samples = []
                      labels = []
                      for batch in train_loader:
                          batch_x, batch_label = batch
                          x_list = [batch_x]
                          mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                          sigma = torch.exp(0.5 * logsigmasq)
                          eps = Normal(0, 1).sample(mean.shape)
                          z = mean + eps * sigma
                          means.append(mean)
                          samples.append(z)
                          labels.append(batch_label)

                  means = torch.vstack(means).cpu()
                  samples = torch.vstack(samples).cpu()
                  labels = torch.hstack(labels).cpu()

                  savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

                  savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


                  # plot samples from generative model
                  n_gen = n_train
                  cluster_probs = params['pi_c'].cpu().detach().numpy() #
                  fig, ax = plt.subplots(figsize=(4.5, 4))
                  for j in range(n_gen):
                      c = np.random.choice(K, p=cluster_probs)
                      mu_c = params['mu_c'][c].clone().detach()
                      sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
                      z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
                      mu_x = decoder.forward(z)[0]
                      ax.plot(mu_x.cpu().detach().numpy())
                  fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
                  plt.close()


              val_elbo = 0
              val_mse = 0
              val_elbo_term = np.zeros(4)
              with torch.no_grad():
                  for (batch_idx, batch) in enumerate(val_loader):
                      batch_x, _ = batch
                      x_list = [batch_x]
                      mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                      sigma = torch.exp(0.5 * logsigmasq)
                      eps = Normal(0, 1).sample(mu.shape)
                      z = mu + eps * sigma
                      with torch.no_grad():
                          gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
                      elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                      val_elbo += elbo.item()
                      val_mse += sse.item()
                      val_elbo_term += elbo_items

              train_elbo /= len(train_loader.dataset)
              train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
              val_elbo /= len(val_loader.dataset)
              val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
              train_mse /= len(train_loader.dataset)
              val_mse /= len(val_loader.dataset)

              tf = time.time()
              toc = time.perf_counter()
              print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

              train_loss[epoch] = - train_elbo
              val_loss[epoch] = - val_elbo
              train_elbo_terms[epoch,:] = - train_elbo_term
              val_elbo_terms[epoch,:] = - val_elbo_term
              pi_history[epoch] = params['pi_c']
              train_mse_history[epoch] = train_mse
              val_mse_history[epoch] = val_mse

              if - val_elbo < min_val_loss:
                  min_val_loss = - val_elbo
                  torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
                  torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
                  torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
                  torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
                  torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

              if epoch % plot_interval == 0 or epoch == n_epochs:
                # Plot the training and validation loss vs. epoch number
                plt.figure(figsize=(4.5, 4))
                # const = min(min(train_loss), min(val_loss))
                train_loss_adjusted = train_loss
                val_loss_adjusted = val_loss
                plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
                # print(train_loss_adjusted.cpu()[:epoch])
                plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
                plt.yscale('symlog')
                plt.xlabel("number of epochs")
                plt.ylabel("loss")
                plt.title("Negative Loss")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot each term of the training loss and validation loss
                plt.figure(figsize=(4.5, 4))
                labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
                for ii in range(4):
                    train_loss_adjusted = train_elbo_terms[:epoch, ii]
                    val_loss_adjusted = val_elbo_terms[:epoch, ii]
                    plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
                    plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
                plt.xlabel("number of epochs")
                plt.yscale('symlog')
                plt.ylabel("loss")
                plt.title("Negative Loss Terms")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the training and validation mse vs. epoch number
                plt.figure(figsize=(4.5, 4))
                plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
                plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the history of pi
                plt.figure(figsize=(4.5, 4))
                for i in range(K):
                    plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()


          te = time.time()
          import datetime
          duration = datetime.timedelta(seconds=te - ts)
          print("Training took ", duration)

          # Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
          torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))

          if loadFlag:
            path = dirname
            epoch = n_epochs - 1
          params = {}
          encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
          decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")

          # Use if you need to load in the data
          if loadFlag:
            suffix = postfix
            encoder.load_state_dict(torch.load(os.path.join(path, f'encoder_{suffix}.pt'),map_location=torch.device('cpu')))
            decoder.load_state_dict(torch.load(os.path.join(path, f'decoder_{suffix}.pt'),map_location=torch.device('cpu')))
            logsigmasq = torch.load(os.path.join(path, f'gmm_params_logsigmasq_{suffix}.pt'),map_location=torch.device('cpu'))
            mu = torch.load(os.path.join(path, f'gmm_params_mu_{suffix}.pt'),map_location=torch.device('cpu'))
            pi = torch.load(os.path.join(path, f'gmm_params_pi_{suffix}.pt'),map_location=torch.device('cpu'))

          encoder_list = [encoder]
          decoder_list = [decoder]

          device = next(encoder.parameters()).device
          # Load in training history metrics
          pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]
          data_colors = label_colors

          # Plot training history
          # Plot the training and validation loss vs. epoch number
          plt.figure(figsize=(4, 4))
          const = min(min(train_loss), min(val_loss))
          # const = min(10, const)
          train_loss_adjusted = train_loss
          val_loss_adjusted = val_loss
          plt.plot(train_loss_adjusted.cpu(), label='Training')
          plt.plot(val_loss_adjusted.cpu(), label='Validation')
          plt.xlabel("Number of Epochs")
          plt.ylabel("Negative Loss")
          # plt.title("Negative Loss")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
          for ii in range(4):
              # print(train_elbo_terms.cpu()[ii, :epoch])
              # print(len(train_elbo_terms.cpu()[ii, :epoch]))
              train_loss_adjusted = train_elbo_terms[:, ii]
              val_loss_adjusted = val_elbo_terms[:, ii]
              plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
              plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Negative Loss Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot the sum of each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          # print(train_elbo_terms.cpu()[ii, :epoch])
          # print(len(train_elbo_terms.cpu()[ii, :epoch]))
          train_loss_adjusted = train_elbo_terms.sum(axis=1)
          val_loss_adjusted = val_elbo_terms.sum(axis=1)
          plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
          plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Sum of ELBO Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the training and validation mse vs. epoch number
          plt.figure(figsize=(4.5, 4))
          plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
          plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
          plt.xlabel("number of epochs")
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the history of pi
          plt.figure(figsize=(4, 4))
          for i in range(K):
              plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
          plt.xlabel("Number of Epochs")
          plt.ylabel("Predicted Cluster Probability")
          plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
          plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Load best model saved
          params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
          params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
          params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
          encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
          decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

          encoder.eval()
          decoder.eval()

          # run one last EM step and plot training data in latent space
          for encoder in encoder_list:
              encoder.eval()

          with torch.no_grad():
              means = []
              samples = []
              labels = []
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
              for batch in train_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma
                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  means.append(mu)
                  samples.append(z)
                  labels.append(batch_label)

          means = torch.vstack(means).cpu()
          samples = torch.vstack(samples).cpu()
          labels = torch.hstack(labels).cpu()


          savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
          plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
          plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot test data in latent space
          with torch.no_grad():
              test_means = []
              test_labels = []
              for batch in test_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mean, _ = encoder_step(x_list, encoder_list, decoder_list)
                  test_means.append(mean)
                  test_labels.append(batch_label)

          test_means = torch.vstack(test_means).cpu()
          test_labels = torch.hstack(test_labels).cpu()


          savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
          plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot decoding results from cluster means # todo: expand this function for multi-modal data
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for i in range(K):
              # with torch.no_grad:
              x_mean = decoder.forward(params['mu_c'][i])[0]
              ax.plot(x_mean.cpu().detach().numpy(), label=r"decoded $\mu$"+str(i+1))
          ax.legend()
          plt.title("Decoded Means")
          fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
          # plt.close()

          # plot samples from generative model
          n_gen = n_train
          cluster_probs = params['pi_c'].cpu().detach().numpy()
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_gen):
              c = np.random.choice(K, p=cluster_probs)
              # print(c)
              mu_c = params['mu_c'][c].cpu().clone().detach()
              sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
              z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
              # print(z)
              mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
              sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
              sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
              ax.plot(sample_x.cpu().detach().numpy())
          plt.title("Generated Samples")
          fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
          plt.close()

          # np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
              # train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
              # pi_history=pi_history.cpu().detach().numpy(),
              # cluster_probs=params['pi_c'].cpu().detach().numpy(),
              # cluster_means=params['mu_c'].cpu().detach().numpy(),
              # cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


          print("Training data size", n_train)
          print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
          print("Cluster 1 probability:", cluster_probs.min().item())
# Out:
# Filepath directory: /content/drive/MyDrive/rev_pipag_data/gmvae_rev_gu_mixture_energy_biased_down_20260223_230824_L6_C44_30_20_10
# Filepath postfix: _42_800_100_100_30_20_10_6_4_0.001000_128_0.001000_0.000010_15000.000000_
# [543, 139, 827, 571, 171, 15, 199, 163, 416, 589, 492, 661, 556, 570, 177, 667, 354, 510, 778, 430, 319, 967, 860, 329, 633, 29, 404, 836, 847, 388, 885, 229, 69, 921, 132, 839, 96, 835, 227, 181, 968, 351, 925, 24, 336, 123, 759, 189, 455, 626, 862, 469, 110, 219, 285, 445, 738, 723, 179, 77, 353, 84, 424, 948, 963, 266, 735, 576, 83, 724, 259, 387, 959, 551, 733, 658, 260, 516, 806, 651, 11, 522, 343, 40, 493, 692, 919, 995, 558, 352, 359, 368, 251, 893, 479, 777, 102, 90, 870, 310, 538, 745, 891, 150, 380, 324, 505, 144, 375, 66, 656, 631, 216, 306, 987, 371, 673, 5, 190, 804, 487, 757, 153, 884, 78, 555, 438, 758, 21, 597, 706, 303, 254, 47, 373, 87, 224, 1, 523, 754, 247, 390, 992, 986, 764, 947, 665, 527, 271, 322, 39, 586, 760, 148, 280, 678, 539, 26, 779, 335, 299, 439, 748, 140, 741, 494, 415, 30, 8, 914, 278, 514, 409, 498, 853, 822, 64, 52, 640, 103, 225, 557, 82, 742, 160, 363, 286, 880, 545, 924, 604, 376, 344, 502, 194, 563, 568, 526, 300, 927, 944, 496, 296, 23, 710, 378, 312, 323, 210, 517, 790, 625, 718, 890, 704, 566, 737, 432, 331, 550, 874, 372, 111, 427, 67, 230, 497, 488, 611, 408, 956, 128, 788, 783, 814, 34, 273, 459, 58, 993, 75, 426, 185, 466, 42, 751, 175, 482, 607, 531, 463, 172, 826, 863, 73, 781, 242, 241, 707, 326, 320, 582, 698, 346, 134, 327, 664, 700, 187, 183, 205, 410, 269, 696, 13, 898, 195, 917, 297, 464, 540, 248, 989, 41, 355, 95, 138, 164, 868, 699, 174, 629, 393, 107, 546, 904, 386, 622, 182, 867, 470, 690, 796, 521, 518, 660, 37, 930, 795, 889, 869, 499, 501, 437, 772, 151, 734, 902, 206, 731, 792, 905, 873, 512, 752, 365, 855, 528, 419, 773, 395, 184, 909, 829, 202, 131, 819, 657, 200, 274, 119, 485, 749, 101, 776, 596, 542, 418, 208, 56, 845, 209, 519, 221, 89, 789, 674, 805, 933, 669, 616, 381, 234, 328, 984, 304, 94, 142, 980, 358, 79, 524, 237, 121, 832, 43, 588, 676, 332, 800, 246, 133, 483, 965, 135, 53, 728, 431, 446, 928, 276, 173, 530, 609, 16, 309, 621, 389, 864, 726, 287, 261, 979, 547, 413, 105, 666, 294, 567, 275, 983, 383, 716, 315, 892, 577, 946, 552, 367, 683, 19, 985, 283, 220, 307, 876, 603, 239, 769, 701, 414, 215, 708, 338, 915, 774, 99, 955, 149, 711, 212, 337, 952, 113, 397, 982, 314, 693, 746, 385, 341, 852, 49, 178, 793, 771, 695, 828, 529, 672, 218, 481, 396, 20, 236, 452, 349, 214, 325, 975, 912, 536, 143, 932, 866, 270, 458, 775, 460, 770, 922, 645, 197, 856, 462, 807, 207, 255, 412, 203, 361, 612, 392, 86, 899, 405, 920, 28, 9, 926, 508, 14, 55, 249, 619, 3, 115, 594, 560, 808, 998, 117, 936, 291, 691, 490, 333, 233, 590, 937, 146, 243, 977, 450, 879, 677, 841, 374, 763, 451, 801, 532, 399, 688, 457, 950, 961, 653, 694, 895, 562, 797, 471, 442, 98, 268, 646, 785, 668, 434, 896, 714, 59, 940, 787, 476, 681, 311, 250, 957, 971, 990, 655, 169, 624, 671, 284, 475, 515, 71, 972, 823, 705, 72, 93, 507, 454, 578, 473, 191, 391, 960, 549, 684, 402, 581, 301, 421, 401, 0, 91, 755, 417, 340, 872, 644, 908, 159, 491, 837, 725, 384, 7, 461, 882, 730, 489, 258, 97, 815, 652, 465, 76, 593, 106, 595, 632, 180, 580, 305, 468, 65, 583, 824, 316, 689, 978, 293, 613, 330, 18, 288, 894, 659, 743, 598, 166, 736, 643, 916, 118, 675, 802, 157, 145, 537, 54, 756, 865, 818, 638, 45, 298, 591, 35, 168, 302, 31, 433, 996, 697, 51, 830, 112, 799, 970, 939, 641, 816, 345, 141, 575, 720, 838, 766, 686, 585, 423, 559, 147, 292, 57, 859, 425, 991, 687, 61, 232, 321, 941, 2, 584, 500, 561, 478, 608, 949, 544, 125, 534, 263, 721, 379, 122, 377, 525, 812, 903, 636, 615, 883, 610, 253, 918, 27, 136, 753, 362, 614, 938, 295, 553, 364, 124, 628, 506, 861, 226, 176, 886, 877, 654, 887, 116, 170, 192, 634, 834, 317, 712, 999, 257, 279, 520, 313, 719, 152, 277, 444, 436, 809, 129, 264, 334, 477, 605, 662, 394, 929, 265, 541, 486, 441, 350, 126, 627, 36, 851, 339, 104, 443, 74, 875, 821, 981, 403, 988, 953, 901, 784, 848, 966, 60, 100, 188, 411, 88, 740, 747, 974, 685, 348, 680, 198, 606, 435, 767, 484, 997, 618, 308, 25, 858, 620, 897, 165, 572, 878, 92, 154, 648, 642, 535, 913, 942, 356, 256, 84 ...
# Loading File...
# ...File Loaded
# Sample List: [543, 139, 827, 571, 171, 15, 199, 163, 416, 589, 492, 661, 556, 570, 177, 667, 354, 510, 778, 430, 319, 967, 860, 329, 633, 29, 404, 836, 847, 388, 885, 229, 69, 921, 132, 839, 96, 835, 227, 181, 968, 351, 925, 24, 336, 123, 759, 189, 455, 626, 862, 469, 110, 219, 285, 445, 738, 723, 179, 77, 353, 84, 424, 948, 963, 266, 735, 576, 83, 724, 259, 387, 959, 551, 733, 658, 260, 516, 806, 651, 11, 522, 343, 40, 493, 692, 919, 995, 558, 352, 359, 368, 251, 893, 479, 777, 102, 90, 870, 310, 538, 745, 891, 150, 380, 324, 505, 144, 375, 66, 656, 631, 216, 306, 987, 371, 673, 5, 190, 804, 487, 757, 153, 884, 78, 555, 438, 758, 21, 597, 706, 303, 254, 47, 373, 87, 224, 1, 523, 754, 247, 390, 992, 986, 764, 947, 665, 527, 271, 322, 39, 586, 760, 148, 280, 678, 539, 26, 779, 335, 299, 439, 748, 140, 741, 494, 415, 30, 8, 914, 278, 514, 409, 498, 853, 822, 64, 52, 640, 103, 225, 557, 82, 742, 160, 363, 286, 880, 545, 924, 604, 376, 344, 502, 194, 563, 568, 526, 300, 927, 944, 496, 296, 23, 710, 378, 312, 323, 210, 517, 790, 625, 718, 890, 704, 566, 737, 432, 331, 550, 874, 372, 111, 427, 67, 230, 497, 488, 611, 408, 956, 128, 788, 783, 814, 34, 273, 459, 58, 993, 75, 426, 185, 466, 42, 751, 175, 482, 607, 531, 463, 172, 826, 863, 73, 781, 242, 241, 707, 326, 320, 582, 698, 346, 134, 327, 664, 700, 187, 183, 205, 410, 269, 696, 13, 898, 195, 917, 297, 464, 540, 248, 989, 41, 355, 95, 138, 164, 868, 699, 174, 629, 393, 107, 546, 904, 386, 622, 182, 867, 470, 690, 796, 521, 518, 660, 37, 930, 795, 889, 869, 499, 501, 437, 772, 151, 734, 902, 206, 731, 792, 905, 873, 512, 752, 365, 855, 528, 419, 773, 395, 184, 909, 829, 202, 131, 819, 657, 200, 274, 119, 485, 749, 101, 776, 596, 542, 418, 208, 56, 845, 209, 519, 221, 89, 789, 674, 805, 933, 669, 616, 381, 234, 328, 984, 304, 94, 142, 980, 358, 79, 524, 237, 121, 832, 43, 588, 676, 332, 800, 246, 133, 483, 965, 135, 53, 728, 431, 446, 928, 276, 173, 530, 609, 16, 309, 621, 389, 864, 726, 287, 261, 979, 547, 413, 105, 666, 294, 567, 275, 983, 383, 716, 315, 892, 577, 946, 552, 367, 683, 19, 985, 283, 220, 307, 876, 603, 239, 769, 701, 414, 215, 708, 338, 915, 774, 99, 955, 149, 711, 212, 337, 952, 113, 397, 982, 314, 693, 746, 385, 341, 852, 49, 178, 793, 771, 695, 828, 529, 672, 218, 481, 396, 20, 236, 452, 349, 214, 325, 975, 912, 536, 143, 932, 866, 270, 458, 775, 460, 770, 922, 645, 197, 856, 462, 807, 207, 255, 412, 203, 361, 612, 392, 86, 899, 405, 920, 28, 9, 926, 508, 14, 55, 249, 619, 3, 115, 594, 560, 808, 998, 117, 936, 291, 691, 490, 333, 233, 590, 937, 146, 243, 977, 450, 879, 677, 841, 374, 763, 451, 801, 532, 399, 688, 457, 950, 961, 653, 694, 895, 562, 797, 471, 442, 98, 268, 646, 785, 668, 434, 896, 714, 59, 940, 787, 476, 681, 311, 250, 957, 971, 990, 655, 169, 624, 671, 284, 475, 515, 71, 972, 823, 705, 72, 93, 507, 454, 578, 473, 191, 391, 960, 549, 684, 402, 581, 301, 421, 401, 0, 91, 755, 417, 340, 872, 644, 908, 159, 491, 837, 725, 384, 7, 461, 882, 730, 489, 258, 97, 815, 652, 465, 76, 593, 106, 595, 632, 180, 580, 305, 468, 65, 583, 824, 316, 689, 978, 293, 613, 330, 18, 288, 894, 659, 743, 598, 166, 736, 643, 916, 118, 675, 802, 157, 145, 537, 54, 756, 865, 818, 638, 45, 298, 591, 35, 168, 302, 31, 433, 996, 697, 51, 830, 112, 799, 970, 939, 641, 816, 345, 141, 575, 720, 838, 766, 686, 585, 423, 559, 147, 292, 57, 859, 425, 991, 687, 61, 232, 321, 941, 2, 584, 500, 561, 478, 608, 949, 544, 125, 534, 263, 721, 379, 122, 377, 525, 812, 903, 636, 615, 883, 610, 253, 918, 27, 136, 753, 362, 614, 938, 295, 553, 364, 124, 628, 506, 861, 226, 176, 886, 877, 654, 887, 116, 170, 192, 634, 834, 317, 712, 999, 257, 279, 520, 313, 719, 152, 277, 444, 436, 809, 129, 264, 334, 477, 605, 662, 394, 929, 265, 541, 486, 441, 350, 126, 627, 36, 851, 339, 104, 443, 74, 875, 821, 981, 403, 988, 953, 901, 784, 848, 966, 60, 100, 188, 411, 88, 740, 747, 974, 685, 348, 680, 198, 606, 435, 767, 484, 997, 618, 308, 25, 858, 620, 897, 165, 572, 878, 92, 154, 648, 642, 535, 913, 942, ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /content/pipag_training/gmvae_common.py:265: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   elbo_terms[0] = Normal(mu_, torch.exp(0.5 * logsigmasq_)).log_prob(x_list[d]).sum()
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 10094 Train ELBO: 60.8110 Val ELBO: -5.9771, Epoch Time (s): 0.07, Total Time (hrs): 0.2559
# ====> Epoch: 10095 Train ELBO: 59.0042 Val ELBO: 8.6778, Epoch Time (s): 0.07, Total Time (hrs): 0.2559
# ====> Epoch: 10096 Train ELBO: 59.7181 Val ELBO: 16.1529, Epoch Time (s): 0.07, Total Time (hrs): 0.2559
# ====> Epoch: 10097 Train ELBO: 64.7818 Val ELBO: 10.6775, Epoch Time (s): 0.08, Total Time (hrs): 0.2559
# ====> Epoch: 10098 Train ELBO: 60.3246 Val ELBO: -15.3322, Epoch Time (s): 0.08, Total Time (hrs): 0.2560
# ====> Epoch: 10099 Train ELBO: 58.4468 Val ELBO: 5.9074, Epoch Time (s): 0.09, Total Time (hrs): 0.2560
# ====> Epoch: 10100 Train ELBO: 67.9152 Val ELBO: 13.0029, Epoch Time (s): 0.07, Total Time (hrs): 0.2560
# ====> Epoch: 10101 Train ELBO: 63.5059 Val ELBO: 11.0462, Epoch Time (s): 0.07, Total Time (hrs): 0.2560
# ====> Epoch: 10102 Train ELBO: 63.3057 Val ELBO: 14.6349, Epoch Time (s): 0.07, Total Time (hrs): 0.2560
# ====> Epoch: 10103 Train ELBO: 64.3980 Val ELBO: 5.2663, Epoch Time (s): 0.07, Total Time (hrs): 0.2561
# ====> Epoch: 10104 Train ELBO: 57.9865 Val ELBO: 14.5476, Epoch Time (s): 0.07, Total Time (hrs): 0.2561
# ====> Epoch: 10105 Train ELBO: 66.8549 Val ELBO: 5.5931, Epoch Time (s): 0.08, Total Time (hrs): 0.2561
# ====> Epoch: 10106 Train ELBO: 60.6838 Val ELBO: -0.5568, Epoch Time (s): 0.07, Total Time (hrs): 0.2561
# ====> Epoch: 10107 Train ELBO: 60.4145 Val ELBO: -12.8908, Epoch Time (s): 0.07, Total Time (hrs): 0.2561
# ====> Epoch: 10108 Train ELBO: 26.0696 Val ELBO: -44.9601, Epoch Time (s): 0.08, Total Time (hrs): 0.2562
# ====> Epoch: 10109 Train ELBO: 19.6416 Val ELBO: -58.4271, Epoch Time (s): 0.07, Total Time (hrs): 0.2562
# ====> Epoch: 10110 Train ELBO: 31.3723 Val ELBO: 2.2411, Epoch Time (s): 0.07, Total Time (hrs): 0.2562
# ====> Epoch: 10111 Train ELBO: 46.0961 Val ELBO: -13.4893, Epoch Time (s): 0.08, Total Time (hrs): 0.2562
# ====> Epoch: 10112 Train ELBO: 51.0625 Val ELBO: 4.1183, Epoch Time (s): 0.07, Total Time (hrs): 0.2562
# ====> Epoch: 10113 Train ELBO: 53.1735 Val ELBO: 11.7025, Epoch Time (s): 0.09, Total Time (hrs): 0.2563
# ====> Epoch: 10114 Train ELBO: 57.7148 Val ELBO: -11.7119, Epoch Time (s): 0.08, Total Time (hrs): 0.2563
# ====> Epoch: 10115 Train ELBO: 56.4312 Val ELBO: -16.1850, Epoch Time (s): 0.07, Total Time (hrs): 0.2563
# ====> Epoch: 10116 Train ELBO: 46.7039 Val ELBO: -3.8186, Epoch Time (s): 0.07, Total Time (hrs): 0.2563
# ====> Epoch: 10117 Train ELBO: 54.9708 Val ELBO: 4.2660, Epoch Time (s): 0.07, Total Time (hrs): 0.2563
# ====> Epoch: 10118 Train ELBO: 61.8783 Val ELBO: 13.7861, Epoch Time (s): 0.07, Total Time (hrs): 0.2564
# ====> Epoch: 10119 Train ELBO: 65.9248 Val ELBO: 9.4687, Epoch Time (s): 0.07, Total Time (hrs): 0.2564
# ====> Epoch: 10120 Train ELBO: 59.0600 Val ELBO: 10.5923, Epoch Time (s): 0.08, Total Time (hrs): 0.2564
# ====> Epoch: 10121 Train ELBO: 57.1608 Val ELBO: -4.7682, Epoch Time (s): 0.07, Total Time (hrs): 0.2564
# ====> Epoch: 10122 Train ELBO: 49.6196 Val ELBO: -14.9026, Epoch Time (s): 0.07, Total Time (hrs): 0.2564
# ====> Epoch: 10123 Train ELBO: 44.5412 Val ELBO: -8.7404, Epoch Time (s): 0.08, Total Time (hrs): 0.2565
# ====> Epoch: 10124 Train ELBO: 45.4193 Val ELBO: 1.2944, Epoch Time (s): 0.07, Total Time (hrs): 0.2565
# ====> Epoch: 10125 Train ELBO: 52.4209 Val ELBO: 2.6777, Epoch Time (s): 0.08, Total Time (hrs): 0.2565
# ====> Epoch: 10126 Train ELBO: 59.2898 Val ELBO: 0.7406, Epoch Time (s): 0.08, Total Time (hrs): 0.2565
# ====> Epoch: 10127 Train ELBO: 61.5844 Val ELBO: -2.6985, Epoch Time (s): 0.08, Total Time (hrs): 0.2566
# ====> Epoch: 10128 Train ELBO: 62.2737 Val ELBO: 1.8661, Epoch Time (s): 0.07, Total Time (hrs): 0.2566
# ====> Epoch: 10129 Train ELBO: 63.4903 Val ELBO: 8.2259, Epoch Time (s): 0.07, Total Time (hrs): 0.2566
# ====> Epoch: 10130 Train ELBO: 65.5242 Val ELBO: 11.7047, Epoch Time (s): 0.07, Total Time (hrs): 0.2566
# ====> Epoch: 10131 Train ELBO: 65.9715 Val ELBO: -26.9209, Epoch Time (s): 0.07, Total Time (hrs): 0.2566
# ====> Epoch: 10132 Train ELBO: 50.8819 Val ELBO: -18.4664, Epoch Time (s): 0.08, Total Time (hrs): 0.2567
# ====> Epoch: 10133 Train ELBO: 32.3247 Val ELBO: -16.0065, Epoch Time (s): 0.07, Total Time (hrs): 0.2567
# ====> Epoch: 10134 Train ELBO: 49.6839 Val ELBO: -4.3804, Epoch Time (s): 0.07, Total Time (hrs): 0.2567
# ====> Epoch: 10135 Train ELBO: 53.5598 Val ELBO: -3.4491, Epoch Time (s): 0.08, Total Time (hrs): 0.2567
# ====> Epoch: 10136 Train ELBO: 59.0965 Val ELBO: 9.9635, Epoch Time (s): 0.07, Total Time (hrs): 0.2567
# ====> Epoch: 10137 Train ELBO: 64.5738 Val ELBO: 3.1663, Epoch Time (s): 0.07, Total Time (hrs): 0.2568
# ====> Epoch: 10138 Train ELBO: 65.3184 Val ELBO: -2.8311, Epoch Time (s): 0.07, Total Time (hrs): 0.2568
# ====> Epoch: 10139 Train ELBO: 60.1221 Val ELBO: -8.3230, Epoch Time (s): 0.07, Total Time (hrs): 0.2568
# ====> Epoch: 10140 Train ELBO: 56.6939 Val ELBO: -0.8671, Epoch Time (s): 0.07, Total Time (hrs): 0.2568
# ====> Epoch: 10141 Train ELBO: 63.5624 Val ELBO: 7.7984, Epoch Time (s): 0.09, Total Time (hrs): 0.2568
# ====> Epoch: 10142 Train ELBO: 68.7298 Val ELBO: 12.6641, Epoch Time (s): 0.07, Total Time (hrs): 0.2569
# ====> Epoch: 10143 Train ELBO: 69.7290 Val ELBO: 0.3604, Epoch Time (s): 0.07, Total Time (hrs): 0.2569
# ====> Epoch: 10144 Train ELBO: 62.2116 Val ELBO: 12.0253, Epoch Time (s): 0.07, Total Time (hrs): 0.2569
# ====> Epoch: 10145 Train ELBO: 68.9127 Val ELBO: 1.8270, Epoch Time (s): 0.07, Total Time (hrs): 0.2569
# ====> Epoch: 10146 Train ELBO: 19.7990 Val ELBO: -40.9590, Epoch Time (s): 0.07, Total Time (hrs): 0.2569
# ====> Epoch: 10147 Train ELBO: 9.5615 Val ELBO: -89.9010, Epoch Time (s): 0.08, Total Time (hrs): 0.2570
# ====> Epoch: 10148 Train ELBO: 18.6397 Val ELBO: -22.3399, Epoch Time (s): 0.07, Total Time (hrs): 0.2570
# ====> Epoch: 10149 Train ELBO: 23.7597 Val ELBO: -14.5312, Epoch Time (s): 0.07, Total Time (hrs): 0.2570
# ====> Epoch: 10150 Train ELBO: 1.9362 Val ELBO: -34.3783, Epoch Time (s): 0.07, Total Time (hrs): 0.2570
# ====> Epoch: 10151 Train ELBO: -84.6356 Val ELBO: -88.6625, Epoch Time (s): 0.07, Total Time (hrs): 0.2570
# ====> Epoch: 10152 Train ELBO: -81.9684 Val ELBO: -63.5666, Epoch Time (s): 0.07, Total Time (hrs): 0.2571
# ====> Epoch: 10153 Train ELBO: -61.7781 Val ELBO: -70.2751, Epoch Time (s): 0.07, Total Time (hrs): 0.2571
# ====> Epoch: 10154 Train ELBO: -38.3088 Val ELBO: -182.1988, Epoch Time (s): 0.07, Total Time (hrs): 0.2571
# ====> Epoch: 10155 Train ELBO: -69.3173 Val ELBO: -236.2133, Epoch Time (s): 0.08, Total Time (hrs): 0.2571
# ====> Epoch: 10156 Train ELBO: -93.2923 Val ELBO: -49.7155, Epoch Time (s): 0.08, Total Time (hrs): 0.2571
# ====> Epoch: 10157 Train ELBO: 7.3473 Val ELBO: -8.2284, Epoch Time (s): 0.07, Total Time (hrs): 0.2572
# ====> Epoch: 10158 Train ELBO: 34.1438 Val ELBO: -12.4873, Epoch Time (s): 0.07, Total Time (hrs): 0.2572
# ====> Epoch: 10159 Train ELBO: 49.1043 Val ELBO: 4.8265, Epoch Time (s): 0.08, Total Time (hrs): 0.2572
# ====> Epoch: 10160 Train ELBO: 58.0155 Val ELBO: 14.4760, Epoch Time (s): 0.07, Total Time (hrs): 0.2572
# ====> Epoch: 10161 Train ELBO: 63.7519 Val ELBO: 8.9071, Epoch Time (s): 0.07, Total Time (hrs): 0.2572
# ====> Epoch: 10162 Train ELBO: 55.9726 Val ELBO: 11.5743, Epoch Time (s): 0.07, Total Time (hrs): 0.2573
# ====> Epoch: 10163 Train ELBO: 55.6322 Val ELBO: 9.5113, Epoch Time (s): 0.07, Total Time (hrs): 0.2573
# ====> Epoch: 10164 Train ELBO: 64.8374 Val ELBO: 8.7277, Epoch Time (s): 0.07, Total Time (hrs): 0.2573
# ====> Epoch: 10165 Train ELBO: 59.5326 Val ELBO: 10.0223, Epoch Time (s): 0.07, Total Time (hrs): 0.2573
# ====> Epoch: 10166 Train ELBO: 65.7266 Val ELBO: -0.4784, Epoch Time (s): 0.08, Total Time (hrs): 0.2573
# ====> Epoch: 10167 Train ELBO: 63.5868 Val ELBO: 5.8062, Epoch Time (s): 0.06, Total Time (hrs): 0.2574
# ====> Epoch: 10168 Train ELBO: 63.8975 Val ELBO: -2.2011, Epoch Time (s): 0.07, Total Time (hrs): 0.2574
# ====> Epoch: 10169 Train ELBO: 56.4396 Val ELBO: 17.2725, Epoch Time (s): 0.09, Total Time (hrs): 0.2574
# ====> Epoch: 10170 Train ELBO: 61.1862 Val ELBO: 8.4427, Epoch Time (s): 0.07, Total Time (hrs): 0.2574
# ====> Epoch: 10171 Train ELBO: 63.8622 Val ELBO: -9.6331, Epoch Time (s): 0.08, Total Time (hrs): 0.2574
# ====> Epoch: 10172 Train ELBO: 61.0844 Val ELBO: 9.4387, Epoch Time (s): 0.07, Total Time (hrs): 0.2575
# ====> Epoch: 10173 Train ELBO: 60.1169 Val ELBO: 22.1975, Epoch Time (s): 0.07, Total Time (hrs): 0.2575
# ====> Epoch: 10174 Train ELBO: 66.4954 Val ELBO: 15.0164, Epoch Time (s): 0.08, Total Time (hrs): 0.2575
# ====> Epoch: 10175 Train ELBO: 63.8655 Val ELBO: 21.3779, Epoch Time (s): 0.07, Total Time (hrs): 0.2575
# ====> Epoch: 10176 Train ELBO: 65.1345 Val ELBO: 9.3842, Epoch Time (s): 0.07, Total Time (hrs): 0.2576
# ====> Epoch: 10177 Train ELBO: 62.7047 Val ELBO: 2.0242, Epoch Time (s): 0.06, Total Time (hrs): 0.2576
# ====> Epoch: 10178 Train ELBO: 67.4201 Val ELBO: 16.7343, Epoch Time (s): 0.07, Total Time (hrs): 0.2576
# ====> Epoch: 10179 Train ELBO: 70.5393 Val ELBO: 17.6632, Epoch Time (s): 0.07, Total Time (hrs): 0.2576
# ====> Epoch: 10180 Train ELBO: 70.4411 Val ELBO: 11.4959, Epoch Time (s): 0.07, Total Time (hrs): 0.2576
# ====> Epoch: 10181 Train ELBO: 68.2367 Val ELBO: 17.3556, Epoch Time (s): 0.07, Total Time (hrs): 0.2577
# ====> Epoch: 10182 Train ELBO: 65.6765 Val ELBO: -2.5247, Epoch Time (s): 0.08, Total Time (hrs): 0.2577
# ====> Epoch: 10183 Train ELBO: 59.1510 Val ELBO: 10.8900, Epoch Time (s): 0.09, Total Time (hrs): 0.2577
# ====> Epoch: 10184 Train ELBO: 61.3492 Val ELBO: 7.3337, Epoch Time (s): 0.08, Total Time (hrs): 0.2577
# ====> Epoch: 10185 Train ELBO: 62.8565 Val ELBO: 18.7171, Epoch Time (s): 0.07, Total Time (hrs): 0.2577
# ====> Epoch: 10186 Train ELBO: 56.7329 Val ELBO: 8.3709, Epoch Time (s): 0.07, Total Time (hrs): 0.2578
# ====> Epoch: 10187 Train ELBO: 58.9396 Val ELBO: 18.4358, Epoch Time (s): 0.08, Total Time (hrs): 0.2578
# ====> Epoch: 10188 Train ELBO: 65.5232 Val ELBO: 11.0889, Epoch Time (s): 0.08, Total Time (hrs): 0.2578
# ====> Epoch: 10189 Train ELBO: 68.8533 Val ELBO: 15.0145, Epoch Time (s): 0.08, Total Time (hrs): 0.2578
# ====> Epoch: 10190 Train ELBO: 65.1120 Val ELBO: 14.0444, Epoch Time (s): 0.10, Total Time (hrs): 0.2579
# ====> Epoch: 10191 Train ELBO: 62.6616 Val ELBO: 4.8587, Epoch Time (s): 0.08, Total Time (hrs): 0.2579
# ====> Epoch: 10192 Train ELBO: 59.8533 Val ELBO: -5.4592, Epoch Time (s): 0.08, Total Time (hrs): 0.2579
# ====> Epoch: 10193 Train ELBO: 53.9207 Val ELBO: -1.4785, Epoch Time (s): 0.09, Total Time (hrs): 0.2579
# ====> Epoch: 10194 Train ELBO: 58.8069 Val ELBO: 0.3859, Epoch Time (s): 0.09, Total Time (hrs): 0.2580
# ====> Epoch: 10195 Train ELBO: 61.0398 Val ELBO: 7.1029, Epoch Time (s): 0.10, Total Time (hrs): 0.2580
# ====> Epoch: 10196 Train ELBO: 62.9197 Val ELBO: 19.7591, Epoch Time (s): 0.10, Total Time (hrs): 0.2580
# ====> Epoch: 10197 Train ELBO: 54.7138 Val ELBO: 12.4782, Epoch Time (s): 0.08, Total Time (hrs): 0.2580
# ====> Epoch: 10198 Train ELBO: 61.4439 Val ELBO: 4.5592, Epoch Time (s): 0.07, Total Time (hrs): 0.2581
# ====> Epoch: 10199 Train ELBO: 58.7873 Val ELBO: 12.1666, Epoch Time (s): 0.09, Total Time (hrs): 0.2581
# ====> Epoch: 10200 Train ELBO: 62.0384 Val ELBO: 10.7837, Epoch Time (s): 0.08, Total Time (hrs): 0.2581
# ====> Epoch: 10201 Train ELBO: 64.8518 Val ELBO: 12.9564, Epoch Time (s): 0.08, Total Time (hrs): 0.2581
# ====> Epoch: 10202 Train ELBO: 68.5919 Val ELBO: 10.2488, Epoch Time (s): 0.09, Total Time (hrs): 0.2581
# ====> Epoch: 10203 Train ELBO: 68.5555 Val ELBO: 13.2413, Epoch Time (s): 0.09, Total Time (hrs): 0.2582
# ====> Epoch: 10204 Train ELBO: 72.9959 Val ELBO: 21.4639, Epoch Time (s): 0.08, Total Time (hrs): 0.2582
# ====> Epoch: 10205 Train ELBO: 74.4204 Val ELBO: 20.0057, Epoch Time (s): 0.08, Total Time (hrs): 0.2582
# ====> Epoch: 10206 Train ELBO: 73.5394 Val ELBO: 17.6673, Epoch Time (s): 0.07, Total Time (hrs): 0.2582
# ====> Epoch: 10207 Train ELBO: 71.3754 Val ELBO: 2.3603, Epoch Time (s): 0.07, Total Time (hrs): 0.2583
# ====> Epoch: 10208 Train ELBO: 66.5526 Val ELBO: 11.7920, Epoch Time (s): 0.09, Total Time (hrs): 0.2583
# ====> Epoch: 10209 Train ELBO: 66.6247 Val ELBO: 9.8385, Epoch Time (s): 0.10, Total Time (hrs): 0.2583
# ====> Epoch: 10210 Train ELBO: 70.3039 Val ELBO: 17.1578, Epoch Time (s): 0.08, Total Time (hrs): 0.2583
# ====> Epoch: 10211 Train ELBO: 71.9738 Val ELBO: 18.6993, Epoch Time (s): 0.10, Total Time (hrs): 0.2584
# ====> Epoch: 10212 Train ELBO: 74.7818 Val ELBO: 17.8385, Epoch Time (s): 0.08, Total Time (hrs): 0.2584
# ====> Epoch: 10213 Train ELBO: 72.8297 Val ELBO: 19.3650, Epoch Time (s): 0.08, Total Time (hrs): 0.2584
# ====> Epoch: 10214 Train ELBO: 74.0532 Val ELBO: 17.5401, Epoch Time (s): 0.09, Total Time (hrs): 0.2584
# ====> Epoch: 10215 Train ELBO: 74.3058 Val ELBO: 24.4757, Epoch Time (s): 0.07, Total Time (hrs): 0.2584
# ====> Epoch: 10216 Train ELBO: 76.3214 Val ELBO: 19.0189, Epoch Time (s): 0.09, Total Time (hrs): 0.2585
# ====> Epoch: 10217 Train ELBO: 72.9722 Val ELBO: 12.8809, Epoch Time (s): 0.08, Total Time (hrs): 0.2585
# ====> Epoch: 10218 Train ELBO: 74.5044 Val ELBO: 16.9267, Epoch Time (s): 0.12, Total Time (hrs): 0.2585
# ====> Epoch: 10219 Train ELBO: 74.3120 Val ELBO: 18.2427, Epoch Time (s): 0.13, Total Time (hrs): 0.2586
# ====> Epoch: 10220 Train ELBO: 73.0165 Val ELBO: 7.7109, Epoch Time (s): 0.11, Total Time (hrs): 0.2586
# ====> Epoch: 10221 Train ELBO: 70.9142 Val ELBO: 19.9280, Epoch Time (s): 0.11, Total Time (hrs): 0.2586
# ====> Epoch: 10222 Train ELBO: 71.1997 Val ELBO: 20.5686, Epoch Time (s): 0.12, Total Time (hrs): 0.2587
# ====> Epoch: 10223 Train ELBO: 67.7002 Val ELBO: -8.5847, Epoch Time (s): 0.11, Total Time (hrs): 0.2587
# ====> Epoch: 10224 Train ELBO: 60.1525 Val ELBO: -0.8666, Epoch Time (s): 0.13, Total Time (hrs): 0.2587
# ====> Epoch: 10225 Train ELBO: 57.4188 Val ELBO: 11.5305, Epoch Time (s): 0.12, Total Time (hrs): 0.2588
# ====> Epoch: 10226 Train ELBO: 47.0941 Val ELBO: -22.2312, Epoch Time (s): 0.11, Total Time (hrs): 0.2588
# ====> Epoch: 10227 Train ELBO: 52.8894 Val ELBO: -6.0288, Epoch Time (s): 0.10, Total Time (hrs): 0.2588
# ====> Epoch: 10228 Train ELBO: 61.2546 Val ELBO: 11.8452, Epoch Time (s): 0.13, Total Time (hrs): 0.2589
# ====> Epoch: 10229 Train ELBO: 59.3447 Val ELBO: 11.0494, Epoch Time (s): 0.11, Total Time (hrs): 0.2589
# ====> Epoch: 10230 Train ELBO: 66.1064 Val ELBO: 4.2778, Epoch Time (s): 0.12, Total Time (hrs): 0.2589
# ====> Epoch: 10231 Train ELBO: 58.5612 Val ELBO: -14.4998, Epoch Time (s): 0.11, Total Time (hrs): 0.2590
# ====> Epoch: 10232 Train ELBO: 56.4132 Val ELBO: 4.8879, Epoch Time (s): 0.12, Total Time (hrs): 0.2590
# ====> Epoch: 10233 Train ELBO: 59.2634 Val ELBO: 7.6504, Epoch Time (s): 0.11, Total Time (hrs): 0.2590
# ====> Epoch: 10234 Train ELBO: 60.9294 Val ELBO: 8.9430, Epoch Time (s): 0.12, Total Time (hrs): 0.2591
# ====> Epoch: 10235 Train ELBO: 63.6795 Val ELBO: 4.8965, Epoch Time (s): 0.11, Total Time (hrs): 0.2591
# ====> Epoch: 10236 Train ELBO: 68.4362 Val ELBO: 13.7373, Epoch Time (s): 0.12, Total Time (hrs): 0.2591
# ====> Epoch: 10237 Train ELBO: 70.2035 Val ELBO: 6.5331, Epoch Time (s): 0.12, Total Time (hrs): 0.2592
# ====> Epoch: 10238 Train ELBO: 42.1857 Val ELBO: -104.0812, Epoch Time (s): 0.12, Total Time (hrs): 0.2592
# ====> Epoch: 10239 Train ELBO: -20.9075 Val ELBO: -39.0270, Epoch Time (s): 0.10, Total Time (hrs): 0.2592
# ====> Epoch: 10240 Train ELBO: -13.6852 Val ELBO: -47.5071, Epoch Time (s): 0.10, Total Time (hrs): 0.2593
# ====> Epoch: 10241 Train ELBO: 12.9248 Val ELBO: -1.3267, Epoch Time (s): 0.10, Total Time (hrs): 0.2593
# ====> Epoch: 10242 Train ELBO: 47.8325 Val ELBO: -7.3895, Epoch Time (s): 0.10, Total Time (hrs): 0.2593
# ====> Epoch: 10243 Train ELBO: 41.9854 Val ELBO: -20.2526, Epoch Time (s): 0.11, Total Time (hrs): 0.2593
# ====> Epoch: 10244 Train ELBO: 51.3011 Val ELBO: 7.3138, Epoch Time (s): 0.13, Total Time (hrs): 0.2594
# ====> Epoch: 10245 Train ELBO: 62.2073 Val ELBO: 5.9429, Epoch Time (s): 0.12, Total Time (hrs): 0.2594
# ====> Epoch: 10246 Train ELBO: 65.6918 Val ELBO: 17.3186, Epoch Time (s): 0.12, Total Time (hrs): 0.2594
# ====> Epoch: 10247 Train ELBO: 62.4877 Val ELBO: 11.6723, Epoch Time (s): 0.13, Total Time (hrs): 0.2595
# ====> Epoch: 10248 Train ELBO: 61.9525 Val ELBO: 2.6477, Epoch Time (s): 0.14, Total Time (hrs): 0.2595
# ====> Epoch: 10249 Train ELBO: 65.5213 Val ELBO: 4.3991, Epoch Time (s): 0.11, Total Time (hrs): 0.2596
# ====> Epoch: 10250 Train ELBO: 70.4971 Val ELBO: 17.9653, Epoch Time (s): 0.13, Total Time (hrs): 0.2596
# ====> Epoch: 10251 Train ELBO: 74.1211 Val ELBO: 17.3004, Epoch Time (s): 0.12, Total Time (hrs): 0.2596
# ====> Epoch: 10252 Train ELBO: 72.5521 Val ELBO: 12.7755, Epoch Time (s): 0.07, Total Time (hrs): 0.2596
# ====> Epoch: 10253 Train ELBO: 71.7363 Val ELBO: 13.3685, Epoch Time (s): 0.08, Total Time (hrs): 0.2597
# ====> Epoch: 10254 Train ELBO: 73.7893 Val ELBO: 12.0904, Epoch Time (s): 0.07, Total Time (hrs): 0.2597
# ====> Epoch: 10255 Train ELBO: 66.6595 Val ELBO: -10.7668, Epoch Time (s): 0.07, Total Time (hrs): 0.2597
# ====> Epoch: 10256 Train ELBO: 55.5415 Val ELBO: -7.3749, Epoch Time (s): 0.07, Total Time (hrs): 0.2597
# ====> Epoch: 10257 Train ELBO: 61.0947 Val ELBO: 8.8325, Epoch Time (s): 0.08, Total Time (hrs): 0.2597
# ====> Epoch: 10258 Train ELBO: 64.7255 Val ELBO: -3.8201, Epoch Time (s): 0.08, Total Time (hrs): 0.2598
# ====> Epoch: 10259 Train ELBO: 64.6111 Val ELBO: 21.0110, Epoch Time (s): 0.08, Total Time (hrs): 0.2598
# ====> Epoch: 10260 Train ELBO: 72.1892 Val ELBO: 14.4629, Epoch Time (s): 0.07, Total Time (hrs): 0.2598
# ====> Epoch: 10261 Train ELBO: 72.4944 Val ELBO: 20.8766, Epoch Time (s): 0.07, Total Time (hrs): 0.2598
# ====> Epoch: 10262 Train ELBO: 72.5261 Val ELBO: 9.3013, Epoch Time (s): 0.09, Total Time (hrs): 0.2599
# ====> Epoch: 10263 Train ELBO: 64.5607 Val ELBO: 0.6174, Epoch Time (s): 0.07, Total Time (hrs): 0.2599
# ====> Epoch: 10264 Train ELBO: 63.5063 Val ELBO: 4.2228, Epoch Time (s): 0.07, Total Time (hrs): 0.2599
# ====> Epoch: 10265 Train ELBO: 41.9774 Val ELBO: 16.0211, Epoch Time (s): 0.08, Total Time (hrs): 0.2599
# ====> Epoch: 10266 Train ELBO: 61.7739 Val ELBO: 14.2095, Epoch Time (s): 0.07, Total Time (hrs): 0.2599
# ====> Epoch: 10267 Train ELBO: 62.6045 Val ELBO: -0.4465, Epoch Time (s): 0.07, Total Time (hrs): 0.2600
# ====> Epoch: 10268 Train ELBO: 57.3863 Val ELBO: 14.5764, Epoch Time (s): 0.08, Total Time (hrs): 0.2600
# ====> Epoch: 10269 Train ELBO: 67.8382 Val ELBO: 23.8988, Epoch Time (s): 0.07, Total Time (hrs): 0.2600
# ====> Epoch: 10270 Train ELBO: 71.9308 Val ELBO: 21.5515, Epoch Time (s): 0.07, Total Time (hrs): 0.2600
# ====> Epoch: 10271 Train ELBO: 69.0492 Val ELBO: 14.1331, Epoch Time (s): 0.10, Total Time (hrs): 0.2600
# ====> Epoch: 10272 Train ELBO: 67.6922 Val ELBO: 14.9794, Epoch Time (s): 0.07, Total Time (hrs): 0.2601
# ====> Epoch: 10273 Train ELBO: 69.4324 Val ELBO: 22.9221, Epoch Time (s): 0.07, Total Time (hrs): 0.2601
# ====> Epoch: 10274 Train ELBO: 71.9980 Val ELBO: 17.1142, Epoch Time (s): 0.08, Total Time (hrs): 0.2601
# ====> Epoch: 10275 Train ELBO: 73.1253 Val ELBO: 19.8764, Epoch Time (s): 0.07, Total Time (hrs): 0.2601
# ====> Epoch: 10276 Train ELBO: 75.3248 Val ELBO: 8.8895, Epoch Time (s): 0.08, Total Time (hrs): 0.2602
# ====> Epoch: 10277 Train ELBO: 70.0095 Val ELBO: 9.6301, Epoch Time (s): 0.09, Total Time (hrs): 0.2602
# ====> Epoch: 10278 Train ELBO: 69.3088 Val ELBO: 18.4522, Epoch Time (s): 0.08, Total Time (hrs): 0.2602
# ====> Epoch: 10279 Train ELBO: 67.5211 Val ELBO: 13.6158, Epoch Time (s): 0.08, Total Time (hrs): 0.2602
# ====> Epoch: 10280 Train ELBO: 66.3554 Val ELBO: 10.5140, Epoch Time (s): 0.07, Total Time (hrs): 0.2602
# ====> Epoch: 10281 Train ELBO: 69.6113 Val ELBO: 9.8780, Epoch Time (s): 0.07, Total Time (hrs): 0.2603
# ====> Epoch: 10282 Train ELBO: 73.9448 Val ELBO: 13.1305, Epoch Time (s): 0.07, Total Time (hrs): 0.2603
# ====> Epoch: 10283 Train ELBO: 72.1862 Val ELBO: 6.0416, Epoch Time (s): 0.07, Total Time (hrs): 0.2603
# ====> Epoch: 10284 Train ELBO: 68.0877 Val ELBO: 0.2707, Epoch Time (s): 0.08, Total Time (hrs): 0.2603
# ====> Epoch: 10285 Train ELBO: 51.2365 Val ELBO: -17.1546, Epoch Time (s): 0.09, Total Time (hrs): 0.2603
# ====> Epoch: 10286 Train ELBO: 50.9159 Val ELBO: 5.2547, Epoch Time (s): 0.08, Total Time (hrs): 0.2604
# ====> Epoch: 10287 Train ELBO: 56.8267 Val ELBO: 10.2322, Epoch Time (s): 0.08, Total Time (hrs): 0.2604
# ====> Epoch: 10288 Train ELBO: 64.6759 Val ELBO: 15.5274, Epoch Time (s): 0.07, Total Time (hrs): 0.2604
# ====> Epoch: 10289 Train ELBO: 68.4703 Val ELBO: 8.0822, Epoch Time (s): 0.08, Total Time (hrs): 0.2604
# ====> Epoch: 10290 Train ELBO: 71.5103 Val ELBO: 11.5588, Epoch Time (s): 0.07, Total Time (hrs): 0.2605
# ====> Epoch: 10291 Train ELBO: 75.2390 Val ELBO: 18.1302, Epoch Time (s): 0.07, Total Time (hrs): 0.2605
# ====> Epoch: 10292 Train ELBO: 70.5986 Val ELBO: 17.9149, Epoch Time (s): 0.08, Total Time (hrs): 0.2605
# ====> Epoch: 10293 Train ELBO: 64.2308 Val ELBO: 19.2710, Epoch Time (s): 0.07, Total Time (hrs): 0.2605
# ====> Epoch: 10294 Train ELBO: 60.4002 Val ELBO: -1.9904, Epoch Time (s): 0.07, Total Time (hrs): 0.2605
# ====> Epoch: 10295 Train ELBO: 61.7041 Val ELBO: -4.1215, Epoch Time (s): 0.07, Total Time (hrs): 0.2606
# ====> Epoch: 10296 Train ELBO: 60.2354 Val ELBO: 2.6154, Epoch Time (s): 0.08, Total Time (hrs): 0.2606
# ====> Epoch: 10297 Train ELBO: 66.2529 Val ELBO: 19.6462, Epoch Time (s): 0.07, Total Time (hrs): 0.2606
# ====> Epoch: 10298 Train ELBO: 68.1309 Val ELBO: 13.0039, Epoch Time (s): 0.10, Total Time (hrs): 0.2606
# ====> Epoch: 10299 Train ELBO: 69.6132 Val ELBO: 9.5886, Epoch Time (s): 0.08, Total Time (hrs): 0.2606
# ====> Epoch: 10300 Train ELBO: 68.1278 Val ELBO: 15.1170, Epoch Time (s): 0.08, Total Time (hrs): 0.2607
# ====> Epoch: 10301 Train ELBO: 71.7847 Val ELBO: 22.3511, Epoch Time (s): 0.08, Total Time (hrs): 0.2607
# ====> Epoch: 10302 Train ELBO: 74.1618 Val ELBO: 19.6732, Epoch Time (s): 0.07, Total Time (hrs): 0.2607
# ====> Epoch: 10303 Train ELBO: 72.6073 Val ELBO: 14.3656, Epoch Time (s): 0.07, Total Time (hrs): 0.2607
# ====> Epoch: 10304 Train ELBO: 71.5022 Val ELBO: 19.5364, Epoch Time (s): 0.08, Total Time (hrs): 0.2607
# ====> Epoch: 10305 Train ELBO: 74.9389 Val ELBO: 18.8185, Epoch Time (s): 0.07, Total Time (hrs): 0.2608
# ====> Epoch: 10306 Train ELBO: 71.3910 Val ELBO: 22.0565, Epoch Time (s): 0.07, Total Time (hrs): 0.2608
# ====> Epoch: 10307 Train ELBO: 74.3299 Val ELBO: 18.2799, Epoch Time (s): 0.08, Total Time (hrs): 0.2608
# ====> Epoch: 10308 Train ELBO: 73.5185 Val ELBO: 21.5849, Epoch Time (s): 0.07, Total Time (hrs): 0.2608
# ====> Epoch: 10309 Train ELBO: 74.8272 Val ELBO: 18.1254, Epoch Time (s): 0.09, Total Time (hrs): 0.2609
# ====> Epoch: 10310 Train ELBO: 63.2430 Val ELBO: -4.3806, Epoch Time (s): 0.09, Total Time (hrs): 0.2609
# ====> Epoch: 10311 Train ELBO: 48.4401 Val ELBO: -10.8037, Epoch Time (s): 0.07, Total Time (hrs): 0.2609
# ====> Epoch: 10312 Train ELBO: 40.7800 Val ELBO: 19.4987, Epoch Time (s): 0.10, Total Time (hrs): 0.2609
# ====> Epoch: 10313 Train ELBO: 47.4415 Val ELBO: 14.4003, Epoch Time (s): 0.08, Total Time (hrs): 0.2610
# ====> Epoch: 10314 Train ELBO: 64.0413 Val ELBO: 7.3555, Epoch Time (s): 0.07, Total Time (hrs): 0.2610
# ====> Epoch: 10315 Train ELBO: 62.7124 Val ELBO: 14.4402, Epoch Time (s): 0.07, Total Time (hrs): 0.2610
# ====> Epoch: 10316 Train ELBO: 65.4775 Val ELBO: 8.5770, Epoch Time (s): 0.08, Total Time (hrs): 0.2610
# ====> Epoch: 10317 Train ELBO: 68.1089 Val ELBO: 8.6760, Epoch Time (s): 0.07, Total Time (hrs): 0.2610
# ====> Epoch: 10318 Train ELBO: 63.2813 Val ELBO: 24.5026, Epoch Time (s): 0.07, Total Time (hrs): 0.2611
# ====> Epoch: 10319 Train ELBO: 62.7282 Val ELBO: 7.7480, Epoch Time (s): 0.08, Total Time (hrs): 0.2611
# ====> Epoch: 10320 Train ELBO: 58.1112 Val ELBO: 7.4911, Epoch Time (s): 0.07, Total Time (hrs): 0.2611
# ====> Epoch: 10321 Train ELBO: 60.6004 Val ELBO: 18.7200, Epoch Time (s): 0.07, Total Time (hrs): 0.2611
# ====> Epoch: 10322 Train ELBO: 68.3982 Val ELBO: 6.6412, Epoch Time (s): 0.08, Total Time (hrs): 0.2611
# ====> Epoch: 10323 Train ELBO: 64.1182 Val ELBO: 11.8532, Epoch Time (s): 0.08, Total Time (hrs): 0.2612
# ====> Epoch: 10324 Train ELBO: 71.9679 Val ELBO: 11.7560, Epoch Time (s): 0.08, Total Time (hrs): 0.2612
# ====> Epoch: 10325 Train ELBO: 68.2281 Val ELBO: -28.3719, Epoch Time (s): 0.09, Total Time (hrs): 0.2612
# ====> Epoch: 10326 Train ELBO: 30.9549 Val ELBO: 7.8400, Epoch Time (s): 0.08, Total Time (hrs): 0.2612
# ====> Epoch: 10327 Train ELBO: 45.9140 Val ELBO: -12.9869, Epoch Time (s): 0.07, Total Time (hrs): 0.2613
# ====> Epoch: 10328 Train ELBO: 51.1722 Val ELBO: -1.5640, Epoch Time (s): 0.08, Total Time (hrs): 0.2613
# ====> Epoch: 10329 Train ELBO: 52.7249 Val ELBO: 12.4516, Epoch Time (s): 0.07, Total Time (hrs): 0.2613
# ====> Epoch: 10330 Train ELBO: 45.7215 Val ELBO: 5.4311, Epoch Time (s): 0.07, Total Time (hrs): 0.2613
# ====> Epoch: 10331 Train ELBO: 36.5081 Val ELBO: 6.8104, Epoch Time (s): 0.08, Total Time (hrs): 0.2613
# ====> Epoch: 10332 Train ELBO: 35.3802 Val ELBO: -11.9773, Epoch Time (s): 0.07, Total Time (hrs): 0.2614
# ====> Epoch: 10333 Train ELBO: 41.6416 Val ELBO: 16.1215, Epoch Time (s): 0.07, Total Time (hrs): 0.2614
# ====> Epoch: 10334 Train ELBO: 58.7805 Val ELBO: 0.8398, Epoch Time (s): 0.08, Total Time (hrs): 0.2614
# ====> Epoch: 10335 Train ELBO: 59.0467 Val ELBO: 11.6548, Epoch Time (s): 0.07, Total Time (hrs): 0.2614
# ====> Epoch: 10336 Train ELBO: 58.4900 Val ELBO: -27.9654, Epoch Time (s): 0.07, Total Time (hrs): 0.2614
# ====> Epoch: 10337 Train ELBO: 48.3043 Val ELBO: 2.4352, Epoch Time (s): 0.07, Total Time (hrs): 0.2615
# ====> Epoch: 10338 Train ELBO: 63.9289 Val ELBO: 0.5876, Epoch Time (s): 0.08, Total Time (hrs): 0.2615
# ====> Epoch: 10339 Train ELBO: 65.7838 Val ELBO: 20.1953, Epoch Time (s): 0.07, Total Time (hrs): 0.2615
# ====> Epoch: 10340 Train ELBO: 70.9507 Val ELBO: 23.2885, Epoch Time (s): 0.08, Total Time (hrs): 0.2615
# ====> Epoch: 10341 Train ELBO: 72.0623 Val ELBO: 13.8162, Epoch Time (s): 0.07, Total Time (hrs): 0.2616
# ====> Epoch: 10342 Train ELBO: 69.4718 Val ELBO: 5.9026, Epoch Time (s): 0.07, Total Time (hrs): 0.2616
# ====> Epoch: 10343 Train ELBO: 68.0075 Val ELBO: 4.8908, Epoch Time (s): 0.08, Total Time (hrs): 0.2616
# ====> Epoch: 10344 Train ELBO: 64.1213 Val ELBO: 4.5745, Epoch Time (s): 0.07, Total Time (hrs): 0.2616
# ====> Epoch: 10345 Train ELBO: 65.3431 Val ELBO: 10.8836, Epoch Time (s): 0.07, Total Time (hrs): 0.2616
# ====> Epoch: 10346 Train ELBO: 61.8620 Val ELBO: 6.9920, Epoch Time (s): 0.08, Total Time (hrs): 0.2617
# ====> Epoch: 10347 Train ELBO: 62.8702 Val ELBO: -3.5734, Epoch Time (s): 0.07, Total Time (hrs): 0.2617
# ====> Epoch: 10348 Train ELBO: 65.4239 Val ELBO: 18.8149, Epoch Time (s): 0.07, Total Time (hrs): 0.2617
# ====> Epoch: 10349 Train ELBO: 68.0494 Val ELBO: 14.8700, Epoch Time (s): 0.08, Total Time (hrs): 0.2617
# ====> Epoch: 10350 Train ELBO: 64.5915 Val ELBO: 16.8028, Epoch Time (s): 0.07, Total Time (hrs): 0.2617
# ====> Epoch: 10351 Train ELBO: 72.1912 Val ELBO: 13.2604, Epoch Time (s): 0.07, Total Time (hrs): 0.2618
# ====> Epoch: 10352 Train ELBO: 64.3227 Val ELBO: 25.3616, Epoch Time (s): 0.10, Total Time (hrs): 0.2618
# ====> Epoch: 10353 Train ELBO: 69.1341 Val ELBO: 7.4468, Epoch Time (s): 0.07, Total Time (hrs): 0.2618
# ====> Epoch: 10354 Train ELBO: 63.1007 Val ELBO: 4.5553, Epoch Time (s): 0.07, Total Time (hrs): 0.2618
# ====> Epoch: 10355 Train ELBO: 66.5141 Val ELBO: -0.2067, Epoch Time (s): 0.09, Total Time (hrs): 0.2619
# ====> Epoch: 10356 Train ELBO: 64.7529 Val ELBO: 26.4094, Epoch Time (s): 0.08, Total Time (hrs): 0.2619
# ====> Epoch: 10357 Train ELBO: 71.5091 Val ELBO: 6.5744, Epoch Time (s): 0.08, Total Time (hrs): 0.2619
# ====> Epoch: 10358 Train ELBO: 64.1999 Val ELBO: 11.8575, Epoch Time (s): 0.08, Total Time (hrs): 0.2619
# ====> Epoch: 10359 Train ELBO: 63.2469 Val ELBO: 20.8558, Epoch Time (s): 0.07, Total Time (hrs): 0.2620
# ====> Epoch: 10360 Train ELBO: 59.1038 Val ELBO: -24.5552, Epoch Time (s): 0.08, Total Time (hrs): 0.2620
# ====> Epoch: 10361 Train ELBO: 36.5538 Val ELBO: 0.6095, Epoch Time (s): 0.08, Total Time (hrs): 0.2620
# ====> Epoch: 10362 Train ELBO: 25.9417 Val ELBO: -13.3555, Epoch Time (s): 0.07, Total Time (hrs): 0.2620
# ====> Epoch: 10363 Train ELBO: 31.7542 Val ELBO: -2.2570, Epoch Time (s): 0.08, Total Time (hrs): 0.2620
# ====> Epoch: 10364 Train ELBO: 43.7601 Val ELBO: -25.4811, Epoch Time (s): 0.08, Total Time (hrs): 0.2621
# ====> Epoch: 10365 Train ELBO: 21.9412 Val ELBO: -5.4616, Epoch Time (s): 0.07, Total Time (hrs): 0.2621
# ====> Epoch: 10366 Train ELBO: 34.8102 Val ELBO: -32.2753, Epoch Time (s): 0.08, Total Time (hrs): 0.2621
# ====> Epoch: 10367 Train ELBO: 36.4620 Val ELBO: -32.3713, Epoch Time (s): 0.08, Total Time (hrs): 0.2621
# ====> Epoch: 10368 Train ELBO: 37.6575 Val ELBO: 8.0511, Epoch Time (s): 0.07, Total Time (hrs): 0.2622
# ====> Epoch: 10369 Train ELBO: 56.1162 Val ELBO: -0.6658, Epoch Time (s): 0.09, Total Time (hrs): 0.2622
# ====> Epoch: 10370 Train ELBO: 63.5518 Val ELBO: 3.6082, Epoch Time (s): 0.08, Total Time (hrs): 0.2622
# ====> Epoch: 10371 Train ELBO: 67.4576 Val ELBO: 21.5464, Epoch Time (s): 0.07, Total Time (hrs): 0.2622
# ====> Epoch: 10372 Train ELBO: 70.3833 Val ELBO: 12.3449, Epoch Time (s): 0.08, Total Time (hrs): 0.2622
# ====> Epoch: 10373 Train ELBO: 70.9829 Val ELBO: 16.7439, Epoch Time (s): 0.07, Total Time (hrs): 0.2623
# ====> Epoch: 10374 Train ELBO: 66.9350 Val ELBO: 12.5039, Epoch Time (s): 0.08, Total Time (hrs): 0.2623
# ====> Epoch: 10375 Train ELBO: 64.2449 Val ELBO: 14.6750, Epoch Time (s): 0.09, Total Time (hrs): 0.2623
# ====> Epoch: 10376 Train ELBO: 68.5991 Val ELBO: 11.3237, Epoch Time (s): 0.09, Total Time (hrs): 0.2623
# ====> Epoch: 10377 Train ELBO: 69.6706 Val ELBO: -0.7011, Epoch Time (s): 0.09, Total Time (hrs): 0.2624
# ====> Epoch: 10378 Train ELBO: 64.1000 Val ELBO: 9.1267, Epoch Time (s): 0.08, Total Time (hrs): 0.2624
# ====> Epoch: 10379 Train ELBO: 66.1877 Val ELBO: 14.3587, Epoch Time (s): 0.07, Total Time (hrs): 0.2624
# ====> Epoch: 10380 Train ELBO: 65.6585 Val ELBO: -14.0748, Epoch Time (s): 0.11, Total Time (hrs): 0.2624
# ====> Epoch: 10381 Train ELBO: 57.7915 Val ELBO: -31.8082, Epoch Time (s): 0.13, Total Time (hrs): 0.2625
# ====> Epoch: 10382 Train ELBO: 42.3018 Val ELBO: -21.2230, Epoch Time (s): 0.10, Total Time (hrs): 0.2625
# ====> Epoch: 10383 Train ELBO: 42.5701 Val ELBO: -41.6006, Epoch Time (s): 0.10, Total Time (hrs): 0.2625
# ====> Epoch: 10384 Train ELBO: 27.6083 Val ELBO: -3.0315, Epoch Time (s): 0.11, Total Time (hrs): 0.2626
# ====> Epoch: 10385 Train ELBO: 25.5705 Val ELBO: -67.1654, Epoch Time (s): 0.11, Total Time (hrs): 0.2626
# ====> Epoch: 10386 Train ELBO: 21.6921 Val ELBO: -46.6972, Epoch Time (s): 0.10, Total Time (hrs): 0.2626
# ====> Epoch: 10387 Train ELBO: 21.5945 Val ELBO: -37.6395, Epoch Time (s): 0.12, Total Time (hrs): 0.2626
# ====> Epoch: 10388 Train ELBO: 37.0145 Val ELBO: 3.1106, Epoch Time (s): 0.11, Total Time (hrs): 0.2627
# ====> Epoch: 10389 Train ELBO: 61.8203 Val ELBO: -3.2851, Epoch Time (s): 0.10, Total Time (hrs): 0.2627
# ====> Epoch: 10390 Train ELBO: 56.4471 Val ELBO: 10.0401, Epoch Time (s): 0.10, Total Time (hrs): 0.2627
# ====> Epoch: 10391 Train ELBO: 55.7764 Val ELBO: -2.6637, Epoch Time (s): 0.10, Total Time (hrs): 0.2628
# ====> Epoch: 10392 Train ELBO: 62.8911 Val ELBO: 10.3789, Epoch Time (s): 0.10, Total Time (hrs): 0.2628
# ====> Epoch: 10393 Train ELBO: 70.6456 Val ELBO: 17.3331, Epoch Time (s): 0.10, Total Time (hrs): 0.2628
# ====> Epoch: 10394 Train ELBO: 71.2740 Val ELBO: 13.4277, Epoch Time (s): 0.12, Total Time (hrs): 0.2628
# ====> Epoch: 10395 Train ELBO: 70.0459 Val ELBO: 15.8638, Epoch Time (s): 0.10, Total Time (hrs): 0.2629
# ====> Epoch: 10396 Train ELBO: 72.0503 Val ELBO: 22.7108, Epoch Time (s): 0.10, Total Time (hrs): 0.2629
# ====> Epoch: 10397 Train ELBO: 74.0380 Val ELBO: 17.7523, Epoch Time (s): 0.12, Total Time (hrs): 0.2629
# ====> Epoch: 10398 Train ELBO: 65.1074 Val ELBO: -1.3402, Epoch Time (s): 0.10, Total Time (hrs): 0.2630
# ====> Epoch: 10399 Train ELBO: 72.8087 Val ELBO: 10.6628, Epoch Time (s): 0.10, Total Time (hrs): 0.2630
# ====> Epoch: 10400 Train ELBO: 70.2516 Val ELBO: 20.5133, Epoch Time (s): 0.10, Total Time (hrs): 0.2630
# ====> Epoch: 10401 Train ELBO: 72.7908 Val ELBO: 11.9042, Epoch Time (s): 0.09, Total Time (hrs): 0.2630
# ====> Epoch: 10402 Train ELBO: 67.3168 Val ELBO: 8.3502, Epoch Time (s): 0.10, Total Time (hrs): 0.2631
# ====> Epoch: 10403 Train ELBO: 73.2466 Val ELBO: 25.0107, Epoch Time (s): 0.12, Total Time (hrs): 0.2631
# ====> Epoch: 10404 Train ELBO: 73.9067 Val ELBO: 15.9904, Epoch Time (s): 0.10, Total Time (hrs): 0.2631
# ====> Epoch: 10405 Train ELBO: 66.6654 Val ELBO: 16.6438, Epoch Time (s): 0.11, Total Time (hrs): 0.2632
# ====> Epoch: 10406 Train ELBO: 60.9555 Val ELBO: -1.2186, Epoch Time (s): 0.12, Total Time (hrs): 0.2632
# ====> Epoch: 10407 Train ELBO: 56.6089 Val ELBO: 10.0604, Epoch Time (s): 0.12, Total Time (hrs): 0.2632
# ====> Epoch: 10408 Train ELBO: 54.3115 Val ELBO: 4.0075, Epoch Time (s): 0.12, Total Time (hrs): 0.2633
# ====> Epoch: 10409 Train ELBO: 57.7322 Val ELBO: -1.0875, Epoch Time (s): 0.12, Total Time (hrs): 0.2633
# ====> Epoch: 10410 Train ELBO: 66.3140 Val ELBO: 11.7806, Epoch Time (s): 0.12, Total Time (hrs): 0.2633
# ====> Epoch: 10411 Train ELBO: 65.7891 Val ELBO: -8.4418, Epoch Time (s): 0.11, Total Time (hrs): 0.2634
# ====> Epoch: 10412 Train ELBO: 57.1117 Val ELBO: 0.7671, Epoch Time (s): 0.12, Total Time (hrs): 0.2634
# ====> Epoch: 10413 Train ELBO: 58.1318 Val ELBO: -15.1227, Epoch Time (s): 0.13, Total Time (hrs): 0.2634
# ====> Epoch: 10414 Train ELBO: 53.2117 Val ELBO: 7.9434, Epoch Time (s): 0.07, Total Time (hrs): 0.2635
# ====> Epoch: 10415 Train ELBO: 66.2191 Val ELBO: 11.7961, Epoch Time (s): 0.09, Total Time (hrs): 0.2635
# ====> Epoch: 10416 Train ELBO: 69.8866 Val ELBO: 9.4535, Epoch Time (s): 0.08, Total Time (hrs): 0.2635
# ====> Epoch: 10417 Train ELBO: 74.3224 Val ELBO: 16.5916, Epoch Time (s): 0.07, Total Time (hrs): 0.2635
# ====> Epoch: 10418 Train ELBO: 73.2467 Val ELBO: 20.2287, Epoch Time (s): 0.09, Total Time (hrs): 0.2635
# ====> Epoch: 10419 Train ELBO: 75.0246 Val ELBO: 20.0219, Epoch Time (s): 0.08, Total Time (hrs): 0.2636
# ====> Epoch: 10420 Train ELBO: 74.6427 Val ELBO: 12.5996, Epoch Time (s): 0.07, Total Time (hrs): 0.2636
# ====> Epoch: 10421 Train ELBO: 73.7206 Val ELBO: 16.1415, Epoch Time (s): 0.07, Total Time (hrs): 0.2636
# ====> Epoch: 10422 Train ELBO: 73.0828 Val ELBO: 17.8132, Epoch Time (s): 0.08, Total Time (hrs): 0.2636
# ====> Epoch: 10423 Train ELBO: 74.6968 Val ELBO: 15.0248, Epoch Time (s): 0.07, Total Time (hrs): 0.2636
# ====> Epoch: 10424 Train ELBO: 73.0177 Val ELBO: 9.1210, Epoch Time (s): 0.08, Total Time (hrs): 0.2637
# ====> Epoch: 10425 Train ELBO: 68.9472 Val ELBO: 18.3398, Epoch Time (s): 0.07, Total Time (hrs): 0.2637
# ====> Epoch: 10426 Train ELBO: 63.0677 Val ELBO: 1.5827, Epoch Time (s): 0.07, Total Time (hrs): 0.2637
# ====> Epoch: 10427 Train ELBO: 34.8997 Val ELBO: -68.9377, Epoch Time (s): 0.07, Total Time (hrs): 0.2637
# ====> Epoch: 10428 Train ELBO: 23.3473 Val ELBO: -39.7677, Epoch Time (s): 0.07, Total Time (hrs): 0.2638
# ====> Epoch: 10429 Train ELBO: 31.0503 Val ELBO: -41.9484, Epoch Time (s): 0.07, Total Time (hrs): 0.2638
# ====> Epoch: 10430 Train ELBO: 8.1555 Val ELBO: -23.6813, Epoch Time (s): 0.07, Total Time (hrs): 0.2638
# ====> Epoch: 10431 Train ELBO: 37.1831 Val ELBO: 3.7464, Epoch Time (s): 0.07, Total Time (hrs): 0.2638
# ====> Epoch: 10432 Train ELBO: 59.0232 Val ELBO: 11.2727, Epoch Time (s): 0.11, Total Time (hrs): 0.2638
# ====> Epoch: 10433 Train ELBO: 67.1487 Val ELBO: 29.4779, Epoch Time (s): 0.07, Total Time (hrs): 0.2639
# ====> Epoch: 10434 Train ELBO: 72.2233 Val ELBO: 20.7866, Epoch Time (s): 0.07, Total Time (hrs): 0.2639
# ====> Epoch: 10435 Train ELBO: 66.5451 Val ELBO: 16.9686, Epoch Time (s): 0.09, Total Time (hrs): 0.2639
# ====> Epoch: 10436 Train ELBO: 67.5333 Val ELBO: 11.4309, Epoch Time (s): 0.08, Total Time (hrs): 0.2639
# ====> Epoch: 10437 Train ELBO: 67.9967 Val ELBO: 6.5476, Epoch Time (s): 0.09, Total Time (hrs): 0.2640
# ====> Epoch: 10438 Train ELBO: 68.8841 Val ELBO: -1.0436, Epoch Time (s): 0.07, Total Time (hrs): 0.2640
# ====> Epoch: 10439 Train ELBO: 58.7667 Val ELBO: 5.9611, Epoch Time (s): 0.07, Total Time (hrs): 0.2640
# ====> Epoch: 10440 Train ELBO: 62.0700 Val ELBO: 5.7798, Epoch Time (s): 0.08, Total Time (hrs): 0.2640
# ====> Epoch: 10441 Train ELBO: 71.1450 Val ELBO: 21.1239, Epoch Time (s): 0.08, Total Time (hrs): 0.2640
# ====> Epoch: 10442 Train ELBO: 72.2908 Val ELBO: 23.5049, Epoch Time (s): 0.07, Total Time (hrs): 0.2641
# ====> Epoch: 10443 Train ELBO: 74.3382 Val ELBO: 22.4037, Epoch Time (s): 0.08, Total Time (hrs): 0.2641
# ====> Epoch: 10444 Train ELBO: 70.8963 Val ELBO: 19.9498, Epoch Time (s): 0.09, Total Time (hrs): 0.2641
# ====> Epoch: 10445 Train ELBO: 61.4414 Val ELBO: 7.4085, Epoch Time (s): 0.07, Total Time (hrs): 0.2641
# ====> Epoch: 10446 Train ELBO: 61.0915 Val ELBO: 11.5335, Epoch Time (s): 0.08, Total Time (hrs): 0.2642
# ====> Epoch: 10447 Train ELBO: 69.2023 Val ELBO: 18.8428, Epoch Time (s): 0.07, Total Time (hrs): 0.2642
# ====> Epoch: 10448 Train ELBO: 67.2263 Val ELBO: 4.1574, Epoch Time (s): 0.07, Total Time (hrs): 0.2642
# ====> Epoch: 10449 Train ELBO: 59.9475 Val ELBO: -1.8860, Epoch Time (s): 0.08, Total Time (hrs): 0.2642
# ====> Epoch: 10450 Train ELBO: 62.8574 Val ELBO: 7.1218, Epoch Time (s): 0.07, Total Time (hrs): 0.2642
# ====> Epoch: 10451 Train ELBO: 66.7343 Val ELBO: 10.0870, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 10452 Train ELBO: 68.1770 Val ELBO: 13.1901, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 10453 Train ELBO: 61.5894 Val ELBO: 1.6820, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 10454 Train ELBO: 68.3121 Val ELBO: 17.9234, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 10455 Train ELBO: 70.8017 Val ELBO: 22.9077, Epoch Time (s): 0.07, Total Time (hrs): 0.2643
# ====> Epoch: 10456 Train ELBO: 72.8597 Val ELBO: 25.0155, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 10457 Train ELBO: 74.3242 Val ELBO: 17.6226, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 10458 Train ELBO: 76.8575 Val ELBO: 23.2403, Epoch Time (s): 0.09, Total Time (hrs): 0.2644
# ====> Epoch: 10459 Train ELBO: 76.6238 Val ELBO: 18.4704, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 10460 Train ELBO: 75.0270 Val ELBO: 17.3820, Epoch Time (s): 0.07, Total Time (hrs): 0.2644
# ====> Epoch: 10461 Train ELBO: 67.3051 Val ELBO: 8.7757, Epoch Time (s): 0.07, Total Time (hrs): 0.2645
# ====> Epoch: 10462 Train ELBO: 65.8334 Val ELBO: 10.1260, Epoch Time (s): 0.07, Total Time (hrs): 0.2645
# ====> Epoch: 10463 Train ELBO: 69.8499 Val ELBO: 17.7489, Epoch Time (s): 0.08, Total Time (hrs): 0.2645
# ====> Epoch: 10464 Train ELBO: 74.8310 Val ELBO: 12.2972, Epoch Time (s): 0.07, Total Time (hrs): 0.2645
# ====> Epoch: 10465 Train ELBO: 70.8747 Val ELBO: 12.4400, Epoch Time (s): 0.07, Total Time (hrs): 0.2645
# ====> Epoch: 10466 Train ELBO: 65.5250 Val ELBO: 11.6032, Epoch Time (s): 0.07, Total Time (hrs): 0.2646
# ====> Epoch: 10467 Train ELBO: 68.8741 Val ELBO: 24.2180, Epoch Time (s): 0.07, Total Time (hrs): 0.2646
# ...
# ====> Epoch: 3584 Train ELBO: -108.1447 Val ELBO: -175.8256, Epoch Time (s): 0.07, Total Time (hrs): 0.0965
# ====> Epoch: 3585 Train ELBO: -108.1441 Val ELBO: -177.4167, Epoch Time (s): 0.08, Total Time (hrs): 0.0965
# ====> Epoch: 3586 Train ELBO: -105.2296 Val ELBO: -204.1889, Epoch Time (s): 0.07, Total Time (hrs): 0.0966
# ====> Epoch: 3587 Train ELBO: -115.4573 Val ELBO: -165.4575, Epoch Time (s): 0.07, Total Time (hrs): 0.0966
# ====> Epoch: 3588 Train ELBO: -116.5440 Val ELBO: -146.6443, Epoch Time (s): 0.08, Total Time (hrs): 0.0966
# ====> Epoch: 3589 Train ELBO: -103.8454 Val ELBO: -156.8013, Epoch Time (s): 0.08, Total Time (hrs): 0.0966
# ====> Epoch: 3590 Train ELBO: -106.5111 Val ELBO: -175.6621, Epoch Time (s): 0.08, Total Time (hrs): 0.0967
# ====> Epoch: 3591 Train ELBO: -112.0549 Val ELBO: -156.5841, Epoch Time (s): 0.08, Total Time (hrs): 0.0967
# ====> Epoch: 3592 Train ELBO: -104.6747 Val ELBO: -156.8201, Epoch Time (s): 0.07, Total Time (hrs): 0.0967
# ====> Epoch: 3593 Train ELBO: -102.0062 Val ELBO: -157.8130, Epoch Time (s): 0.07, Total Time (hrs): 0.0967
# ====> Epoch: 3594 Train ELBO: -105.5448 Val ELBO: -160.6025, Epoch Time (s): 0.08, Total Time (hrs): 0.0967
# ====> Epoch: 3595 Train ELBO: -99.9777 Val ELBO: -162.2850, Epoch Time (s): 0.09, Total Time (hrs): 0.0968
# ====> Epoch: 3596 Train ELBO: -100.1998 Val ELBO: -154.7838, Epoch Time (s): 0.17, Total Time (hrs): 0.0968
# ====> Epoch: 3597 Train ELBO: -94.4711 Val ELBO: -151.1482, Epoch Time (s): 0.14, Total Time (hrs): 0.0968
# ====> Epoch: 3598 Train ELBO: -92.5279 Val ELBO: -150.2327, Epoch Time (s): 0.16, Total Time (hrs): 0.0969
# ====> Epoch: 3599 Train ELBO: -96.9243 Val ELBO: -170.0597, Epoch Time (s): 0.14, Total Time (hrs): 0.0969
# ====> Epoch: 3600 Train ELBO: -97.2634 Val ELBO: -156.3794, Epoch Time (s): 0.14, Total Time (hrs): 0.0970
# ====> Epoch: 3601 Train ELBO: -93.9066 Val ELBO: -159.8443, Epoch Time (s): 0.16, Total Time (hrs): 0.0970
# ====> Epoch: 3602 Train ELBO: -96.1717 Val ELBO: -147.9324, Epoch Time (s): 0.24, Total Time (hrs): 0.0971
# ====> Epoch: 3603 Train ELBO: -96.6250 Val ELBO: -161.3696, Epoch Time (s): 0.29, Total Time (hrs): 0.0972
# ====> Epoch: 3604 Train ELBO: -108.3738 Val ELBO: -193.7984, Epoch Time (s): 0.31, Total Time (hrs): 0.0972
# ====> Epoch: 3605 Train ELBO: -127.2016 Val ELBO: -268.5858, Epoch Time (s): 0.28, Total Time (hrs): 0.0973
# ====> Epoch: 3606 Train ELBO: -151.6168 Val ELBO: -156.6060, Epoch Time (s): 0.49, Total Time (hrs): 0.0975
# ====> Epoch: 3607 Train ELBO: -111.7567 Val ELBO: -204.8978, Epoch Time (s): 0.50, Total Time (hrs): 0.0976
# ====> Epoch: 3608 Train ELBO: -130.1486 Val ELBO: -210.3017, Epoch Time (s): 0.42, Total Time (hrs): 0.0977
# ====> Epoch: 3609 Train ELBO: -121.6581 Val ELBO: -178.0472, Epoch Time (s): 0.34, Total Time (hrs): 0.0978
# ====> Epoch: 3610 Train ELBO: -128.6556 Val ELBO: -162.4180, Epoch Time (s): 0.27, Total Time (hrs): 0.0979
# ====> Epoch: 3611 Train ELBO: -114.9468 Val ELBO: -173.5258, Epoch Time (s): 0.39, Total Time (hrs): 0.0980
# ====> Epoch: 3612 Train ELBO: -115.8428 Val ELBO: -169.5464, Epoch Time (s): 0.35, Total Time (hrs): 0.0981
# ====> Epoch: 3613 Train ELBO: -110.8655 Val ELBO: -168.9092, Epoch Time (s): 0.35, Total Time (hrs): 0.0982
# ====> Epoch: 3614 Train ELBO: -118.7329 Val ELBO: -168.5489, Epoch Time (s): 0.30, Total Time (hrs): 0.0983
# ====> Epoch: 3615 Train ELBO: -109.6853 Val ELBO: -201.8502, Epoch Time (s): 0.32, Total Time (hrs): 0.0984
# ====> Epoch: 3616 Train ELBO: -119.1498 Val ELBO: -168.9035, Epoch Time (s): 0.31, Total Time (hrs): 0.0985
# ====> Epoch: 3617 Train ELBO: -120.0032 Val ELBO: -232.6983, Epoch Time (s): 0.29, Total Time (hrs): 0.0985
# ====> Epoch: 3618 Train ELBO: -139.8903 Val ELBO: -211.3672, Epoch Time (s): 0.28, Total Time (hrs): 0.0986
# ====> Epoch: 3619 Train ELBO: -133.6294 Val ELBO: -177.9752, Epoch Time (s): 0.13, Total Time (hrs): 0.0987
# ====> Epoch: 3620 Train ELBO: -123.2194 Val ELBO: -157.8912, Epoch Time (s): 0.15, Total Time (hrs): 0.0987
# ====> Epoch: 3621 Train ELBO: -113.1793 Val ELBO: -181.8418, Epoch Time (s): 0.18, Total Time (hrs): 0.0987
# ====> Epoch: 3622 Train ELBO: -110.8092 Val ELBO: -180.0032, Epoch Time (s): 0.18, Total Time (hrs): 0.0988
# ====> Epoch: 3623 Train ELBO: -111.1487 Val ELBO: -164.0686, Epoch Time (s): 0.23, Total Time (hrs): 0.0989
# ====> Epoch: 3624 Train ELBO: -107.4335 Val ELBO: -178.9093, Epoch Time (s): 0.23, Total Time (hrs): 0.0989
# ====> Epoch: 3625 Train ELBO: -106.6510 Val ELBO: -166.1309, Epoch Time (s): 0.22, Total Time (hrs): 0.0990
# ====> Epoch: 3626 Train ELBO: -113.9514 Val ELBO: -193.9973, Epoch Time (s): 0.17, Total Time (hrs): 0.0990
# ====> Epoch: 3627 Train ELBO: -113.8392 Val ELBO: -197.7833, Epoch Time (s): 0.20, Total Time (hrs): 0.0991
# ====> Epoch: 3628 Train ELBO: -137.8583 Val ELBO: -182.5362, Epoch Time (s): 0.15, Total Time (hrs): 0.0991
# ====> Epoch: 3629 Train ELBO: -112.9727 Val ELBO: -179.8281, Epoch Time (s): 0.18, Total Time (hrs): 0.0992
# ====> Epoch: 3630 Train ELBO: -105.2626 Val ELBO: -169.3672, Epoch Time (s): 0.09, Total Time (hrs): 0.0992
# ====> Epoch: 3631 Train ELBO: -98.5787 Val ELBO: -164.6407, Epoch Time (s): 0.07, Total Time (hrs): 0.0992
# ====> Epoch: 3632 Train ELBO: -102.9277 Val ELBO: -160.6985, Epoch Time (s): 0.08, Total Time (hrs): 0.0992
# ====> Epoch: 3633 Train ELBO: -106.5510 Val ELBO: -200.2518, Epoch Time (s): 0.12, Total Time (hrs): 0.0993
# ====> Epoch: 3634 Train ELBO: -114.4680 Val ELBO: -182.3189, Epoch Time (s): 0.15, Total Time (hrs): 0.0993
# ====> Epoch: 3635 Train ELBO: -193.9391 Val ELBO: -447.8894, Epoch Time (s): 0.07, Total Time (hrs): 0.0993
# ====> Epoch: 3636 Train ELBO: -312.2593 Val ELBO: -424.9086, Epoch Time (s): 0.07, Total Time (hrs): 0.0994
# ====> Epoch: 3637 Train ELBO: -248.6944 Val ELBO: -190.7477, Epoch Time (s): 0.12, Total Time (hrs): 0.0994
# ====> Epoch: 3638 Train ELBO: -170.8228 Val ELBO: -280.1782, Epoch Time (s): 0.20, Total Time (hrs): 0.0995
# ====> Epoch: 3639 Train ELBO: -157.6686 Val ELBO: -175.1972, Epoch Time (s): 0.21, Total Time (hrs): 0.0995
# ====> Epoch: 3640 Train ELBO: -139.1203 Val ELBO: -208.8563, Epoch Time (s): 0.17, Total Time (hrs): 0.0996
# ====> Epoch: 3641 Train ELBO: -140.4684 Val ELBO: -189.7857, Epoch Time (s): 0.19, Total Time (hrs): 0.0996
# ====> Epoch: 3642 Train ELBO: -128.5548 Val ELBO: -199.2022, Epoch Time (s): 0.18, Total Time (hrs): 0.0997
# ====> Epoch: 3643 Train ELBO: -129.4475 Val ELBO: -208.8079, Epoch Time (s): 0.39, Total Time (hrs): 0.0998
# ====> Epoch: 3644 Train ELBO: -123.4713 Val ELBO: -176.9567, Epoch Time (s): 0.19, Total Time (hrs): 0.0998
# ====> Epoch: 3645 Train ELBO: -115.3871 Val ELBO: -204.9033, Epoch Time (s): 0.20, Total Time (hrs): 0.0999
# ====> Epoch: 3646 Train ELBO: -110.6327 Val ELBO: -174.5521, Epoch Time (s): 0.14, Total Time (hrs): 0.0999
# ====> Epoch: 3647 Train ELBO: -113.2468 Val ELBO: -168.5683, Epoch Time (s): 0.20, Total Time (hrs): 0.1000
# ====> Epoch: 3648 Train ELBO: -110.7854 Val ELBO: -161.3773, Epoch Time (s): 0.15, Total Time (hrs): 0.1000
# ====> Epoch: 3649 Train ELBO: -98.0952 Val ELBO: -164.2620, Epoch Time (s): 0.17, Total Time (hrs): 0.1001
# ====> Epoch: 3650 Train ELBO: -93.9146 Val ELBO: -162.4859, Epoch Time (s): 0.33, Total Time (hrs): 0.1002
# ====> Epoch: 3651 Train ELBO: -98.9907 Val ELBO: -156.9667, Epoch Time (s): 0.16, Total Time (hrs): 0.1002
# ====> Epoch: 3652 Train ELBO: -98.2530 Val ELBO: -208.0744, Epoch Time (s): 0.08, Total Time (hrs): 0.1002
# ====> Epoch: 3653 Train ELBO: -107.5211 Val ELBO: -169.5240, Epoch Time (s): 0.07, Total Time (hrs): 0.1002
# ====> Epoch: 3654 Train ELBO: -111.0870 Val ELBO: -158.7661, Epoch Time (s): 0.07, Total Time (hrs): 0.1003
# ====> Epoch: 3655 Train ELBO: -101.8033 Val ELBO: -158.1095, Epoch Time (s): 0.08, Total Time (hrs): 0.1003
# ====> Epoch: 3656 Train ELBO: -100.3934 Val ELBO: -169.1634, Epoch Time (s): 0.07, Total Time (hrs): 0.1003
# ====> Epoch: 3657 Train ELBO: -109.0139 Val ELBO: -208.4227, Epoch Time (s): 0.07, Total Time (hrs): 0.1003
# ====> Epoch: 3658 Train ELBO: -118.8954 Val ELBO: -166.9196, Epoch Time (s): 0.09, Total Time (hrs): 0.1003
# ====> Epoch: 3659 Train ELBO: -108.0298 Val ELBO: -164.3890, Epoch Time (s): 0.10, Total Time (hrs): 0.1004
# ====> Epoch: 3660 Train ELBO: -107.1741 Val ELBO: -160.9181, Epoch Time (s): 0.07, Total Time (hrs): 0.1004
# ====> Epoch: 3661 Train ELBO: -106.3158 Val ELBO: -155.3434, Epoch Time (s): 0.08, Total Time (hrs): 0.1004
# ====> Epoch: 3662 Train ELBO: -102.9343 Val ELBO: -155.3315, Epoch Time (s): 0.08, Total Time (hrs): 0.1004
# ====> Epoch: 3663 Train ELBO: -101.2439 Val ELBO: -158.1851, Epoch Time (s): 0.07, Total Time (hrs): 0.1005
# ====> Epoch: 3664 Train ELBO: -97.6738 Val ELBO: -163.4890, Epoch Time (s): 0.08, Total Time (hrs): 0.1005
# ====> Epoch: 3665 Train ELBO: -97.9881 Val ELBO: -162.0567, Epoch Time (s): 0.07, Total Time (hrs): 0.1005
# ====> Epoch: 3666 Train ELBO: -96.0831 Val ELBO: -155.7311, Epoch Time (s): 0.07, Total Time (hrs): 0.1005
# ====> Epoch: 3667 Train ELBO: -94.3028 Val ELBO: -169.7604, Epoch Time (s): 0.08, Total Time (hrs): 0.1005
# ====> Epoch: 3668 Train ELBO: -104.3945 Val ELBO: -153.4866, Epoch Time (s): 0.07, Total Time (hrs): 0.1006
# ====> Epoch: 3669 Train ELBO: -100.6438 Val ELBO: -182.9165, Epoch Time (s): 0.07, Total Time (hrs): 0.1006
# ====> Epoch: 3670 Train ELBO: -105.0256 Val ELBO: -189.2342, Epoch Time (s): 0.08, Total Time (hrs): 0.1006
# ====> Epoch: 3671 Train ELBO: -109.8349 Val ELBO: -173.3152, Epoch Time (s): 0.07, Total Time (hrs): 0.1006
# ====> Epoch: 3672 Train ELBO: -100.8013 Val ELBO: -160.6359, Epoch Time (s): 0.07, Total Time (hrs): 0.1006
# ====> Epoch: 3673 Train ELBO: -98.0432 Val ELBO: -177.2631, Epoch Time (s): 0.09, Total Time (hrs): 0.1007
# ====> Epoch: 3674 Train ELBO: -95.7144 Val ELBO: -164.5827, Epoch Time (s): 0.07, Total Time (hrs): 0.1007
# ====> Epoch: 3675 Train ELBO: -99.8303 Val ELBO: -166.2054, Epoch Time (s): 0.08, Total Time (hrs): 0.1007
# ====> Epoch: 3676 Train ELBO: -97.1707 Val ELBO: -147.1604, Epoch Time (s): 0.08, Total Time (hrs): 0.1007
# ====> Epoch: 3677 Train ELBO: -96.2943 Val ELBO: -157.9837, Epoch Time (s): 0.07, Total Time (hrs): 0.1008
# ====> Epoch: 3678 Train ELBO: -97.9741 Val ELBO: -155.6110, Epoch Time (s): 0.07, Total Time (hrs): 0.1008
# ====> Epoch: 3679 Train ELBO: -96.8378 Val ELBO: -157.2331, Epoch Time (s): 0.08, Total Time (hrs): 0.1008
# ====> Epoch: 3680 Train ELBO: -96.9234 Val ELBO: -152.0573, Epoch Time (s): 0.07, Total Time (hrs): 0.1008
# ====> Epoch: 3681 Train ELBO: -93.7685 Val ELBO: -151.2659, Epoch Time (s): 0.07, Total Time (hrs): 0.1008
# ====> Epoch: 3682 Train ELBO: -93.4444 Val ELBO: -147.6018, Epoch Time (s): 0.08, Total Time (hrs): 0.1009
# ====> Epoch: 3683 Train ELBO: -96.2867 Val ELBO: -157.8977, Epoch Time (s): 0.07, Total Time (hrs): 0.1009
# ====> Epoch: 3684 Train ELBO: -102.4193 Val ELBO: -170.3253, Epoch Time (s): 0.07, Total Time (hrs): 0.1009
# ====> Epoch: 3685 Train ELBO: -111.1026 Val ELBO: -160.4933, Epoch Time (s): 0.08, Total Time (hrs): 0.1009
# ====> Epoch: 3686 Train ELBO: -100.1044 Val ELBO: -173.3928, Epoch Time (s): 0.09, Total Time (hrs): 0.1009
# ====> Epoch: 3687 Train ELBO: -99.7170 Val ELBO: -170.9231, Epoch Time (s): 0.07, Total Time (hrs): 0.1010
# ====> Epoch: 3688 Train ELBO: -102.6474 Val ELBO: -178.5547, Epoch Time (s): 0.09, Total Time (hrs): 0.1010
# ====> Epoch: 3689 Train ELBO: -99.8513 Val ELBO: -170.0660, Epoch Time (s): 0.07, Total Time (hrs): 0.1010
# ====> Epoch: 3690 Train ELBO: -97.0911 Val ELBO: -158.6237, Epoch Time (s): 0.07, Total Time (hrs): 0.1010
# ====> Epoch: 3691 Train ELBO: -97.9122 Val ELBO: -164.4372, Epoch Time (s): 0.08, Total Time (hrs): 0.1010
# ====> Epoch: 3692 Train ELBO: -100.6443 Val ELBO: -165.1415, Epoch Time (s): 0.08, Total Time (hrs): 0.1011
# ====> Epoch: 3693 Train ELBO: -97.0669 Val ELBO: -160.3579, Epoch Time (s): 0.07, Total Time (hrs): 0.1011
# ====> Epoch: 3694 Train ELBO: -99.0809 Val ELBO: -168.9274, Epoch Time (s): 0.08, Total Time (hrs): 0.1011
# ====> Epoch: 3695 Train ELBO: -100.4776 Val ELBO: -163.4878, Epoch Time (s): 0.07, Total Time (hrs): 0.1011
# ====> Epoch: 3696 Train ELBO: -101.2710 Val ELBO: -145.4247, Epoch Time (s): 0.07, Total Time (hrs): 0.1011
# ====> Epoch: 3697 Train ELBO: -97.6692 Val ELBO: -162.3509, Epoch Time (s): 0.08, Total Time (hrs): 0.1012
# ====> Epoch: 3698 Train ELBO: -94.8710 Val ELBO: -159.0668, Epoch Time (s): 0.07, Total Time (hrs): 0.1012
# ====> Epoch: 3699 Train ELBO: -95.3823 Val ELBO: -155.4250, Epoch Time (s): 0.08, Total Time (hrs): 0.1012
# ====> Epoch: 3700 Train ELBO: -99.7917 Val ELBO: -162.0254, Epoch Time (s): 0.09, Total Time (hrs): 0.1012
# ====> Epoch: 3701 Train ELBO: -104.3115 Val ELBO: -187.2474, Epoch Time (s): 0.07, Total Time (hrs): 0.1013
# ====> Epoch: 3702 Train ELBO: -139.0664 Val ELBO: -376.9411, Epoch Time (s): 0.07, Total Time (hrs): 0.1013
# ====> Epoch: 3703 Train ELBO: -214.5782 Val ELBO: -382.7776, Epoch Time (s): 0.07, Total Time (hrs): 0.1013
# ====> Epoch: 3704 Train ELBO: -210.8250 Val ELBO: -210.8182, Epoch Time (s): 0.08, Total Time (hrs): 0.1013
# ====> Epoch: 3705 Train ELBO: -169.6810 Val ELBO: -216.5240, Epoch Time (s): 0.07, Total Time (hrs): 0.1013
# ====> Epoch: 3706 Train ELBO: -159.5880 Val ELBO: -223.5921, Epoch Time (s): 0.08, Total Time (hrs): 0.1014
# ====> Epoch: 3707 Train ELBO: -127.2237 Val ELBO: -168.5979, Epoch Time (s): 0.07, Total Time (hrs): 0.1014
# ====> Epoch: 3708 Train ELBO: -134.9218 Val ELBO: -245.4872, Epoch Time (s): 0.11, Total Time (hrs): 0.1014
# ====> Epoch: 3709 Train ELBO: -145.1419 Val ELBO: -199.3147, Epoch Time (s): 0.12, Total Time (hrs): 0.1015
# ====> Epoch: 3710 Train ELBO: -140.0059 Val ELBO: -206.6819, Epoch Time (s): 0.10, Total Time (hrs): 0.1015
# ====> Epoch: 3711 Train ELBO: -129.5512 Val ELBO: -205.5020, Epoch Time (s): 0.11, Total Time (hrs): 0.1015
# ====> Epoch: 3712 Train ELBO: -118.7363 Val ELBO: -165.2585, Epoch Time (s): 0.12, Total Time (hrs): 0.1015
# ====> Epoch: 3713 Train ELBO: -106.1447 Val ELBO: -156.2008, Epoch Time (s): 0.11, Total Time (hrs): 0.1016
# ====> Epoch: 3714 Train ELBO: -107.4613 Val ELBO: -163.8712, Epoch Time (s): 0.11, Total Time (hrs): 0.1016
# ====> Epoch: 3715 Train ELBO: -106.1577 Val ELBO: -164.0646, Epoch Time (s): 0.10, Total Time (hrs): 0.1016
# ====> Epoch: 3716 Train ELBO: -107.7477 Val ELBO: -180.1102, Epoch Time (s): 0.10, Total Time (hrs): 0.1017
# ====> Epoch: 3717 Train ELBO: -108.6184 Val ELBO: -164.6195, Epoch Time (s): 0.10, Total Time (hrs): 0.1017
# ====> Epoch: 3718 Train ELBO: -94.5295 Val ELBO: -170.2308, Epoch Time (s): 0.10, Total Time (hrs): 0.1017
# ====> Epoch: 3719 Train ELBO: -101.0784 Val ELBO: -165.3050, Epoch Time (s): 0.10, Total Time (hrs): 0.1017
# ====> Epoch: 3720 Train ELBO: -110.0762 Val ELBO: -167.6719, Epoch Time (s): 0.10, Total Time (hrs): 0.1018
# ====> Epoch: 3721 Train ELBO: -103.5369 Val ELBO: -172.4504, Epoch Time (s): 0.10, Total Time (hrs): 0.1018
# ====> Epoch: 3722 Train ELBO: -105.4975 Val ELBO: -185.2687, Epoch Time (s): 0.11, Total Time (hrs): 0.1018
# ====> Epoch: 3723 Train ELBO: -142.3246 Val ELBO: -185.3854, Epoch Time (s): 0.12, Total Time (hrs): 0.1019
# ====> Epoch: 3724 Train ELBO: -157.6112 Val ELBO: -236.6025, Epoch Time (s): 0.11, Total Time (hrs): 0.1019
# ====> Epoch: 3725 Train ELBO: -164.4973 Val ELBO: -289.0330, Epoch Time (s): 0.11, Total Time (hrs): 0.1019
# ====> Epoch: 3726 Train ELBO: -244.7738 Val ELBO: -409.3372, Epoch Time (s): 0.10, Total Time (hrs): 0.1020
# ====> Epoch: 3727 Train ELBO: -221.1746 Val ELBO: -303.1726, Epoch Time (s): 0.10, Total Time (hrs): 0.1020
# ====> Epoch: 3728 Train ELBO: -183.4793 Val ELBO: -269.8420, Epoch Time (s): 0.10, Total Time (hrs): 0.1020
# ====> Epoch: 3729 Train ELBO: -139.5964 Val ELBO: -187.2463, Epoch Time (s): 0.11, Total Time (hrs): 0.1020
# ====> Epoch: 3730 Train ELBO: -131.6075 Val ELBO: -191.4887, Epoch Time (s): 0.10, Total Time (hrs): 0.1021
# ====> Epoch: 3731 Train ELBO: -125.9783 Val ELBO: -168.3079, Epoch Time (s): 0.10, Total Time (hrs): 0.1021
