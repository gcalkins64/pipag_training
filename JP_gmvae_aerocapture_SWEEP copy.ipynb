# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.9.0+cu128)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.3)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (26.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.5.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 22.3 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 69.5 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.2 pytorch_lightning-2.6.1 torchmetrics-1.8.2

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/pipag_training.git
# Out:
# Cloning into 'pipag_training'...
# remote: Enumerating objects: 334, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 334 (delta 81), reused 76 (delta 35), pack-reused 184 (from 1)
# Receiving objects: 100% (334/334), 11.81 MiB | 16.45 MiB/s, done.
# Resolving deltas: 100% (170/170), done.

# %%
# %cd pipag_training
# !cd /content/pipag_training && git pull
# !git pull
sys.path.append('/content/pipag_training')
# Out:
# /content/pipag_training
# Already up to date.

# %%
# !ls
# Out:
#  compare_classification_accuracy.py     models.py
#  compare_variance_gmvae.py	        move_figures_to_LB.py
#  generate_gif_from_pngs.py	       'old notebooks'
#  generate_training_json.py	        README.md
#  gmvae_common.py		        svd.py
#  JP_gmvae_aerocapture_BASE_copy.ipynb   test_git_imports.ipynb
#  JP_gmvae_aerocapture_BASE.ipynb        vae_aerocapture_vel.py
#  JP_gmvae_aerocapture_energy.ipynb      VAE_Capture.ipynb
#  JP_gmvae_aerocapture_SWEEP.ipynb       VAE_sweep_arch.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1275: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
# n_train = 1024
# n_val = 128
# n_test = 128
# For testing small batches of data
n_train = 800
n_val = 100
n_test = 100
# THREE LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = 24
hd1 = 30
hd2 = 20
hd3 = 10
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = None
# hidden_dims = [hd1, hd2]

latent_dims = [5,6,7]
n_clustersS = [5,6]
skip_combos = []
lr = 1e-3
n_epochs = 10_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

plot_interval = 500
dpi = 300

D = 1  #num_modalities
# downsampleNum = 64
downsampleNum = 36 # Revision

loadFlag = False  # True to load in old case, False to run a new case

# data = '1_near_escape_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_fnpag_1999_inds_energy_scaled_downsampled_'
# tag = 'near_escape'

# data = '1_near_crash_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_crash_fnpag_2000_inds_energy_scaled_downsampled_'
# tag = 'near_crash'

# data = 'UOP_inc_lit_disps_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_inc_lit_disps_4999_inds_energy_scaled_downsampled_'
# tag = 'near_escape_OLD'

# data = 'UOP_near_crash_steeper_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_near_crash_steeper_4997_inds_energy_scaled_downsampled_'
# tag = 'near_crash_OLD'

# data = '1_near_escape_new_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_new_2000_inds_energy_scaled_downsampled_'
# tag = 'near_escape_new'

# data = 'rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_'
# inds = 'rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_'
# tag = 'rev_gu_mixture'
# dataName = 'velocity_fpa'

data = 'rev_gumixture_1000_data_energy_scaled_downsampled_'
inds = 'rev_gumixture_1000_inds_energy_scaled_downsampled_'
tag = 'rev_gu_mixture_energy'
dataName = 'energy'

# %%
# !ls /content/drive/MyDrive/rev_pipag_data/
# Out:
# rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_.json
# rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_.json

# %% [markdown]
# # LOOP GMVAE TRAINING

# %%
for latent_dim in latent_dims:
   for n_clusters in n_clustersS:
      if [latent_dim, n_clusters] in skip_combos:
        continue
      else:
          K = n_clusters
          Z = latent_dim

          from datetime import datetime
          timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

          if loadFlag:  # Load in old data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", 'gmvae_em_aerocapture_energy_20250429_155508_5_4')
          else:  # generate new data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters))
          os.makedirs(dirname, exist_ok=True)
          print("Filepath directory: " + dirname)

          if loadFlag:  # load old data
              postfix = '_42_1024_128_128_32_16_5_4_0.001000_128_0.001000_0.000010_1000.000000_'
          else:  # Generate new suffix
              if hd3 is not None:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
              else:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
          print("Filepath postfix: " + postfix)

          data_dir = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{data}.json")

          with open(os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{inds}.json"), 'r') as f:
              sample_list_load = json.load(f)
          sample_list = [int(sample) for sample in sample_list_load['sample_list']]
          print(sample_list)

          data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                          train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                          num_workers=0, dataName=dataName)

          data_module.setup("fit", sample_list = sample_list)

          train_loader = data_module.train_dataloader()
          val_loader = data_module.val_dataloader()
          test_loader = data_module.test_dataloader()
          data_dim = len(train_loader.dataset[0][0])
          text_labels = ['capture', 'escape', 'impact']
          label_colors = ['C2', 'C3', 'C4']

          num_train_batches = len(train_loader)

          ts_plot = np.linspace(0,450,36)
          seabornSettings()
          fig, ax = plt.subplots(figsize=(4, 4))
          for j in range(n_train):
              ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.75)

          eline = mlines.Line2D([], [], color='C2', label='Escape')
          cline = mlines.Line2D([], [], color='C3', label='Capture')
          iline = mlines.Line2D([], [], color='C4', label='Impact')
          plt.legend(handles=[eline, cline, iline])
          plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
          plt.xlabel("Time [s]")
          plt.ylabel("Nondimensionalized Energy")
          plt.title("Training Data")
          plt.tight_layout()
          fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_val):
              ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()])
          plt.title("Validation Data")
          fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_test):
              ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()])
          plt.title("Test Data")
          fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)
          # initialize latent GMM model parameters
          params = {}
          pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
          params['pi_c'] = torch.ones(K) / K
          params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
          params['logsigmasq_c'] = torch.zeros((K, Z))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]

          # initialize neural networks
          encoder_list = []
          decoder_list = []
          trainable_parameters = []
          trainable_parameters.append(pi_variables)

          for _ in range(D):
              encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
              decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
              encoder_list.append(encoder)
              decoder_list.append(decoder)
              trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

          optimizer = optim.Adam(trainable_parameters, lr=lr)

          # training

          import time
          ts = time.time()
          tic = time.perf_counter()

          train_loss = torch.zeros(n_epochs)
          train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_loss = torch.zeros(n_epochs)
          pi_history = torch.zeros((n_epochs, K))
          train_mse_history = torch.zeros(n_epochs)
          val_mse_history = torch.zeros(n_epochs)
          min_val_loss = torch.inf
          seabornSettings()

          for epoch in range(n_epochs):
              ti = time.time()
              for encoder in encoder_list:
                  encoder.train()
              for decoder in decoder_list:
                  decoder.train()

              train_elbo = 0
              train_mse = 0
              train_elbo_term = np.zeros(4)
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

              for (batch_idx, batch) in enumerate(train_loader):
                  batch_x, _ = batch
                  x_list = [batch_x]  # assume D=2 and each modality has data_dim
                  optimizer.zero_grad()
                  pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
                  params['pi_c'] = pi_c

                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma

                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                  train_elbo += elbo.item()
                  train_elbo_term += elbo_terms
                  train_mse += sse.item()
                  loss = - elbo / batch_x.shape[0]
                  loss.backward()
                  optimizer.step()

              for encoder in encoder_list:
                  encoder.eval()
              for decoder in decoder_list:
                  decoder.eval()

              if epoch % plot_interval == 0 or epoch == n_epochs:
                  # Plot the first two dimensions of the latents
                  with torch.no_grad():
                      means = []
                      samples = []
                      labels = []
                      for batch in train_loader:
                          batch_x, batch_label = batch
                          x_list = [batch_x]
                          mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                          sigma = torch.exp(0.5 * logsigmasq)
                          eps = Normal(0, 1).sample(mean.shape)
                          z = mean + eps * sigma
                          means.append(mean)
                          samples.append(z)
                          labels.append(batch_label)

                  means = torch.vstack(means).cpu()
                  samples = torch.vstack(samples).cpu()
                  labels = torch.hstack(labels).cpu()

                  savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

                  savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


                  # plot samples from generative model
                  n_gen = n_train
                  cluster_probs = params['pi_c'].cpu().detach().numpy() #
                  fig, ax = plt.subplots(figsize=(4.5, 4))
                  for j in range(n_gen):
                      c = np.random.choice(K, p=cluster_probs)
                      mu_c = params['mu_c'][c].clone().detach()
                      sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
                      z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
                      mu_x = decoder.forward(z)[0]
                      ax.plot(mu_x.cpu().detach().numpy())
                  fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
                  plt.close()


              val_elbo = 0
              val_mse = 0
              val_elbo_term = np.zeros(4)
              with torch.no_grad():
                  for (batch_idx, batch) in enumerate(val_loader):
                      batch_x, _ = batch
                      x_list = [batch_x]
                      mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                      sigma = torch.exp(0.5 * logsigmasq)
                      eps = Normal(0, 1).sample(mu.shape)
                      z = mu + eps * sigma
                      with torch.no_grad():
                          gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
                      elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                      val_elbo += elbo.item()
                      val_mse += sse.item()
                      val_elbo_term += elbo_items

              train_elbo /= len(train_loader.dataset)
              train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
              val_elbo /= len(val_loader.dataset)
              val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
              train_mse /= len(train_loader.dataset)
              val_mse /= len(val_loader.dataset)

              tf = time.time()
              toc = time.perf_counter()
              print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

              train_loss[epoch] = - train_elbo
              val_loss[epoch] = - val_elbo
              train_elbo_terms[epoch,:] = - train_elbo_term
              val_elbo_terms[epoch,:] = - val_elbo_term
              pi_history[epoch] = params['pi_c']
              train_mse_history[epoch] = train_mse
              val_mse_history[epoch] = val_mse

              if - val_elbo < min_val_loss:
                  min_val_loss = - val_elbo
                  torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
                  torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
                  torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
                  torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
                  torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

              if epoch % plot_interval == 0 or epoch == n_epochs:
                # Plot the training and validation loss vs. epoch number
                plt.figure(figsize=(4.5, 4))
                # const = min(min(train_loss), min(val_loss))
                train_loss_adjusted = train_loss
                val_loss_adjusted = val_loss
                plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
                # print(train_loss_adjusted.cpu()[:epoch])
                plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
                plt.yscale('symlog')
                plt.xlabel("number of epochs")
                plt.ylabel("loss")
                plt.title("Negative Loss")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot each term of the training loss and validation loss
                plt.figure(figsize=(4.5, 4))
                labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
                for ii in range(4):
                    train_loss_adjusted = train_elbo_terms[:epoch, ii]
                    val_loss_adjusted = val_elbo_terms[:epoch, ii]
                    plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
                    plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
                plt.xlabel("number of epochs")
                plt.yscale('symlog')
                plt.ylabel("loss")
                plt.title("Negative Loss Terms")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the training and validation mse vs. epoch number
                plt.figure(figsize=(4.5, 4))
                plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
                plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the history of pi
                plt.figure(figsize=(4.5, 4))
                for i in range(K):
                    plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()


          te = time.time()
          import datetime
          duration = datetime.timedelta(seconds=te - ts)
          print("Training took ", duration)

          # Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
          torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))

          if loadFlag:
            path = dirname
            epoch = n_epochs - 1
          params = {}
          encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
          decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")

          # Use if you need to load in the data
          if loadFlag:
            suffix = postfix
            encoder.load_state_dict(torch.load(os.path.join(path, f'encoder_{suffix}.pt'),map_location=torch.device('cpu')))
            decoder.load_state_dict(torch.load(os.path.join(path, f'decoder_{suffix}.pt'),map_location=torch.device('cpu')))
            logsigmasq = torch.load(os.path.join(path, f'gmm_params_logsigmasq_{suffix}.pt'),map_location=torch.device('cpu'))
            mu = torch.load(os.path.join(path, f'gmm_params_mu_{suffix}.pt'),map_location=torch.device('cpu'))
            pi = torch.load(os.path.join(path, f'gmm_params_pi_{suffix}.pt'),map_location=torch.device('cpu'))

          encoder_list = [encoder]
          decoder_list = [decoder]

          device = next(encoder.parameters()).device
          # Load in training history metrics
          pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]
          data_colors = label_colors

          # Plot training history
          # Plot the training and validation loss vs. epoch number
          plt.figure(figsize=(4, 4))
          const = min(min(train_loss), min(val_loss))
          # const = min(10, const)
          train_loss_adjusted = train_loss
          val_loss_adjusted = val_loss
          plt.plot(train_loss_adjusted.cpu(), label='Training')
          plt.plot(val_loss_adjusted.cpu(), label='Validation')
          plt.xlabel("Number of Epochs")
          plt.ylabel("Negative Loss")
          # plt.title("Negative Loss")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
          for ii in range(4):
              # print(train_elbo_terms.cpu()[ii, :epoch])
              # print(len(train_elbo_terms.cpu()[ii, :epoch]))
              train_loss_adjusted = train_elbo_terms[:, ii]
              val_loss_adjusted = val_elbo_terms[:, ii]
              plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
              plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Negative Loss Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot the sum of each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          # print(train_elbo_terms.cpu()[ii, :epoch])
          # print(len(train_elbo_terms.cpu()[ii, :epoch]))
          train_loss_adjusted = train_elbo_terms.sum(axis=1)
          val_loss_adjusted = val_elbo_terms.sum(axis=1)
          plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
          plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Sum of ELBO Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the training and validation mse vs. epoch number
          plt.figure(figsize=(4.5, 4))
          plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
          plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
          plt.xlabel("number of epochs")
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the history of pi
          plt.figure(figsize=(4, 4))
          for i in range(K):
              plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
          plt.xlabel("Number of Epochs")
          plt.ylabel("Predicted Cluster Probability")
          plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
          plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Load best model saved
          params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
          params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
          params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
          encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
          decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

          encoder.eval()
          decoder.eval()

          # run one last EM step and plot training data in latent space
          for encoder in encoder_list:
              encoder.eval()

          with torch.no_grad():
              means = []
              samples = []
              labels = []
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
              for batch in train_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma
                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  means.append(mu)
                  samples.append(z)
                  labels.append(batch_label)

          means = torch.vstack(means).cpu()
          samples = torch.vstack(samples).cpu()
          labels = torch.hstack(labels).cpu()


          savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
          plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
          plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot test data in latent space
          with torch.no_grad():
              test_means = []
              test_labels = []
              for batch in test_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mean, _ = encoder_step(x_list, encoder_list, decoder_list)
                  test_means.append(mean)
                  test_labels.append(batch_label)

          test_means = torch.vstack(test_means).cpu()
          test_labels = torch.hstack(test_labels).cpu()


          savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
          plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot decoding results from cluster means # todo: expand this function for multi-modal data
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for i in range(K):
              # with torch.no_grad:
              x_mean = decoder.forward(params['mu_c'][i])[0]
              ax.plot(x_mean.cpu().detach().numpy(), label=r"decoded $\mu$"+str(i+1))
          ax.legend()
          plt.title("Decoded Means")
          fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
          # plt.close()

          # plot samples from generative model
          n_gen = n_train
          cluster_probs = params['pi_c'].cpu().detach().numpy()
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_gen):
              c = np.random.choice(K, p=cluster_probs)
              # print(c)
              mu_c = params['mu_c'][c].cpu().clone().detach()
              sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
              z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
              # print(z)
              mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
              sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
              sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
              ax.plot(sample_x.cpu().detach().numpy())
          plt.title("Generated Samples")
          fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
          plt.close()

          # np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
              # train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
              # pi_history=pi_history.cpu().detach().numpy(),
              # cluster_probs=params['pi_c'].cpu().detach().numpy(),
              # cluster_means=params['mu_c'].cpu().detach().numpy(),
              # cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


          print("Training data size", n_train)
          print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
          print("Cluster 1 probability:", cluster_probs.min().item())
# Out:
# Filepath directory: /content/drive/MyDrive/rev_pipag_data/gmvae_rev_gu_mixture_20260216_184454_L5_C3
# Filepath postfix: _42_800_100_100_30_20_10_5_3_0.001000_128_0.001000_0.000010_10000.000000_
# [147, 67, 454, 345, 575, 998, 115, 715, 819, 179, 711, 59, 613, 267, 834, 403, 488, 335, 134, 752, 755, 706, 986, 448, 446, 472, 792, 657, 99, 34, 436, 311, 566, 165, 910, 526, 442, 627, 523, 383, 619, 26, 385, 414, 105, 648, 233, 924, 574, 463, 101, 336, 259, 87, 874, 63, 441, 997, 828, 374, 83, 680, 973, 161, 443, 555, 82, 912, 408, 60, 517, 164, 121, 237, 756, 864, 977, 758, 717, 770, 607, 201, 270, 502, 858, 873, 61, 876, 265, 224, 591, 462, 869, 338, 838, 171, 748, 141, 293, 870, 283, 75, 251, 163, 621, 392, 384, 365, 588, 158, 552, 380, 542, 148, 284, 468, 882, 954, 77, 599, 500, 195, 950, 275, 236, 149, 15, 501, 440, 618, 538, 367, 409, 754, 387, 394, 731, 143, 227, 1, 775, 865, 427, 800, 495, 316, 98, 30, 671, 660, 434, 106, 991, 716, 642, 893, 326, 587, 809, 103, 614, 276, 220, 493, 324, 791, 447, 138, 520, 883, 479, 96, 631, 286, 92, 386, 931, 139, 157, 687, 248, 830, 533, 445, 947, 582, 673, 508, 608, 420, 421, 871, 611, 363, 713, 53, 840, 373, 3, 518, 302, 304, 691, 690, 69, 80, 929, 166, 920, 86, 175, 564, 918, 457, 496, 84, 624, 371, 578, 698, 483, 928, 405, 880, 169, 963, 272, 937, 507, 902, 314, 966, 192, 185, 27, 177, 66, 16, 21, 985, 240, 203, 993, 595, 362, 342, 743, 572, 881, 269, 556, 890, 807, 232, 930, 215, 609, 176, 0, 903, 730, 992, 661, 287, 796, 22, 100, 19, 125, 759, 400, 708, 776, 649, 891, 318, 626, 952, 506, 972, 402, 296, 532, 258, 460, 44, 622, 757, 633, 585, 705, 4, 669, 503, 504, 976, 473, 650, 377, 959, 824, 803, 263, 79, 643, 477, 470, 866, 54, 540, 769, 509, 723, 898, 995, 511, 831, 629, 841, 216, 945, 8, 845, 999, 10, 728, 91, 590, 142, 562, 395, 469, 234, 410, 742, 339, 949, 12, 471, 93, 557, 519, 183, 486, 793, 299, 279, 548, 110, 925, 536, 568, 146, 481, 391, 922, 857, 703, 569, 480, 546, 850, 875, 900, 677, 668, 802, 108, 709, 51, 639, 784, 68, 489, 113, 764, 942, 38, 114, 815, 822, 242, 167, 450, 340, 379, 678, 48, 255, 740, 218, 795, 247, 497, 310, 193, 684, 226, 439, 407, 111, 726, 612, 777, 852, 967, 301, 638, 490, 368, 658, 55, 268, 941, 17, 238, 894, 964, 253, 494, 988, 404, 693, 72, 974, 71, 406, 589, 785, 219, 46, 18, 786, 352, 29, 990, 559, 119, 664, 74, 186, 547, 369, 637, 604, 206, 953, 593, 366, 199, 688, 151, 97, 905, 210, 295, 580, 666, 787, 603, 309, 573, 561, 5, 936, 485, 962, 904, 524, 859, 116, 354, 49, 592, 356, 40, 829, 724, 2, 358, 645, 475, 325, 927, 419, 958, 464, 132, 839, 944, 667, 746, 695, 417, 889, 459, 844, 343, 222, 212, 244, 529, 975, 266, 938, 596, 779, 563, 319, 444, 62, 689, 801, 432, 213, 381, 89, 376, 600, 541, 525, 799, 168, 208, 396, 955, 768, 109, 879, 586, 241, 823, 229, 749, 429, 721, 31, 85, 331, 766, 173, 915, 133, 553, 699, 885, 707, 872, 33, 422, 20, 281, 818, 901, 182, 416, 466, 198, 209, 260, 914, 911, 899, 970, 919, 813, 646, 181, 674, 47, 916, 853, 438, 65, 56, 623, 313, 156, 254, 282, 892, 189, 833, 670, 359, 933, 896, 58, 571, 360, 262, 274, 934, 867, 772, 763, 888, 152, 491, 665, 397, 117, 676, 510, 996, 433, 351, 736, 155, 923, 989, 346, 704, 662, 347, 249, 112, 581, 868, 672, 783, 333, 378, 971, 641, 694, 979, 264, 745, 683, 290, 430, 122, 300, 814, 602, 45, 969, 663, 452, 355, 73, 738, 565, 329, 211, 956, 289, 598, 712, 197, 228, 760, 372, 697, 294, 826, 652, 327, 961, 120, 70, 453, 288, 710, 610, 780, 804, 415, 848, 277, 714, 36, 527, 243, 832, 308, 425, 545, 235, 558, 887, 812, 634, 994, 344, 940, 375, 636, 535, 190, 482, 737, 278, 9, 245, 312, 256, 605, 136, 854, 348, 821, 965, 330, 257, 337, 733, 725, 458, 361, 104, 908, 261, 847, 252, 449, 987, 628, 943, 515, 681, 601, 539, 153, 751, 357, 851, 364, 842, 980, 382, 24, 150, 656, 543, 28, 654, 735, 413, 145, 451, 576, 788, 341, 322, 162, 37, 679, 349, 567, 204, 32, 126, 398, 78, 200, 789, 655, 188, 739, 560, 906, 307, 692, 797, 393, 130, 202, 700, 90, 635, 696, 981, 76, 118, 246, 250, 95, 617, 64, 750, 426, 514, 205, 390, 968, 630, 94, 616, 476, 837, 531, 632, 825, 935, 856, 424, 907, 194, 877, 516, 418, 57, 191, 570, 435, 808, 428, 675, 271, 620, 207, 39, 388, 321, 184, 370, 79 ...
# Loading File...
# ...File Loaded
# Sample List: [147, 67, 454, 345, 575, 998, 115, 715, 819, 179, 711, 59, 613, 267, 834, 403, 488, 335, 134, 752, 755, 706, 986, 448, 446, 472, 792, 657, 99, 34, 436, 311, 566, 165, 910, 526, 442, 627, 523, 383, 619, 26, 385, 414, 105, 648, 233, 924, 574, 463, 101, 336, 259, 87, 874, 63, 441, 997, 828, 374, 83, 680, 973, 161, 443, 555, 82, 912, 408, 60, 517, 164, 121, 237, 756, 864, 977, 758, 717, 770, 607, 201, 270, 502, 858, 873, 61, 876, 265, 224, 591, 462, 869, 338, 838, 171, 748, 141, 293, 870, 283, 75, 251, 163, 621, 392, 384, 365, 588, 158, 552, 380, 542, 148, 284, 468, 882, 954, 77, 599, 500, 195, 950, 275, 236, 149, 15, 501, 440, 618, 538, 367, 409, 754, 387, 394, 731, 143, 227, 1, 775, 865, 427, 800, 495, 316, 98, 30, 671, 660, 434, 106, 991, 716, 642, 893, 326, 587, 809, 103, 614, 276, 220, 493, 324, 791, 447, 138, 520, 883, 479, 96, 631, 286, 92, 386, 931, 139, 157, 687, 248, 830, 533, 445, 947, 582, 673, 508, 608, 420, 421, 871, 611, 363, 713, 53, 840, 373, 3, 518, 302, 304, 691, 690, 69, 80, 929, 166, 920, 86, 175, 564, 918, 457, 496, 84, 624, 371, 578, 698, 483, 928, 405, 880, 169, 963, 272, 937, 507, 902, 314, 966, 192, 185, 27, 177, 66, 16, 21, 985, 240, 203, 993, 595, 362, 342, 743, 572, 881, 269, 556, 890, 807, 232, 930, 215, 609, 176, 0, 903, 730, 992, 661, 287, 796, 22, 100, 19, 125, 759, 400, 708, 776, 649, 891, 318, 626, 952, 506, 972, 402, 296, 532, 258, 460, 44, 622, 757, 633, 585, 705, 4, 669, 503, 504, 976, 473, 650, 377, 959, 824, 803, 263, 79, 643, 477, 470, 866, 54, 540, 769, 509, 723, 898, 995, 511, 831, 629, 841, 216, 945, 8, 845, 999, 10, 728, 91, 590, 142, 562, 395, 469, 234, 410, 742, 339, 949, 12, 471, 93, 557, 519, 183, 486, 793, 299, 279, 548, 110, 925, 536, 568, 146, 481, 391, 922, 857, 703, 569, 480, 546, 850, 875, 900, 677, 668, 802, 108, 709, 51, 639, 784, 68, 489, 113, 764, 942, 38, 114, 815, 822, 242, 167, 450, 340, 379, 678, 48, 255, 740, 218, 795, 247, 497, 310, 193, 684, 226, 439, 407, 111, 726, 612, 777, 852, 967, 301, 638, 490, 368, 658, 55, 268, 941, 17, 238, 894, 964, 253, 494, 988, 404, 693, 72, 974, 71, 406, 589, 785, 219, 46, 18, 786, 352, 29, 990, 559, 119, 664, 74, 186, 547, 369, 637, 604, 206, 953, 593, 366, 199, 688, 151, 97, 905, 210, 295, 580, 666, 787, 603, 309, 573, 561, 5, 936, 485, 962, 904, 524, 859, 116, 354, 49, 592, 356, 40, 829, 724, 2, 358, 645, 475, 325, 927, 419, 958, 464, 132, 839, 944, 667, 746, 695, 417, 889, 459, 844, 343, 222, 212, 244, 529, 975, 266, 938, 596, 779, 563, 319, 444, 62, 689, 801, 432, 213, 381, 89, 376, 600, 541, 525, 799, 168, 208, 396, 955, 768, 109, 879, 586, 241, 823, 229, 749, 429, 721, 31, 85, 331, 766, 173, 915, 133, 553, 699, 885, 707, 872, 33, 422, 20, 281, 818, 901, 182, 416, 466, 198, 209, 260, 914, 911, 899, 970, 919, 813, 646, 181, 674, 47, 916, 853, 438, 65, 56, 623, 313, 156, 254, 282, 892, 189, 833, 670, 359, 933, 896, 58, 571, 360, 262, 274, 934, 867, 772, 763, 888, 152, 491, 665, 397, 117, 676, 510, 996, 433, 351, 736, 155, 923, 989, 346, 704, 662, 347, 249, 112, 581, 868, 672, 783, 333, 378, 971, 641, 694, 979, 264, 745, 683, 290, 430, 122, 300, 814, 602, 45, 969, 663, 452, 355, 73, 738, 565, 329, 211, 956, 289, 598, 712, 197, 228, 760, 372, 697, 294, 826, 652, 327, 961, 120, 70, 453, 288, 710, 610, 780, 804, 415, 848, 277, 714, 36, 527, 243, 832, 308, 425, 545, 235, 558, 887, 812, 634, 994, 344, 940, 375, 636, 535, 190, 482, 737, 278, 9, 245, 312, 256, 605, 136, 854, 348, 821, 965, 330, 257, 337, 733, 725, 458, 361, 104, 908, 261, 847, 252, 449, 987, 628, 943, 515, 681, 601, 539, 153, 751, 357, 851, 364, 842, 980, 382, 24, 150, 656, 543, 28, 654, 735, 413, 145, 451, 576, 788, 341, 322, 162, 37, 679, 349, 567, 204, 32, 126, 398, 78, 200, 789, 655, 188, 739, 560, 906, 307, 692, 797, 393, 130, 202, 700, 90, 635, 696, 981, 76, 118, 246, 250, 95, 617, 64, 750, 426, 514, 205, 390, 968, 630, 94, 616, 476, 837, 531, 632, 825, 935, 856, 424, 907, 194, 877, 516, 418, 57, 191, 570, 435, 808, 428, 675, 271, 620, 207, 39, 388, 321, ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /content/pipag_training/gmvae_common.py:265: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   elbo_terms[0] = Normal(mu_, torch.exp(0.5 * logsigmasq_)).log_prob(x_list[d]).sum()
# 3
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# ====> Epoch: 0 Train ELBO: -114028.2100 Val ELBO: -111091.4100, Epoch Time (s): 4.85, Total Time (hrs): 0.0013
# ====> Epoch: 1 Train ELBO: -98381.0513 Val ELBO: -96346.9000, Epoch Time (s): 0.07, Total Time (hrs): 0.0017
# ====> Epoch: 2 Train ELBO: -84614.6766 Val ELBO: -81486.2000, Epoch Time (s): 0.08, Total Time (hrs): 0.0017
# ====> Epoch: 3 Train ELBO: -71402.6506 Val ELBO: -68838.3450, Epoch Time (s): 0.08, Total Time (hrs): 0.0017
# ====> Epoch: 4 Train ELBO: -60360.3148 Val ELBO: -57324.6200, Epoch Time (s): 0.07, Total Time (hrs): 0.0017
# ====> Epoch: 5 Train ELBO: -51671.7900 Val ELBO: -50359.5450, Epoch Time (s): 0.07, Total Time (hrs): 0.0018
# ====> Epoch: 6 Train ELBO: -44468.0820 Val ELBO: -45644.4050, Epoch Time (s): 0.07, Total Time (hrs): 0.0018
# ====> Epoch: 7 Train ELBO: -41611.4319 Val ELBO: -41047.2100, Epoch Time (s): 0.07, Total Time (hrs): 0.0018
# ====> Epoch: 8 Train ELBO: -37644.2980 Val ELBO: -37305.4200, Epoch Time (s): 0.07, Total Time (hrs): 0.0019
# ====> Epoch: 9 Train ELBO: -33707.7602 Val ELBO: -36844.6475, Epoch Time (s): 0.07, Total Time (hrs): 0.0019
# ====> Epoch: 10 Train ELBO: -29393.4336 Val ELBO: -29736.9400, Epoch Time (s): 0.08, Total Time (hrs): 0.0019
# ====> Epoch: 11 Train ELBO: -24881.7389 Val ELBO: -22604.3725, Epoch Time (s): 0.09, Total Time (hrs): 0.0020
# ====> Epoch: 12 Train ELBO: -20121.8005 Val ELBO: -17062.5387, Epoch Time (s): 0.07, Total Time (hrs): 0.0020
# ====> Epoch: 13 Train ELBO: -14474.8090 Val ELBO: -11692.2512, Epoch Time (s): 0.08, Total Time (hrs): 0.0020
# ====> Epoch: 14 Train ELBO: -10115.5458 Val ELBO: -9380.9831, Epoch Time (s): 0.07, Total Time (hrs): 0.0021
# ====> Epoch: 15 Train ELBO: -7970.2493 Val ELBO: -8031.9575, Epoch Time (s): 0.07, Total Time (hrs): 0.0021
# ====> Epoch: 16 Train ELBO: -7118.9781 Val ELBO: -6814.3287, Epoch Time (s): 0.07, Total Time (hrs): 0.0021
# ====> Epoch: 17 Train ELBO: -6232.8874 Val ELBO: -6378.5331, Epoch Time (s): 0.07, Total Time (hrs): 0.0021
# ====> Epoch: 18 Train ELBO: -5500.3054 Val ELBO: -5970.8606, Epoch Time (s): 0.07, Total Time (hrs): 0.0022
# ====> Epoch: 19 Train ELBO: -5138.6216 Val ELBO: -5589.2250, Epoch Time (s): 0.07, Total Time (hrs): 0.0022
# ====> Epoch: 20 Train ELBO: -4961.4169 Val ELBO: -5698.9362, Epoch Time (s): 0.07, Total Time (hrs): 0.0022
# ====> Epoch: 21 Train ELBO: -4700.2673 Val ELBO: -5161.9616, Epoch Time (s): 0.08, Total Time (hrs): 0.0022
# ====> Epoch: 22 Train ELBO: -4698.9695 Val ELBO: -5143.5625, Epoch Time (s): 0.07, Total Time (hrs): 0.0023
# ====> Epoch: 23 Train ELBO: -4396.3538 Val ELBO: -4866.8884, Epoch Time (s): 0.07, Total Time (hrs): 0.0023
# ====> Epoch: 24 Train ELBO: -4245.9414 Val ELBO: -4770.5988, Epoch Time (s): 0.07, Total Time (hrs): 0.0023
# ====> Epoch: 25 Train ELBO: -4088.1713 Val ELBO: -4978.2622, Epoch Time (s): 0.08, Total Time (hrs): 0.0024
# ====> Epoch: 26 Train ELBO: -3968.4696 Val ELBO: -4508.5769, Epoch Time (s): 0.07, Total Time (hrs): 0.0024
# ====> Epoch: 27 Train ELBO: -3940.7282 Val ELBO: -4514.6484, Epoch Time (s): 0.07, Total Time (hrs): 0.0024
# ====> Epoch: 28 Train ELBO: -3851.5721 Val ELBO: -4101.8075, Epoch Time (s): 0.07, Total Time (hrs): 0.0024
# ====> Epoch: 29 Train ELBO: -3679.2761 Val ELBO: -4101.0375, Epoch Time (s): 0.07, Total Time (hrs): 0.0025
# ====> Epoch: 30 Train ELBO: -3636.5154 Val ELBO: -4162.6097, Epoch Time (s): 0.07, Total Time (hrs): 0.0025
# ====> Epoch: 31 Train ELBO: -3487.9031 Val ELBO: -3863.9016, Epoch Time (s): 0.07, Total Time (hrs): 0.0025
# ====> Epoch: 32 Train ELBO: -3368.1135 Val ELBO: -3821.6744, Epoch Time (s): 0.08, Total Time (hrs): 0.0025
# ====> Epoch: 33 Train ELBO: -3294.2018 Val ELBO: -3841.3522, Epoch Time (s): 0.07, Total Time (hrs): 0.0026
# ====> Epoch: 34 Train ELBO: -3229.5980 Val ELBO: -3447.5481, Epoch Time (s): 0.07, Total Time (hrs): 0.0026
# ====> Epoch: 35 Train ELBO: -3060.8512 Val ELBO: -3365.9228, Epoch Time (s): 0.07, Total Time (hrs): 0.0026
# ====> Epoch: 36 Train ELBO: -2947.5643 Val ELBO: -3352.8328, Epoch Time (s): 0.07, Total Time (hrs): 0.0026
# ====> Epoch: 37 Train ELBO: -2831.2989 Val ELBO: -3020.2456, Epoch Time (s): 0.07, Total Time (hrs): 0.0027
# ====> Epoch: 38 Train ELBO: -2660.4386 Val ELBO: -3020.3569, Epoch Time (s): 0.07, Total Time (hrs): 0.0027
# ====> Epoch: 39 Train ELBO: -2549.1001 Val ELBO: -2821.0181, Epoch Time (s): 0.07, Total Time (hrs): 0.0027
# ====> Epoch: 40 Train ELBO: -2304.0257 Val ELBO: -2550.3484, Epoch Time (s): 0.07, Total Time (hrs): 0.0028
# ====> Epoch: 41 Train ELBO: -2118.7178 Val ELBO: -2327.5103, Epoch Time (s): 0.07, Total Time (hrs): 0.0028
# ====> Epoch: 42 Train ELBO: -1972.0274 Val ELBO: -2085.0742, Epoch Time (s): 0.07, Total Time (hrs): 0.0028
# ====> Epoch: 43 Train ELBO: -1881.5368 Val ELBO: -1956.1719, Epoch Time (s): 0.08, Total Time (hrs): 0.0028
# ====> Epoch: 44 Train ELBO: -1702.4923 Val ELBO: -1862.4953, Epoch Time (s): 0.08, Total Time (hrs): 0.0029
# ====> Epoch: 45 Train ELBO: -1635.8239 Val ELBO: -1726.2141, Epoch Time (s): 0.10, Total Time (hrs): 0.0029
# ====> Epoch: 46 Train ELBO: -1572.4335 Val ELBO: -1539.9011, Epoch Time (s): 0.10, Total Time (hrs): 0.0030
# ====> Epoch: 47 Train ELBO: -1452.7993 Val ELBO: -1466.6452, Epoch Time (s): 0.10, Total Time (hrs): 0.0030
# ====> Epoch: 48 Train ELBO: -1409.9163 Val ELBO: -1441.9413, Epoch Time (s): 0.10, Total Time (hrs): 0.0030
# ====> Epoch: 49 Train ELBO: -1348.7327 Val ELBO: -1329.2802, Epoch Time (s): 0.11, Total Time (hrs): 0.0031
# ====> Epoch: 50 Train ELBO: -1286.8100 Val ELBO: -1309.2194, Epoch Time (s): 0.10, Total Time (hrs): 0.0031
# ====> Epoch: 51 Train ELBO: -1244.0229 Val ELBO: -1292.6667, Epoch Time (s): 0.11, Total Time (hrs): 0.0031
# ====> Epoch: 52 Train ELBO: -1216.2446 Val ELBO: -1251.9005, Epoch Time (s): 0.12, Total Time (hrs): 0.0032
# ====> Epoch: 53 Train ELBO: -1182.2083 Val ELBO: -1172.0244, Epoch Time (s): 0.10, Total Time (hrs): 0.0032
# ====> Epoch: 54 Train ELBO: -1134.1354 Val ELBO: -1149.8195, Epoch Time (s): 0.10, Total Time (hrs): 0.0033
# ====> Epoch: 55 Train ELBO: -1104.6667 Val ELBO: -1152.9835, Epoch Time (s): 0.11, Total Time (hrs): 0.0033
# ====> Epoch: 56 Train ELBO: -1069.0482 Val ELBO: -1120.7857, Epoch Time (s): 0.10, Total Time (hrs): 0.0033
# ====> Epoch: 57 Train ELBO: -1106.6100 Val ELBO: -1091.9685, Epoch Time (s): 0.10, Total Time (hrs): 0.0034
# ====> Epoch: 58 Train ELBO: -1064.8812 Val ELBO: -1041.4184, Epoch Time (s): 0.12, Total Time (hrs): 0.0034
# ====> Epoch: 59 Train ELBO: -1048.8304 Val ELBO: -1043.7667, Epoch Time (s): 0.10, Total Time (hrs): 0.0035
# ====> Epoch: 60 Train ELBO: -1021.3010 Val ELBO: -1020.5059, Epoch Time (s): 0.09, Total Time (hrs): 0.0035
# ====> Epoch: 61 Train ELBO: -1005.1781 Val ELBO: -1005.5865, Epoch Time (s): 0.10, Total Time (hrs): 0.0035
# ====> Epoch: 62 Train ELBO: -967.3997 Val ELBO: -1015.3546, Epoch Time (s): 0.09, Total Time (hrs): 0.0036
# ====> Epoch: 63 Train ELBO: -958.4250 Val ELBO: -981.5034, Epoch Time (s): 0.10, Total Time (hrs): 0.0036
# ====> Epoch: 64 Train ELBO: -926.2667 Val ELBO: -975.8111, Epoch Time (s): 0.10, Total Time (hrs): 0.0036
# ====> Epoch: 65 Train ELBO: -913.6371 Val ELBO: -989.7595, Epoch Time (s): 0.11, Total Time (hrs): 0.0037
# ====> Epoch: 66 Train ELBO: -899.3095 Val ELBO: -939.6978, Epoch Time (s): 0.10, Total Time (hrs): 0.0037
# ====> Epoch: 67 Train ELBO: -900.8905 Val ELBO: -972.0247, Epoch Time (s): 0.12, Total Time (hrs): 0.0037
# ====> Epoch: 68 Train ELBO: -910.8004 Val ELBO: -908.8477, Epoch Time (s): 0.11, Total Time (hrs): 0.0038
# ====> Epoch: 69 Train ELBO: -871.5854 Val ELBO: -876.4249, Epoch Time (s): 0.12, Total Time (hrs): 0.0038
# ====> Epoch: 70 Train ELBO: -855.5036 Val ELBO: -903.0585, Epoch Time (s): 0.08, Total Time (hrs): 0.0039
# ====> Epoch: 71 Train ELBO: -832.0558 Val ELBO: -879.2790, Epoch Time (s): 0.07, Total Time (hrs): 0.0039
# ====> Epoch: 72 Train ELBO: -845.0770 Val ELBO: -862.8603, Epoch Time (s): 0.07, Total Time (hrs): 0.0039
# ====> Epoch: 73 Train ELBO: -833.4931 Val ELBO: -841.2954, Epoch Time (s): 0.07, Total Time (hrs): 0.0039
# ====> Epoch: 74 Train ELBO: -803.4472 Val ELBO: -813.7558, Epoch Time (s): 0.07, Total Time (hrs): 0.0040
# ====> Epoch: 75 Train ELBO: -784.0144 Val ELBO: -846.7719, Epoch Time (s): 0.07, Total Time (hrs): 0.0040
# ====> Epoch: 76 Train ELBO: -781.9548 Val ELBO: -825.5015, Epoch Time (s): 0.07, Total Time (hrs): 0.0040
# ====> Epoch: 77 Train ELBO: -773.8522 Val ELBO: -835.9964, Epoch Time (s): 0.08, Total Time (hrs): 0.0040
# ====> Epoch: 78 Train ELBO: -772.2858 Val ELBO: -805.0361, Epoch Time (s): 0.07, Total Time (hrs): 0.0040
# ====> Epoch: 79 Train ELBO: -771.2586 Val ELBO: -777.7233, Epoch Time (s): 0.07, Total Time (hrs): 0.0041
# ====> Epoch: 80 Train ELBO: -749.5612 Val ELBO: -827.0743, Epoch Time (s): 0.07, Total Time (hrs): 0.0041
# ====> Epoch: 81 Train ELBO: -743.0466 Val ELBO: -756.3716, Epoch Time (s): 0.07, Total Time (hrs): 0.0041
# ====> Epoch: 82 Train ELBO: -737.7099 Val ELBO: -767.0709, Epoch Time (s): 0.07, Total Time (hrs): 0.0041
# ====> Epoch: 83 Train ELBO: -724.0819 Val ELBO: -774.0711, Epoch Time (s): 0.26, Total Time (hrs): 0.0042
# ====> Epoch: 84 Train ELBO: -722.9522 Val ELBO: -747.1612, Epoch Time (s): 0.13, Total Time (hrs): 0.0042
# ====> Epoch: 85 Train ELBO: -733.2185 Val ELBO: -760.9156, Epoch Time (s): 0.07, Total Time (hrs): 0.0043
# ====> Epoch: 86 Train ELBO: -701.6874 Val ELBO: -800.5799, Epoch Time (s): 0.08, Total Time (hrs): 0.0043
# ====> Epoch: 87 Train ELBO: -722.3347 Val ELBO: -758.2467, Epoch Time (s): 0.07, Total Time (hrs): 0.0043
# ====> Epoch: 88 Train ELBO: -721.8088 Val ELBO: -744.2245, Epoch Time (s): 0.07, Total Time (hrs): 0.0043
# ====> Epoch: 89 Train ELBO: -730.9338 Val ELBO: -744.8380, Epoch Time (s): 0.08, Total Time (hrs): 0.0044
# ====> Epoch: 90 Train ELBO: -687.7485 Val ELBO: -741.2951, Epoch Time (s): 0.25, Total Time (hrs): 0.0044
# ====> Epoch: 91 Train ELBO: -658.4804 Val ELBO: -743.6701, Epoch Time (s): 0.11, Total Time (hrs): 0.0045
# ====> Epoch: 92 Train ELBO: -677.5492 Val ELBO: -737.6730, Epoch Time (s): 0.07, Total Time (hrs): 0.0045
# ====> Epoch: 93 Train ELBO: -673.3448 Val ELBO: -696.4368, Epoch Time (s): 0.07, Total Time (hrs): 0.0045
# ====> Epoch: 94 Train ELBO: -673.1624 Val ELBO: -720.4940, Epoch Time (s): 0.08, Total Time (hrs): 0.0046
# ====> Epoch: 95 Train ELBO: -658.9106 Val ELBO: -678.3823, Epoch Time (s): 0.08, Total Time (hrs): 0.0046
# ====> Epoch: 96 Train ELBO: -650.9203 Val ELBO: -670.4050, Epoch Time (s): 0.07, Total Time (hrs): 0.0046
# ====> Epoch: 97 Train ELBO: -638.2736 Val ELBO: -666.5208, Epoch Time (s): 0.19, Total Time (hrs): 0.0047
# ====> Epoch: 98 Train ELBO: -634.1883 Val ELBO: -693.6870, Epoch Time (s): 0.07, Total Time (hrs): 0.0047
# ====> Epoch: 99 Train ELBO: -633.9306 Val ELBO: -684.7673, Epoch Time (s): 0.07, Total Time (hrs): 0.0048
# ====> Epoch: 100 Train ELBO: -633.6557 Val ELBO: -654.7489, Epoch Time (s): 0.07, Total Time (hrs): 0.0048
# ====> Epoch: 101 Train ELBO: -624.6444 Val ELBO: -630.1209, Epoch Time (s): 0.07, Total Time (hrs): 0.0048
# ====> Epoch: 102 Train ELBO: -632.9510 Val ELBO: -646.7266, Epoch Time (s): 0.07, Total Time (hrs): 0.0048
# ====> Epoch: 103 Train ELBO: -616.4045 Val ELBO: -664.2877, Epoch Time (s): 0.07, Total Time (hrs): 0.0049
# ====> Epoch: 104 Train ELBO: -602.7610 Val ELBO: -628.0950, Epoch Time (s): 0.08, Total Time (hrs): 0.0049
# ====> Epoch: 105 Train ELBO: -604.6682 Val ELBO: -681.0505, Epoch Time (s): 0.07, Total Time (hrs): 0.0049
# ====> Epoch: 106 Train ELBO: -616.5014 Val ELBO: -618.6818, Epoch Time (s): 0.06, Total Time (hrs): 0.0049
# ====> Epoch: 107 Train ELBO: -575.9911 Val ELBO: -653.0343, Epoch Time (s): 0.07, Total Time (hrs): 0.0050
# ====> Epoch: 108 Train ELBO: -612.1209 Val ELBO: -643.6007, Epoch Time (s): 0.07, Total Time (hrs): 0.0050
# ====> Epoch: 109 Train ELBO: -576.4747 Val ELBO: -597.4121, Epoch Time (s): 0.07, Total Time (hrs): 0.0050
# ====> Epoch: 110 Train ELBO: -578.4786 Val ELBO: -606.3091, Epoch Time (s): 0.07, Total Time (hrs): 0.0050
# ====> Epoch: 111 Train ELBO: -556.1506 Val ELBO: -603.7694, Epoch Time (s): 0.07, Total Time (hrs): 0.0050
# ====> Epoch: 112 Train ELBO: -532.5440 Val ELBO: -587.2195, Epoch Time (s): 0.07, Total Time (hrs): 0.0051
# ====> Epoch: 113 Train ELBO: -540.0017 Val ELBO: -576.6005, Epoch Time (s): 0.07, Total Time (hrs): 0.0051
# ====> Epoch: 114 Train ELBO: -528.0965 Val ELBO: -581.6057, Epoch Time (s): 0.07, Total Time (hrs): 0.0051
# ====> Epoch: 115 Train ELBO: -521.5702 Val ELBO: -554.9457, Epoch Time (s): 0.07, Total Time (hrs): 0.0051
# ====> Epoch: 116 Train ELBO: -540.3025 Val ELBO: -586.0050, Epoch Time (s): 0.08, Total Time (hrs): 0.0052
# ====> Epoch: 117 Train ELBO: -521.5822 Val ELBO: -577.9475, Epoch Time (s): 0.07, Total Time (hrs): 0.0052
# ====> Epoch: 118 Train ELBO: -510.8830 Val ELBO: -541.3998, Epoch Time (s): 0.07, Total Time (hrs): 0.0052
# ====> Epoch: 119 Train ELBO: -511.8579 Val ELBO: -557.7883, Epoch Time (s): 0.07, Total Time (hrs): 0.0052
# ====> Epoch: 120 Train ELBO: -505.7047 Val ELBO: -542.0228, Epoch Time (s): 0.07, Total Time (hrs): 0.0052
# ====> Epoch: 121 Train ELBO: -480.7661 Val ELBO: -527.9092, Epoch Time (s): 0.07, Total Time (hrs): 0.0053
# ====> Epoch: 122 Train ELBO: -497.0060 Val ELBO: -550.7689, Epoch Time (s): 0.07, Total Time (hrs): 0.0053
# ====> Epoch: 123 Train ELBO: -487.2380 Val ELBO: -561.9471, Epoch Time (s): 0.07, Total Time (hrs): 0.0053
# ====> Epoch: 124 Train ELBO: -492.6092 Val ELBO: -529.6474, Epoch Time (s): 0.07, Total Time (hrs): 0.0053
# ====> Epoch: 125 Train ELBO: -471.0639 Val ELBO: -506.7937, Epoch Time (s): 0.07, Total Time (hrs): 0.0054
# ====> Epoch: 126 Train ELBO: -477.1707 Val ELBO: -484.2826, Epoch Time (s): 0.07, Total Time (hrs): 0.0054
# ====> Epoch: 127 Train ELBO: -455.9821 Val ELBO: -495.8525, Epoch Time (s): 0.07, Total Time (hrs): 0.0054
# ====> Epoch: 128 Train ELBO: -468.8007 Val ELBO: -489.7018, Epoch Time (s): 0.06, Total Time (hrs): 0.0054
# ====> Epoch: 129 Train ELBO: -461.2276 Val ELBO: -489.4099, Epoch Time (s): 0.09, Total Time (hrs): 0.0055
# ====> Epoch: 130 Train ELBO: -444.4190 Val ELBO: -470.0461, Epoch Time (s): 0.07, Total Time (hrs): 0.0055
# ====> Epoch: 131 Train ELBO: -455.8501 Val ELBO: -436.6441, Epoch Time (s): 0.07, Total Time (hrs): 0.0055
# ====> Epoch: 132 Train ELBO: -428.6522 Val ELBO: -452.2643, Epoch Time (s): 0.07, Total Time (hrs): 0.0055
# ====> Epoch: 133 Train ELBO: -431.5880 Val ELBO: -444.3646, Epoch Time (s): 0.07, Total Time (hrs): 0.0055
# ====> Epoch: 134 Train ELBO: -428.2543 Val ELBO: -422.3465, Epoch Time (s): 0.06, Total Time (hrs): 0.0056
# ====> Epoch: 135 Train ELBO: -410.5802 Val ELBO: -429.4436, Epoch Time (s): 0.08, Total Time (hrs): 0.0056
# ====> Epoch: 136 Train ELBO: -396.5202 Val ELBO: -429.1068, Epoch Time (s): 0.06, Total Time (hrs): 0.0056
# ====> Epoch: 137 Train ELBO: -388.9188 Val ELBO: -401.7002, Epoch Time (s): 0.07, Total Time (hrs): 0.0056
# ====> Epoch: 138 Train ELBO: -390.2892 Val ELBO: -423.7987, Epoch Time (s): 0.07, Total Time (hrs): 0.0057
# ====> Epoch: 139 Train ELBO: -387.7037 Val ELBO: -372.8564, Epoch Time (s): 0.07, Total Time (hrs): 0.0057
# ====> Epoch: 140 Train ELBO: -368.7236 Val ELBO: -387.0500, Epoch Time (s): 0.07, Total Time (hrs): 0.0057
# ====> Epoch: 141 Train ELBO: -362.2690 Val ELBO: -384.7662, Epoch Time (s): 0.08, Total Time (hrs): 0.0057
# ====> Epoch: 142 Train ELBO: -359.1506 Val ELBO: -364.5848, Epoch Time (s): 0.07, Total Time (hrs): 0.0058
# ====> Epoch: 143 Train ELBO: -373.6980 Val ELBO: -401.9873, Epoch Time (s): 0.07, Total Time (hrs): 0.0058
# ====> Epoch: 144 Train ELBO: -374.6734 Val ELBO: -392.7346, Epoch Time (s): 0.07, Total Time (hrs): 0.0058
# ====> Epoch: 145 Train ELBO: -370.4776 Val ELBO: -393.1562, Epoch Time (s): 0.07, Total Time (hrs): 0.0058
# ====> Epoch: 146 Train ELBO: -361.3184 Val ELBO: -362.6095, Epoch Time (s): 0.06, Total Time (hrs): 0.0058
# ====> Epoch: 147 Train ELBO: -364.4548 Val ELBO: -372.6161, Epoch Time (s): 0.07, Total Time (hrs): 0.0059
# ====> Epoch: 148 Train ELBO: -357.3067 Val ELBO: -363.5668, Epoch Time (s): 0.07, Total Time (hrs): 0.0059
# ====> Epoch: 149 Train ELBO: -338.1600 Val ELBO: -337.8019, Epoch Time (s): 0.07, Total Time (hrs): 0.0059
# ====> Epoch: 150 Train ELBO: -329.9667 Val ELBO: -340.9420, Epoch Time (s): 0.07, Total Time (hrs): 0.0059
# ====> Epoch: 151 Train ELBO: -323.3386 Val ELBO: -349.1810, Epoch Time (s): 0.07, Total Time (hrs): 0.0059
# ====> Epoch: 152 Train ELBO: -337.1319 Val ELBO: -314.8908, Epoch Time (s): 0.07, Total Time (hrs): 0.0060
# ====> Epoch: 153 Train ELBO: -323.0161 Val ELBO: -344.9161, Epoch Time (s): 0.07, Total Time (hrs): 0.0060
# ====> Epoch: 154 Train ELBO: -318.3003 Val ELBO: -330.3798, Epoch Time (s): 0.08, Total Time (hrs): 0.0060
# ====> Epoch: 155 Train ELBO: -316.9772 Val ELBO: -341.1393, Epoch Time (s): 0.06, Total Time (hrs): 0.0060
# ====> Epoch: 156 Train ELBO: -317.1385 Val ELBO: -334.0574, Epoch Time (s): 0.07, Total Time (hrs): 0.0061
# ====> Epoch: 157 Train ELBO: -308.3414 Val ELBO: -317.7594, Epoch Time (s): 0.07, Total Time (hrs): 0.0061
# ====> Epoch: 158 Train ELBO: -305.4073 Val ELBO: -287.2618, Epoch Time (s): 0.07, Total Time (hrs): 0.0061
# ====> Epoch: 159 Train ELBO: -306.3592 Val ELBO: -309.6688, Epoch Time (s): 0.07, Total Time (hrs): 0.0061
# ====> Epoch: 160 Train ELBO: -309.2626 Val ELBO: -355.0209, Epoch Time (s): 0.06, Total Time (hrs): 0.0061
# ====> Epoch: 161 Train ELBO: -302.2561 Val ELBO: -308.9728, Epoch Time (s): 0.07, Total Time (hrs): 0.0062
# ====> Epoch: 162 Train ELBO: -291.9677 Val ELBO: -316.1895, Epoch Time (s): 0.07, Total Time (hrs): 0.0062
# ====> Epoch: 163 Train ELBO: -313.1695 Val ELBO: -325.2415, Epoch Time (s): 0.07, Total Time (hrs): 0.0062
# ====> Epoch: 164 Train ELBO: -304.8871 Val ELBO: -305.8255, Epoch Time (s): 0.06, Total Time (hrs): 0.0062
# ====> Epoch: 165 Train ELBO: -294.1310 Val ELBO: -302.0270, Epoch Time (s): 0.07, Total Time (hrs): 0.0062
# ====> Epoch: 166 Train ELBO: -299.2982 Val ELBO: -309.5869, Epoch Time (s): 0.07, Total Time (hrs): 0.0063
# ====> Epoch: 167 Train ELBO: -294.6939 Val ELBO: -293.4800, Epoch Time (s): 0.07, Total Time (hrs): 0.0063
# ====> Epoch: 168 Train ELBO: -300.9373 Val ELBO: -289.5016, Epoch Time (s): 0.07, Total Time (hrs): 0.0063
# ====> Epoch: 169 Train ELBO: -285.2008 Val ELBO: -296.6768, Epoch Time (s): 0.08, Total Time (hrs): 0.0063
# ====> Epoch: 170 Train ELBO: -282.8879 Val ELBO: -290.4045, Epoch Time (s): 0.07, Total Time (hrs): 0.0063
# ====> Epoch: 171 Train ELBO: -281.1470 Val ELBO: -289.2141, Epoch Time (s): 0.07, Total Time (hrs): 0.0063
# ====> Epoch: 172 Train ELBO: -291.1686 Val ELBO: -289.4595, Epoch Time (s): 0.07, Total Time (hrs): 0.0064
# ====> Epoch: 173 Train ELBO: -276.9285 Val ELBO: -281.3663, Epoch Time (s): 0.07, Total Time (hrs): 0.0064
# ====> Epoch: 174 Train ELBO: -291.1143 Val ELBO: -298.3210, Epoch Time (s): 0.07, Total Time (hrs): 0.0064
# ====> Epoch: 175 Train ELBO: -285.5572 Val ELBO: -305.6371, Epoch Time (s): 0.07, Total Time (hrs): 0.0064
# ====> Epoch: 176 Train ELBO: -280.0820 Val ELBO: -280.4527, Epoch Time (s): 0.07, Total Time (hrs): 0.0065
# ====> Epoch: 177 Train ELBO: -282.0907 Val ELBO: -303.0844, Epoch Time (s): 0.07, Total Time (hrs): 0.0065
# ====> Epoch: 178 Train ELBO: -279.9018 Val ELBO: -298.0626, Epoch Time (s): 0.07, Total Time (hrs): 0.0065
# ====> Epoch: 179 Train ELBO: -278.0296 Val ELBO: -276.2010, Epoch Time (s): 0.07, Total Time (hrs): 0.0065
# ====> Epoch: 180 Train ELBO: -275.5826 Val ELBO: -291.2686, Epoch Time (s): 0.07, Total Time (hrs): 0.0066
# ====> Epoch: 181 Train ELBO: -288.7235 Val ELBO: -290.8251, Epoch Time (s): 0.07, Total Time (hrs): 0.0066
# ====> Epoch: 182 Train ELBO: -301.2765 Val ELBO: -268.6968, Epoch Time (s): 0.08, Total Time (hrs): 0.0066
# ====> Epoch: 183 Train ELBO: -289.4944 Val ELBO: -298.6125, Epoch Time (s): 0.07, Total Time (hrs): 0.0066
# ====> Epoch: 184 Train ELBO: -270.0435 Val ELBO: -283.1140, Epoch Time (s): 0.12, Total Time (hrs): 0.0067
# ====> Epoch: 185 Train ELBO: -267.1378 Val ELBO: -282.1569, Epoch Time (s): 0.10, Total Time (hrs): 0.0067
# ====> Epoch: 186 Train ELBO: -277.1952 Val ELBO: -275.7476, Epoch Time (s): 0.10, Total Time (hrs): 0.0067
# ====> Epoch: 187 Train ELBO: -267.1449 Val ELBO: -268.2967, Epoch Time (s): 0.11, Total Time (hrs): 0.0067
# ====> Epoch: 188 Train ELBO: -260.4521 Val ELBO: -273.0775, Epoch Time (s): 0.10, Total Time (hrs): 0.0068
# ====> Epoch: 189 Train ELBO: -261.4616 Val ELBO: -273.5711, Epoch Time (s): 0.10, Total Time (hrs): 0.0068
# ====> Epoch: 190 Train ELBO: -267.0490 Val ELBO: -269.3566, Epoch Time (s): 0.10, Total Time (hrs): 0.0068
# ====> Epoch: 191 Train ELBO: -262.9185 Val ELBO: -277.2378, Epoch Time (s): 0.10, Total Time (hrs): 0.0069
# ====> Epoch: 192 Train ELBO: -268.5405 Val ELBO: -274.3096, Epoch Time (s): 0.10, Total Time (hrs): 0.0069
# ====> Epoch: 193 Train ELBO: -268.6001 Val ELBO: -282.4251, Epoch Time (s): 0.09, Total Time (hrs): 0.0069
# ====> Epoch: 194 Train ELBO: -266.9172 Val ELBO: -270.0340, Epoch Time (s): 0.10, Total Time (hrs): 0.0069
# ====> Epoch: 195 Train ELBO: -256.4389 Val ELBO: -272.9682, Epoch Time (s): 0.09, Total Time (hrs): 0.0070
# ====> Epoch: 196 Train ELBO: -258.4686 Val ELBO: -279.8410, Epoch Time (s): 0.10, Total Time (hrs): 0.0070
# ====> Epoch: 197 Train ELBO: -255.2126 Val ELBO: -261.3125, Epoch Time (s): 0.11, Total Time (hrs): 0.0070
# ====> Epoch: 198 Train ELBO: -254.2128 Val ELBO: -267.5786, Epoch Time (s): 0.10, Total Time (hrs): 0.0071
# ====> Epoch: 199 Train ELBO: -260.7719 Val ELBO: -284.1463, Epoch Time (s): 0.10, Total Time (hrs): 0.0071
# ====> Epoch: 200 Train ELBO: -271.7090 Val ELBO: -268.9580, Epoch Time (s): 0.10, Total Time (hrs): 0.0071
# ====> Epoch: 201 Train ELBO: -256.3708 Val ELBO: -268.7539, Epoch Time (s): 0.53, Total Time (hrs): 0.0073
# ====> Epoch: 202 Train ELBO: -263.6007 Val ELBO: -283.0968, Epoch Time (s): 0.22, Total Time (hrs): 0.0073
# ====> Epoch: 203 Train ELBO: -257.2414 Val ELBO: -257.5063, Epoch Time (s): 0.11, Total Time (hrs): 0.0074
# ====> Epoch: 204 Train ELBO: -254.0742 Val ELBO: -260.7077, Epoch Time (s): 0.11, Total Time (hrs): 0.0074
# ====> Epoch: 205 Train ELBO: -257.9380 Val ELBO: -274.7005, Epoch Time (s): 0.12, Total Time (hrs): 0.0074
# ====> Epoch: 206 Train ELBO: -260.4045 Val ELBO: -259.8627, Epoch Time (s): 0.47, Total Time (hrs): 0.0076
# ====> Epoch: 207 Train ELBO: -258.2690 Val ELBO: -273.4501, Epoch Time (s): 0.21, Total Time (hrs): 0.0076
# ====> Epoch: 208 Train ELBO: -254.3275 Val ELBO: -274.0789, Epoch Time (s): 0.10, Total Time (hrs): 0.0077
# ====> Epoch: 209 Train ELBO: -263.1054 Val ELBO: -258.3688, Epoch Time (s): 0.07, Total Time (hrs): 0.0077
# ====> Epoch: 210 Train ELBO: -247.9945 Val ELBO: -272.3670, Epoch Time (s): 0.07, Total Time (hrs): 0.0077
# ====> Epoch: 211 Train ELBO: -252.5074 Val ELBO: -284.1224, Epoch Time (s): 0.06, Total Time (hrs): 0.0077
# ====> Epoch: 212 Train ELBO: -259.2904 Val ELBO: -260.1322, Epoch Time (s): 0.07, Total Time (hrs): 0.0077
# ====> Epoch: 213 Train ELBO: -246.9821 Val ELBO: -258.3234, Epoch Time (s): 0.07, Total Time (hrs): 0.0077
# ====> Epoch: 214 Train ELBO: -247.1739 Val ELBO: -250.9989, Epoch Time (s): 0.16, Total Time (hrs): 0.0078
# ====> Epoch: 215 Train ELBO: -245.3437 Val ELBO: -272.2532, Epoch Time (s): 0.18, Total Time (hrs): 0.0079
# ====> Epoch: 216 Train ELBO: -249.3432 Val ELBO: -261.4485, Epoch Time (s): 0.06, Total Time (hrs): 0.0079
# ====> Epoch: 217 Train ELBO: -248.9716 Val ELBO: -260.2768, Epoch Time (s): 0.07, Total Time (hrs): 0.0079
# ====> Epoch: 218 Train ELBO: -240.8647 Val ELBO: -255.6690, Epoch Time (s): 0.07, Total Time (hrs): 0.0079
# ====> Epoch: 219 Train ELBO: -250.4091 Val ELBO: -268.5420, Epoch Time (s): 0.07, Total Time (hrs): 0.0079
# ====> Epoch: 220 Train ELBO: -256.6088 Val ELBO: -282.3457, Epoch Time (s): 0.07, Total Time (hrs): 0.0080
# ====> Epoch: 221 Train ELBO: -256.3956 Val ELBO: -255.9231, Epoch Time (s): 0.07, Total Time (hrs): 0.0080
# ====> Epoch: 222 Train ELBO: -245.5894 Val ELBO: -260.1968, Epoch Time (s): 0.07, Total Time (hrs): 0.0080
# ====> Epoch: 223 Train ELBO: -247.4022 Val ELBO: -253.7929, Epoch Time (s): 0.07, Total Time (hrs): 0.0080
# ====> Epoch: 224 Train ELBO: -239.9779 Val ELBO: -249.1864, Epoch Time (s): 0.07, Total Time (hrs): 0.0080
# ====> Epoch: 225 Train ELBO: -242.9950 Val ELBO: -251.3480, Epoch Time (s): 0.07, Total Time (hrs): 0.0081
# ====> Epoch: 226 Train ELBO: -240.1000 Val ELBO: -255.5266, Epoch Time (s): 0.08, Total Time (hrs): 0.0081
# ====> Epoch: 227 Train ELBO: -242.2696 Val ELBO: -243.0401, Epoch Time (s): 0.07, Total Time (hrs): 0.0081
# ====> Epoch: 228 Train ELBO: -242.7819 Val ELBO: -259.7824, Epoch Time (s): 0.07, Total Time (hrs): 0.0081
# ====> Epoch: 229 Train ELBO: -244.5234 Val ELBO: -263.2532, Epoch Time (s): 0.07, Total Time (hrs): 0.0081
# ====> Epoch: 230 Train ELBO: -242.0702 Val ELBO: -281.8455, Epoch Time (s): 0.06, Total Time (hrs): 0.0082
# ====> Epoch: 231 Train ELBO: -251.3881 Val ELBO: -260.8923, Epoch Time (s): 0.07, Total Time (hrs): 0.0082
# ====> Epoch: 232 Train ELBO: -237.5131 Val ELBO: -249.5944, Epoch Time (s): 0.07, Total Time (hrs): 0.0082
# ====> Epoch: 233 Train ELBO: -239.9893 Val ELBO: -260.8904, Epoch Time (s): 0.07, Total Time (hrs): 0.0082
# ====> Epoch: 234 Train ELBO: -254.7424 Val ELBO: -266.5917, Epoch Time (s): 0.06, Total Time (hrs): 0.0082
# ====> Epoch: 235 Train ELBO: -246.6574 Val ELBO: -242.9530, Epoch Time (s): 0.07, Total Time (hrs): 0.0083
# ====> Epoch: 236 Train ELBO: -254.4566 Val ELBO: -288.3047, Epoch Time (s): 0.07, Total Time (hrs): 0.0083
# ====> Epoch: 237 Train ELBO: -252.7827 Val ELBO: -235.8530, Epoch Time (s): 0.07, Total Time (hrs): 0.0083
# ====> Epoch: 238 Train ELBO: -243.0947 Val ELBO: -238.8690, Epoch Time (s): 0.07, Total Time (hrs): 0.0083
# ====> Epoch: 239 Train ELBO: -243.3607 Val ELBO: -265.0605, Epoch Time (s): 0.08, Total Time (hrs): 0.0084
# ====> Epoch: 240 Train ELBO: -241.6222 Val ELBO: -239.5983, Epoch Time (s): 0.08, Total Time (hrs): 0.0084
# ====> Epoch: 241 Train ELBO: -230.5862 Val ELBO: -240.2352, Epoch Time (s): 0.07, Total Time (hrs): 0.0084
# ====> Epoch: 242 Train ELBO: -237.3650 Val ELBO: -241.0746, Epoch Time (s): 0.07, Total Time (hrs): 0.0084
# ====> Epoch: 243 Train ELBO: -242.9636 Val ELBO: -258.4214, Epoch Time (s): 0.07, Total Time (hrs): 0.0084
# ====> Epoch: 244 Train ELBO: -251.8252 Val ELBO: -251.6279, Epoch Time (s): 0.07, Total Time (hrs): 0.0085
# ====> Epoch: 245 Train ELBO: -240.3686 Val ELBO: -256.4088, Epoch Time (s): 0.07, Total Time (hrs): 0.0085
# ====> Epoch: 246 Train ELBO: -237.4958 Val ELBO: -253.0635, Epoch Time (s): 0.07, Total Time (hrs): 0.0085
# ====> Epoch: 247 Train ELBO: -244.2872 Val ELBO: -234.6769, Epoch Time (s): 0.07, Total Time (hrs): 0.0085
# ====> Epoch: 248 Train ELBO: -234.5395 Val ELBO: -234.7694, Epoch Time (s): 0.07, Total Time (hrs): 0.0085
# ====> Epoch: 249 Train ELBO: -233.4951 Val ELBO: -230.1740, Epoch Time (s): 0.07, Total Time (hrs): 0.0086
# ====> Epoch: 250 Train ELBO: -224.5008 Val ELBO: -239.0016, Epoch Time (s): 0.07, Total Time (hrs): 0.0086
# ====> Epoch: 251 Train ELBO: -226.5693 Val ELBO: -232.4840, Epoch Time (s): 0.07, Total Time (hrs): 0.0086
# ====> Epoch: 252 Train ELBO: -229.0803 Val ELBO: -244.1523, Epoch Time (s): 0.06, Total Time (hrs): 0.0086
# ====> Epoch: 253 Train ELBO: -228.2064 Val ELBO: -236.3927, Epoch Time (s): 0.08, Total Time (hrs): 0.0086
# ====> Epoch: 254 Train ELBO: -232.0936 Val ELBO: -235.5131, Epoch Time (s): 0.07, Total Time (hrs): 0.0087
# ====> Epoch: 255 Train ELBO: -230.2326 Val ELBO: -237.9094, Epoch Time (s): 0.07, Total Time (hrs): 0.0087
# ====> Epoch: 256 Train ELBO: -225.0592 Val ELBO: -240.5545, Epoch Time (s): 0.07, Total Time (hrs): 0.0087
# ====> Epoch: 257 Train ELBO: -226.5123 Val ELBO: -229.3455, Epoch Time (s): 0.07, Total Time (hrs): 0.0087
# ====> Epoch: 258 Train ELBO: -227.7552 Val ELBO: -236.5289, Epoch Time (s): 0.07, Total Time (hrs): 0.0088
# ====> Epoch: 259 Train ELBO: -223.5721 Val ELBO: -236.6302, Epoch Time (s): 0.07, Total Time (hrs): 0.0088
# ====> Epoch: 260 Train ELBO: -224.8521 Val ELBO: -247.0304, Epoch Time (s): 0.07, Total Time (hrs): 0.0088
# ====> Epoch: 261 Train ELBO: -225.8127 Val ELBO: -225.8519, Epoch Time (s): 0.07, Total Time (hrs): 0.0088
# ====> Epoch: 262 Train ELBO: -228.5396 Val ELBO: -235.5902, Epoch Time (s): 0.07, Total Time (hrs): 0.0088
# ====> Epoch: 263 Train ELBO: -223.9038 Val ELBO: -228.7164, Epoch Time (s): 0.07, Total Time (hrs): 0.0089
# ====> Epoch: 264 Train ELBO: -227.0139 Val ELBO: -241.4119, Epoch Time (s): 0.07, Total Time (hrs): 0.0089
# ====> Epoch: 265 Train ELBO: -224.8963 Val ELBO: -241.3484, Epoch Time (s): 0.07, Total Time (hrs): 0.0089
# ====> Epoch: 266 Train ELBO: -227.1092 Val ELBO: -234.3137, Epoch Time (s): 0.07, Total Time (hrs): 0.0089
# ====> Epoch: 267 Train ELBO: -222.0197 Val ELBO: -243.7434, Epoch Time (s): 0.10, Total Time (hrs): 0.0089
# ====> Epoch: 268 Train ELBO: -217.9160 Val ELBO: -243.6285, Epoch Time (s): 0.07, Total Time (hrs): 0.0090
# ====> Epoch: 269 Train ELBO: -227.3195 Val ELBO: -229.0176, Epoch Time (s): 0.07, Total Time (hrs): 0.0090
# ====> Epoch: 270 Train ELBO: -229.3582 Val ELBO: -238.7951, Epoch Time (s): 0.07, Total Time (hrs): 0.0090
# ====> Epoch: 271 Train ELBO: -227.6286 Val ELBO: -231.1610, Epoch Time (s): 0.07, Total Time (hrs): 0.0090
# ====> Epoch: 272 Train ELBO: -222.3308 Val ELBO: -232.4482, Epoch Time (s): 0.06, Total Time (hrs): 0.0090
# ====> Epoch: 273 Train ELBO: -218.4671 Val ELBO: -230.2836, Epoch Time (s): 0.07, Total Time (hrs): 0.0091
# ====> Epoch: 274 Train ELBO: -220.2756 Val ELBO: -244.3360, Epoch Time (s): 0.07, Total Time (hrs): 0.0091
# ====> Epoch: 275 Train ELBO: -226.8111 Val ELBO: -244.4759, Epoch Time (s): 0.07, Total Time (hrs): 0.0091
# ====> Epoch: 276 Train ELBO: -230.7348 Val ELBO: -226.7945, Epoch Time (s): 0.06, Total Time (hrs): 0.0091
# ====> Epoch: 277 Train ELBO: -216.9352 Val ELBO: -224.6569, Epoch Time (s): 0.07, Total Time (hrs): 0.0091
# ====> Epoch: 278 Train ELBO: -217.2286 Val ELBO: -250.6078, Epoch Time (s): 0.07, Total Time (hrs): 0.0092
# ====> Epoch: 279 Train ELBO: -223.3953 Val ELBO: -238.6756, Epoch Time (s): 0.06, Total Time (hrs): 0.0092
# ====> Epoch: 280 Train ELBO: -222.8643 Val ELBO: -248.0596, Epoch Time (s): 0.07, Total Time (hrs): 0.0092
# ====> Epoch: 281 Train ELBO: -223.3513 Val ELBO: -251.8911, Epoch Time (s): 0.07, Total Time (hrs): 0.0092
# ====> Epoch: 282 Train ELBO: -219.6151 Val ELBO: -227.3610, Epoch Time (s): 0.08, Total Time (hrs): 0.0092
# ====> Epoch: 283 Train ELBO: -214.2571 Val ELBO: -219.2698, Epoch Time (s): 0.07, Total Time (hrs): 0.0093
# ====> Epoch: 284 Train ELBO: -222.6163 Val ELBO: -241.6665, Epoch Time (s): 0.07, Total Time (hrs): 0.0093
# ====> Epoch: 285 Train ELBO: -226.1640 Val ELBO: -241.1350, Epoch Time (s): 0.07, Total Time (hrs): 0.0093
# ====> Epoch: 286 Train ELBO: -220.9581 Val ELBO: -243.6762, Epoch Time (s): 0.07, Total Time (hrs): 0.0093
# ====> Epoch: 287 Train ELBO: -218.8833 Val ELBO: -223.9176, Epoch Time (s): 0.07, Total Time (hrs): 0.0093
# ====> Epoch: 288 Train ELBO: -216.1206 Val ELBO: -239.2229, Epoch Time (s): 0.07, Total Time (hrs): 0.0094
# ====> Epoch: 289 Train ELBO: -216.7881 Val ELBO: -226.4752, Epoch Time (s): 0.06, Total Time (hrs): 0.0094
# ====> Epoch: 290 Train ELBO: -220.3072 Val ELBO: -232.6234, Epoch Time (s): 0.07, Total Time (hrs): 0.0094
# ====> Epoch: 291 Train ELBO: -214.3478 Val ELBO: -216.1371, Epoch Time (s): 0.07, Total Time (hrs): 0.0094
# ====> Epoch: 292 Train ELBO: -219.1121 Val ELBO: -224.6975, Epoch Time (s): 0.07, Total Time (hrs): 0.0094
# ====> Epoch: 293 Train ELBO: -220.5886 Val ELBO: -229.0109, Epoch Time (s): 0.07, Total Time (hrs): 0.0095
# ====> Epoch: 294 Train ELBO: -222.9006 Val ELBO: -214.4661, Epoch Time (s): 0.07, Total Time (hrs): 0.0095
# ====> Epoch: 295 Train ELBO: -214.4796 Val ELBO: -221.3074, Epoch Time (s): 0.09, Total Time (hrs): 0.0095
# ====> Epoch: 296 Train ELBO: -210.5636 Val ELBO: -215.2259, Epoch Time (s): 0.07, Total Time (hrs): 0.0095
# ====> Epoch: 297 Train ELBO: -211.5972 Val ELBO: -209.1084, Epoch Time (s): 0.07, Total Time (hrs): 0.0096
# ====> Epoch: 298 Train ELBO: -203.7040 Val ELBO: -212.3368, Epoch Time (s): 0.07, Total Time (hrs): 0.0096
# ====> Epoch: 299 Train ELBO: -209.3209 Val ELBO: -216.1256, Epoch Time (s): 0.07, Total Time (hrs): 0.0096
# ====> Epoch: 300 Train ELBO: -213.4236 Val ELBO: -233.8802, Epoch Time (s): 0.07, Total Time (hrs): 0.0096
# ====> Epoch: 301 Train ELBO: -224.7703 Val ELBO: -221.2609, Epoch Time (s): 0.06, Total Time (hrs): 0.0096
# ====> Epoch: 302 Train ELBO: -224.6192 Val ELBO: -216.8531, Epoch Time (s): 0.06, Total Time (hrs): 0.0097
# ====> Epoch: 303 Train ELBO: -207.6287 Val ELBO: -215.1517, Epoch Time (s): 0.07, Total Time (hrs): 0.0097
# ====> Epoch: 304 Train ELBO: -204.2648 Val ELBO: -224.0595, Epoch Time (s): 0.07, Total Time (hrs): 0.0097
# ====> Epoch: 305 Train ELBO: -201.5705 Val ELBO: -218.7906, Epoch Time (s): 0.07, Total Time (hrs): 0.0097
# ====> Epoch: 306 Train ELBO: -202.5137 Val ELBO: -221.5478, Epoch Time (s): 0.06, Total Time (hrs): 0.0097
# ====> Epoch: 307 Train ELBO: -208.9730 Val ELBO: -209.4567, Epoch Time (s): 0.07, Total Time (hrs): 0.0097
# ====> Epoch: 308 Train ELBO: -208.1955 Val ELBO: -219.0993, Epoch Time (s): 0.07, Total Time (hrs): 0.0098
# ====> Epoch: 309 Train ELBO: -212.2090 Val ELBO: -203.9716, Epoch Time (s): 0.07, Total Time (hrs): 0.0098
# ====> Epoch: 310 Train ELBO: -204.0075 Val ELBO: -208.9521, Epoch Time (s): 0.07, Total Time (hrs): 0.0098
# ====> Epoch: 311 Train ELBO: -208.5127 Val ELBO: -203.8838, Epoch Time (s): 0.07, Total Time (hrs): 0.0098
# ====> Epoch: 312 Train ELBO: -199.9525 Val ELBO: -215.7952, Epoch Time (s): 0.07, Total Time (hrs): 0.0099
# ====> Epoch: 313 Train ELBO: -199.0496 Val ELBO: -224.4711, Epoch Time (s): 0.07, Total Time (hrs): 0.0099
# ====> Epoch: 314 Train ELBO: -205.8265 Val ELBO: -227.4561, Epoch Time (s): 0.07, Total Time (hrs): 0.0099
# ====> Epoch: 315 Train ELBO: -196.2269 Val ELBO: -232.6921, Epoch Time (s): 0.07, Total Time (hrs): 0.0099
# ====> Epoch: 316 Train ELBO: -205.5501 Val ELBO: -205.4596, Epoch Time (s): 0.07, Total Time (hrs): 0.0099
# ====> Epoch: 317 Train ELBO: -201.9037 Val ELBO: -196.8075, Epoch Time (s): 0.07, Total Time (hrs): 0.0100
# ====> Epoch: 318 Train ELBO: -199.2914 Val ELBO: -207.1639, Epoch Time (s): 0.07, Total Time (hrs): 0.0100
# ====> Epoch: 319 Train ELBO: -200.0234 Val ELBO: -206.5678, Epoch Time (s): 0.07, Total Time (hrs): 0.0100
# ====> Epoch: 320 Train ELBO: -201.7945 Val ELBO: -208.3495, Epoch Time (s): 0.07, Total Time (hrs): 0.0100
# ====> Epoch: 321 Train ELBO: -204.4977 Val ELBO: -205.9899, Epoch Time (s): 0.07, Total Time (hrs): 0.0100
# ====> Epoch: 322 Train ELBO: -198.0678 Val ELBO: -215.3160, Epoch Time (s): 0.07, Total Time (hrs): 0.0101
# ====> Epoch: 323 Train ELBO: -202.5196 Val ELBO: -226.9105, Epoch Time (s): 0.09, Total Time (hrs): 0.0101
# ====> Epoch: 324 Train ELBO: -211.8262 Val ELBO: -207.7526, Epoch Time (s): 0.07, Total Time (hrs): 0.0101
# ====> Epoch: 325 Train ELBO: -195.2478 Val ELBO: -199.3117, Epoch Time (s): 0.07, Total Time (hrs): 0.0101
# ====> Epoch: 326 Train ELBO: -188.2414 Val ELBO: -192.3429, Epoch Time (s): 0.07, Total Time (hrs): 0.0101
# ====> Epoch: 327 Train ELBO: -191.4979 Val ELBO: -193.7737, Epoch Time (s): 0.07, Total Time (hrs): 0.0102
# ====> Epoch: 328 Train ELBO: -191.8174 Val ELBO: -200.1505, Epoch Time (s): 0.07, Total Time (hrs): 0.0102
# ====> Epoch: 329 Train ELBO: -189.4655 Val ELBO: -188.7647, Epoch Time (s): 0.07, Total Time (hrs): 0.0102
# ====> Epoch: 330 Train ELBO: -194.8707 Val ELBO: -192.9234, Epoch Time (s): 0.07, Total Time (hrs): 0.0102
# ====> Epoch: 331 Train ELBO: -191.8297 Val ELBO: -199.0227, Epoch Time (s): 0.07, Total Time (hrs): 0.0103
# ====> Epoch: 332 Train ELBO: -196.8154 Val ELBO: -207.6595, Epoch Time (s): 0.07, Total Time (hrs): 0.0103
# ====> Epoch: 333 Train ELBO: -196.0738 Val ELBO: -202.1320, Epoch Time (s): 0.07, Total Time (hrs): 0.0103
# ====> Epoch: 334 Train ELBO: -194.8189 Val ELBO: -209.8716, Epoch Time (s): 0.07, Total Time (hrs): 0.0103
# ====> Epoch: 335 Train ELBO: -200.1165 Val ELBO: -196.7656, Epoch Time (s): 0.07, Total Time (hrs): 0.0103
# ====> Epoch: 336 Train ELBO: -208.3110 Val ELBO: -223.3209, Epoch Time (s): 0.07, Total Time (hrs): 0.0104
# ====> Epoch: 337 Train ELBO: -217.2249 Val ELBO: -214.7416, Epoch Time (s): 0.08, Total Time (hrs): 0.0104
# ====> Epoch: 338 Train ELBO: -201.6200 Val ELBO: -214.9382, Epoch Time (s): 0.07, Total Time (hrs): 0.0104
# ====> Epoch: 339 Train ELBO: -193.2967 Val ELBO: -194.8413, Epoch Time (s): 0.07, Total Time (hrs): 0.0104
# ====> Epoch: 340 Train ELBO: -194.6573 Val ELBO: -198.3203, Epoch Time (s): 0.08, Total Time (hrs): 0.0104
# ====> Epoch: 341 Train ELBO: -191.5630 Val ELBO: -198.3427, Epoch Time (s): 0.12, Total Time (hrs): 0.0105
# ====> Epoch: 342 Train ELBO: -185.2052 Val ELBO: -186.6299, Epoch Time (s): 0.10, Total Time (hrs): 0.0105
# ====> Epoch: 343 Train ELBO: -182.6844 Val ELBO: -191.9918, Epoch Time (s): 0.10, Total Time (hrs): 0.0105
# ====> Epoch: 344 Train ELBO: -187.5760 Val ELBO: -190.9025, Epoch Time (s): 0.09, Total Time (hrs): 0.0106
# ====> Epoch: 345 Train ELBO: -190.3337 Val ELBO: -190.9035, Epoch Time (s): 0.09, Total Time (hrs): 0.0106
# ====> Epoch: 346 Train ELBO: -186.0059 Val ELBO: -204.5226, Epoch Time (s): 0.11, Total Time (hrs): 0.0106
# ====> Epoch: 347 Train ELBO: -189.4025 Val ELBO: -189.2785, Epoch Time (s): 0.10, Total Time (hrs): 0.0106
# ====> Epoch: 348 Train ELBO: -185.3399 Val ELBO: -195.2202, Epoch Time (s): 0.11, Total Time (hrs): 0.0107
# ====> Epoch: 349 Train ELBO: -184.5697 Val ELBO: -189.5128, Epoch Time (s): 0.10, Total Time (hrs): 0.0107
# ====> Epoch: 350 Train ELBO: -188.3342 Val ELBO: -185.5945, Epoch Time (s): 0.09, Total Time (hrs): 0.0107
# ====> Epoch: 351 Train ELBO: -180.9749 Val ELBO: -182.0005, Epoch Time (s): 0.09, Total Time (hrs): 0.0108
# ====> Epoch: 352 Train ELBO: -177.3588 Val ELBO: -181.3294, Epoch Time (s): 0.10, Total Time (hrs): 0.0108
# ====> Epoch: 353 Train ELBO: -177.0745 Val ELBO: -183.5629, Epoch Time (s): 0.10, Total Time (hrs): 0.0108
# ====> Epoch: 354 Train ELBO: -171.1400 Val ELBO: -179.4660, Epoch Time (s): 0.10, Total Time (hrs): 0.0109
# ====> Epoch: 355 Train ELBO: -176.0794 Val ELBO: -175.3205, Epoch Time (s): 0.10, Total Time (hrs): 0.0109
# ====> Epoch: 356 Train ELBO: -179.2543 Val ELBO: -177.5515, Epoch Time (s): 0.10, Total Time (hrs): 0.0109
# ====> Epoch: 357 Train ELBO: -174.1502 Val ELBO: -180.0579, Epoch Time (s): 0.12, Total Time (hrs): 0.0110
# ====> Epoch: 358 Train ELBO: -167.3463 Val ELBO: -172.3237, Epoch Time (s): 0.09, Total Time (hrs): 0.0110
# ====> Epoch: 359 Train ELBO: -176.4594 Val ELBO: -176.9685, Epoch Time (s): 0.10, Total Time (hrs): 0.0110
# ====> Epoch: 360 Train ELBO: -175.4876 Val ELBO: -169.7204, Epoch Time (s): 0.09, Total Time (hrs): 0.0111
# ====> Epoch: 361 Train ELBO: -169.9659 Val ELBO: -166.7371, Epoch Time (s): 0.11, Total Time (hrs): 0.0111
# ====> Epoch: 362 Train ELBO: -172.4884 Val ELBO: -169.9035, Epoch Time (s): 0.11, Total Time (hrs): 0.0111
# ====> Epoch: 363 Train ELBO: -176.3715 Val ELBO: -191.9054, Epoch Time (s): 0.12, Total Time (hrs): 0.0112
# ====> Epoch: 364 Train ELBO: -181.1888 Val ELBO: -181.8891, Epoch Time (s): 0.10, Total Time (hrs): 0.0112
# ====> Epoch: 365 Train ELBO: -176.9449 Val ELBO: -177.1770, Epoch Time (s): 0.12, Total Time (hrs): 0.0112
# ====> Epoch: 366 Train ELBO: -176.7311 Val ELBO: -167.9384, Epoch Time (s): 0.12, Total Time (hrs): 0.0113
# ...
# ====> Epoch: 1068 Train ELBO: 72.0334 Val ELBO: 35.4849, Epoch Time (s): 0.10, Total Time (hrs): 0.0293
# ====> Epoch: 1069 Train ELBO: 69.7972 Val ELBO: 30.2135, Epoch Time (s): 0.10, Total Time (hrs): 0.0293
# ====> Epoch: 1070 Train ELBO: 72.3947 Val ELBO: 36.4877, Epoch Time (s): 0.10, Total Time (hrs): 0.0293
# ====> Epoch: 1071 Train ELBO: 69.6588 Val ELBO: 39.0061, Epoch Time (s): 0.10, Total Time (hrs): 0.0294
# ====> Epoch: 1072 Train ELBO: 68.3272 Val ELBO: 34.1933, Epoch Time (s): 0.10, Total Time (hrs): 0.0294
# ====> Epoch: 1073 Train ELBO: 67.3109 Val ELBO: 36.2735, Epoch Time (s): 0.10, Total Time (hrs): 0.0294
# ====> Epoch: 1074 Train ELBO: 64.6658 Val ELBO: 29.4011, Epoch Time (s): 0.10, Total Time (hrs): 0.0294
# ====> Epoch: 1075 Train ELBO: 67.6470 Val ELBO: 23.4573, Epoch Time (s): 0.12, Total Time (hrs): 0.0295
# ====> Epoch: 1076 Train ELBO: 65.8434 Val ELBO: 39.4847, Epoch Time (s): 0.10, Total Time (hrs): 0.0295
# ====> Epoch: 1077 Train ELBO: 66.8774 Val ELBO: 22.6520, Epoch Time (s): 0.10, Total Time (hrs): 0.0295
# ====> Epoch: 1078 Train ELBO: 67.0362 Val ELBO: 33.7931, Epoch Time (s): 0.09, Total Time (hrs): 0.0295
# ====> Epoch: 1079 Train ELBO: 67.9529 Val ELBO: 34.9894, Epoch Time (s): 0.12, Total Time (hrs): 0.0296
# ====> Epoch: 1080 Train ELBO: 71.5365 Val ELBO: 45.4020, Epoch Time (s): 0.12, Total Time (hrs): 0.0296
# ====> Epoch: 1081 Train ELBO: 71.3824 Val ELBO: 41.7992, Epoch Time (s): 0.11, Total Time (hrs): 0.0297
# ====> Epoch: 1082 Train ELBO: 71.4680 Val ELBO: 26.1319, Epoch Time (s): 0.11, Total Time (hrs): 0.0297
# ====> Epoch: 1083 Train ELBO: 69.5677 Val ELBO: 30.5663, Epoch Time (s): 0.12, Total Time (hrs): 0.0297
# ====> Epoch: 1084 Train ELBO: 63.5295 Val ELBO: 39.3825, Epoch Time (s): 0.12, Total Time (hrs): 0.0298
# ====> Epoch: 1085 Train ELBO: 70.3592 Val ELBO: 34.8225, Epoch Time (s): 0.12, Total Time (hrs): 0.0298
# ====> Epoch: 1086 Train ELBO: 71.8886 Val ELBO: 34.6745, Epoch Time (s): 0.12, Total Time (hrs): 0.0298
# ====> Epoch: 1087 Train ELBO: 72.0901 Val ELBO: 39.9850, Epoch Time (s): 0.12, Total Time (hrs): 0.0298
# ====> Epoch: 1088 Train ELBO: 66.7849 Val ELBO: 29.7547, Epoch Time (s): 0.09, Total Time (hrs): 0.0299
# ====> Epoch: 1089 Train ELBO: 67.0884 Val ELBO: 35.0280, Epoch Time (s): 0.07, Total Time (hrs): 0.0299
# ====> Epoch: 1090 Train ELBO: 70.1376 Val ELBO: 28.9840, Epoch Time (s): 0.07, Total Time (hrs): 0.0299
# ====> Epoch: 1091 Train ELBO: 68.5364 Val ELBO: 31.0175, Epoch Time (s): 0.07, Total Time (hrs): 0.0299
# ====> Epoch: 1092 Train ELBO: 69.3322 Val ELBO: 33.3052, Epoch Time (s): 0.07, Total Time (hrs): 0.0299
# ====> Epoch: 1093 Train ELBO: 67.6772 Val ELBO: 39.0076, Epoch Time (s): 0.08, Total Time (hrs): 0.0300
# ====> Epoch: 1094 Train ELBO: 71.2259 Val ELBO: 37.6567, Epoch Time (s): 0.07, Total Time (hrs): 0.0300
# ====> Epoch: 1095 Train ELBO: 71.8175 Val ELBO: 34.1754, Epoch Time (s): 0.07, Total Time (hrs): 0.0300
# ====> Epoch: 1096 Train ELBO: 68.2419 Val ELBO: 44.2566, Epoch Time (s): 0.09, Total Time (hrs): 0.0300
# ====> Epoch: 1097 Train ELBO: 70.3216 Val ELBO: 29.6027, Epoch Time (s): 0.07, Total Time (hrs): 0.0300
# ====> Epoch: 1098 Train ELBO: 67.6940 Val ELBO: 30.2729, Epoch Time (s): 0.07, Total Time (hrs): 0.0301
# ====> Epoch: 1099 Train ELBO: 71.3508 Val ELBO: 28.1777, Epoch Time (s): 0.07, Total Time (hrs): 0.0301
# ====> Epoch: 1100 Train ELBO: 62.8654 Val ELBO: 38.8297, Epoch Time (s): 0.07, Total Time (hrs): 0.0301
# ====> Epoch: 1101 Train ELBO: 70.9533 Val ELBO: 37.6781, Epoch Time (s): 0.07, Total Time (hrs): 0.0301
# ====> Epoch: 1102 Train ELBO: 71.5050 Val ELBO: 34.1173, Epoch Time (s): 0.07, Total Time (hrs): 0.0301
# ====> Epoch: 1103 Train ELBO: 72.1712 Val ELBO: 44.8226, Epoch Time (s): 0.07, Total Time (hrs): 0.0302
# ====> Epoch: 1104 Train ELBO: 73.5281 Val ELBO: 37.8452, Epoch Time (s): 0.07, Total Time (hrs): 0.0302
# ====> Epoch: 1105 Train ELBO: 72.3554 Val ELBO: 23.8297, Epoch Time (s): 0.07, Total Time (hrs): 0.0302
# ====> Epoch: 1106 Train ELBO: 72.9909 Val ELBO: 37.7175, Epoch Time (s): 0.08, Total Time (hrs): 0.0302
# ====> Epoch: 1107 Train ELBO: 75.6689 Val ELBO: 40.0155, Epoch Time (s): 0.08, Total Time (hrs): 0.0302
# ====> Epoch: 1108 Train ELBO: 75.3664 Val ELBO: 43.9709, Epoch Time (s): 0.07, Total Time (hrs): 0.0303
# ====> Epoch: 1109 Train ELBO: 72.8280 Val ELBO: 37.7303, Epoch Time (s): 0.08, Total Time (hrs): 0.0303
# ====> Epoch: 1110 Train ELBO: 76.2032 Val ELBO: 39.8314, Epoch Time (s): 0.07, Total Time (hrs): 0.0303
# ====> Epoch: 1111 Train ELBO: 76.2014 Val ELBO: 43.3336, Epoch Time (s): 0.09, Total Time (hrs): 0.0303
# ====> Epoch: 1112 Train ELBO: 77.0496 Val ELBO: 40.7491, Epoch Time (s): 0.07, Total Time (hrs): 0.0304
# ====> Epoch: 1113 Train ELBO: 75.7376 Val ELBO: 39.8158, Epoch Time (s): 0.07, Total Time (hrs): 0.0304
# ====> Epoch: 1114 Train ELBO: 76.7288 Val ELBO: 39.5034, Epoch Time (s): 0.07, Total Time (hrs): 0.0304
# ====> Epoch: 1115 Train ELBO: 75.7554 Val ELBO: 45.3891, Epoch Time (s): 0.07, Total Time (hrs): 0.0304
# ====> Epoch: 1116 Train ELBO: 74.4439 Val ELBO: 31.3407, Epoch Time (s): 0.07, Total Time (hrs): 0.0304
# ====> Epoch: 1117 Train ELBO: 76.4528 Val ELBO: 50.0507, Epoch Time (s): 0.07, Total Time (hrs): 0.0304
# ====> Epoch: 1118 Train ELBO: 75.1235 Val ELBO: 36.7537, Epoch Time (s): 0.08, Total Time (hrs): 0.0305
# ====> Epoch: 1119 Train ELBO: 73.5910 Val ELBO: 43.2157, Epoch Time (s): 0.07, Total Time (hrs): 0.0305
# ====> Epoch: 1120 Train ELBO: 74.8513 Val ELBO: 39.4031, Epoch Time (s): 0.07, Total Time (hrs): 0.0305
# ====> Epoch: 1121 Train ELBO: 73.7534 Val ELBO: 34.0849, Epoch Time (s): 0.07, Total Time (hrs): 0.0305
# ====> Epoch: 1122 Train ELBO: 69.3362 Val ELBO: 33.3720, Epoch Time (s): 0.08, Total Time (hrs): 0.0306
# ====> Epoch: 1123 Train ELBO: 65.1438 Val ELBO: 30.5376, Epoch Time (s): 0.07, Total Time (hrs): 0.0306
# ====> Epoch: 1124 Train ELBO: 67.3110 Val ELBO: 40.7229, Epoch Time (s): 0.08, Total Time (hrs): 0.0306
# ====> Epoch: 1125 Train ELBO: 67.9453 Val ELBO: 31.7283, Epoch Time (s): 0.07, Total Time (hrs): 0.0306
# ====> Epoch: 1126 Train ELBO: 69.1360 Val ELBO: 26.7498, Epoch Time (s): 0.07, Total Time (hrs): 0.0306
# ====> Epoch: 1127 Train ELBO: 70.0527 Val ELBO: 38.1715, Epoch Time (s): 0.07, Total Time (hrs): 0.0307
# ====> Epoch: 1128 Train ELBO: 71.0521 Val ELBO: 42.9922, Epoch Time (s): 0.07, Total Time (hrs): 0.0307
# ====> Epoch: 1129 Train ELBO: 74.6125 Val ELBO: 42.2728, Epoch Time (s): 0.06, Total Time (hrs): 0.0307
# ====> Epoch: 1130 Train ELBO: 74.3589 Val ELBO: 44.1902, Epoch Time (s): 0.06, Total Time (hrs): 0.0307
# ====> Epoch: 1131 Train ELBO: 77.1337 Val ELBO: 43.1449, Epoch Time (s): 0.07, Total Time (hrs): 0.0307
# ====> Epoch: 1132 Train ELBO: 78.0283 Val ELBO: 42.2182, Epoch Time (s): 0.07, Total Time (hrs): 0.0308
# ====> Epoch: 1133 Train ELBO: 74.6564 Val ELBO: 43.2375, Epoch Time (s): 0.07, Total Time (hrs): 0.0308
# ====> Epoch: 1134 Train ELBO: 73.5678 Val ELBO: 42.0831, Epoch Time (s): 0.07, Total Time (hrs): 0.0308
# ====> Epoch: 1135 Train ELBO: 76.0111 Val ELBO: 43.5741, Epoch Time (s): 0.07, Total Time (hrs): 0.0308
# ====> Epoch: 1136 Train ELBO: 75.9670 Val ELBO: 35.3279, Epoch Time (s): 0.07, Total Time (hrs): 0.0308
# ====> Epoch: 1137 Train ELBO: 74.3418 Val ELBO: 45.0754, Epoch Time (s): 0.06, Total Time (hrs): 0.0308
# ====> Epoch: 1138 Train ELBO: 75.7797 Val ELBO: 42.9319, Epoch Time (s): 0.07, Total Time (hrs): 0.0309
# ====> Epoch: 1139 Train ELBO: 75.4467 Val ELBO: 41.7330, Epoch Time (s): 0.08, Total Time (hrs): 0.0309
# ====> Epoch: 1140 Train ELBO: 75.5421 Val ELBO: 51.8203, Epoch Time (s): 0.07, Total Time (hrs): 0.0309
# ====> Epoch: 1141 Train ELBO: 76.9488 Val ELBO: 40.2503, Epoch Time (s): 0.07, Total Time (hrs): 0.0309
# ====> Epoch: 1142 Train ELBO: 75.2942 Val ELBO: 46.7187, Epoch Time (s): 0.07, Total Time (hrs): 0.0310
# ====> Epoch: 1143 Train ELBO: 73.1068 Val ELBO: 40.7042, Epoch Time (s): 0.07, Total Time (hrs): 0.0310
# ====> Epoch: 1144 Train ELBO: 72.8660 Val ELBO: 35.2925, Epoch Time (s): 0.06, Total Time (hrs): 0.0310
# ====> Epoch: 1145 Train ELBO: 71.7989 Val ELBO: 29.4276, Epoch Time (s): 0.07, Total Time (hrs): 0.0310
# ====> Epoch: 1146 Train ELBO: 75.2844 Val ELBO: 49.6392, Epoch Time (s): 0.07, Total Time (hrs): 0.0310
# ====> Epoch: 1147 Train ELBO: 74.3906 Val ELBO: 44.9689, Epoch Time (s): 0.08, Total Time (hrs): 0.0311
# ====> Epoch: 1148 Train ELBO: 72.8655 Val ELBO: 32.0544, Epoch Time (s): 0.08, Total Time (hrs): 0.0311
# ====> Epoch: 1149 Train ELBO: 75.9137 Val ELBO: 38.5785, Epoch Time (s): 0.07, Total Time (hrs): 0.0311
# ====> Epoch: 1150 Train ELBO: 65.9706 Val ELBO: 41.2645, Epoch Time (s): 0.07, Total Time (hrs): 0.0311
# ====> Epoch: 1151 Train ELBO: 73.8206 Val ELBO: 36.6450, Epoch Time (s): 0.07, Total Time (hrs): 0.0311
# ====> Epoch: 1152 Train ELBO: 75.8122 Val ELBO: 38.2323, Epoch Time (s): 0.07, Total Time (hrs): 0.0312
# ====> Epoch: 1153 Train ELBO: 75.3501 Val ELBO: 46.1972, Epoch Time (s): 0.07, Total Time (hrs): 0.0312
# ====> Epoch: 1154 Train ELBO: 75.0103 Val ELBO: 45.8492, Epoch Time (s): 0.08, Total Time (hrs): 0.0312
# ====> Epoch: 1155 Train ELBO: 73.1057 Val ELBO: 38.1301, Epoch Time (s): 0.07, Total Time (hrs): 0.0312
# ====> Epoch: 1156 Train ELBO: 71.9344 Val ELBO: 13.6127, Epoch Time (s): 0.06, Total Time (hrs): 0.0312
# ====> Epoch: 1157 Train ELBO: 64.6043 Val ELBO: 31.3665, Epoch Time (s): 0.07, Total Time (hrs): 0.0312
# ====> Epoch: 1158 Train ELBO: 73.4171 Val ELBO: 47.2914, Epoch Time (s): 0.07, Total Time (hrs): 0.0313
# ====> Epoch: 1159 Train ELBO: 70.7127 Val ELBO: 40.1080, Epoch Time (s): 0.07, Total Time (hrs): 0.0313
# ====> Epoch: 1160 Train ELBO: 74.9826 Val ELBO: 42.8391, Epoch Time (s): 0.07, Total Time (hrs): 0.0313
# ====> Epoch: 1161 Train ELBO: 75.9363 Val ELBO: 44.3638, Epoch Time (s): 0.06, Total Time (hrs): 0.0313
# ====> Epoch: 1162 Train ELBO: 71.7616 Val ELBO: 27.4326, Epoch Time (s): 0.07, Total Time (hrs): 0.0313
# ====> Epoch: 1163 Train ELBO: 71.7322 Val ELBO: 29.3596, Epoch Time (s): 0.07, Total Time (hrs): 0.0314
# ====> Epoch: 1164 Train ELBO: 73.8000 Val ELBO: 44.8738, Epoch Time (s): 0.07, Total Time (hrs): 0.0314
# ====> Epoch: 1165 Train ELBO: 77.3649 Val ELBO: 43.2745, Epoch Time (s): 0.07, Total Time (hrs): 0.0314
# ====> Epoch: 1166 Train ELBO: 75.4275 Val ELBO: 42.3138, Epoch Time (s): 0.07, Total Time (hrs): 0.0314
# ====> Epoch: 1167 Train ELBO: 78.6882 Val ELBO: 51.1637, Epoch Time (s): 0.07, Total Time (hrs): 0.0314
# ====> Epoch: 1168 Train ELBO: 78.9998 Val ELBO: 40.7137, Epoch Time (s): 0.07, Total Time (hrs): 0.0315
# ====> Epoch: 1169 Train ELBO: 75.0794 Val ELBO: 41.5760, Epoch Time (s): 0.08, Total Time (hrs): 0.0315
# ====> Epoch: 1170 Train ELBO: 76.0465 Val ELBO: 46.2178, Epoch Time (s): 0.06, Total Time (hrs): 0.0315
# ====> Epoch: 1171 Train ELBO: 76.8575 Val ELBO: 45.3590, Epoch Time (s): 0.07, Total Time (hrs): 0.0315
# ====> Epoch: 1172 Train ELBO: 78.4372 Val ELBO: 44.7185, Epoch Time (s): 0.07, Total Time (hrs): 0.0315
# ====> Epoch: 1173 Train ELBO: 75.0122 Val ELBO: 48.5411, Epoch Time (s): 0.07, Total Time (hrs): 0.0316
# ====> Epoch: 1174 Train ELBO: 77.8642 Val ELBO: 33.9511, Epoch Time (s): 0.07, Total Time (hrs): 0.0316
# ====> Epoch: 1175 Train ELBO: 76.8725 Val ELBO: 41.7753, Epoch Time (s): 0.07, Total Time (hrs): 0.0316
# ====> Epoch: 1176 Train ELBO: 73.9745 Val ELBO: 32.4532, Epoch Time (s): 0.07, Total Time (hrs): 0.0316
# ====> Epoch: 1177 Train ELBO: 72.2866 Val ELBO: 36.7507, Epoch Time (s): 0.07, Total Time (hrs): 0.0316
# ====> Epoch: 1178 Train ELBO: 70.5565 Val ELBO: 47.5131, Epoch Time (s): 0.07, Total Time (hrs): 0.0316
# ====> Epoch: 1179 Train ELBO: 76.0464 Val ELBO: 34.4586, Epoch Time (s): 0.07, Total Time (hrs): 0.0317
# ====> Epoch: 1180 Train ELBO: 73.1236 Val ELBO: 35.6865, Epoch Time (s): 0.07, Total Time (hrs): 0.0317
# ====> Epoch: 1181 Train ELBO: 76.0387 Val ELBO: 44.5706, Epoch Time (s): 0.07, Total Time (hrs): 0.0317
# ====> Epoch: 1182 Train ELBO: 76.2285 Val ELBO: 36.8138, Epoch Time (s): 0.07, Total Time (hrs): 0.0317
# ====> Epoch: 1183 Train ELBO: 74.0912 Val ELBO: 30.1636, Epoch Time (s): 0.07, Total Time (hrs): 0.0317
# ====> Epoch: 1184 Train ELBO: 73.9931 Val ELBO: 39.6744, Epoch Time (s): 0.08, Total Time (hrs): 0.0318
# ====> Epoch: 1185 Train ELBO: 67.3585 Val ELBO: 43.4450, Epoch Time (s): 0.07, Total Time (hrs): 0.0318
# ====> Epoch: 1186 Train ELBO: 76.2449 Val ELBO: 44.9314, Epoch Time (s): 0.07, Total Time (hrs): 0.0318
# ====> Epoch: 1187 Train ELBO: 78.3277 Val ELBO: 46.3839, Epoch Time (s): 0.06, Total Time (hrs): 0.0318
# ====> Epoch: 1188 Train ELBO: 75.4611 Val ELBO: 43.9085, Epoch Time (s): 0.07, Total Time (hrs): 0.0318
# ====> Epoch: 1189 Train ELBO: 78.0751 Val ELBO: 35.7199, Epoch Time (s): 0.07, Total Time (hrs): 0.0319
# ====> Epoch: 1190 Train ELBO: 76.6957 Val ELBO: 50.9607, Epoch Time (s): 0.07, Total Time (hrs): 0.0319
# ====> Epoch: 1191 Train ELBO: 75.7190 Val ELBO: 39.3805, Epoch Time (s): 0.06, Total Time (hrs): 0.0319
# ====> Epoch: 1192 Train ELBO: 77.1222 Val ELBO: 45.7555, Epoch Time (s): 0.07, Total Time (hrs): 0.0319
# ====> Epoch: 1193 Train ELBO: 78.7655 Val ELBO: 42.4842, Epoch Time (s): 0.07, Total Time (hrs): 0.0319
# ====> Epoch: 1194 Train ELBO: 75.9164 Val ELBO: 32.0197, Epoch Time (s): 0.07, Total Time (hrs): 0.0319
# ====> Epoch: 1195 Train ELBO: 75.8943 Val ELBO: 46.7933, Epoch Time (s): 0.07, Total Time (hrs): 0.0320
# ====> Epoch: 1196 Train ELBO: 78.3147 Val ELBO: 51.8699, Epoch Time (s): 0.07, Total Time (hrs): 0.0320
# ====> Epoch: 1197 Train ELBO: 77.7656 Val ELBO: 33.1474, Epoch Time (s): 0.07, Total Time (hrs): 0.0320
# ====> Epoch: 1198 Train ELBO: 76.7302 Val ELBO: 42.7077, Epoch Time (s): 0.08, Total Time (hrs): 0.0320
# ====> Epoch: 1199 Train ELBO: 77.8744 Val ELBO: 48.9282, Epoch Time (s): 0.08, Total Time (hrs): 0.0321
# ====> Epoch: 1200 Train ELBO: 81.4949 Val ELBO: 47.8104, Epoch Time (s): 0.07, Total Time (hrs): 0.0321
# ====> Epoch: 1201 Train ELBO: 79.6774 Val ELBO: 47.3255, Epoch Time (s): 0.06, Total Time (hrs): 0.0321
# ====> Epoch: 1202 Train ELBO: 80.3910 Val ELBO: 45.3815, Epoch Time (s): 0.12, Total Time (hrs): 0.0321
# ====> Epoch: 1203 Train ELBO: 77.4423 Val ELBO: 49.4900, Epoch Time (s): 0.07, Total Time (hrs): 0.0321
# ====> Epoch: 1204 Train ELBO: 81.0533 Val ELBO: 51.4753, Epoch Time (s): 0.07, Total Time (hrs): 0.0322
# ====> Epoch: 1205 Train ELBO: 74.8130 Val ELBO: 45.7893, Epoch Time (s): 0.07, Total Time (hrs): 0.0322
# ====> Epoch: 1206 Train ELBO: 78.2818 Val ELBO: 49.6821, Epoch Time (s): 0.07, Total Time (hrs): 0.0322
# ====> Epoch: 1207 Train ELBO: 76.2302 Val ELBO: 48.0318, Epoch Time (s): 0.07, Total Time (hrs): 0.0322
# ====> Epoch: 1208 Train ELBO: 79.3595 Val ELBO: 50.9303, Epoch Time (s): 0.07, Total Time (hrs): 0.0322
# ====> Epoch: 1209 Train ELBO: 80.7135 Val ELBO: 53.2587, Epoch Time (s): 0.07, Total Time (hrs): 0.0323
# ====> Epoch: 1210 Train ELBO: 79.8548 Val ELBO: 46.9439, Epoch Time (s): 0.07, Total Time (hrs): 0.0323
# ====> Epoch: 1211 Train ELBO: 80.1664 Val ELBO: 46.1852, Epoch Time (s): 0.10, Total Time (hrs): 0.0323
# ====> Epoch: 1212 Train ELBO: 82.3288 Val ELBO: 47.5579, Epoch Time (s): 0.08, Total Time (hrs): 0.0323
# ====> Epoch: 1213 Train ELBO: 80.7545 Val ELBO: 50.5049, Epoch Time (s): 0.07, Total Time (hrs): 0.0324
# ====> Epoch: 1214 Train ELBO: 81.9942 Val ELBO: 32.7850, Epoch Time (s): 0.08, Total Time (hrs): 0.0324
# ====> Epoch: 1215 Train ELBO: 82.3479 Val ELBO: 49.5701, Epoch Time (s): 0.07, Total Time (hrs): 0.0324
# ====> Epoch: 1216 Train ELBO: 82.4622 Val ELBO: 52.7386, Epoch Time (s): 0.06, Total Time (hrs): 0.0324
# ====> Epoch: 1217 Train ELBO: 83.1605 Val ELBO: 28.9729, Epoch Time (s): 0.06, Total Time (hrs): 0.0324
# ====> Epoch: 1218 Train ELBO: 76.8710 Val ELBO: 53.9164, Epoch Time (s): 0.07, Total Time (hrs): 0.0325
# ====> Epoch: 1219 Train ELBO: 76.6624 Val ELBO: 52.7266, Epoch Time (s): 0.07, Total Time (hrs): 0.0325
# ====> Epoch: 1220 Train ELBO: 70.9020 Val ELBO: 40.5697, Epoch Time (s): 0.06, Total Time (hrs): 0.0325
