# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (2.10.0+cu128)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.67.3)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (26.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.24.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1.0->pytorch_lightning) (1.3.4)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 20.7 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 60.0 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.15.3 pytorch_lightning-2.6.1 torchmetrics-1.8.2

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://github.com/gcalkins64/pipag_training.git
# Out:
# Cloning into 'pipag_training'...
# remote: Enumerating objects: 388, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 388 (delta 27), reused 12 (delta 8), pack-reused 337 (from 1)
# Receiving objects: 100% (388/388), 16.69 MiB | 13.99 MiB/s, done.
# Resolving deltas: 100% (210/210), done.

# %%
# %cd pipag_training
# !cd /content/pipag_training && git pull
# !git pull
sys.path.append('/content/pipag_training')
# Out:
# /content/pipag_training
# Already up to date.

# %%
# !ls
# Out:
#  compare_classification_accuracy.py	  models.py
#  compare_variance_gmvae.py		  move_figures_to_LB.py
#  generate_gif_from_pngs.py		 'old notebooks'
#  generate_training_json.py		  README.md
#  gmvae_common.py			  svd.py
#  JP_gmvae_aerocapture_BASE_copy.ipynb	  test_git_imports.ipynb
#  JP_gmvae_aerocapture_BASE.ipynb	  vae_aerocapture_vel.py
#  JP_gmvae_aerocapture_energy.ipynb	  VAE_Capture.ipynb
# 'JP_gmvae_aerocapture_SWEEP copy.ipynb'   VAE_sweep_arch.ipynb
#  JP_gmvae_aerocapture_SWEEP.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1305: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
# n_train = 1024
# n_val = 128
# n_test = 128
# For testing small batches of data
n_train = 800
n_val = 100
n_test = 100
# THREE LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = 24
hd1 = 30
hd2 = 20
hd3 = 10
hidden_dims = [hd1, hd2, hd3]
hidden_dims_r = [hd3, hd2, hd1]
# TWO LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = None
# hidden_dims = [hd1, hd2]

# latent_dims = [6]
# n_clustersS = [9]
# latent_dims = [3,4,5,6,7,8,9]
latent_dims = [5]
n_clustersS = [4]
skip_combos = []
lr = 1e-3
n_epochs = 15_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

plot_interval = 500
dpi = 300

D = 1  #num_modalities
# downsampleNum = 64
downsampleNum = 36 # Revision

loadFlag = False  # True to load in old case, False to run a new case

# data = '1_near_escape_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_fnpag_1999_inds_energy_scaled_downsampled_'
# tag = 'near_escape'

# data = '1_near_crash_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_crash_fnpag_2000_inds_energy_scaled_downsampled_'
# tag = 'near_crash'

# data = 'UOP_inc_lit_disps_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_inc_lit_disps_4999_inds_energy_scaled_downsampled_'
# tag = 'near_escape_OLD'

# data = 'UOP_near_crash_steeper_5000_data_energy_scaled_downsampled_'
# inds = 'UOP_near_crash_steeper_4997_inds_energy_scaled_downsampled_'
# tag = 'near_crash_OLD'

# data = '1_near_escape_new_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_new_2000_inds_energy_scaled_downsampled_'
# tag = 'near_escape_new'

# data = 'rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_'
# inds = 'rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_'
# tag = 'rev_gu_mixture'
# dataName = 'velocity_fpa'

# data = 'rev_gumixture_1000_data_energy_scaled_downsampled_'
# inds = 'rev_gumixture_1000_inds_energy_scaled_downsampled_'
# tag = 'rev_gu_mixture_energy'
# dataName = 'energy'

data = 'rev_gumixture_dp15_more_downwards_1000_data_energy_scaled_downsampled_'
inds = 'rev_gumixture_dp15_more_downwards_1000_inds_energy_scaled_downsampled_'
tag = 'rev_gu_mixture_energy_biased_down'
dataName = 'energy'

# %%
# !ls /content/drive/MyDrive/rev_pipag_data/
# Out:
# gmvae_rev_gu_mixture_20260216_184454_L5_C3
# gmvae_rev_gu_mixture_20260216_185127_L6_C3
# gmvae_rev_gu_mixture_20260216_190125_L5_C4
# gmvae_rev_gu_mixture_20260216_190656_L6_C4
# gmvae_rev_gu_mixture_20260216_191906_L5_C5
# gmvae_rev_gu_mixture_20260216_192236_L6_C5
# gmvae_rev_gu_mixture_20260216_193657_L5_C6
# gmvae_rev_gu_mixture_20260216_193840_L6_C6
# gmvae_rev_gu_mixture_20260216_201930_L7_C3
# gmvae_rev_gu_mixture_20260216_201945_L8_C3
# gmvae_rev_gu_mixture_20260216_203450_L7_C4
# gmvae_rev_gu_mixture_20260216_203532_L8_C4
# gmvae_rev_gu_mixture_20260216_205019_L7_C5
# gmvae_rev_gu_mixture_20260216_205122_L8_C5
# gmvae_rev_gu_mixture_20260216_210557_L7_C6
# gmvae_rev_gu_mixture_20260216_210713_L8_C6
# gmvae_rev_gu_mixture_20260216_221130_L5_C7
# gmvae_rev_gu_mixture_20260216_221251_L5_C3_24_18_12
# gmvae_rev_gu_mixture_20260216_221358_L5_C7
# gmvae_rev_gu_mixture_20260216_222846_L5_C4_24_18_12
# gmvae_rev_gu_mixture_20260216_223026_L5_C8
# gmvae_rev_gu_mixture_20260216_224438_L5_C5_24_18_12
# gmvae_rev_gu_mixture_20260216_224634_L6_C7
# gmvae_rev_gu_mixture_20260216_231212_L5_C6_24_18_12
# gmvae_rev_gu_mixture_20260216_231213_L6_C8
# gmvae_rev_gu_mixture_20260216_232708_L7_C7
# gmvae_rev_gu_mixture_20260216_232738_L6_C3_24_18_12
# gmvae_rev_gu_mixture_20260216_234208_L7_C8
# gmvae_rev_gu_mixture_20260216_234341_L6_C4_24_18_12
# gmvae_rev_gu_mixture_20260216_235712_L8_C7
# gmvae_rev_gu_mixture_20260216_235933_L6_C5_24_18_12
# gmvae_rev_gu_mixture_20260217_001230_L8_C8
# gmvae_rev_gu_mixture_20260217_001541_L6_C6_24_18_12
# gmvae_rev_gu_mixture_20260217_003159_L7_C3_24_18_12
# gmvae_rev_gu_mixture_20260217_004818_L7_C4_24_18_12
# gmvae_rev_gu_mixture_20260217_010413_L7_C5_24_18_12
# gmvae_rev_gu_mixture_20260217_034212_L5_C3
# gmvae_rev_gu_mixture_20260217_034216_L6_C3
# gmvae_rev_gu_mixture_20260217_035654_L6_C4
# gmvae_rev_gu_mixture_20260217_035749_L5_C4
# gmvae_rev_gu_mixture_20260217_041343_L5_C5
# gmvae_rev_gu_mixture_20260217_042650_L6_C6
# gmvae_rev_gu_mixture_20260217_042947_L5_C6
# gmvae_rev_gu_mixture_energy_20260217_181312_L5_C5
# gmvae_rev_gu_mixture_energy_20260217_181348_L5_C3
# gmvae_rev_gu_mixture_energy_20260217_182833_L5_C4
# gmvae_rev_gu_mixture_energy_20260217_182842_L5_C6
# gmvae_rev_gu_mixture_energy_20260217_184319_L6_C3
# gmvae_rev_gu_mixture_energy_20260217_184424_L6_C5
# gmvae_rev_gu_mixture_energy_20260217_185813_L6_C4
# gmvae_rev_gu_mixture_energy_20260217_190003_L6_C6
# gmvae_rev_gu_mixture_energy_20260217_191317_L7_C3
# gmvae_rev_gu_mixture_energy_20260217_191558_L7_C5
# gmvae_rev_gu_mixture_energy_20260217_192829_L7_C4
# gmvae_rev_gu_mixture_energy_20260217_193201_L7_C6
# gmvae_rev_gu_mixture_energy_20260218_000315_L5_C7
# gmvae_rev_gu_mixture_energy_20260218_000322_L8_C3
# gmvae_rev_gu_mixture_energy_20260218_001906_L8_C4
# gmvae_rev_gu_mixture_energy_20260218_002010_L5_C8
# gmvae_rev_gu_mixture_energy_20260218_003512_L8_C5
# gmvae_rev_gu_mixture_energy_20260218_003725_L6_C7
# gmvae_rev_gu_mixture_energy_20260218_005116_L8_C6
# gmvae_rev_gu_mixture_energy_20260218_011222_L6_C8
# gmvae_rev_gu_mixture_energy_20260218_011225_L8_C7
# gmvae_rev_gu_mixture_energy_20260218_012805_L8_C8
# gmvae_rev_gu_mixture_energy_20260218_012918_L7_C7
# gmvae_rev_gu_mixture_energy_20260218_014406_L9_C7
# gmvae_rev_gu_mixture_energy_20260218_014631_L7_C8
# gmvae_rev_gu_mixture_energy_20260218_015955_L9_C8
# gmvae_rev_gu_mixture_energy_20260218_211300_L9_C3
# gmvae_rev_gu_mixture_energy_20260218_211315_L9_C5
# gmvae_rev_gu_mixture_energy_20260218_212759_L9_C4
# gmvae_rev_gu_mixture_energy_20260218_212935_L9_C6
# gmvae_rev_gu_mixture_energy_biased_down_20260221_234903_L7_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260221_234920_L3_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_001119_L3_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_001514_L7_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_003345_L3_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_004152_L7_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_005654_L3_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_010903_L7_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_012030_L3_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_044731_L7_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_044827_L3_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_051155_L3_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_051250_L7_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_053457_L4_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_053647_L7_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_055734_L4_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_060048_L8_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_065508_L8_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_065517_L4_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_071818_L8_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_072116_L4_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_074139_L8_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_074639_L4_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_080533_L8_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260222_081213_L4_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_024308_L8_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_024328_L4_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_030455_L8_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_030531_L5_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_032658_L9_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_034937_L9_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_034940_L5_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_041207_L5_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_201426_L9_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_201512_L5_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_203727_L5_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_204218_L9_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_210002_L5_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_211041_L9_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_212252_L6_C3_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_213859_L9_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_230824_L6_C4_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_230826_L9_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_233138_L6_C5_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260223_233722_L3_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260223_235531_L6_C6_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260224_000019_L3_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_001941_L6_C7_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260224_002347_L3_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_004338_L6_C8_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260224_004618_L3_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_010834_L3_C7_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_013007_L6_C9_30_20_10
# gmvae_rev_gu_mixture_energy_biased_down_20260224_013957_L3_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_014112_L3_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_015723_L6_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_020125_L3_C9_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_022046_L6_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_022142_L4_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_024140_L4_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_024424_L6_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_030153_L4_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_030819_L6_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_032223_L4_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_034239_L4_C7_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_040536_L4_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_041832_L6_C7_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_043329_L4_C9_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_044759_L9_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_045335_L5_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_051043_L9_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_051337_L5_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_053347_L5_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_053357_L9_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_055358_L5_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_055718_L9_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_061429_L5_C7_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_063511_L5_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_065554_L5_C9_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_071645_L6_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_073732_L6_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_075824_L6_C9_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_081919_L7_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_083957_L7_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_090046_L7_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_092127_L7_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_094212_L7_C7_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_100257_L7_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_102350_L7_C9_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_104447_L8_C3_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_110523_L8_C4_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_112600_L8_C5_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_114729_L8_C6_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_120858_L8_C7_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_144645_L9_C7_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_144657_L8_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_150637_L8_C9_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_150934_L9_C8_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_153246_L9_C9_24_18_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_160040_L3_C3_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_160042_L4_C3_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_162145_L4_C4_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_162307_L3_C4_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_164306_L4_C5_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_164530_L3_C5_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_170435_L4_C6_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_170821_L3_C6_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_172618_L4_C7_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_173149_L3_C7_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_174829_L4_C8_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_181048_L4_C9_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_181402_L3_C8_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_183231_L5_C3_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_183739_L3_C9_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_185352_L5_C4_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_191515_L5_C5_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_193703_L5_C6_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_200045_L5_C7_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_202452_L5_C8_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_204912_L5_C9_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_210721_L9_C3_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_211557_L6_C3_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_212924_L9_C4_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_213528_L6_C4_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_215152_L9_C5_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_215503_L6_C5_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_221444_L6_C6_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_221528_L9_C6_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_223427_L6_C7_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_223835_L9_C7_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_225420_L6_C8_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_230507_L9_C8_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_231410_L6_C9_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_232745_L9_C9_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_233410_L7_C3_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260224_235355_L7_C4_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_001339_L7_C5_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_003336_L7_C6_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_004808_L8_C7_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_005545_L7_C7_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_011139_L8_C8_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_011806_L7_C8_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_013459_L8_C9_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_014130_L7_C9_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_020509_L8_C3_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_022738_L8_C4_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_024827_L8_C5_36_24_12
# gmvae_rev_gu_mixture_energy_biased_down_20260225_030918_L8_C6_36_24_12
# rev_gumixture_1000_data_energy_scaled_downsampled_.json
# rev_gumixture_1000_data_velocity_fpa_scaled_downsampled_.json
# rev_gumixture_1000_inds_energy_scaled_downsampled_.json
# rev_gumixture_1000_inds_velocity_fpa_scaled_downsampled_.json
# rev_gumixture_dp15_more_downwards_1000_data_energy_scaled_downsampled_.json
# rev_gumixture_dp15_more_downwards_1000_inds_energy_scaled_downsampled_.json

# %% [markdown]
# # LOOP GMVAE TRAINING

# %%
for latent_dim in latent_dims:
   for n_clusters in n_clustersS:
      if [latent_dim, n_clusters] in skip_combos:
        continue
      else:
          K = n_clusters
          Z = latent_dim

          from datetime import datetime
          timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

          if loadFlag:  # Load in old data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", 'gmvae_em_aerocapture_energy_20250429_155508_5_4')
          else:  # generate new data
              dirname = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters)+"_"+str(hd1)+"_"+str(hd2)+"_"+str(hd3))
          os.makedirs(dirname, exist_ok=True)
          print("Filepath directory: " + dirname)

          if loadFlag:  # load old data
              postfix = '_42_1024_128_128_32_16_5_4_0.001000_128_0.001000_0.000010_1000.000000_'
          else:  # Generate new suffix
              if hd3 is not None:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
              else:
                  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
                  SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
          print("Filepath postfix: " + postfix)

          data_dir = os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{data}.json")

          with open(os.path.join("/content", "drive", "MyDrive", "rev_pipag_data", f"{inds}.json"), 'r') as f:
              sample_list_load = json.load(f)
          sample_list = [int(sample) for sample in sample_list_load['sample_list']]
          print(sample_list)

          data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                          train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                          num_workers=0, dataName=dataName)

          data_module.setup("fit", sample_list = sample_list)

          train_loader = data_module.train_dataloader()
          val_loader = data_module.val_dataloader()
          test_loader = data_module.test_dataloader()
          data_dim = len(train_loader.dataset[0][0])
          text_labels = ['capture', 'escape', 'impact']
          label_colors = ['C2', 'C3', 'C4']

          num_train_batches = len(train_loader)

          ts_plot = np.linspace(0,450,36)
          seabornSettings()
          fig, ax = plt.subplots(figsize=(4, 4))
          for j in range(n_train):
              ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.75)

          eline = mlines.Line2D([], [], color='C2', label='Escape')
          cline = mlines.Line2D([], [], color='C3', label='Capture')
          iline = mlines.Line2D([], [], color='C4', label='Impact')
          plt.legend(handles=[eline, cline, iline])
          plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
          plt.xlabel("Time [s]")
          plt.ylabel("Nondimensionalized Energy")
          plt.title("Training Data")
          plt.tight_layout()
          fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_val):
              ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()])
          plt.title("Validation Data")
          fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_test):
              ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()])
          plt.title("Test Data")
          fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)
          # initialize latent GMM model parameters
          params = {}
          pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
          params['pi_c'] = torch.ones(K) / K
          params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
          params['logsigmasq_c'] = torch.zeros((K, Z))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]

          # initialize neural networks
          encoder_list = []
          decoder_list = []
          trainable_parameters = []
          trainable_parameters.append(pi_variables)

          for _ in range(D):
              encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims)
              decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var)
              encoder_list.append(encoder)
              decoder_list.append(decoder)
              trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

          optimizer = optim.Adam(trainable_parameters, lr=lr)

          # training

          import time
          ts = time.time()
          tic = time.perf_counter()

          train_loss = torch.zeros(n_epochs)
          train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
          val_loss = torch.zeros(n_epochs)
          pi_history = torch.zeros((n_epochs, K))
          train_mse_history = torch.zeros(n_epochs)
          val_mse_history = torch.zeros(n_epochs)
          min_val_loss = torch.inf
          seabornSettings()

          for epoch in range(n_epochs):
              ti = time.time()
              for encoder in encoder_list:
                  encoder.train()
              for decoder in decoder_list:
                  decoder.train()

              train_elbo = 0
              train_mse = 0
              train_elbo_term = np.zeros(4)
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

              for (batch_idx, batch) in enumerate(train_loader):
                  batch_x, _ = batch
                  x_list = [batch_x]  # assume D=2 and each modality has data_dim
                  optimizer.zero_grad()
                  pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
                  params['pi_c'] = pi_c

                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma

                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                  train_elbo += elbo.item()
                  train_elbo_term += elbo_terms
                  train_mse += sse.item()
                  loss = - elbo / batch_x.shape[0]
                  loss.backward()
                  optimizer.step()

              for encoder in encoder_list:
                  encoder.eval()
              for decoder in decoder_list:
                  decoder.eval()

              if epoch % plot_interval == 0 or epoch == n_epochs:
                  # Plot the first two dimensions of the latents
                  with torch.no_grad():
                      means = []
                      samples = []
                      labels = []
                      for batch in train_loader:
                          batch_x, batch_label = batch
                          x_list = [batch_x]
                          mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                          sigma = torch.exp(0.5 * logsigmasq)
                          eps = Normal(0, 1).sample(mean.shape)
                          z = mean + eps * sigma
                          means.append(mean)
                          samples.append(z)
                          labels.append(batch_label)

                  means = torch.vstack(means).cpu()
                  samples = torch.vstack(samples).cpu()
                  labels = torch.hstack(labels).cpu()

                  savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

                  savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
                  plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


                  # plot samples from generative model
                  n_gen = n_train
                  cluster_probs = params['pi_c'].cpu().detach().numpy() #
                  fig, ax = plt.subplots(figsize=(4.5, 4))
                  for j in range(n_gen):
                      c = np.random.choice(K, p=cluster_probs)
                      mu_c = params['mu_c'][c].clone().detach()
                      sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
                      z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
                      mu_x = decoder.forward(z)[0]
                      ax.plot(mu_x.cpu().detach().numpy())
                  fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
                  plt.close()


              val_elbo = 0
              val_mse = 0
              val_elbo_term = np.zeros(4)
              with torch.no_grad():
                  for (batch_idx, batch) in enumerate(val_loader):
                      batch_x, _ = batch
                      x_list = [batch_x]
                      mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                      sigma = torch.exp(0.5 * logsigmasq)
                      eps = Normal(0, 1).sample(mu.shape)
                      z = mu + eps * sigma
                      with torch.no_grad():
                          gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
                      elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
                      val_elbo += elbo.item()
                      val_mse += sse.item()
                      val_elbo_term += elbo_items

              train_elbo /= len(train_loader.dataset)
              train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
              val_elbo /= len(val_loader.dataset)
              val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
              train_mse /= len(train_loader.dataset)
              val_mse /= len(val_loader.dataset)

              tf = time.time()
              toc = time.perf_counter()
              print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

              train_loss[epoch] = - train_elbo
              val_loss[epoch] = - val_elbo
              train_elbo_terms[epoch,:] = - train_elbo_term
              val_elbo_terms[epoch,:] = - val_elbo_term
              pi_history[epoch] = params['pi_c']
              train_mse_history[epoch] = train_mse
              val_mse_history[epoch] = val_mse

              if - val_elbo < min_val_loss:
                  min_val_loss = - val_elbo
                  torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
                  torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
                  torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
                  torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
                  torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

              if epoch % plot_interval == 0 or epoch == n_epochs:
                # Plot the training and validation loss vs. epoch number
                plt.figure(figsize=(4.5, 4))
                # const = min(min(train_loss), min(val_loss))
                train_loss_adjusted = train_loss
                val_loss_adjusted = val_loss
                plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
                # print(train_loss_adjusted.cpu()[:epoch])
                plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
                plt.yscale('symlog')
                plt.xlabel("number of epochs")
                plt.ylabel("loss")
                plt.title("Negative Loss")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot each term of the training loss and validation loss
                plt.figure(figsize=(4.5, 4))
                labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
                for ii in range(4):
                    train_loss_adjusted = train_elbo_terms[:epoch, ii]
                    val_loss_adjusted = val_elbo_terms[:epoch, ii]
                    plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
                    plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
                plt.xlabel("number of epochs")
                plt.yscale('symlog')
                plt.ylabel("loss")
                plt.title("Negative Loss Terms")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the training and validation mse vs. epoch number
                plt.figure(figsize=(4.5, 4))
                plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
                plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()

                # Plot the history of pi
                plt.figure(figsize=(4.5, 4))
                for i in range(K):
                    plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
                plt.xlabel("number of epochs")
                plt.legend()
                plt.tight_layout()
                plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
                plt.close()


          te = time.time()
          import datetime
          duration = datetime.timedelta(seconds=te - ts)
          print("Training took ", duration)

          # Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
          torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))

          if loadFlag:
            path = dirname
            epoch = n_epochs - 1
          params = {}
          encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims).to("cuda")
          decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=hidden_dims_r, decoder_var=decoder_var).to("cuda")

          # Use if you need to load in the data
          if loadFlag:
            suffix = postfix
            encoder.load_state_dict(torch.load(os.path.join(path, f'encoder_{suffix}.pt'),map_location=torch.device('cpu')))
            decoder.load_state_dict(torch.load(os.path.join(path, f'decoder_{suffix}.pt'),map_location=torch.device('cpu')))
            logsigmasq = torch.load(os.path.join(path, f'gmm_params_logsigmasq_{suffix}.pt'),map_location=torch.device('cpu'))
            mu = torch.load(os.path.join(path, f'gmm_params_mu_{suffix}.pt'),map_location=torch.device('cpu'))
            pi = torch.load(os.path.join(path, f'gmm_params_pi_{suffix}.pt'),map_location=torch.device('cpu'))

          encoder_list = [encoder]
          decoder_list = [decoder]

          device = next(encoder.parameters()).device
          # Load in training history metrics
          pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
          train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
          val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
          train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
          val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
          train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
          val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


          text_labels = [f'Cluster {i}' for i in range((n_clusters))]
          label_colors = [f'C{i+1}' for i in range((n_clusters))]
          data_colors = label_colors

          # Plot training history
          # Plot the training and validation loss vs. epoch number
          plt.figure(figsize=(4, 4))
          const = min(min(train_loss), min(val_loss))
          # const = min(10, const)
          train_loss_adjusted = train_loss
          val_loss_adjusted = val_loss
          plt.plot(train_loss_adjusted.cpu(), label='Training')
          plt.plot(val_loss_adjusted.cpu(), label='Validation')
          plt.xlabel("Number of Epochs")
          plt.ylabel("Negative Loss")
          # plt.title("Negative Loss")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
          for ii in range(4):
              # print(train_elbo_terms.cpu()[ii, :epoch])
              # print(len(train_elbo_terms.cpu()[ii, :epoch]))
              train_loss_adjusted = train_elbo_terms[:, ii]
              val_loss_adjusted = val_elbo_terms[:, ii]
              plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
              plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Negative Loss Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()


          # Plot the sum of each term of the training loss and validation loss
          plt.figure(figsize=(4.5, 4))
          # print(train_elbo_terms.cpu()[ii, :epoch])
          # print(len(train_elbo_terms.cpu()[ii, :epoch]))
          train_loss_adjusted = train_elbo_terms.sum(axis=1)
          val_loss_adjusted = val_elbo_terms.sum(axis=1)
          plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
          plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
          plt.xlabel("number of epochs")
          plt.ylabel("loss")
          plt.title("Sum of ELBO Terms")
          plt.yscale('symlog')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the training and validation mse vs. epoch number
          plt.figure(figsize=(4.5, 4))
          plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
          plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
          plt.xlabel("number of epochs")
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Plot the history of pi
          plt.figure(figsize=(4, 4))
          for i in range(K):
              plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
          plt.xlabel("Number of Epochs")
          plt.ylabel("Predicted Cluster Probability")
          plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
          plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
          plt.legend()
          plt.tight_layout()
          plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
          # plt.close()

          # Load best model saved
          params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
          params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
          params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
          encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
          decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

          encoder.eval()
          decoder.eval()

          # run one last EM step and plot training data in latent space
          for encoder in encoder_list:
              encoder.eval()

          with torch.no_grad():
              means = []
              samples = []
              labels = []
              params['hist_weights'] = torch.zeros((K, 1))
              params['hist_mu_c'] = torch.zeros((K, latent_dim))
              params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
              for batch in train_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                  sigma = torch.exp(0.5 * logsigmasq)
                  eps = Normal(0, 1).sample(mu.shape)
                  z = mu + eps * sigma
                  with torch.no_grad():
                      gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
                  params['mu_c'] = mu_c
                  params['logsigmasq_c'] = logsigmasq_c

                  means.append(mu)
                  samples.append(z)
                  labels.append(batch_label)

          means = torch.vstack(means).cpu()
          samples = torch.vstack(samples).cpu()
          labels = torch.hstack(labels).cpu()


          savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
          plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
          plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot test data in latent space
          with torch.no_grad():
              test_means = []
              test_labels = []
              for batch in test_loader:
                  batch_x, batch_label = batch
                  x_list = [batch_x]
                  mean, _ = encoder_step(x_list, encoder_list, decoder_list)
                  test_means.append(mean)
                  test_labels.append(batch_label)

          test_means = torch.vstack(test_means).cpu()
          test_labels = torch.hstack(test_labels).cpu()


          savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
          plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

          # plot decoding results from cluster means # todo: expand this function for multi-modal data
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for i in range(K):
              # with torch.no_grad:
              x_mean = decoder.forward(params['mu_c'][i])[0]
              ax.plot(x_mean.cpu().detach().numpy(), label=r"decoded $\mu$"+str(i+1))
          ax.legend()
          plt.title("Decoded Means")
          fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
          # plt.close()

          # plot samples from generative model
          n_gen = n_train
          cluster_probs = params['pi_c'].cpu().detach().numpy()
          fig, ax = plt.subplots(figsize=(4.5, 4))
          for j in range(n_gen):
              c = np.random.choice(K, p=cluster_probs)
              # print(c)
              mu_c = params['mu_c'][c].cpu().clone().detach()
              sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
              z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
              # print(z)
              mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
              sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
              sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
              ax.plot(sample_x.cpu().detach().numpy())
          plt.title("Generated Samples")
          fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
          plt.close()

          # np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
              # train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
              # pi_history=pi_history.cpu().detach().numpy(),
              # cluster_probs=params['pi_c'].cpu().detach().numpy(),
              # cluster_means=params['mu_c'].cpu().detach().numpy(),
              # cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


          print("Training data size", n_train)
          print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
          print("Cluster 1 probability:", cluster_probs.min().item())

          # ---- CLEANUP ----
          del encoder
          del decoder
          del encoder_list
          del decoder_list
          del optimizer
          del train_loader
          del val_loader
          del test_loader
          del data_module
          del means
          del samples
          del labels
          del train_loss
          del val_loss
          del train_elbo_terms
          del val_elbo_terms
          del train_mse_history
          del val_mse_history
          del pi_history
          del params

          import gc
          gc.collect()
          torch.cuda.empty_cache()
# Out:
# Filepath directory: /content/drive/MyDrive/rev_pipag_data/gmvae_rev_gu_mixture_energy_biased_down_20260225_163948_L5_C4_30_20_10
# Filepath postfix: _42_800_100_100_30_20_10_5_4_0.001000_128_0.001000_0.000010_15000.000000_
# [543, 139, 827, 571, 171, 15, 199, 163, 416, 589, 492, 661, 556, 570, 177, 667, 354, 510, 778, 430, 319, 967, 860, 329, 633, 29, 404, 836, 847, 388, 885, 229, 69, 921, 132, 839, 96, 835, 227, 181, 968, 351, 925, 24, 336, 123, 759, 189, 455, 626, 862, 469, 110, 219, 285, 445, 738, 723, 179, 77, 353, 84, 424, 948, 963, 266, 735, 576, 83, 724, 259, 387, 959, 551, 733, 658, 260, 516, 806, 651, 11, 522, 343, 40, 493, 692, 919, 995, 558, 352, 359, 368, 251, 893, 479, 777, 102, 90, 870, 310, 538, 745, 891, 150, 380, 324, 505, 144, 375, 66, 656, 631, 216, 306, 987, 371, 673, 5, 190, 804, 487, 757, 153, 884, 78, 555, 438, 758, 21, 597, 706, 303, 254, 47, 373, 87, 224, 1, 523, 754, 247, 390, 992, 986, 764, 947, 665, 527, 271, 322, 39, 586, 760, 148, 280, 678, 539, 26, 779, 335, 299, 439, 748, 140, 741, 494, 415, 30, 8, 914, 278, 514, 409, 498, 853, 822, 64, 52, 640, 103, 225, 557, 82, 742, 160, 363, 286, 880, 545, 924, 604, 376, 344, 502, 194, 563, 568, 526, 300, 927, 944, 496, 296, 23, 710, 378, 312, 323, 210, 517, 790, 625, 718, 890, 704, 566, 737, 432, 331, 550, 874, 372, 111, 427, 67, 230, 497, 488, 611, 408, 956, 128, 788, 783, 814, 34, 273, 459, 58, 993, 75, 426, 185, 466, 42, 751, 175, 482, 607, 531, 463, 172, 826, 863, 73, 781, 242, 241, 707, 326, 320, 582, 698, 346, 134, 327, 664, 700, 187, 183, 205, 410, 269, 696, 13, 898, 195, 917, 297, 464, 540, 248, 989, 41, 355, 95, 138, 164, 868, 699, 174, 629, 393, 107, 546, 904, 386, 622, 182, 867, 470, 690, 796, 521, 518, 660, 37, 930, 795, 889, 869, 499, 501, 437, 772, 151, 734, 902, 206, 731, 792, 905, 873, 512, 752, 365, 855, 528, 419, 773, 395, 184, 909, 829, 202, 131, 819, 657, 200, 274, 119, 485, 749, 101, 776, 596, 542, 418, 208, 56, 845, 209, 519, 221, 89, 789, 674, 805, 933, 669, 616, 381, 234, 328, 984, 304, 94, 142, 980, 358, 79, 524, 237, 121, 832, 43, 588, 676, 332, 800, 246, 133, 483, 965, 135, 53, 728, 431, 446, 928, 276, 173, 530, 609, 16, 309, 621, 389, 864, 726, 287, 261, 979, 547, 413, 105, 666, 294, 567, 275, 983, 383, 716, 315, 892, 577, 946, 552, 367, 683, 19, 985, 283, 220, 307, 876, 603, 239, 769, 701, 414, 215, 708, 338, 915, 774, 99, 955, 149, 711, 212, 337, 952, 113, 397, 982, 314, 693, 746, 385, 341, 852, 49, 178, 793, 771, 695, 828, 529, 672, 218, 481, 396, 20, 236, 452, 349, 214, 325, 975, 912, 536, 143, 932, 866, 270, 458, 775, 460, 770, 922, 645, 197, 856, 462, 807, 207, 255, 412, 203, 361, 612, 392, 86, 899, 405, 920, 28, 9, 926, 508, 14, 55, 249, 619, 3, 115, 594, 560, 808, 998, 117, 936, 291, 691, 490, 333, 233, 590, 937, 146, 243, 977, 450, 879, 677, 841, 374, 763, 451, 801, 532, 399, 688, 457, 950, 961, 653, 694, 895, 562, 797, 471, 442, 98, 268, 646, 785, 668, 434, 896, 714, 59, 940, 787, 476, 681, 311, 250, 957, 971, 990, 655, 169, 624, 671, 284, 475, 515, 71, 972, 823, 705, 72, 93, 507, 454, 578, 473, 191, 391, 960, 549, 684, 402, 581, 301, 421, 401, 0, 91, 755, 417, 340, 872, 644, 908, 159, 491, 837, 725, 384, 7, 461, 882, 730, 489, 258, 97, 815, 652, 465, 76, 593, 106, 595, 632, 180, 580, 305, 468, 65, 583, 824, 316, 689, 978, 293, 613, 330, 18, 288, 894, 659, 743, 598, 166, 736, 643, 916, 118, 675, 802, 157, 145, 537, 54, 756, 865, 818, 638, 45, 298, 591, 35, 168, 302, 31, 433, 996, 697, 51, 830, 112, 799, 970, 939, 641, 816, 345, 141, 575, 720, 838, 766, 686, 585, 423, 559, 147, 292, 57, 859, 425, 991, 687, 61, 232, 321, 941, 2, 584, 500, 561, 478, 608, 949, 544, 125, 534, 263, 721, 379, 122, 377, 525, 812, 903, 636, 615, 883, 610, 253, 918, 27, 136, 753, 362, 614, 938, 295, 553, 364, 124, 628, 506, 861, 226, 176, 886, 877, 654, 887, 116, 170, 192, 634, 834, 317, 712, 999, 257, 279, 520, 313, 719, 152, 277, 444, 436, 809, 129, 264, 334, 477, 605, 662, 394, 929, 265, 541, 486, 441, 350, 126, 627, 36, 851, 339, 104, 443, 74, 875, 821, 981, 403, 988, 953, 901, 784, 848, 966, 60, 100, 188, 411, 88, 740, 747, 974, 685, 348, 680, 198, 606, 435, 767, 484, 997, 618, 308, 25, 858, 620, 897, 165, 572, 878, 92, 154, 648, 642, 535, 913, 942, 356, 256, 84 ...
# Loading File...
# ...File Loaded
# Sample List: [543, 139, 827, 571, 171, 15, 199, 163, 416, 589, 492, 661, 556, 570, 177, 667, 354, 510, 778, 430, 319, 967, 860, 329, 633, 29, 404, 836, 847, 388, 885, 229, 69, 921, 132, 839, 96, 835, 227, 181, 968, 351, 925, 24, 336, 123, 759, 189, 455, 626, 862, 469, 110, 219, 285, 445, 738, 723, 179, 77, 353, 84, 424, 948, 963, 266, 735, 576, 83, 724, 259, 387, 959, 551, 733, 658, 260, 516, 806, 651, 11, 522, 343, 40, 493, 692, 919, 995, 558, 352, 359, 368, 251, 893, 479, 777, 102, 90, 870, 310, 538, 745, 891, 150, 380, 324, 505, 144, 375, 66, 656, 631, 216, 306, 987, 371, 673, 5, 190, 804, 487, 757, 153, 884, 78, 555, 438, 758, 21, 597, 706, 303, 254, 47, 373, 87, 224, 1, 523, 754, 247, 390, 992, 986, 764, 947, 665, 527, 271, 322, 39, 586, 760, 148, 280, 678, 539, 26, 779, 335, 299, 439, 748, 140, 741, 494, 415, 30, 8, 914, 278, 514, 409, 498, 853, 822, 64, 52, 640, 103, 225, 557, 82, 742, 160, 363, 286, 880, 545, 924, 604, 376, 344, 502, 194, 563, 568, 526, 300, 927, 944, 496, 296, 23, 710, 378, 312, 323, 210, 517, 790, 625, 718, 890, 704, 566, 737, 432, 331, 550, 874, 372, 111, 427, 67, 230, 497, 488, 611, 408, 956, 128, 788, 783, 814, 34, 273, 459, 58, 993, 75, 426, 185, 466, 42, 751, 175, 482, 607, 531, 463, 172, 826, 863, 73, 781, 242, 241, 707, 326, 320, 582, 698, 346, 134, 327, 664, 700, 187, 183, 205, 410, 269, 696, 13, 898, 195, 917, 297, 464, 540, 248, 989, 41, 355, 95, 138, 164, 868, 699, 174, 629, 393, 107, 546, 904, 386, 622, 182, 867, 470, 690, 796, 521, 518, 660, 37, 930, 795, 889, 869, 499, 501, 437, 772, 151, 734, 902, 206, 731, 792, 905, 873, 512, 752, 365, 855, 528, 419, 773, 395, 184, 909, 829, 202, 131, 819, 657, 200, 274, 119, 485, 749, 101, 776, 596, 542, 418, 208, 56, 845, 209, 519, 221, 89, 789, 674, 805, 933, 669, 616, 381, 234, 328, 984, 304, 94, 142, 980, 358, 79, 524, 237, 121, 832, 43, 588, 676, 332, 800, 246, 133, 483, 965, 135, 53, 728, 431, 446, 928, 276, 173, 530, 609, 16, 309, 621, 389, 864, 726, 287, 261, 979, 547, 413, 105, 666, 294, 567, 275, 983, 383, 716, 315, 892, 577, 946, 552, 367, 683, 19, 985, 283, 220, 307, 876, 603, 239, 769, 701, 414, 215, 708, 338, 915, 774, 99, 955, 149, 711, 212, 337, 952, 113, 397, 982, 314, 693, 746, 385, 341, 852, 49, 178, 793, 771, 695, 828, 529, 672, 218, 481, 396, 20, 236, 452, 349, 214, 325, 975, 912, 536, 143, 932, 866, 270, 458, 775, 460, 770, 922, 645, 197, 856, 462, 807, 207, 255, 412, 203, 361, 612, 392, 86, 899, 405, 920, 28, 9, 926, 508, 14, 55, 249, 619, 3, 115, 594, 560, 808, 998, 117, 936, 291, 691, 490, 333, 233, 590, 937, 146, 243, 977, 450, 879, 677, 841, 374, 763, 451, 801, 532, 399, 688, 457, 950, 961, 653, 694, 895, 562, 797, 471, 442, 98, 268, 646, 785, 668, 434, 896, 714, 59, 940, 787, 476, 681, 311, 250, 957, 971, 990, 655, 169, 624, 671, 284, 475, 515, 71, 972, 823, 705, 72, 93, 507, 454, 578, 473, 191, 391, 960, 549, 684, 402, 581, 301, 421, 401, 0, 91, 755, 417, 340, 872, 644, 908, 159, 491, 837, 725, 384, 7, 461, 882, 730, 489, 258, 97, 815, 652, 465, 76, 593, 106, 595, 632, 180, 580, 305, 468, 65, 583, 824, 316, 689, 978, 293, 613, 330, 18, 288, 894, 659, 743, 598, 166, 736, 643, 916, 118, 675, 802, 157, 145, 537, 54, 756, 865, 818, 638, 45, 298, 591, 35, 168, 302, 31, 433, 996, 697, 51, 830, 112, 799, 970, 939, 641, 816, 345, 141, 575, 720, 838, 766, 686, 585, 423, 559, 147, 292, 57, 859, 425, 991, 687, 61, 232, 321, 941, 2, 584, 500, 561, 478, 608, 949, 544, 125, 534, 263, 721, 379, 122, 377, 525, 812, 903, 636, 615, 883, 610, 253, 918, 27, 136, 753, 362, 614, 938, 295, 553, 364, 124, 628, 506, 861, 226, 176, 886, 877, 654, 887, 116, 170, 192, 634, 834, 317, 712, 999, 257, 279, 520, 313, 719, 152, 277, 444, 436, 809, 129, 264, 334, 477, 605, 662, 394, 929, 265, 541, 486, 441, 350, 126, 627, 36, 851, 339, 104, 443, 74, 875, 821, 981, 403, 988, 953, 901, 784, 848, 966, 60, 100, 188, 411, 88, 740, 747, 974, 685, 348, 680, 198, 606, 435, 767, 484, 997, 618, 308, 25, 858, 620, 897, 165, 572, 878, 92, 154, 648, 642, 535, 913, 942, ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 10025 Train ELBO: -22.1326 Val ELBO: -150.3439, Epoch Time (s): 0.07, Total Time (hrs): 0.2478
# ====> Epoch: 10026 Train ELBO: -52.0792 Val ELBO: -75.7385, Epoch Time (s): 0.07, Total Time (hrs): 0.2479
# ====> Epoch: 10027 Train ELBO: -22.3266 Val ELBO: -108.8937, Epoch Time (s): 0.07, Total Time (hrs): 0.2479
# ====> Epoch: 10028 Train ELBO: -0.0883 Val ELBO: -55.0858, Epoch Time (s): 0.07, Total Time (hrs): 0.2479
# ====> Epoch: 10029 Train ELBO: 15.1479 Val ELBO: -70.6230, Epoch Time (s): 0.07, Total Time (hrs): 0.2479
# ====> Epoch: 10030 Train ELBO: 13.8415 Val ELBO: -96.9660, Epoch Time (s): 0.07, Total Time (hrs): 0.2479
# ====> Epoch: 10031 Train ELBO: -1.4105 Val ELBO: -152.5442, Epoch Time (s): 0.08, Total Time (hrs): 0.2480
# ====> Epoch: 10032 Train ELBO: -6.0268 Val ELBO: -82.0554, Epoch Time (s): 0.07, Total Time (hrs): 0.2480
# ====> Epoch: 10033 Train ELBO: 25.3856 Val ELBO: -73.6459, Epoch Time (s): 0.07, Total Time (hrs): 0.2480
# ====> Epoch: 10034 Train ELBO: 40.9106 Val ELBO: -49.7928, Epoch Time (s): 0.07, Total Time (hrs): 0.2480
# ====> Epoch: 10035 Train ELBO: 46.5264 Val ELBO: -36.9686, Epoch Time (s): 0.08, Total Time (hrs): 0.2480
# ====> Epoch: 10036 Train ELBO: 55.5130 Val ELBO: -53.2173, Epoch Time (s): 0.07, Total Time (hrs): 0.2480
# ====> Epoch: 10037 Train ELBO: 53.1754 Val ELBO: -39.6989, Epoch Time (s): 0.08, Total Time (hrs): 0.2481
# ====> Epoch: 10038 Train ELBO: 57.0502 Val ELBO: -38.5779, Epoch Time (s): 0.08, Total Time (hrs): 0.2481
# ====> Epoch: 10039 Train ELBO: 59.5251 Val ELBO: -38.1600, Epoch Time (s): 0.07, Total Time (hrs): 0.2481
# ====> Epoch: 10040 Train ELBO: 57.4124 Val ELBO: -44.5441, Epoch Time (s): 0.07, Total Time (hrs): 0.2481
# ====> Epoch: 10041 Train ELBO: 50.5762 Val ELBO: -58.9522, Epoch Time (s): 0.07, Total Time (hrs): 0.2481
# ====> Epoch: 10042 Train ELBO: 35.0098 Val ELBO: -58.2778, Epoch Time (s): 0.07, Total Time (hrs): 0.2482
# ====> Epoch: 10043 Train ELBO: 39.3903 Val ELBO: -73.5756, Epoch Time (s): 0.07, Total Time (hrs): 0.2482
# ====> Epoch: 10044 Train ELBO: 22.9051 Val ELBO: -93.5865, Epoch Time (s): 0.07, Total Time (hrs): 0.2482
# ====> Epoch: 10045 Train ELBO: 16.5436 Val ELBO: -79.0715, Epoch Time (s): 0.07, Total Time (hrs): 0.2482
# ====> Epoch: 10046 Train ELBO: 31.0112 Val ELBO: -72.0267, Epoch Time (s): 0.07, Total Time (hrs): 0.2482
# ====> Epoch: 10047 Train ELBO: 31.5394 Val ELBO: -54.7933, Epoch Time (s): 0.07, Total Time (hrs): 0.2483
# ====> Epoch: 10048 Train ELBO: 45.0473 Val ELBO: -47.5369, Epoch Time (s): 0.07, Total Time (hrs): 0.2483
# ====> Epoch: 10049 Train ELBO: 47.7847 Val ELBO: -49.1513, Epoch Time (s): 0.07, Total Time (hrs): 0.2483
# ====> Epoch: 10050 Train ELBO: 56.0058 Val ELBO: -49.9001, Epoch Time (s): 0.06, Total Time (hrs): 0.2483
# ====> Epoch: 10051 Train ELBO: 58.0665 Val ELBO: -39.4833, Epoch Time (s): 0.08, Total Time (hrs): 0.2483
# ====> Epoch: 10052 Train ELBO: 60.2734 Val ELBO: -29.8280, Epoch Time (s): 0.08, Total Time (hrs): 0.2484
# ====> Epoch: 10053 Train ELBO: 57.7630 Val ELBO: -51.1259, Epoch Time (s): 0.07, Total Time (hrs): 0.2484
# ====> Epoch: 10054 Train ELBO: 56.0392 Val ELBO: -40.4876, Epoch Time (s): 0.07, Total Time (hrs): 0.2484
# ====> Epoch: 10055 Train ELBO: 57.6617 Val ELBO: -47.3694, Epoch Time (s): 0.07, Total Time (hrs): 0.2484
# ====> Epoch: 10056 Train ELBO: 52.5718 Val ELBO: -47.9881, Epoch Time (s): 0.07, Total Time (hrs): 0.2484
# ====> Epoch: 10057 Train ELBO: 52.9264 Val ELBO: -60.1132, Epoch Time (s): 0.07, Total Time (hrs): 0.2485
# ====> Epoch: 10058 Train ELBO: 47.8231 Val ELBO: -59.5138, Epoch Time (s): 0.07, Total Time (hrs): 0.2485
# ====> Epoch: 10059 Train ELBO: 44.0891 Val ELBO: -49.4726, Epoch Time (s): 0.07, Total Time (hrs): 0.2485
# ====> Epoch: 10060 Train ELBO: 48.6496 Val ELBO: -53.4922, Epoch Time (s): 0.07, Total Time (hrs): 0.2485
# ====> Epoch: 10061 Train ELBO: 52.2503 Val ELBO: -33.8684, Epoch Time (s): 0.07, Total Time (hrs): 0.2485
# ====> Epoch: 10062 Train ELBO: 57.9863 Val ELBO: -36.3071, Epoch Time (s): 0.08, Total Time (hrs): 0.2486
# ====> Epoch: 10063 Train ELBO: 56.2511 Val ELBO: -51.5104, Epoch Time (s): 0.07, Total Time (hrs): 0.2486
# ====> Epoch: 10064 Train ELBO: 52.2256 Val ELBO: -53.4484, Epoch Time (s): 0.07, Total Time (hrs): 0.2486
# ====> Epoch: 10065 Train ELBO: 53.7130 Val ELBO: -58.9886, Epoch Time (s): 0.07, Total Time (hrs): 0.2486
# ====> Epoch: 10066 Train ELBO: 54.8247 Val ELBO: -41.0578, Epoch Time (s): 0.08, Total Time (hrs): 0.2486
# ====> Epoch: 10067 Train ELBO: 58.2415 Val ELBO: -41.3291, Epoch Time (s): 0.07, Total Time (hrs): 0.2487
# ====> Epoch: 10068 Train ELBO: 59.7100 Val ELBO: -47.0324, Epoch Time (s): 0.08, Total Time (hrs): 0.2487
# ====> Epoch: 10069 Train ELBO: 53.9092 Val ELBO: -42.9884, Epoch Time (s): 0.07, Total Time (hrs): 0.2487
# ====> Epoch: 10070 Train ELBO: 55.5506 Val ELBO: -46.9247, Epoch Time (s): 0.07, Total Time (hrs): 0.2487
# ====> Epoch: 10071 Train ELBO: 53.0885 Val ELBO: -57.1578, Epoch Time (s): 0.07, Total Time (hrs): 0.2487
# ====> Epoch: 10072 Train ELBO: 53.5207 Val ELBO: -40.8123, Epoch Time (s): 0.07, Total Time (hrs): 0.2488
# ====> Epoch: 10073 Train ELBO: 56.3353 Val ELBO: -47.1222, Epoch Time (s): 0.07, Total Time (hrs): 0.2488
# ====> Epoch: 10074 Train ELBO: 58.7555 Val ELBO: -45.6857, Epoch Time (s): 0.07, Total Time (hrs): 0.2488
# ====> Epoch: 10075 Train ELBO: 59.7362 Val ELBO: -45.6972, Epoch Time (s): 0.07, Total Time (hrs): 0.2488
# ====> Epoch: 10076 Train ELBO: 56.6084 Val ELBO: -48.7785, Epoch Time (s): 0.07, Total Time (hrs): 0.2488
# ====> Epoch: 10077 Train ELBO: 57.0740 Val ELBO: -54.1755, Epoch Time (s): 0.07, Total Time (hrs): 0.2489
# ====> Epoch: 10078 Train ELBO: 58.5965 Val ELBO: -41.7933, Epoch Time (s): 0.07, Total Time (hrs): 0.2489
# ====> Epoch: 10079 Train ELBO: 55.8332 Val ELBO: -38.8891, Epoch Time (s): 0.07, Total Time (hrs): 0.2489
# ====> Epoch: 10080 Train ELBO: 57.4422 Val ELBO: -39.4064, Epoch Time (s): 0.07, Total Time (hrs): 0.2489
# ====> Epoch: 10081 Train ELBO: 58.5093 Val ELBO: -39.2403, Epoch Time (s): 0.08, Total Time (hrs): 0.2489
# ====> Epoch: 10082 Train ELBO: 60.2134 Val ELBO: -42.1918, Epoch Time (s): 0.07, Total Time (hrs): 0.2490
# ====> Epoch: 10083 Train ELBO: 57.8439 Val ELBO: -62.8759, Epoch Time (s): 0.07, Total Time (hrs): 0.2490
# ====> Epoch: 10084 Train ELBO: 51.6256 Val ELBO: -52.2701, Epoch Time (s): 0.07, Total Time (hrs): 0.2490
# ====> Epoch: 10085 Train ELBO: 57.7280 Val ELBO: -33.2922, Epoch Time (s): 0.07, Total Time (hrs): 0.2490
# ====> Epoch: 10086 Train ELBO: 53.7519 Val ELBO: -52.5476, Epoch Time (s): 0.07, Total Time (hrs): 0.2490
# ====> Epoch: 10087 Train ELBO: 39.9698 Val ELBO: -66.8215, Epoch Time (s): 0.07, Total Time (hrs): 0.2490
# ====> Epoch: 10088 Train ELBO: 44.5764 Val ELBO: -71.3597, Epoch Time (s): 0.07, Total Time (hrs): 0.2491
# ====> Epoch: 10089 Train ELBO: 25.9070 Val ELBO: -41.2565, Epoch Time (s): 0.07, Total Time (hrs): 0.2491
# ====> Epoch: 10090 Train ELBO: 39.9277 Val ELBO: -52.3493, Epoch Time (s): 0.07, Total Time (hrs): 0.2491
# ====> Epoch: 10091 Train ELBO: 51.9145 Val ELBO: -46.8847, Epoch Time (s): 0.07, Total Time (hrs): 0.2491
# ====> Epoch: 10092 Train ELBO: 51.2722 Val ELBO: -46.3355, Epoch Time (s): 0.07, Total Time (hrs): 0.2491
# ====> Epoch: 10093 Train ELBO: 54.3248 Val ELBO: -58.4304, Epoch Time (s): 0.07, Total Time (hrs): 0.2492
# ====> Epoch: 10094 Train ELBO: 49.4169 Val ELBO: -54.9361, Epoch Time (s): 0.07, Total Time (hrs): 0.2492
# ====> Epoch: 10095 Train ELBO: 52.9351 Val ELBO: -59.5886, Epoch Time (s): 0.08, Total Time (hrs): 0.2492
# ====> Epoch: 10096 Train ELBO: 52.0064 Val ELBO: -43.4661, Epoch Time (s): 0.06, Total Time (hrs): 0.2492
# ====> Epoch: 10097 Train ELBO: 39.9508 Val ELBO: -69.1060, Epoch Time (s): 0.07, Total Time (hrs): 0.2492
# ====> Epoch: 10098 Train ELBO: 41.4002 Val ELBO: -55.2728, Epoch Time (s): 0.07, Total Time (hrs): 0.2493
# ====> Epoch: 10099 Train ELBO: 43.5041 Val ELBO: -56.1757, Epoch Time (s): 0.07, Total Time (hrs): 0.2493
# ====> Epoch: 10100 Train ELBO: 40.7798 Val ELBO: -57.8906, Epoch Time (s): 0.07, Total Time (hrs): 0.2493
# ====> Epoch: 10101 Train ELBO: 37.4620 Val ELBO: -49.1136, Epoch Time (s): 0.07, Total Time (hrs): 0.2493
# ====> Epoch: 10102 Train ELBO: 35.4657 Val ELBO: -51.7625, Epoch Time (s): 0.07, Total Time (hrs): 0.2493
# ====> Epoch: 10103 Train ELBO: 32.5745 Val ELBO: -49.8222, Epoch Time (s): 0.07, Total Time (hrs): 0.2494
# ====> Epoch: 10104 Train ELBO: 20.6804 Val ELBO: -63.0333, Epoch Time (s): 0.07, Total Time (hrs): 0.2494
# ====> Epoch: 10105 Train ELBO: 12.5560 Val ELBO: -111.8155, Epoch Time (s): 0.07, Total Time (hrs): 0.2494
# ====> Epoch: 10106 Train ELBO: 26.5119 Val ELBO: -68.0579, Epoch Time (s): 0.07, Total Time (hrs): 0.2494
# ====> Epoch: 10107 Train ELBO: 36.2224 Val ELBO: -85.3094, Epoch Time (s): 0.07, Total Time (hrs): 0.2494
# ====> Epoch: 10108 Train ELBO: 10.4223 Val ELBO: -71.7345, Epoch Time (s): 0.07, Total Time (hrs): 0.2495
# ====> Epoch: 10109 Train ELBO: 19.1208 Val ELBO: -87.7695, Epoch Time (s): 0.07, Total Time (hrs): 0.2495
# ====> Epoch: 10110 Train ELBO: 24.3062 Val ELBO: -88.0612, Epoch Time (s): 0.09, Total Time (hrs): 0.2495
# ====> Epoch: 10111 Train ELBO: 15.2009 Val ELBO: -52.7169, Epoch Time (s): 0.07, Total Time (hrs): 0.2495
# ====> Epoch: 10112 Train ELBO: 27.7159 Val ELBO: -75.0454, Epoch Time (s): 0.08, Total Time (hrs): 0.2495
# ====> Epoch: 10113 Train ELBO: 35.0451 Val ELBO: -69.7611, Epoch Time (s): 0.08, Total Time (hrs): 0.2496
# ====> Epoch: 10114 Train ELBO: 49.7829 Val ELBO: -46.2528, Epoch Time (s): 0.08, Total Time (hrs): 0.2496
# ====> Epoch: 10115 Train ELBO: 53.6914 Val ELBO: -54.4317, Epoch Time (s): 0.08, Total Time (hrs): 0.2496
# ====> Epoch: 10116 Train ELBO: 50.0919 Val ELBO: -57.7608, Epoch Time (s): 0.07, Total Time (hrs): 0.2496
# ====> Epoch: 10117 Train ELBO: 54.9499 Val ELBO: -42.5682, Epoch Time (s): 0.08, Total Time (hrs): 0.2497
# ====> Epoch: 10118 Train ELBO: 54.8137 Val ELBO: -54.7130, Epoch Time (s): 0.08, Total Time (hrs): 0.2497
# ====> Epoch: 10119 Train ELBO: 54.6783 Val ELBO: -40.0163, Epoch Time (s): 0.07, Total Time (hrs): 0.2497
# ====> Epoch: 10120 Train ELBO: 56.1539 Val ELBO: -43.2377, Epoch Time (s): 0.07, Total Time (hrs): 0.2497
# ====> Epoch: 10121 Train ELBO: 55.8134 Val ELBO: -42.1504, Epoch Time (s): 0.09, Total Time (hrs): 0.2497
# ====> Epoch: 10122 Train ELBO: 53.4006 Val ELBO: -42.0188, Epoch Time (s): 0.08, Total Time (hrs): 0.2498
# ====> Epoch: 10123 Train ELBO: 53.8021 Val ELBO: -65.4905, Epoch Time (s): 0.08, Total Time (hrs): 0.2498
# ====> Epoch: 10124 Train ELBO: 46.3659 Val ELBO: -83.7756, Epoch Time (s): 0.10, Total Time (hrs): 0.2498
# ====> Epoch: 10125 Train ELBO: 41.9713 Val ELBO: -93.1322, Epoch Time (s): 0.11, Total Time (hrs): 0.2498
# ====> Epoch: 10126 Train ELBO: 33.9024 Val ELBO: -62.1614, Epoch Time (s): 0.10, Total Time (hrs): 0.2499
# ====> Epoch: 10127 Train ELBO: 44.8405 Val ELBO: -40.5956, Epoch Time (s): 0.10, Total Time (hrs): 0.2499
# ====> Epoch: 10128 Train ELBO: 51.6932 Val ELBO: -48.2823, Epoch Time (s): 0.10, Total Time (hrs): 0.2499
# ====> Epoch: 10129 Train ELBO: 53.9994 Val ELBO: -47.7639, Epoch Time (s): 0.10, Total Time (hrs): 0.2500
# ====> Epoch: 10130 Train ELBO: 59.8021 Val ELBO: -36.2159, Epoch Time (s): 0.11, Total Time (hrs): 0.2500
# ====> Epoch: 10131 Train ELBO: 58.4165 Val ELBO: -33.4826, Epoch Time (s): 0.12, Total Time (hrs): 0.2500
# ====> Epoch: 10132 Train ELBO: 59.2478 Val ELBO: -53.4719, Epoch Time (s): 0.11, Total Time (hrs): 0.2500
# ====> Epoch: 10133 Train ELBO: 50.3490 Val ELBO: -50.5333, Epoch Time (s): 0.13, Total Time (hrs): 0.2501
# ====> Epoch: 10134 Train ELBO: 54.3553 Val ELBO: -46.1777, Epoch Time (s): 0.10, Total Time (hrs): 0.2501
# ====> Epoch: 10135 Train ELBO: 50.1487 Val ELBO: -57.4052, Epoch Time (s): 0.11, Total Time (hrs): 0.2501
# ====> Epoch: 10136 Train ELBO: 53.2220 Val ELBO: -40.5150, Epoch Time (s): 0.11, Total Time (hrs): 0.2502
# ====> Epoch: 10137 Train ELBO: 50.2040 Val ELBO: -57.6305, Epoch Time (s): 0.11, Total Time (hrs): 0.2502
# ====> Epoch: 10138 Train ELBO: 51.3794 Val ELBO: -49.8015, Epoch Time (s): 0.10, Total Time (hrs): 0.2502
# ====> Epoch: 10139 Train ELBO: 52.5924 Val ELBO: -54.4369, Epoch Time (s): 0.15, Total Time (hrs): 0.2503
# ====> Epoch: 10140 Train ELBO: 51.1842 Val ELBO: -47.8036, Epoch Time (s): 0.11, Total Time (hrs): 0.2503
# ====> Epoch: 10141 Train ELBO: 50.0015 Val ELBO: -43.1641, Epoch Time (s): 0.10, Total Time (hrs): 0.2503
# ====> Epoch: 10142 Train ELBO: 49.5450 Val ELBO: -43.3020, Epoch Time (s): 0.10, Total Time (hrs): 0.2504
# ====> Epoch: 10143 Train ELBO: 50.0485 Val ELBO: -36.1414, Epoch Time (s): 0.10, Total Time (hrs): 0.2504
# ====> Epoch: 10144 Train ELBO: 60.7535 Val ELBO: -36.4536, Epoch Time (s): 0.10, Total Time (hrs): 0.2504
# ====> Epoch: 10145 Train ELBO: 57.1045 Val ELBO: -64.8507, Epoch Time (s): 0.10, Total Time (hrs): 0.2504
# ====> Epoch: 10146 Train ELBO: 42.9320 Val ELBO: -58.8338, Epoch Time (s): 0.10, Total Time (hrs): 0.2505
# ====> Epoch: 10147 Train ELBO: 48.8650 Val ELBO: -37.1649, Epoch Time (s): 0.10, Total Time (hrs): 0.2505
# ====> Epoch: 10148 Train ELBO: 57.3865 Val ELBO: -36.2850, Epoch Time (s): 0.10, Total Time (hrs): 0.2505
# ====> Epoch: 10149 Train ELBO: 59.1200 Val ELBO: -48.0211, Epoch Time (s): 0.09, Total Time (hrs): 0.2506
# ====> Epoch: 10150 Train ELBO: 59.2424 Val ELBO: -41.3897, Epoch Time (s): 0.10, Total Time (hrs): 0.2506
# ====> Epoch: 10151 Train ELBO: 48.1916 Val ELBO: -59.8214, Epoch Time (s): 0.11, Total Time (hrs): 0.2506
# ====> Epoch: 10152 Train ELBO: 42.3653 Val ELBO: -60.3139, Epoch Time (s): 0.10, Total Time (hrs): 0.2506
# ====> Epoch: 10153 Train ELBO: 52.6065 Val ELBO: -41.2155, Epoch Time (s): 0.13, Total Time (hrs): 0.2507
# ====> Epoch: 10154 Train ELBO: 52.5219 Val ELBO: -46.8182, Epoch Time (s): 0.11, Total Time (hrs): 0.2507
# ====> Epoch: 10155 Train ELBO: 45.8891 Val ELBO: -44.3077, Epoch Time (s): 0.11, Total Time (hrs): 0.2507
# ====> Epoch: 10156 Train ELBO: 40.3200 Val ELBO: -48.1907, Epoch Time (s): 0.10, Total Time (hrs): 0.2508
# ====> Epoch: 10157 Train ELBO: 42.4406 Val ELBO: -65.8778, Epoch Time (s): 0.11, Total Time (hrs): 0.2508
# ====> Epoch: 10158 Train ELBO: 23.9572 Val ELBO: -66.9452, Epoch Time (s): 0.11, Total Time (hrs): 0.2508
# ====> Epoch: 10159 Train ELBO: 36.6116 Val ELBO: -58.6775, Epoch Time (s): 0.11, Total Time (hrs): 0.2509
# ====> Epoch: 10160 Train ELBO: 43.8685 Val ELBO: -54.8360, Epoch Time (s): 0.11, Total Time (hrs): 0.2509
# ====> Epoch: 10161 Train ELBO: 46.7431 Val ELBO: -58.9960, Epoch Time (s): 0.11, Total Time (hrs): 0.2509
# ====> Epoch: 10162 Train ELBO: 19.2881 Val ELBO: -47.4629, Epoch Time (s): 0.07, Total Time (hrs): 0.2509
# ====> Epoch: 10163 Train ELBO: 16.4554 Val ELBO: -66.5510, Epoch Time (s): 0.08, Total Time (hrs): 0.2510
# ====> Epoch: 10164 Train ELBO: 29.6161 Val ELBO: -69.6209, Epoch Time (s): 0.07, Total Time (hrs): 0.2510
# ====> Epoch: 10165 Train ELBO: 35.6492 Val ELBO: -58.5446, Epoch Time (s): 0.07, Total Time (hrs): 0.2510
# ====> Epoch: 10166 Train ELBO: 41.7960 Val ELBO: -35.4981, Epoch Time (s): 0.07, Total Time (hrs): 0.2510
# ====> Epoch: 10167 Train ELBO: 26.6800 Val ELBO: -72.2380, Epoch Time (s): 0.07, Total Time (hrs): 0.2510
# ====> Epoch: 10168 Train ELBO: 38.6217 Val ELBO: -56.5167, Epoch Time (s): 0.07, Total Time (hrs): 0.2511
# ====> Epoch: 10169 Train ELBO: 44.3486 Val ELBO: -63.7312, Epoch Time (s): 0.07, Total Time (hrs): 0.2511
# ====> Epoch: 10170 Train ELBO: 46.7732 Val ELBO: -72.4277, Epoch Time (s): 0.08, Total Time (hrs): 0.2511
# ====> Epoch: 10171 Train ELBO: 48.4689 Val ELBO: -55.6540, Epoch Time (s): 0.07, Total Time (hrs): 0.2511
# ====> Epoch: 10172 Train ELBO: 50.1974 Val ELBO: -52.7252, Epoch Time (s): 0.07, Total Time (hrs): 0.2511
# ====> Epoch: 10173 Train ELBO: 43.8460 Val ELBO: -56.6272, Epoch Time (s): 0.07, Total Time (hrs): 0.2512
# ====> Epoch: 10174 Train ELBO: 39.6099 Val ELBO: -105.2921, Epoch Time (s): 0.07, Total Time (hrs): 0.2512
# ====> Epoch: 10175 Train ELBO: 7.7868 Val ELBO: -99.3058, Epoch Time (s): 0.07, Total Time (hrs): 0.2512
# ====> Epoch: 10176 Train ELBO: 24.5706 Val ELBO: -77.7898, Epoch Time (s): 0.07, Total Time (hrs): 0.2512
# ====> Epoch: 10177 Train ELBO: 19.4745 Val ELBO: -66.4610, Epoch Time (s): 0.09, Total Time (hrs): 0.2512
# ====> Epoch: 10178 Train ELBO: 30.8471 Val ELBO: -64.1219, Epoch Time (s): 0.07, Total Time (hrs): 0.2513
# ====> Epoch: 10179 Train ELBO: 37.3642 Val ELBO: -61.9013, Epoch Time (s): 0.08, Total Time (hrs): 0.2513
# ====> Epoch: 10180 Train ELBO: 32.6650 Val ELBO: -55.6465, Epoch Time (s): 0.07, Total Time (hrs): 0.2513
# ====> Epoch: 10181 Train ELBO: 46.2841 Val ELBO: -47.4234, Epoch Time (s): 0.08, Total Time (hrs): 0.2513
# ====> Epoch: 10182 Train ELBO: 49.8206 Val ELBO: -58.3555, Epoch Time (s): 0.09, Total Time (hrs): 0.2513
# ====> Epoch: 10183 Train ELBO: 46.1778 Val ELBO: -36.6294, Epoch Time (s): 0.08, Total Time (hrs): 0.2514
# ====> Epoch: 10184 Train ELBO: 49.6105 Val ELBO: -57.0189, Epoch Time (s): 0.07, Total Time (hrs): 0.2514
# ====> Epoch: 10185 Train ELBO: 49.9085 Val ELBO: -47.5715, Epoch Time (s): 0.07, Total Time (hrs): 0.2514
# ====> Epoch: 10186 Train ELBO: 51.2955 Val ELBO: -38.3426, Epoch Time (s): 0.07, Total Time (hrs): 0.2514
# ====> Epoch: 10187 Train ELBO: 60.3697 Val ELBO: -41.1644, Epoch Time (s): 0.07, Total Time (hrs): 0.2514
# ====> Epoch: 10188 Train ELBO: 60.9700 Val ELBO: -46.0296, Epoch Time (s): 0.09, Total Time (hrs): 0.2515
# ====> Epoch: 10189 Train ELBO: 55.4969 Val ELBO: -46.4291, Epoch Time (s): 0.07, Total Time (hrs): 0.2515
# ====> Epoch: 10190 Train ELBO: 56.9840 Val ELBO: -44.8946, Epoch Time (s): 0.07, Total Time (hrs): 0.2515
# ====> Epoch: 10191 Train ELBO: 53.4244 Val ELBO: -30.4466, Epoch Time (s): 0.09, Total Time (hrs): 0.2515
# ====> Epoch: 10192 Train ELBO: 57.2855 Val ELBO: -51.6571, Epoch Time (s): 0.07, Total Time (hrs): 0.2516
# ====> Epoch: 10193 Train ELBO: 51.2575 Val ELBO: -43.3445, Epoch Time (s): 0.07, Total Time (hrs): 0.2516
# ====> Epoch: 10194 Train ELBO: 56.3043 Val ELBO: -47.5382, Epoch Time (s): 0.07, Total Time (hrs): 0.2516
# ====> Epoch: 10195 Train ELBO: 58.9057 Val ELBO: -38.7612, Epoch Time (s): 0.07, Total Time (hrs): 0.2516
# ====> Epoch: 10196 Train ELBO: 57.7196 Val ELBO: -37.2654, Epoch Time (s): 0.07, Total Time (hrs): 0.2516
# ====> Epoch: 10197 Train ELBO: 57.7649 Val ELBO: -37.7362, Epoch Time (s): 0.07, Total Time (hrs): 0.2517
# ====> Epoch: 10198 Train ELBO: 53.2523 Val ELBO: -51.2666, Epoch Time (s): 0.07, Total Time (hrs): 0.2517
# ====> Epoch: 10199 Train ELBO: 54.6094 Val ELBO: -51.7548, Epoch Time (s): 0.07, Total Time (hrs): 0.2517
# ====> Epoch: 10200 Train ELBO: 45.8724 Val ELBO: -52.4410, Epoch Time (s): 0.07, Total Time (hrs): 0.2517
# ====> Epoch: 10201 Train ELBO: 48.4723 Val ELBO: -72.5683, Epoch Time (s): 0.07, Total Time (hrs): 0.2517
# ====> Epoch: 10202 Train ELBO: 45.7046 Val ELBO: -47.5028, Epoch Time (s): 0.07, Total Time (hrs): 0.2518
# ====> Epoch: 10203 Train ELBO: 52.1139 Val ELBO: -46.3665, Epoch Time (s): 0.07, Total Time (hrs): 0.2518
# ====> Epoch: 10204 Train ELBO: 50.6511 Val ELBO: -58.2098, Epoch Time (s): 0.07, Total Time (hrs): 0.2518
# ====> Epoch: 10205 Train ELBO: 46.9063 Val ELBO: -50.1919, Epoch Time (s): 0.08, Total Time (hrs): 0.2518
# ====> Epoch: 10206 Train ELBO: 43.5294 Val ELBO: -75.3359, Epoch Time (s): 0.07, Total Time (hrs): 0.2518
# ====> Epoch: 10207 Train ELBO: 33.1737 Val ELBO: -136.1528, Epoch Time (s): 0.07, Total Time (hrs): 0.2519
# ====> Epoch: 10208 Train ELBO: 5.7081 Val ELBO: -89.0962, Epoch Time (s): 0.07, Total Time (hrs): 0.2519
# ====> Epoch: 10209 Train ELBO: 28.9639 Val ELBO: -65.1547, Epoch Time (s): 0.07, Total Time (hrs): 0.2519
# ====> Epoch: 10210 Train ELBO: 34.7768 Val ELBO: -75.8194, Epoch Time (s): 0.07, Total Time (hrs): 0.2519
# ====> Epoch: 10211 Train ELBO: 42.3322 Val ELBO: -79.2087, Epoch Time (s): 0.07, Total Time (hrs): 0.2519
# ====> Epoch: 10212 Train ELBO: 45.6309 Val ELBO: -53.7246, Epoch Time (s): 0.07, Total Time (hrs): 0.2519
# ====> Epoch: 10213 Train ELBO: 49.4431 Val ELBO: -37.8197, Epoch Time (s): 0.07, Total Time (hrs): 0.2520
# ====> Epoch: 10214 Train ELBO: 50.3111 Val ELBO: -50.6599, Epoch Time (s): 0.07, Total Time (hrs): 0.2520
# ====> Epoch: 10215 Train ELBO: 57.7542 Val ELBO: -36.6192, Epoch Time (s): 0.07, Total Time (hrs): 0.2520
# ====> Epoch: 10216 Train ELBO: 59.6131 Val ELBO: -50.0807, Epoch Time (s): 0.07, Total Time (hrs): 0.2520
# ====> Epoch: 10217 Train ELBO: 57.0057 Val ELBO: -47.5722, Epoch Time (s): 0.08, Total Time (hrs): 0.2520
# ====> Epoch: 10218 Train ELBO: 62.0905 Val ELBO: -35.7083, Epoch Time (s): 0.07, Total Time (hrs): 0.2521
# ====> Epoch: 10219 Train ELBO: 64.8449 Val ELBO: -33.9824, Epoch Time (s): 0.07, Total Time (hrs): 0.2521
# ====> Epoch: 10220 Train ELBO: 63.0771 Val ELBO: -35.2151, Epoch Time (s): 0.09, Total Time (hrs): 0.2521
# ====> Epoch: 10221 Train ELBO: 61.7833 Val ELBO: -39.9360, Epoch Time (s): 0.07, Total Time (hrs): 0.2521
# ====> Epoch: 10222 Train ELBO: 61.6708 Val ELBO: -34.6989, Epoch Time (s): 0.07, Total Time (hrs): 0.2521
# ====> Epoch: 10223 Train ELBO: 51.3534 Val ELBO: -42.1030, Epoch Time (s): 0.08, Total Time (hrs): 0.2522
# ====> Epoch: 10224 Train ELBO: 53.9809 Val ELBO: -68.3759, Epoch Time (s): 0.07, Total Time (hrs): 0.2522
# ====> Epoch: 10225 Train ELBO: 40.7714 Val ELBO: -67.7490, Epoch Time (s): 0.07, Total Time (hrs): 0.2522
# ====> Epoch: 10226 Train ELBO: 41.1093 Val ELBO: -68.2855, Epoch Time (s): 0.08, Total Time (hrs): 0.2522
# ====> Epoch: 10227 Train ELBO: 48.9201 Val ELBO: -30.7860, Epoch Time (s): 0.07, Total Time (hrs): 0.2522
# ====> Epoch: 10228 Train ELBO: 48.0500 Val ELBO: -45.3576, Epoch Time (s): 0.07, Total Time (hrs): 0.2523
# ====> Epoch: 10229 Train ELBO: 39.0940 Val ELBO: -57.7372, Epoch Time (s): 0.07, Total Time (hrs): 0.2523
# ====> Epoch: 10230 Train ELBO: 42.3661 Val ELBO: -68.0333, Epoch Time (s): 0.07, Total Time (hrs): 0.2523
# ====> Epoch: 10231 Train ELBO: 42.7035 Val ELBO: -60.0580, Epoch Time (s): 0.07, Total Time (hrs): 0.2523
# ====> Epoch: 10232 Train ELBO: 48.5086 Val ELBO: -76.8653, Epoch Time (s): 0.07, Total Time (hrs): 0.2523
# ====> Epoch: 10233 Train ELBO: 51.9263 Val ELBO: -48.1210, Epoch Time (s): 0.07, Total Time (hrs): 0.2524
# ====> Epoch: 10234 Train ELBO: 43.0983 Val ELBO: -69.2388, Epoch Time (s): 0.07, Total Time (hrs): 0.2524
# ====> Epoch: 10235 Train ELBO: 42.3151 Val ELBO: -121.9408, Epoch Time (s): 0.08, Total Time (hrs): 0.2524
# ====> Epoch: 10236 Train ELBO: 40.6795 Val ELBO: -47.3631, Epoch Time (s): 0.07, Total Time (hrs): 0.2524
# ====> Epoch: 10237 Train ELBO: 47.5627 Val ELBO: -62.7824, Epoch Time (s): 0.07, Total Time (hrs): 0.2524
# ====> Epoch: 10238 Train ELBO: -84.3477 Val ELBO: -390.8257, Epoch Time (s): 0.07, Total Time (hrs): 0.2525
# ====> Epoch: 10239 Train ELBO: -201.1209 Val ELBO: -177.9376, Epoch Time (s): 0.07, Total Time (hrs): 0.2525
# ====> Epoch: 10240 Train ELBO: -133.3553 Val ELBO: -208.6454, Epoch Time (s): 0.07, Total Time (hrs): 0.2525
# ====> Epoch: 10241 Train ELBO: -98.8408 Val ELBO: -162.8886, Epoch Time (s): 0.07, Total Time (hrs): 0.2525
# ====> Epoch: 10242 Train ELBO: -65.6371 Val ELBO: -125.5962, Epoch Time (s): 0.07, Total Time (hrs): 0.2525
# ====> Epoch: 10243 Train ELBO: -38.1147 Val ELBO: -117.8758, Epoch Time (s): 0.06, Total Time (hrs): 0.2526
# ====> Epoch: 10244 Train ELBO: -7.5723 Val ELBO: -48.7250, Epoch Time (s): 0.07, Total Time (hrs): 0.2526
# ====> Epoch: 10245 Train ELBO: 36.6058 Val ELBO: -59.6528, Epoch Time (s): 0.07, Total Time (hrs): 0.2526
# ====> Epoch: 10246 Train ELBO: 50.0506 Val ELBO: -47.3030, Epoch Time (s): 0.07, Total Time (hrs): 0.2526
# ====> Epoch: 10247 Train ELBO: 49.3941 Val ELBO: -53.1371, Epoch Time (s): 0.07, Total Time (hrs): 0.2526
# ====> Epoch: 10248 Train ELBO: 49.6026 Val ELBO: -61.3193, Epoch Time (s): 0.07, Total Time (hrs): 0.2527
# ====> Epoch: 10249 Train ELBO: 57.5013 Val ELBO: -41.0103, Epoch Time (s): 0.09, Total Time (hrs): 0.2527
# ====> Epoch: 10250 Train ELBO: 63.6129 Val ELBO: -45.7288, Epoch Time (s): 0.07, Total Time (hrs): 0.2527
# ====> Epoch: 10251 Train ELBO: 60.1720 Val ELBO: -51.9387, Epoch Time (s): 0.07, Total Time (hrs): 0.2527
# ====> Epoch: 10252 Train ELBO: 59.3334 Val ELBO: -41.4511, Epoch Time (s): 0.07, Total Time (hrs): 0.2527
# ====> Epoch: 10253 Train ELBO: 60.3200 Val ELBO: -43.3987, Epoch Time (s): 0.07, Total Time (hrs): 0.2528
# ====> Epoch: 10254 Train ELBO: 61.5243 Val ELBO: -31.3172, Epoch Time (s): 0.07, Total Time (hrs): 0.2528
# ====> Epoch: 10255 Train ELBO: 63.6824 Val ELBO: -43.0821, Epoch Time (s): 0.07, Total Time (hrs): 0.2528
# ====> Epoch: 10256 Train ELBO: 51.2006 Val ELBO: -59.8265, Epoch Time (s): 0.07, Total Time (hrs): 0.2528
# ====> Epoch: 10257 Train ELBO: 46.5747 Val ELBO: -54.2192, Epoch Time (s): 0.07, Total Time (hrs): 0.2528
# ====> Epoch: 10258 Train ELBO: 48.0683 Val ELBO: -52.5076, Epoch Time (s): 0.07, Total Time (hrs): 0.2529
# ====> Epoch: 10259 Train ELBO: 46.1219 Val ELBO: -41.3836, Epoch Time (s): 0.07, Total Time (hrs): 0.2529
# ====> Epoch: 10260 Train ELBO: 53.3479 Val ELBO: -53.8259, Epoch Time (s): 0.07, Total Time (hrs): 0.2529
# ====> Epoch: 10261 Train ELBO: 55.2122 Val ELBO: -59.5969, Epoch Time (s): 0.08, Total Time (hrs): 0.2529
# ====> Epoch: 10262 Train ELBO: 52.5504 Val ELBO: -57.0380, Epoch Time (s): 0.07, Total Time (hrs): 0.2529
# ====> Epoch: 10263 Train ELBO: 53.9089 Val ELBO: -51.2389, Epoch Time (s): 0.07, Total Time (hrs): 0.2530
# ====> Epoch: 10264 Train ELBO: 48.9386 Val ELBO: -56.0656, Epoch Time (s): 0.09, Total Time (hrs): 0.2530
# ====> Epoch: 10265 Train ELBO: 49.1060 Val ELBO: -50.7750, Epoch Time (s): 0.07, Total Time (hrs): 0.2530
# ====> Epoch: 10266 Train ELBO: 54.3266 Val ELBO: -59.7192, Epoch Time (s): 0.07, Total Time (hrs): 0.2530
# ====> Epoch: 10267 Train ELBO: 38.3336 Val ELBO: -71.4200, Epoch Time (s): 0.07, Total Time (hrs): 0.2530
# ====> Epoch: 10268 Train ELBO: 48.8888 Val ELBO: -32.6292, Epoch Time (s): 0.07, Total Time (hrs): 0.2531
# ====> Epoch: 10269 Train ELBO: 60.0925 Val ELBO: -46.4623, Epoch Time (s): 0.07, Total Time (hrs): 0.2531
# ====> Epoch: 10270 Train ELBO: 58.9168 Val ELBO: -48.1907, Epoch Time (s): 0.07, Total Time (hrs): 0.2531
# ====> Epoch: 10271 Train ELBO: 61.1083 Val ELBO: -49.9526, Epoch Time (s): 0.07, Total Time (hrs): 0.2531
# ====> Epoch: 10272 Train ELBO: 57.7191 Val ELBO: -39.5241, Epoch Time (s): 0.07, Total Time (hrs): 0.2531
# ====> Epoch: 10273 Train ELBO: 60.1300 Val ELBO: -37.9941, Epoch Time (s): 0.07, Total Time (hrs): 0.2532
# ====> Epoch: 10274 Train ELBO: 60.2966 Val ELBO: -47.4279, Epoch Time (s): 0.07, Total Time (hrs): 0.2532
# ====> Epoch: 10275 Train ELBO: 57.4564 Val ELBO: -39.8760, Epoch Time (s): 0.07, Total Time (hrs): 0.2532
# ====> Epoch: 10276 Train ELBO: 57.0104 Val ELBO: -41.9376, Epoch Time (s): 0.08, Total Time (hrs): 0.2532
# ====> Epoch: 10277 Train ELBO: 56.1565 Val ELBO: -52.6108, Epoch Time (s): 0.07, Total Time (hrs): 0.2532
# ====> Epoch: 10278 Train ELBO: 59.5156 Val ELBO: -40.1252, Epoch Time (s): 0.08, Total Time (hrs): 0.2533
# ====> Epoch: 10279 Train ELBO: 60.1606 Val ELBO: -45.1993, Epoch Time (s): 0.08, Total Time (hrs): 0.2533
# ====> Epoch: 10280 Train ELBO: 58.5478 Val ELBO: -55.6988, Epoch Time (s): 0.07, Total Time (hrs): 0.2533
# ====> Epoch: 10281 Train ELBO: 57.4189 Val ELBO: -45.9725, Epoch Time (s): 0.07, Total Time (hrs): 0.2533
# ====> Epoch: 10282 Train ELBO: 56.4741 Val ELBO: -75.7535, Epoch Time (s): 0.07, Total Time (hrs): 0.2533
# ====> Epoch: 10283 Train ELBO: 53.0147 Val ELBO: -39.0642, Epoch Time (s): 0.07, Total Time (hrs): 0.2534
# ====> Epoch: 10284 Train ELBO: 54.4856 Val ELBO: -50.9870, Epoch Time (s): 0.06, Total Time (hrs): 0.2534
# ====> Epoch: 10285 Train ELBO: 8.4953 Val ELBO: -147.8940, Epoch Time (s): 0.07, Total Time (hrs): 0.2534
# ====> Epoch: 10286 Train ELBO: -28.4794 Val ELBO: -142.0696, Epoch Time (s): 0.07, Total Time (hrs): 0.2534
# ====> Epoch: 10287 Train ELBO: -47.6231 Val ELBO: -153.3884, Epoch Time (s): 0.07, Total Time (hrs): 0.2534
# ====> Epoch: 10288 Train ELBO: -25.1655 Val ELBO: -147.7203, Epoch Time (s): 0.08, Total Time (hrs): 0.2534
# ====> Epoch: 10289 Train ELBO: -13.8959 Val ELBO: -109.2071, Epoch Time (s): 0.13, Total Time (hrs): 0.2535
# ====> Epoch: 10290 Train ELBO: 22.9377 Val ELBO: -66.3974, Epoch Time (s): 0.10, Total Time (hrs): 0.2535
# ====> Epoch: 10291 Train ELBO: 45.4741 Val ELBO: -70.7815, Epoch Time (s): 0.07, Total Time (hrs): 0.2535
# ====> Epoch: 10292 Train ELBO: 45.6942 Val ELBO: -39.5401, Epoch Time (s): 0.08, Total Time (hrs): 0.2536
# ====> Epoch: 10293 Train ELBO: 54.5211 Val ELBO: -51.3187, Epoch Time (s): 0.07, Total Time (hrs): 0.2536
# ====> Epoch: 10294 Train ELBO: 47.1609 Val ELBO: -42.4541, Epoch Time (s): 0.07, Total Time (hrs): 0.2536
# ====> Epoch: 10295 Train ELBO: 53.5474 Val ELBO: -53.2869, Epoch Time (s): 0.07, Total Time (hrs): 0.2536
# ====> Epoch: 10296 Train ELBO: 56.0650 Val ELBO: -52.1760, Epoch Time (s): 0.07, Total Time (hrs): 0.2536
# ====> Epoch: 10297 Train ELBO: 55.3869 Val ELBO: -49.3814, Epoch Time (s): 0.07, Total Time (hrs): 0.2536
# ====> Epoch: 10298 Train ELBO: 55.4617 Val ELBO: -60.5639, Epoch Time (s): 0.07, Total Time (hrs): 0.2537
# ====> Epoch: 10299 Train ELBO: 54.6367 Val ELBO: -46.2049, Epoch Time (s): 0.07, Total Time (hrs): 0.2537
# ====> Epoch: 10300 Train ELBO: 57.3982 Val ELBO: -33.8657, Epoch Time (s): 0.12, Total Time (hrs): 0.2537
# ====> Epoch: 10301 Train ELBO: 63.5143 Val ELBO: -33.1240, Epoch Time (s): 0.11, Total Time (hrs): 0.2537
# ====> Epoch: 10302 Train ELBO: 61.2595 Val ELBO: -39.4522, Epoch Time (s): 0.10, Total Time (hrs): 0.2538
# ====> Epoch: 10303 Train ELBO: 60.2283 Val ELBO: -44.4629, Epoch Time (s): 0.11, Total Time (hrs): 0.2538
# ====> Epoch: 10304 Train ELBO: 61.6084 Val ELBO: -50.1384, Epoch Time (s): 0.11, Total Time (hrs): 0.2538
# ====> Epoch: 10305 Train ELBO: 58.6572 Val ELBO: -46.8969, Epoch Time (s): 0.10, Total Time (hrs): 0.2539
# ====> Epoch: 10306 Train ELBO: 54.6262 Val ELBO: -38.5113, Epoch Time (s): 0.09, Total Time (hrs): 0.2539
# ====> Epoch: 10307 Train ELBO: 60.1579 Val ELBO: -35.5966, Epoch Time (s): 0.11, Total Time (hrs): 0.2539
# ====> Epoch: 10308 Train ELBO: 60.0857 Val ELBO: -42.6516, Epoch Time (s): 0.10, Total Time (hrs): 0.2539
# ====> Epoch: 10309 Train ELBO: 59.6431 Val ELBO: -51.2636, Epoch Time (s): 0.09, Total Time (hrs): 0.2540
# ====> Epoch: 10310 Train ELBO: 50.7038 Val ELBO: -35.7067, Epoch Time (s): 0.11, Total Time (hrs): 0.2540
# ====> Epoch: 10311 Train ELBO: 48.7828 Val ELBO: -79.7865, Epoch Time (s): 0.09, Total Time (hrs): 0.2540
# ====> Epoch: 10312 Train ELBO: 49.0928 Val ELBO: -44.7615, Epoch Time (s): 0.11, Total Time (hrs): 0.2541
# ====> Epoch: 10313 Train ELBO: 58.0290 Val ELBO: -42.7424, Epoch Time (s): 0.11, Total Time (hrs): 0.2541
# ====> Epoch: 10314 Train ELBO: 57.2566 Val ELBO: -49.9158, Epoch Time (s): 0.09, Total Time (hrs): 0.2541
# ====> Epoch: 10315 Train ELBO: 58.3665 Val ELBO: -41.6857, Epoch Time (s): 0.10, Total Time (hrs): 0.2541
# ====> Epoch: 10316 Train ELBO: 57.4291 Val ELBO: -39.7507, Epoch Time (s): 0.12, Total Time (hrs): 0.2542
# ====> Epoch: 10317 Train ELBO: 59.2861 Val ELBO: -39.2144, Epoch Time (s): 0.10, Total Time (hrs): 0.2542
# ====> Epoch: 10318 Train ELBO: 57.2765 Val ELBO: -37.8730, Epoch Time (s): 0.09, Total Time (hrs): 0.2542
# ====> Epoch: 10319 Train ELBO: 53.1933 Val ELBO: -36.4844, Epoch Time (s): 0.10, Total Time (hrs): 0.2543
# ====> Epoch: 10320 Train ELBO: 48.0589 Val ELBO: -60.7248, Epoch Time (s): 0.10, Total Time (hrs): 0.2543
# ====> Epoch: 10321 Train ELBO: 41.4009 Val ELBO: -70.1462, Epoch Time (s): 0.09, Total Time (hrs): 0.2543
# ====> Epoch: 10322 Train ELBO: 39.9429 Val ELBO: -50.3015, Epoch Time (s): 0.11, Total Time (hrs): 0.2543
# ====> Epoch: 10323 Train ELBO: 50.8057 Val ELBO: -38.4556, Epoch Time (s): 0.09, Total Time (hrs): 0.2544
# ====> Epoch: 10324 Train ELBO: 61.6724 Val ELBO: -38.6446, Epoch Time (s): 0.09, Total Time (hrs): 0.2544
# ====> Epoch: 10325 Train ELBO: 59.9926 Val ELBO: -39.5793, Epoch Time (s): 0.11, Total Time (hrs): 0.2544
# ====> Epoch: 10326 Train ELBO: 57.8788 Val ELBO: -57.9121, Epoch Time (s): 0.10, Total Time (hrs): 0.2545
# ====> Epoch: 10327 Train ELBO: 43.5728 Val ELBO: -53.7434, Epoch Time (s): 0.11, Total Time (hrs): 0.2545
# ====> Epoch: 10328 Train ELBO: 46.2084 Val ELBO: -52.2086, Epoch Time (s): 0.11, Total Time (hrs): 0.2545
# ====> Epoch: 10329 Train ELBO: 54.5057 Val ELBO: -51.3540, Epoch Time (s): 0.12, Total Time (hrs): 0.2545
# ====> Epoch: 10330 Train ELBO: 41.1117 Val ELBO: -45.2911, Epoch Time (s): 0.11, Total Time (hrs): 0.2546
# ====> Epoch: 10331 Train ELBO: 41.6102 Val ELBO: -37.1693, Epoch Time (s): 0.10, Total Time (hrs): 0.2546
# ====> Epoch: 10332 Train ELBO: 52.8227 Val ELBO: -54.2133, Epoch Time (s): 0.13, Total Time (hrs): 0.2546
# ====> Epoch: 10333 Train ELBO: 56.7372 Val ELBO: -30.1828, Epoch Time (s): 0.11, Total Time (hrs): 0.2547
# ====> Epoch: 10334 Train ELBO: 53.3036 Val ELBO: -46.5520, Epoch Time (s): 0.11, Total Time (hrs): 0.2547
# ====> Epoch: 10335 Train ELBO: 58.0054 Val ELBO: -36.9217, Epoch Time (s): 0.12, Total Time (hrs): 0.2547
# ====> Epoch: 10336 Train ELBO: 59.7587 Val ELBO: -40.8283, Epoch Time (s): 0.09, Total Time (hrs): 0.2548
# ====> Epoch: 10337 Train ELBO: 61.4271 Val ELBO: -37.3898, Epoch Time (s): 0.07, Total Time (hrs): 0.2548
# ====> Epoch: 10338 Train ELBO: 57.4146 Val ELBO: -43.9920, Epoch Time (s): 0.07, Total Time (hrs): 0.2548
# ====> Epoch: 10339 Train ELBO: 60.8447 Val ELBO: -42.4378, Epoch Time (s): 0.07, Total Time (hrs): 0.2548
# ====> Epoch: 10340 Train ELBO: 58.6872 Val ELBO: -39.6918, Epoch Time (s): 0.07, Total Time (hrs): 0.2548
# ====> Epoch: 10341 Train ELBO: 55.4618 Val ELBO: -58.2938, Epoch Time (s): 0.07, Total Time (hrs): 0.2549
# ====> Epoch: 10342 Train ELBO: 60.9242 Val ELBO: -40.1117, Epoch Time (s): 0.07, Total Time (hrs): 0.2549
# ====> Epoch: 10343 Train ELBO: 59.4984 Val ELBO: -42.6824, Epoch Time (s): 0.07, Total Time (hrs): 0.2549
# ====> Epoch: 10344 Train ELBO: 56.1989 Val ELBO: -47.3145, Epoch Time (s): 0.07, Total Time (hrs): 0.2549
# ====> Epoch: 10345 Train ELBO: 55.0002 Val ELBO: -61.5041, Epoch Time (s): 0.07, Total Time (hrs): 0.2549
# ====> Epoch: 10346 Train ELBO: 53.5600 Val ELBO: -49.5732, Epoch Time (s): 0.07, Total Time (hrs): 0.2550
# ====> Epoch: 10347 Train ELBO: 57.5561 Val ELBO: -40.9809, Epoch Time (s): 0.07, Total Time (hrs): 0.2550
# ====> Epoch: 10348 Train ELBO: 63.1558 Val ELBO: -42.4505, Epoch Time (s): 0.07, Total Time (hrs): 0.2550
# ====> Epoch: 10349 Train ELBO: 65.6396 Val ELBO: -39.8102, Epoch Time (s): 0.07, Total Time (hrs): 0.2550
# ====> Epoch: 10350 Train ELBO: 63.5694 Val ELBO: -35.3437, Epoch Time (s): 0.08, Total Time (hrs): 0.2550
# ====> Epoch: 10351 Train ELBO: 63.7891 Val ELBO: -37.0777, Epoch Time (s): 0.07, Total Time (hrs): 0.2551
# ====> Epoch: 10352 Train ELBO: 54.7485 Val ELBO: -43.0347, Epoch Time (s): 0.07, Total Time (hrs): 0.2551
# ====> Epoch: 10353 Train ELBO: 51.6270 Val ELBO: -77.2003, Epoch Time (s): 0.07, Total Time (hrs): 0.2551
# ====> Epoch: 10354 Train ELBO: 48.7728 Val ELBO: -36.6906, Epoch Time (s): 0.07, Total Time (hrs): 0.2551
# ====> Epoch: 10355 Train ELBO: 56.4805 Val ELBO: -35.0904, Epoch Time (s): 0.06, Total Time (hrs): 0.2551
# ====> Epoch: 10356 Train ELBO: 60.4776 Val ELBO: -35.8686, Epoch Time (s): 0.07, Total Time (hrs): 0.2552
# ====> Epoch: 10357 Train ELBO: 58.2427 Val ELBO: -44.5509, Epoch Time (s): 0.07, Total Time (hrs): 0.2552
# ====> Epoch: 10358 Train ELBO: 53.8499 Val ELBO: -46.1846, Epoch Time (s): 0.07, Total Time (hrs): 0.2552
# ====> Epoch: 10359 Train ELBO: 49.2620 Val ELBO: -46.0211, Epoch Time (s): 0.07, Total Time (hrs): 0.2552
# ====> Epoch: 10360 Train ELBO: 49.9411 Val ELBO: -60.9728, Epoch Time (s): 0.07, Total Time (hrs): 0.2552
# ====> Epoch: 10361 Train ELBO: 41.9066 Val ELBO: -43.1810, Epoch Time (s): 0.07, Total Time (hrs): 0.2552
# ====> Epoch: 10362 Train ELBO: 46.0827 Val ELBO: -55.2083, Epoch Time (s): 0.07, Total Time (hrs): 0.2553
# ====> Epoch: 10363 Train ELBO: 51.1237 Val ELBO: -39.7671, Epoch Time (s): 0.07, Total Time (hrs): 0.2553
# ====> Epoch: 10364 Train ELBO: 53.1808 Val ELBO: -49.1501, Epoch Time (s): 0.07, Total Time (hrs): 0.2553
# ====> Epoch: 10365 Train ELBO: 61.5163 Val ELBO: -35.9092, Epoch Time (s): 0.08, Total Time (hrs): 0.2553
# ====> Epoch: 10366 Train ELBO: 61.9531 Val ELBO: -55.8394, Epoch Time (s): 0.08, Total Time (hrs): 0.2554
# ====> Epoch: 10367 Train ELBO: 53.7354 Val ELBO: -33.5548, Epoch Time (s): 0.07, Total Time (hrs): 0.2554
# ====> Epoch: 10368 Train ELBO: 56.6335 Val ELBO: -36.1112, Epoch Time (s): 0.07, Total Time (hrs): 0.2554
# ====> Epoch: 10369 Train ELBO: 43.4361 Val ELBO: -43.8104, Epoch Time (s): 0.07, Total Time (hrs): 0.2554
# ====> Epoch: 10370 Train ELBO: 45.9344 Val ELBO: -61.4530, Epoch Time (s): 0.07, Total Time (hrs): 0.2554
# ====> Epoch: 10371 Train ELBO: 51.9330 Val ELBO: -39.0178, Epoch Time (s): 0.07, Total Time (hrs): 0.2554
# ====> Epoch: 10372 Train ELBO: 56.2037 Val ELBO: -45.4477, Epoch Time (s): 0.07, Total Time (hrs): 0.2555
# ====> Epoch: 10373 Train ELBO: 57.4128 Val ELBO: -37.9590, Epoch Time (s): 0.07, Total Time (hrs): 0.2555
# ====> Epoch: 10374 Train ELBO: 49.6091 Val ELBO: -66.8336, Epoch Time (s): 0.07, Total Time (hrs): 0.2555
# ====> Epoch: 10375 Train ELBO: 43.3110 Val ELBO: -46.4210, Epoch Time (s): 0.07, Total Time (hrs): 0.2555
# ====> Epoch: 10376 Train ELBO: 50.8005 Val ELBO: -39.2976, Epoch Time (s): 0.07, Total Time (hrs): 0.2555
# ====> Epoch: 10377 Train ELBO: 56.0889 Val ELBO: -51.1382, Epoch Time (s): 0.07, Total Time (hrs): 0.2556
# ====> Epoch: 10378 Train ELBO: 59.3300 Val ELBO: -38.2683, Epoch Time (s): 0.07, Total Time (hrs): 0.2556
# ====> Epoch: 10379 Train ELBO: 59.4290 Val ELBO: -56.0821, Epoch Time (s): 0.07, Total Time (hrs): 0.2556
# ====> Epoch: 10380 Train ELBO: 58.6156 Val ELBO: -46.2950, Epoch Time (s): 0.08, Total Time (hrs): 0.2556
# ====> Epoch: 10381 Train ELBO: 59.6282 Val ELBO: -80.2334, Epoch Time (s): 0.07, Total Time (hrs): 0.2556
# ====> Epoch: 10382 Train ELBO: 42.5804 Val ELBO: -68.9308, Epoch Time (s): 0.07, Total Time (hrs): 0.2557
# ====> Epoch: 10383 Train ELBO: 45.3035 Val ELBO: -43.1757, Epoch Time (s): 0.07, Total Time (hrs): 0.2557
# ====> Epoch: 10384 Train ELBO: 58.3943 Val ELBO: -35.1461, Epoch Time (s): 0.07, Total Time (hrs): 0.2557
# ====> Epoch: 10385 Train ELBO: 57.2271 Val ELBO: -43.2195, Epoch Time (s): 0.08, Total Time (hrs): 0.2557
# ====> Epoch: 10386 Train ELBO: 54.2310 Val ELBO: -45.7420, Epoch Time (s): 0.07, Total Time (hrs): 0.2557
# ====> Epoch: 10387 Train ELBO: 43.3427 Val ELBO: -50.8908, Epoch Time (s): 0.07, Total Time (hrs): 0.2558
# ====> Epoch: 10388 Train ELBO: 45.8443 Val ELBO: -44.7269, Epoch Time (s): 0.07, Total Time (hrs): 0.2558
# ====> Epoch: 10389 Train ELBO: 48.7061 Val ELBO: -62.2952, Epoch Time (s): 0.08, Total Time (hrs): 0.2558
# ====> Epoch: 10390 Train ELBO: 50.7184 Val ELBO: -50.9235, Epoch Time (s): 0.07, Total Time (hrs): 0.2558
# ====> Epoch: 10391 Train ELBO: 45.3529 Val ELBO: -65.9175, Epoch Time (s): 0.07, Total Time (hrs): 0.2558
# ====> Epoch: 10392 Train ELBO: 51.9386 Val ELBO: -45.0367, Epoch Time (s): 0.07, Total Time (hrs): 0.2559
# ====> Epoch: 10393 Train ELBO: 53.1367 Val ELBO: -37.5677, Epoch Time (s): 0.07, Total Time (hrs): 0.2559
# ====> Epoch: 10394 Train ELBO: 54.3301 Val ELBO: -43.0155, Epoch Time (s): 0.07, Total Time (hrs): 0.2559
# ====> Epoch: 10395 Train ELBO: 51.9730 Val ELBO: -47.8250, Epoch Time (s): 0.09, Total Time (hrs): 0.2559
# ====> Epoch: 10396 Train ELBO: 56.2506 Val ELBO: -44.1819, Epoch Time (s): 0.07, Total Time (hrs): 0.2559
# ====> Epoch: 10397 Train ELBO: 53.4768 Val ELBO: -39.4486, Epoch Time (s): 0.07, Total Time (hrs): 0.2560
# ...
# ====> Epoch: 14850 Train ELBO: 51.8999 Val ELBO: -107.0527, Epoch Time (s): 0.12, Total Time (hrs): 0.3660
# ====> Epoch: 14851 Train ELBO: 39.6080 Val ELBO: -15.5437, Epoch Time (s): 0.10, Total Time (hrs): 0.3661
# ====> Epoch: 14852 Train ELBO: 55.5682 Val ELBO: -15.2290, Epoch Time (s): 0.11, Total Time (hrs): 0.3661
# ====> Epoch: 14853 Train ELBO: 77.1511 Val ELBO: -4.7280, Epoch Time (s): 0.12, Total Time (hrs): 0.3661
# ====> Epoch: 14854 Train ELBO: 77.2624 Val ELBO: -6.4333, Epoch Time (s): 0.10, Total Time (hrs): 0.3661
# ====> Epoch: 14855 Train ELBO: 76.8693 Val ELBO: -25.1137, Epoch Time (s): 0.07, Total Time (hrs): 0.3662
# ====> Epoch: 14856 Train ELBO: 75.2193 Val ELBO: -25.3133, Epoch Time (s): 0.07, Total Time (hrs): 0.3662
# ====> Epoch: 14857 Train ELBO: 80.7543 Val ELBO: -8.9404, Epoch Time (s): 0.07, Total Time (hrs): 0.3662
# ====> Epoch: 14858 Train ELBO: 84.4494 Val ELBO: -1.3439, Epoch Time (s): 0.07, Total Time (hrs): 0.3662
# ====> Epoch: 14859 Train ELBO: 83.6623 Val ELBO: -13.7904, Epoch Time (s): 0.07, Total Time (hrs): 0.3662
# ====> Epoch: 14860 Train ELBO: 72.7808 Val ELBO: -10.0223, Epoch Time (s): 0.07, Total Time (hrs): 0.3663
# ====> Epoch: 14861 Train ELBO: 70.8394 Val ELBO: -10.8306, Epoch Time (s): 0.07, Total Time (hrs): 0.3663
# ====> Epoch: 14862 Train ELBO: 71.3323 Val ELBO: -23.5966, Epoch Time (s): 0.07, Total Time (hrs): 0.3663
# ====> Epoch: 14863 Train ELBO: 75.0377 Val ELBO: -7.8586, Epoch Time (s): 0.07, Total Time (hrs): 0.3663
# ====> Epoch: 14864 Train ELBO: 81.2854 Val ELBO: -7.3613, Epoch Time (s): 0.07, Total Time (hrs): 0.3663
# ====> Epoch: 14865 Train ELBO: 84.2347 Val ELBO: -3.5404, Epoch Time (s): 0.07, Total Time (hrs): 0.3664
# ====> Epoch: 14866 Train ELBO: 88.6164 Val ELBO: -3.1000, Epoch Time (s): 0.07, Total Time (hrs): 0.3664
# ====> Epoch: 14867 Train ELBO: 87.6017 Val ELBO: -11.6331, Epoch Time (s): 0.08, Total Time (hrs): 0.3664
# ====> Epoch: 14868 Train ELBO: 87.0062 Val ELBO: -2.8011, Epoch Time (s): 0.07, Total Time (hrs): 0.3664
# ====> Epoch: 14869 Train ELBO: 85.9161 Val ELBO: 2.0253, Epoch Time (s): 0.09, Total Time (hrs): 0.3664
# ====> Epoch: 14870 Train ELBO: 85.6183 Val ELBO: 5.4048, Epoch Time (s): 0.07, Total Time (hrs): 0.3665
# ====> Epoch: 14871 Train ELBO: 86.3679 Val ELBO: -6.7731, Epoch Time (s): 0.07, Total Time (hrs): 0.3665
# ====> Epoch: 14872 Train ELBO: 82.0756 Val ELBO: 1.9569, Epoch Time (s): 0.07, Total Time (hrs): 0.3665
# ====> Epoch: 14873 Train ELBO: 82.4378 Val ELBO: -4.5848, Epoch Time (s): 0.07, Total Time (hrs): 0.3665
# ====> Epoch: 14874 Train ELBO: 75.9089 Val ELBO: -5.3271, Epoch Time (s): 0.07, Total Time (hrs): 0.3665
# ====> Epoch: 14875 Train ELBO: 78.1745 Val ELBO: -12.9824, Epoch Time (s): 0.07, Total Time (hrs): 0.3666
# ====> Epoch: 14876 Train ELBO: 73.9915 Val ELBO: -22.1451, Epoch Time (s): 0.07, Total Time (hrs): 0.3666
# ====> Epoch: 14877 Train ELBO: 73.7465 Val ELBO: -9.1234, Epoch Time (s): 0.07, Total Time (hrs): 0.3666
# ====> Epoch: 14878 Train ELBO: 66.6963 Val ELBO: -23.8215, Epoch Time (s): 0.08, Total Time (hrs): 0.3666
# ====> Epoch: 14879 Train ELBO: 75.7132 Val ELBO: -16.5973, Epoch Time (s): 0.07, Total Time (hrs): 0.3666
# ====> Epoch: 14880 Train ELBO: 77.8803 Val ELBO: -11.8526, Epoch Time (s): 0.07, Total Time (hrs): 0.3667
# ====> Epoch: 14881 Train ELBO: 69.5142 Val ELBO: -33.4698, Epoch Time (s): 0.07, Total Time (hrs): 0.3667
# ====> Epoch: 14882 Train ELBO: 68.4673 Val ELBO: -6.3099, Epoch Time (s): 0.07, Total Time (hrs): 0.3667
# ====> Epoch: 14883 Train ELBO: 75.5951 Val ELBO: -9.4526, Epoch Time (s): 0.08, Total Time (hrs): 0.3667
# ====> Epoch: 14884 Train ELBO: 72.1919 Val ELBO: -6.1641, Epoch Time (s): 0.08, Total Time (hrs): 0.3667
# ====> Epoch: 14885 Train ELBO: 79.9426 Val ELBO: -4.5319, Epoch Time (s): 0.07, Total Time (hrs): 0.3668
# ====> Epoch: 14886 Train ELBO: 82.4260 Val ELBO: -0.3212, Epoch Time (s): 0.07, Total Time (hrs): 0.3668
# ====> Epoch: 14887 Train ELBO: 84.5933 Val ELBO: -5.2424, Epoch Time (s): 0.07, Total Time (hrs): 0.3668
# ====> Epoch: 14888 Train ELBO: 84.8849 Val ELBO: -10.6242, Epoch Time (s): 0.07, Total Time (hrs): 0.3668
# ====> Epoch: 14889 Train ELBO: 79.9053 Val ELBO: -12.1994, Epoch Time (s): 0.07, Total Time (hrs): 0.3668
# ====> Epoch: 14890 Train ELBO: 77.5847 Val ELBO: -6.6270, Epoch Time (s): 0.07, Total Time (hrs): 0.3669
# ====> Epoch: 14891 Train ELBO: 83.5625 Val ELBO: -23.1510, Epoch Time (s): 0.07, Total Time (hrs): 0.3669
# ====> Epoch: 14892 Train ELBO: 77.7266 Val ELBO: -0.4720, Epoch Time (s): 0.07, Total Time (hrs): 0.3669
# ====> Epoch: 14893 Train ELBO: 85.4782 Val ELBO: -11.9384, Epoch Time (s): 0.07, Total Time (hrs): 0.3669
# ====> Epoch: 14894 Train ELBO: 83.5393 Val ELBO: -12.1593, Epoch Time (s): 0.07, Total Time (hrs): 0.3669
# ====> Epoch: 14895 Train ELBO: 79.4297 Val ELBO: -10.4441, Epoch Time (s): 0.07, Total Time (hrs): 0.3669
# ====> Epoch: 14896 Train ELBO: 81.8200 Val ELBO: 0.1342, Epoch Time (s): 0.07, Total Time (hrs): 0.3670
# ====> Epoch: 14897 Train ELBO: 89.4306 Val ELBO: -4.4393, Epoch Time (s): 0.07, Total Time (hrs): 0.3670
# ====> Epoch: 14898 Train ELBO: 82.3227 Val ELBO: -10.0780, Epoch Time (s): 0.08, Total Time (hrs): 0.3670
# ====> Epoch: 14899 Train ELBO: 86.9883 Val ELBO: -1.1136, Epoch Time (s): 0.07, Total Time (hrs): 0.3670
# ====> Epoch: 14900 Train ELBO: 86.2134 Val ELBO: -12.0652, Epoch Time (s): 0.08, Total Time (hrs): 0.3670
# ====> Epoch: 14901 Train ELBO: 81.9370 Val ELBO: -17.6923, Epoch Time (s): 0.07, Total Time (hrs): 0.3671
# ====> Epoch: 14902 Train ELBO: 80.8400 Val ELBO: -11.6553, Epoch Time (s): 0.07, Total Time (hrs): 0.3671
# ====> Epoch: 14903 Train ELBO: 76.8743 Val ELBO: -10.0684, Epoch Time (s): 0.07, Total Time (hrs): 0.3671
# ====> Epoch: 14904 Train ELBO: 81.5111 Val ELBO: -16.5645, Epoch Time (s): 0.07, Total Time (hrs): 0.3671
# ====> Epoch: 14905 Train ELBO: 75.1732 Val ELBO: -13.8672, Epoch Time (s): 0.07, Total Time (hrs): 0.3671
# ====> Epoch: 14906 Train ELBO: 74.0751 Val ELBO: -10.9824, Epoch Time (s): 0.07, Total Time (hrs): 0.3672
# ====> Epoch: 14907 Train ELBO: 75.0613 Val ELBO: -29.8573, Epoch Time (s): 0.07, Total Time (hrs): 0.3672
# ====> Epoch: 14908 Train ELBO: 71.3434 Val ELBO: -12.5812, Epoch Time (s): 0.07, Total Time (hrs): 0.3672
# ====> Epoch: 14909 Train ELBO: 68.6373 Val ELBO: -14.3597, Epoch Time (s): 0.07, Total Time (hrs): 0.3672
# ====> Epoch: 14910 Train ELBO: 77.8649 Val ELBO: -22.7517, Epoch Time (s): 0.08, Total Time (hrs): 0.3672
# ====> Epoch: 14911 Train ELBO: 65.9577 Val ELBO: -29.4399, Epoch Time (s): 0.07, Total Time (hrs): 0.3673
# ====> Epoch: 14912 Train ELBO: 73.2596 Val ELBO: -30.4645, Epoch Time (s): 0.07, Total Time (hrs): 0.3673
# ====> Epoch: 14913 Train ELBO: 69.9099 Val ELBO: -5.6313, Epoch Time (s): 0.08, Total Time (hrs): 0.3673
# ====> Epoch: 14914 Train ELBO: 67.7506 Val ELBO: -48.1598, Epoch Time (s): 0.07, Total Time (hrs): 0.3673
# ====> Epoch: 14915 Train ELBO: 46.9421 Val ELBO: -83.6966, Epoch Time (s): 0.07, Total Time (hrs): 0.3673
# ====> Epoch: 14916 Train ELBO: 31.0925 Val ELBO: -111.7099, Epoch Time (s): 0.07, Total Time (hrs): 0.3674
# ====> Epoch: 14917 Train ELBO: 16.2989 Val ELBO: -38.1269, Epoch Time (s): 0.07, Total Time (hrs): 0.3674
# ====> Epoch: 14918 Train ELBO: 46.5254 Val ELBO: -45.1961, Epoch Time (s): 0.07, Total Time (hrs): 0.3674
# ====> Epoch: 14919 Train ELBO: 49.4634 Val ELBO: -6.6360, Epoch Time (s): 0.07, Total Time (hrs): 0.3674
# ====> Epoch: 14920 Train ELBO: 61.5634 Val ELBO: -2.2292, Epoch Time (s): 0.07, Total Time (hrs): 0.3674
# ====> Epoch: 14921 Train ELBO: 73.9308 Val ELBO: -18.1778, Epoch Time (s): 0.07, Total Time (hrs): 0.3675
# ====> Epoch: 14922 Train ELBO: 78.6723 Val ELBO: -6.6943, Epoch Time (s): 0.07, Total Time (hrs): 0.3675
# ====> Epoch: 14923 Train ELBO: 70.7812 Val ELBO: -26.4741, Epoch Time (s): 0.07, Total Time (hrs): 0.3675
# ====> Epoch: 14924 Train ELBO: 73.1887 Val ELBO: -3.2154, Epoch Time (s): 0.07, Total Time (hrs): 0.3675
# ====> Epoch: 14925 Train ELBO: 83.6153 Val ELBO: -6.7603, Epoch Time (s): 0.07, Total Time (hrs): 0.3675
# ====> Epoch: 14926 Train ELBO: 86.2660 Val ELBO: -4.2260, Epoch Time (s): 0.07, Total Time (hrs): 0.3676
# ====> Epoch: 14927 Train ELBO: 77.5968 Val ELBO: -23.5339, Epoch Time (s): 0.09, Total Time (hrs): 0.3676
# ====> Epoch: 14928 Train ELBO: 82.3104 Val ELBO: -8.1483, Epoch Time (s): 0.07, Total Time (hrs): 0.3676
# ====> Epoch: 14929 Train ELBO: 77.1853 Val ELBO: 1.2785, Epoch Time (s): 0.07, Total Time (hrs): 0.3676
# ====> Epoch: 14930 Train ELBO: 83.6768 Val ELBO: -2.4011, Epoch Time (s): 0.07, Total Time (hrs): 0.3676
# ====> Epoch: 14931 Train ELBO: 85.8063 Val ELBO: -3.1130, Epoch Time (s): 0.07, Total Time (hrs): 0.3677
# ====> Epoch: 14932 Train ELBO: 83.3588 Val ELBO: -16.1646, Epoch Time (s): 0.07, Total Time (hrs): 0.3677
# ====> Epoch: 14933 Train ELBO: 83.1115 Val ELBO: 0.0005, Epoch Time (s): 0.07, Total Time (hrs): 0.3677
# ====> Epoch: 14934 Train ELBO: 88.1941 Val ELBO: -4.3159, Epoch Time (s): 0.07, Total Time (hrs): 0.3677
# ====> Epoch: 14935 Train ELBO: 82.3112 Val ELBO: -17.2010, Epoch Time (s): 0.07, Total Time (hrs): 0.3677
# ====> Epoch: 14936 Train ELBO: 78.9987 Val ELBO: 1.5147, Epoch Time (s): 0.07, Total Time (hrs): 0.3678
# ====> Epoch: 14937 Train ELBO: 81.6547 Val ELBO: -3.8369, Epoch Time (s): 0.07, Total Time (hrs): 0.3678
# ====> Epoch: 14938 Train ELBO: 83.9365 Val ELBO: -10.8367, Epoch Time (s): 0.07, Total Time (hrs): 0.3678
# ====> Epoch: 14939 Train ELBO: 78.7374 Val ELBO: -16.3358, Epoch Time (s): 0.07, Total Time (hrs): 0.3678
# ====> Epoch: 14940 Train ELBO: 73.8082 Val ELBO: -10.8217, Epoch Time (s): 0.07, Total Time (hrs): 0.3678
# ====> Epoch: 14941 Train ELBO: 71.2607 Val ELBO: -51.6168, Epoch Time (s): 0.07, Total Time (hrs): 0.3678
# ====> Epoch: 14942 Train ELBO: 44.2599 Val ELBO: -31.5739, Epoch Time (s): 0.08, Total Time (hrs): 0.3679
# ====> Epoch: 14943 Train ELBO: 56.9187 Val ELBO: -24.9093, Epoch Time (s): 0.07, Total Time (hrs): 0.3679
# ====> Epoch: 14944 Train ELBO: 69.1416 Val ELBO: -37.8713, Epoch Time (s): 0.07, Total Time (hrs): 0.3679
# ====> Epoch: 14945 Train ELBO: 64.0179 Val ELBO: -22.9573, Epoch Time (s): 0.07, Total Time (hrs): 0.3679
# ====> Epoch: 14946 Train ELBO: 72.8189 Val ELBO: -0.4512, Epoch Time (s): 0.07, Total Time (hrs): 0.3679
# ====> Epoch: 14947 Train ELBO: 76.1134 Val ELBO: -11.1742, Epoch Time (s): 0.07, Total Time (hrs): 0.3680
# ====> Epoch: 14948 Train ELBO: 73.2582 Val ELBO: -12.1259, Epoch Time (s): 0.07, Total Time (hrs): 0.3680
# ====> Epoch: 14949 Train ELBO: 73.3838 Val ELBO: -1.6597, Epoch Time (s): 0.07, Total Time (hrs): 0.3680
# ====> Epoch: 14950 Train ELBO: 81.5202 Val ELBO: -16.8758, Epoch Time (s): 0.07, Total Time (hrs): 0.3680
# ====> Epoch: 14951 Train ELBO: 78.6483 Val ELBO: -13.6059, Epoch Time (s): 0.07, Total Time (hrs): 0.3680
# ====> Epoch: 14952 Train ELBO: 82.8361 Val ELBO: -1.3716, Epoch Time (s): 0.08, Total Time (hrs): 0.3681
# ====> Epoch: 14953 Train ELBO: 90.1500 Val ELBO: 0.6603, Epoch Time (s): 0.07, Total Time (hrs): 0.3681
# ====> Epoch: 14954 Train ELBO: 87.5613 Val ELBO: -17.6206, Epoch Time (s): 0.07, Total Time (hrs): 0.3681
# ====> Epoch: 14955 Train ELBO: 71.4292 Val ELBO: -1.6763, Epoch Time (s): 0.07, Total Time (hrs): 0.3681
# ====> Epoch: 14956 Train ELBO: 75.7977 Val ELBO: -23.5511, Epoch Time (s): 0.07, Total Time (hrs): 0.3681
# ====> Epoch: 14957 Train ELBO: 74.1419 Val ELBO: -12.4039, Epoch Time (s): 0.08, Total Time (hrs): 0.3682
# ====> Epoch: 14958 Train ELBO: 80.3685 Val ELBO: -5.1082, Epoch Time (s): 0.08, Total Time (hrs): 0.3682
# ====> Epoch: 14959 Train ELBO: 77.5609 Val ELBO: -15.4126, Epoch Time (s): 0.08, Total Time (hrs): 0.3682
# ====> Epoch: 14960 Train ELBO: 84.3745 Val ELBO: -9.8103, Epoch Time (s): 0.09, Total Time (hrs): 0.3682
# ====> Epoch: 14961 Train ELBO: 84.3457 Val ELBO: -7.7991, Epoch Time (s): 0.07, Total Time (hrs): 0.3683
# ====> Epoch: 14962 Train ELBO: 85.4091 Val ELBO: -4.3302, Epoch Time (s): 0.07, Total Time (hrs): 0.3683
# ====> Epoch: 14963 Train ELBO: 86.8747 Val ELBO: -10.4783, Epoch Time (s): 0.07, Total Time (hrs): 0.3683
# ====> Epoch: 14964 Train ELBO: 86.6597 Val ELBO: -14.7356, Epoch Time (s): 0.07, Total Time (hrs): 0.3683
# ====> Epoch: 14965 Train ELBO: 83.6903 Val ELBO: -9.5775, Epoch Time (s): 0.07, Total Time (hrs): 0.3683
# ====> Epoch: 14966 Train ELBO: 87.6102 Val ELBO: 1.1489, Epoch Time (s): 0.07, Total Time (hrs): 0.3683
# ====> Epoch: 14967 Train ELBO: 90.6232 Val ELBO: 0.4555, Epoch Time (s): 0.07, Total Time (hrs): 0.3684
# ====> Epoch: 14968 Train ELBO: 88.8339 Val ELBO: 3.0687, Epoch Time (s): 0.07, Total Time (hrs): 0.3684
# ====> Epoch: 14969 Train ELBO: 90.6494 Val ELBO: -1.3735, Epoch Time (s): 0.07, Total Time (hrs): 0.3684
# ====> Epoch: 14970 Train ELBO: 88.2210 Val ELBO: -7.9043, Epoch Time (s): 0.07, Total Time (hrs): 0.3684
# ====> Epoch: 14971 Train ELBO: 74.2831 Val ELBO: -31.2585, Epoch Time (s): 0.08, Total Time (hrs): 0.3685
# ====> Epoch: 14972 Train ELBO: 80.9826 Val ELBO: -22.3262, Epoch Time (s): 0.07, Total Time (hrs): 0.3685
# ====> Epoch: 14973 Train ELBO: 80.0400 Val ELBO: 4.8778, Epoch Time (s): 0.07, Total Time (hrs): 0.3685
# ====> Epoch: 14974 Train ELBO: 86.9483 Val ELBO: -6.9381, Epoch Time (s): 0.07, Total Time (hrs): 0.3685
# ====> Epoch: 14975 Train ELBO: 84.8820 Val ELBO: -22.0731, Epoch Time (s): 0.07, Total Time (hrs): 0.3685
# ====> Epoch: 14976 Train ELBO: 80.9531 Val ELBO: -28.3043, Epoch Time (s): 0.08, Total Time (hrs): 0.3685
# ====> Epoch: 14977 Train ELBO: 75.6698 Val ELBO: -32.6689, Epoch Time (s): 0.07, Total Time (hrs): 0.3686
# ====> Epoch: 14978 Train ELBO: 63.7691 Val ELBO: -35.4316, Epoch Time (s): 0.07, Total Time (hrs): 0.3686
# ====> Epoch: 14979 Train ELBO: 72.3805 Val ELBO: -41.1387, Epoch Time (s): 0.07, Total Time (hrs): 0.3686
# ====> Epoch: 14980 Train ELBO: 75.9108 Val ELBO: -35.6081, Epoch Time (s): 0.07, Total Time (hrs): 0.3686
# ====> Epoch: 14981 Train ELBO: 74.9589 Val ELBO: -23.7310, Epoch Time (s): 0.07, Total Time (hrs): 0.3686
# ====> Epoch: 14982 Train ELBO: 78.1703 Val ELBO: -12.7918, Epoch Time (s): 0.07, Total Time (hrs): 0.3687
# ====> Epoch: 14983 Train ELBO: 79.3730 Val ELBO: -8.9681, Epoch Time (s): 0.07, Total Time (hrs): 0.3687
# ====> Epoch: 14984 Train ELBO: 85.5772 Val ELBO: 4.3557, Epoch Time (s): 0.07, Total Time (hrs): 0.3687
# ====> Epoch: 14985 Train ELBO: 89.8396 Val ELBO: 0.0851, Epoch Time (s): 0.09, Total Time (hrs): 0.3687
# ====> Epoch: 14986 Train ELBO: 86.5056 Val ELBO: -10.5509, Epoch Time (s): 0.07, Total Time (hrs): 0.3687
# ====> Epoch: 14987 Train ELBO: 83.0724 Val ELBO: 3.9446, Epoch Time (s): 0.07, Total Time (hrs): 0.3688
# ====> Epoch: 14988 Train ELBO: 88.1147 Val ELBO: -0.7110, Epoch Time (s): 0.07, Total Time (hrs): 0.3688
# ====> Epoch: 14989 Train ELBO: 88.7106 Val ELBO: 0.6923, Epoch Time (s): 0.07, Total Time (hrs): 0.3688
# ====> Epoch: 14990 Train ELBO: 86.9200 Val ELBO: 0.7803, Epoch Time (s): 0.07, Total Time (hrs): 0.3688
# ====> Epoch: 14991 Train ELBO: 86.1160 Val ELBO: 0.0697, Epoch Time (s): 0.07, Total Time (hrs): 0.3688
# ====> Epoch: 14992 Train ELBO: 85.6277 Val ELBO: -1.3264, Epoch Time (s): 0.07, Total Time (hrs): 0.3689
# ====> Epoch: 14993 Train ELBO: 87.9034 Val ELBO: -6.1764, Epoch Time (s): 0.07, Total Time (hrs): 0.3689
# ====> Epoch: 14994 Train ELBO: 81.4804 Val ELBO: -6.3211, Epoch Time (s): 0.08, Total Time (hrs): 0.3689
# ====> Epoch: 14995 Train ELBO: 82.7892 Val ELBO: -26.4650, Epoch Time (s): 0.12, Total Time (hrs): 0.3689
# ====> Epoch: 14996 Train ELBO: 79.4706 Val ELBO: -7.5733, Epoch Time (s): 0.11, Total Time (hrs): 0.3690
# ====> Epoch: 14997 Train ELBO: 73.7879 Val ELBO: -33.2438, Epoch Time (s): 0.10, Total Time (hrs): 0.3690
# ====> Epoch: 14998 Train ELBO: 70.6942 Val ELBO: -17.8294, Epoch Time (s): 0.10, Total Time (hrs): 0.3690
# ====> Epoch: 14999 Train ELBO: 77.5034 Val ELBO: -22.4756, Epoch Time (s): 0.11, Total Time (hrs): 0.3691
# Training took  0:22:08.593067
# 3
# 3
# 3
# Training data size 800
# Fraction of downward curves: 0.6349999904632568
# Cluster 1 probability: 0.06244824826717377
