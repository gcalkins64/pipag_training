# %% [markdown]
# <a href="https://colab.research.google.com/github/gcalkins64/pipag_training/blob/main/test_git_imports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://gcalkins64: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@github.com/gcalkins64/pipag_training.git
# !cd pipag_training && git pull
import sys
sys.path.append('/content/pipag_training')  # or the subfolder containing your .py file
# Out:
# Already up to date.
