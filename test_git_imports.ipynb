# %% [markdown]
# <a href="https://colab.research.google.com/github/gcalkins64/pipag_training/blob/main/test_git_imports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
