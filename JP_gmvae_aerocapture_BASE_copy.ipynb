# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.11/dist-packages (2.5.1.post0)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.2)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (1.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (24.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (4.13.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (0.14.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics>=0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.10)

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://gcalkins64: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@github.com/gcalkins64/pipag_training.git
# !cd pipag_training && git pull
sys.path.append('/content/pipag_training')
# Out:
# fatal: destination path 'pipag_training' already exists and is not an empty directory.
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda

# %% [markdown]
# # Settings

# %%
n_train = 1024
n_val = 128
n_test = 128
# For testing small batches of data
# n_train = 400
# n_val = 50
# n_test = 50
# THREE LAYERS
# hd1 = 48
# hd2 = 32
# hd3 = 16
# hidden_dims = [hd1, hd2, hd3]
# TWO LAYERS
hd1 = 48
hd2 = 32
hd3 = None
hidden_dims = [hd1, hd2]
latent_dim = 4
n_clusters = 6
lr = 1e-3
n_epochs = 30_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

plot_interval = 500
dpi = 300

K = n_clusters
Z = latent_dim
D = 1  #num_modalities
downsampleNum = 64

loadFlag = False  # True to load in old case, False to run a new case

# data = '1_near_escape_fnpag_2000_data_energy_scaled_downsampled_'
# inds = '1_near_escape_fnpag_1999_inds_energy_scaled_downsampled_'
# tag = 'near_escape'

data = '1_near_crash_fnpag_2000_data_energy_scaled_downsampled_'
inds = '1_near_crash_fnpag_2000_inds_energy_scaled_downsampled_'
tag = 'near_crash'

# %% [markdown]
# # Set Up Data Loader

# %%
from datetime import datetime
timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

# %%
if loadFlag:  # Load in old data
  dirname = os.path.join("drive", "MyDrive", "JP_gmvae_data", 'gmvae_em_aerocapture_energy_20250429_155508_5_4')
else:  # generate new data
  dirname = os.path.join("drive", "MyDrive", "JP_gmvae_data", "gmvae_"+tag+"_"+timestr+"_L"+str(latent_dim)+"_C"+str(n_clusters))
  os.makedirs(dirname, exist_ok=True)
print("Filepath directory: " + dirname)

if loadFlag:  # load old data
  postfix = '_42_1024_128_128_32_16_5_4_0.001000_128_0.001000_0.000010_1000.000000_'
else:  # Generate new suffix
  if hd3 is not None:
    postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:d}_{9:f}_{10:d}_{11:f}_{12:f}_{13:f}_'.format(
          SEED, n_train, n_val, n_test, hd1, hd2, hd3, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
  else:
    postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
          SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
print("Filepath postfix: " + postfix)
# Out:
# Filepath directory: drive/MyDrive/JP_gmvae_data/gmvae_near_crash_20250529_020222_L4_C6
# Filepath postfix: _42_1024_128_128_48_32_4_6_0.001000_128_0.001000_0.000010_30000.000000_

# %%
data_dir = os.path.join("drive", "MyDrive", "JP_gmvae_data", f"{data}.json")

with open(os.path.join("drive", "MyDrive", "JP_gmvae_data", f"{inds}.json"), 'r') as f:
  sample_list_load = json.load(f)
sample_list = [int(sample) for sample in sample_list_load['sample_list']]
print(sample_list)
# Out:
# [325, 767, 1850, 1272, 701, 1270, 1030, 1148, 1698, 1417, 1620, 744, 1651, 541, 1723, 1678, 806, 1442, 968, 465, 549, 982, 1517, 1487, 1813, 1414, 1026, 1085, 152, 1453, 1054, 978, 334, 1849, 1221, 1152, 679, 700, 1119, 107, 630, 447, 338, 1779, 391, 1547, 1950, 1378, 716, 1770, 1308, 1094, 525, 1242, 457, 1016, 147, 627, 331, 545, 397, 1737, 866, 810, 1748, 1834, 85, 507, 976, 656, 1642, 0, 835, 590, 1694, 1229, 1151, 1781, 422, 1041, 742, 1785, 724, 1433, 775, 1444, 1, 779, 1051, 1637, 284, 1572, 739, 1634, 585, 941, 136, 13, 1260, 1034, 1551, 1231, 971, 1045, 1910, 893, 904, 619, 1025, 567, 755, 1186, 51, 1143, 676, 1530, 1874, 352, 1798, 1304, 1120, 174, 276, 1043, 1115, 1906, 1954, 617, 931, 292, 620, 217, 1056, 308, 1286, 1511, 1332, 1463, 179, 112, 698, 693, 392, 1367, 363, 1699, 181, 610, 1701, 491, 320, 289, 1921, 871, 1158, 1105, 1341, 663, 1819, 834, 1996, 1005, 1977, 1622, 1324, 1318, 1657, 791, 930, 1583, 1556, 1360, 1312, 1159, 87, 1658, 1486, 886, 333, 1374, 1553, 1263, 1359, 332, 1826, 1852, 1352, 1446, 29, 1861, 476, 1967, 443, 713, 1672, 456, 1489, 141, 706, 587, 1867, 376, 905, 532, 1566, 973, 1802, 259, 1955, 1801, 303, 677, 1076, 1558, 1827, 1656, 1667, 705, 464, 1922, 1768, 1889, 127, 79, 589, 1640, 1450, 1239, 272, 770, 870, 235, 1676, 246, 1992, 606, 9, 804, 667, 223, 1498, 649, 384, 435, 1262, 852, 1395, 561, 1314, 407, 682, 1856, 1363, 720, 1957, 1046, 1751, 451, 1900, 1223, 444, 1887, 1736, 1010, 762, 1296, 1044, 515, 372, 436, 39, 1443, 1727, 1295, 1167, 1666, 1278, 509, 1995, 146, 847, 461, 293, 793, 1145, 1028, 199, 645, 859, 364, 743, 1549, 1480, 1713, 1842, 375, 1860, 1776, 207, 1690, 1448, 1493, 1650, 1127, 1418, 1970, 42, 1795, 1368, 1689, 100, 1608, 1519, 1796, 1610, 1758, 162, 937, 711, 760, 103, 1756, 873, 1268, 922, 1953, 1408, 689, 908, 173, 558, 583, 76, 1627, 1617, 1683, 1872, 123, 1722, 816, 1248, 1171, 6, 527, 1555, 1854, 1621, 327, 416, 1994, 191, 1592, 1275, 1035, 1074, 1985, 1071, 18, 1407, 1447, 283, 1760, 1733, 1390, 139, 766, 1130, 354, 1981, 1012, 874, 359, 702, 1478, 747, 1840, 1404, 1069, 730, 196, 753, 1811, 400, 1948, 857, 1315, 1027, 220, 1803, 1633, 248, 622, 1002, 16, 470, 55, 1665, 318, 1168, 1290, 269, 1616, 890, 1587, 321, 771, 1595, 213, 631, 917, 1113, 279, 607, 66, 1920, 1870, 1087, 565, 1539, 1868, 1339, 1828, 1321, 460, 683, 1466, 482, 1410, 1881, 612, 1913, 678, 1535, 906, 1141, 1253, 1821, 1079, 32, 1810, 1285, 1456, 1859, 1771, 1934, 1461, 119, 328, 426, 699, 1342, 1460, 539, 189, 1401, 800, 919, 455, 1157, 737, 1761, 92, 1631, 271, 306, 1959, 1427, 1573, 672, 337, 1455, 1298, 818, 1425, 1755, 1685, 694, 1816, 1648, 1284, 1065, 1349, 1663, 879, 628, 686, 594, 1951, 1055, 1216, 965, 95, 1740, 615, 324, 498, 20, 802, 1710, 423, 1063, 172, 911, 1743, 542, 84, 1765, 1358, 814, 336, 608, 952, 853, 128, 1067, 1017, 1540, 1938, 907, 1752, 632, 1962, 463, 1855, 1311, 1660, 1534, 221, 1023, 1086, 1824, 1110, 943, 1618, 657, 1515, 812, 1261, 224, 861, 148, 56, 206, 1464, 205, 1370, 1439, 704, 588, 1931, 1873, 344, 809, 52, 597, 1804, 1799, 1688, 1584, 316, 1008, 909, 1098, 629, 1236, 304, 1753, 1732, 970, 1213, 1482, 1014, 516, 1146, 371, 1907, 950, 1741, 1939, 277, 326, 1329, 41, 53, 1571, 210, 1319, 749, 605, 945, 353, 776, 1421, 550, 727, 984, 602, 1567, 1287, 414, 183, 1471, 997, 175, 844, 96, 1956, 1759, 1172, 626, 1243, 1165, 1614, 1575, 1362, 116, 772, 568, 1884, 37, 1643, 754, 855, 1972, 1180, 1211, 81, 1334, 661, 1475, 555, 1863, 1059, 367, 979, 526, 811, 1265, 1876, 477, 1570, 1437, 305, 714, 725, 386, 1273, 273, 513, 1091, 1917, 1797, 441, 1905, 921, 1178, 524, 453, 815, 1382, 924, 1871, 564, 110, 880, 830, 431, 915, 168, 1177, 1175, 58, 792, 1372, 129, 1746, 28, 651, 425, 956, 281, 1518, 1721, 1980, 1597, 586, 666, 576, 1309, 1068, 1096, 858, 1164, 577, 1800, 1537, 1357, 1307, 837, 312, 951, 785, 875, 286, 822, 1877, 1245, 1208, 1269, 1006, 750, 1670, 49, 995, 242, 177, 954, 618, 633, 1696, 1991, 1904, 433, 1227, 1503, 1132, 722, 865, 1389, 50, 644, 434, 163 ...

# %%
data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                  train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                  num_workers=0)

data_module.setup("fit", sample_list = sample_list)

train_loader = data_module.train_dataloader()
val_loader = data_module.val_dataloader()
test_loader = data_module.test_dataloader()
data_dim = len(train_loader.dataset[0][0])
text_labels = ['capture', 'escape', 'impact']
label_colors = ['C2', 'C3', 'C4']

num_train_batches = len(train_loader)

ts_plot = np.linspace(0,450,64)
seabornSettings()
fig, ax = plt.subplots(figsize=(4, 4))
for j in range(n_train):
    ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.75)

eline = mlines.Line2D([], [], color='C2', label='Escape')
cline = mlines.Line2D([], [], color='C3', label='Capture')
iline = mlines.Line2D([], [], color='C4', label='Impact')
plt.legend(handles=[eline, cline, iline])
plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
plt.xlabel("Time [s]")
plt.ylabel("Nondimensionalized Energy")
plt.title("Training Data")
plt.tight_layout()
fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_val):
    ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()])
plt.title("Validation Data")
fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_test):
    ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()])
plt.title("Test Data")
fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)
# Out:
# Loading File...
# ...File Loaded
# Sample List: [325, 767, 1850, 1272, 701, 1270, 1030, 1148, 1698, 1417, 1620, 744, 1651, 541, 1723, 1678, 806, 1442, 968, 465, 549, 982, 1517, 1487, 1813, 1414, 1026, 1085, 152, 1453, 1054, 978, 334, 1849, 1221, 1152, 679, 700, 1119, 107, 630, 447, 338, 1779, 391, 1547, 1950, 1378, 716, 1770, 1308, 1094, 525, 1242, 457, 1016, 147, 627, 331, 545, 397, 1737, 866, 810, 1748, 1834, 85, 507, 976, 656, 1642, 0, 835, 590, 1694, 1229, 1151, 1781, 422, 1041, 742, 1785, 724, 1433, 775, 1444, 1, 779, 1051, 1637, 284, 1572, 739, 1634, 585, 941, 136, 13, 1260, 1034, 1551, 1231, 971, 1045, 1910, 893, 904, 619, 1025, 567, 755, 1186, 51, 1143, 676, 1530, 1874, 352, 1798, 1304, 1120, 174, 276, 1043, 1115, 1906, 1954, 617, 931, 292, 620, 217, 1056, 308, 1286, 1511, 1332, 1463, 179, 112, 698, 693, 392, 1367, 363, 1699, 181, 610, 1701, 491, 320, 289, 1921, 871, 1158, 1105, 1341, 663, 1819, 834, 1996, 1005, 1977, 1622, 1324, 1318, 1657, 791, 930, 1583, 1556, 1360, 1312, 1159, 87, 1658, 1486, 886, 333, 1374, 1553, 1263, 1359, 332, 1826, 1852, 1352, 1446, 29, 1861, 476, 1967, 443, 713, 1672, 456, 1489, 141, 706, 587, 1867, 376, 905, 532, 1566, 973, 1802, 259, 1955, 1801, 303, 677, 1076, 1558, 1827, 1656, 1667, 705, 464, 1922, 1768, 1889, 127, 79, 589, 1640, 1450, 1239, 272, 770, 870, 235, 1676, 246, 1992, 606, 9, 804, 667, 223, 1498, 649, 384, 435, 1262, 852, 1395, 561, 1314, 407, 682, 1856, 1363, 720, 1957, 1046, 1751, 451, 1900, 1223, 444, 1887, 1736, 1010, 762, 1296, 1044, 515, 372, 436, 39, 1443, 1727, 1295, 1167, 1666, 1278, 509, 1995, 146, 847, 461, 293, 793, 1145, 1028, 199, 645, 859, 364, 743, 1549, 1480, 1713, 1842, 375, 1860, 1776, 207, 1690, 1448, 1493, 1650, 1127, 1418, 1970, 42, 1795, 1368, 1689, 100, 1608, 1519, 1796, 1610, 1758, 162, 937, 711, 760, 103, 1756, 873, 1268, 922, 1953, 1408, 689, 908, 173, 558, 583, 76, 1627, 1617, 1683, 1872, 123, 1722, 816, 1248, 1171, 6, 527, 1555, 1854, 1621, 327, 416, 1994, 191, 1592, 1275, 1035, 1074, 1985, 1071, 18, 1407, 1447, 283, 1760, 1733, 1390, 139, 766, 1130, 354, 1981, 1012, 874, 359, 702, 1478, 747, 1840, 1404, 1069, 730, 196, 753, 1811, 400, 1948, 857, 1315, 1027, 220, 1803, 1633, 248, 622, 1002, 16, 470, 55, 1665, 318, 1168, 1290, 269, 1616, 890, 1587, 321, 771, 1595, 213, 631, 917, 1113, 279, 607, 66, 1920, 1870, 1087, 565, 1539, 1868, 1339, 1828, 1321, 460, 683, 1466, 482, 1410, 1881, 612, 1913, 678, 1535, 906, 1141, 1253, 1821, 1079, 32, 1810, 1285, 1456, 1859, 1771, 1934, 1461, 119, 328, 426, 699, 1342, 1460, 539, 189, 1401, 800, 919, 455, 1157, 737, 1761, 92, 1631, 271, 306, 1959, 1427, 1573, 672, 337, 1455, 1298, 818, 1425, 1755, 1685, 694, 1816, 1648, 1284, 1065, 1349, 1663, 879, 628, 686, 594, 1951, 1055, 1216, 965, 95, 1740, 615, 324, 498, 20, 802, 1710, 423, 1063, 172, 911, 1743, 542, 84, 1765, 1358, 814, 336, 608, 952, 853, 128, 1067, 1017, 1540, 1938, 907, 1752, 632, 1962, 463, 1855, 1311, 1660, 1534, 221, 1023, 1086, 1824, 1110, 943, 1618, 657, 1515, 812, 1261, 224, 861, 148, 56, 206, 1464, 205, 1370, 1439, 704, 588, 1931, 1873, 344, 809, 52, 597, 1804, 1799, 1688, 1584, 316, 1008, 909, 1098, 629, 1236, 304, 1753, 1732, 970, 1213, 1482, 1014, 516, 1146, 371, 1907, 950, 1741, 1939, 277, 326, 1329, 41, 53, 1571, 210, 1319, 749, 605, 945, 353, 776, 1421, 550, 727, 984, 602, 1567, 1287, 414, 183, 1471, 997, 175, 844, 96, 1956, 1759, 1172, 626, 1243, 1165, 1614, 1575, 1362, 116, 772, 568, 1884, 37, 1643, 754, 855, 1972, 1180, 1211, 81, 1334, 661, 1475, 555, 1863, 1059, 367, 979, 526, 811, 1265, 1876, 477, 1570, 1437, 305, 714, 725, 386, 1273, 273, 513, 1091, 1917, 1797, 441, 1905, 921, 1178, 524, 453, 815, 1382, 924, 1871, 564, 110, 880, 830, 431, 915, 168, 1177, 1175, 58, 792, 1372, 129, 1746, 28, 651, 425, 956, 281, 1518, 1721, 1980, 1597, 586, 666, 576, 1309, 1068, 1096, 858, 1164, 577, 1800, 1537, 1357, 1307, 837, 312, 951, 785, 875, 286, 822, 1877, 1245, 1208, 1269, 1006, 750, 1670, 49, 995, 242, 177, 954, 618, 633, 1696, 1991, 1904, 433, 1227, 1503, 1132, 722, 865, 1389, 50,  ...
#   0%|          | 0/1280 [00:00<?, ?it/s]

# %% [markdown]
# # Run GMVAE

# %%
# initialize latent GMM model parameters
params = {}
pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
params['pi_c'] = torch.ones(K) / K
params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
params['logsigmasq_c'] = torch.zeros((K, Z))


text_labels = [f'Cluster {i}' for i in range((n_clusters))]
label_colors = [f'C{i+1}' for i in range((n_clusters))]

# initialize neural networks
encoder_list = []
decoder_list = []
trainable_parameters = []
trainable_parameters.append(pi_variables)

for _ in range(D):
    encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd1, hd2])
    decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd2, hd1], decoder_var=decoder_var)
    encoder_list.append(encoder)
    decoder_list.append(decoder)
    trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

optimizer = optim.Adam(trainable_parameters, lr=lr)

# training

import time
ts = time.time()
tic = time.perf_counter()

train_loss = torch.zeros(n_epochs)
train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
val_loss = torch.zeros(n_epochs)
pi_history = torch.zeros((n_epochs, K))
train_mse_history = torch.zeros(n_epochs)
val_mse_history = torch.zeros(n_epochs)
min_val_loss = torch.inf
seabornSettings()

for epoch in range(n_epochs):
    ti = time.time()
    for encoder in encoder_list:
        encoder.train()
    for decoder in decoder_list:
        decoder.train()

    train_elbo = 0
    train_mse = 0
    train_elbo_term = np.zeros(4)
    params['hist_weights'] = torch.zeros((K, 1))
    params['hist_mu_c'] = torch.zeros((K, latent_dim))
    params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

    for (batch_idx, batch) in enumerate(train_loader):
        batch_x, _ = batch
        x_list = [batch_x]  # assume D=2 and each modality has data_dim
        optimizer.zero_grad()
        pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
        params['pi_c'] = pi_c

        mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
        sigma = torch.exp(0.5 * logsigmasq)
        eps = Normal(0, 1).sample(mu.shape)
        z = mu + eps * sigma

        with torch.no_grad():
            gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
        params['mu_c'] = mu_c
        params['logsigmasq_c'] = logsigmasq_c

        elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
        train_elbo += elbo.item()
        train_elbo_term += elbo_terms
        train_mse += sse.item()
        loss = - elbo / batch_x.shape[0]
        loss.backward()
        optimizer.step()

    for encoder in encoder_list:
        encoder.eval()
    for decoder in decoder_list:
        decoder.eval()

    if epoch % plot_interval == 0 or epoch == n_epochs:
        # Plot the first two dimensions of the latents
        with torch.no_grad():
            means = []
            samples = []
            labels = []
            for batch in train_loader:
                batch_x, batch_label = batch
                x_list = [batch_x]
                mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                sigma = torch.exp(0.5 * logsigmasq)
                eps = Normal(0, 1).sample(mean.shape)
                z = mean + eps * sigma
                means.append(mean)
                samples.append(z)
                labels.append(batch_label)

        means = torch.vstack(means).cpu()
        samples = torch.vstack(samples).cpu()
        labels = torch.hstack(labels).cpu()

        savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
        plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

        savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
        plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


        # plot samples from generative model
        n_gen = n_train
        cluster_probs = params['pi_c'].cpu().detach().numpy() #
        fig, ax = plt.subplots(figsize=(4.5, 4))
        for j in range(n_gen):
            c = np.random.choice(K, p=cluster_probs)
            mu_c = params['mu_c'][c].clone().detach()
            sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
            z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
            mu_x = decoder.forward(z)[0]
            ax.plot(mu_x.cpu().detach().numpy())
        fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
        plt.close()


    val_elbo = 0
    val_mse = 0
    val_elbo_term = np.zeros(4)
    with torch.no_grad():
        for (batch_idx, batch) in enumerate(val_loader):
            batch_x, _ = batch
            x_list = [batch_x]
            mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
            sigma = torch.exp(0.5 * logsigmasq)
            eps = Normal(0, 1).sample(mu.shape)
            z = mu + eps * sigma
            with torch.no_grad():
                gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
            elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
            val_elbo += elbo.item()
            val_mse += sse.item()
            val_elbo_term += elbo_items

    train_elbo /= len(train_loader.dataset)
    train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
    val_elbo /= len(val_loader.dataset)
    val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
    train_mse /= len(train_loader.dataset)
    val_mse /= len(val_loader.dataset)

    tf = time.time()
    toc = time.perf_counter()
    print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

    train_loss[epoch] = - train_elbo
    val_loss[epoch] = - val_elbo
    train_elbo_terms[epoch,:] = - train_elbo_term
    val_elbo_terms[epoch,:] = - val_elbo_term
    pi_history[epoch] = params['pi_c']
    train_mse_history[epoch] = train_mse
    val_mse_history[epoch] = val_mse

    if - val_elbo < min_val_loss:
        min_val_loss = - val_elbo
        torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
        torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
        torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
        torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
        torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

    if epoch % plot_interval == 0 or epoch == n_epochs:
      # Plot the training and validation loss vs. epoch number
      plt.figure(figsize=(4.5, 4))
      # const = min(min(train_loss), min(val_loss))
      train_loss_adjusted = train_loss
      val_loss_adjusted = val_loss
      plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
      # print(train_loss_adjusted.cpu()[:epoch])
      plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
      plt.yscale('symlog')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Negative Loss")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
      for ii in range(4):
        train_loss_adjusted = train_elbo_terms[:epoch, ii]
        val_loss_adjusted = val_elbo_terms[:epoch, ii]
        plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
        plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.yscale('symlog')
      plt.ylabel("loss")
      plt.title("Negative Loss Terms")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot the training and validation mse vs. epoch number
      plt.figure(figsize=(4.5, 4))
      plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
      plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot the history of pi
      plt.figure(figsize=(4.5, 4))
      for i in range(K):
          plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()


te = time.time()
import datetime
duration = datetime.timedelta(seconds=te - ts)
print("Training took ", duration)

# Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))
# Out:
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 25001 Train ELBO: 193.7456 Val ELBO: 163.8642, Epoch Time (s): 0.09, Total Time (hrs): 0.7905
# ====> Epoch: 25002 Train ELBO: 162.6433 Val ELBO: 154.4594, Epoch Time (s): 0.09, Total Time (hrs): 0.7905
# ====> Epoch: 25003 Train ELBO: 152.7701 Val ELBO: 155.4573, Epoch Time (s): 0.09, Total Time (hrs): 0.7905
# ====> Epoch: 25004 Train ELBO: 172.6984 Val ELBO: 150.9225, Epoch Time (s): 0.10, Total Time (hrs): 0.7906
# ====> Epoch: 25005 Train ELBO: 171.6851 Val ELBO: 133.6116, Epoch Time (s): 0.09, Total Time (hrs): 0.7906
# ====> Epoch: 25006 Train ELBO: 178.5591 Val ELBO: 160.2296, Epoch Time (s): 0.10, Total Time (hrs): 0.7906
# ====> Epoch: 25007 Train ELBO: 183.3146 Val ELBO: 152.7329, Epoch Time (s): 0.11, Total Time (hrs): 0.7906
# ====> Epoch: 25008 Train ELBO: 189.3463 Val ELBO: 163.6935, Epoch Time (s): 0.10, Total Time (hrs): 0.7907
# ====> Epoch: 25009 Train ELBO: 188.0996 Val ELBO: 154.5433, Epoch Time (s): 0.12, Total Time (hrs): 0.7907
# ====> Epoch: 25010 Train ELBO: 187.1378 Val ELBO: 158.0322, Epoch Time (s): 0.12, Total Time (hrs): 0.7907
# ====> Epoch: 25011 Train ELBO: 192.5106 Val ELBO: 157.6865, Epoch Time (s): 0.16, Total Time (hrs): 0.7908
# ====> Epoch: 25012 Train ELBO: 194.5634 Val ELBO: 168.8783, Epoch Time (s): 0.14, Total Time (hrs): 0.7908
# ====> Epoch: 25013 Train ELBO: 200.3440 Val ELBO: 170.6052, Epoch Time (s): 0.14, Total Time (hrs): 0.7909
# ====> Epoch: 25014 Train ELBO: 202.2694 Val ELBO: 170.6616, Epoch Time (s): 0.13, Total Time (hrs): 0.7909
# ====> Epoch: 25015 Train ELBO: 203.5256 Val ELBO: 174.2155, Epoch Time (s): 0.16, Total Time (hrs): 0.7909
# ====> Epoch: 25016 Train ELBO: 204.9229 Val ELBO: 173.6147, Epoch Time (s): 0.15, Total Time (hrs): 0.7910
# ====> Epoch: 25017 Train ELBO: 203.0419 Val ELBO: 169.5115, Epoch Time (s): 0.13, Total Time (hrs): 0.7910
# ====> Epoch: 25018 Train ELBO: 197.8845 Val ELBO: 162.7969, Epoch Time (s): 0.12, Total Time (hrs): 0.7911
# ====> Epoch: 25019 Train ELBO: 197.3123 Val ELBO: 167.0902, Epoch Time (s): 0.15, Total Time (hrs): 0.7911
# ====> Epoch: 25020 Train ELBO: 202.5801 Val ELBO: 172.1208, Epoch Time (s): 0.15, Total Time (hrs): 0.7911
# ====> Epoch: 25021 Train ELBO: 205.1660 Val ELBO: 172.6709, Epoch Time (s): 0.14, Total Time (hrs): 0.7912
# ====> Epoch: 25022 Train ELBO: 206.2952 Val ELBO: 174.6898, Epoch Time (s): 0.13, Total Time (hrs): 0.7912
# ====> Epoch: 25023 Train ELBO: 206.8116 Val ELBO: 171.8911, Epoch Time (s): 0.16, Total Time (hrs): 0.7913
# ====> Epoch: 25024 Train ELBO: 206.6054 Val ELBO: 175.8320, Epoch Time (s): 0.16, Total Time (hrs): 0.7913
# ====> Epoch: 25025 Train ELBO: 207.0141 Val ELBO: 173.4195, Epoch Time (s): 0.14, Total Time (hrs): 0.7913
# ====> Epoch: 25026 Train ELBO: 206.6177 Val ELBO: 171.5365, Epoch Time (s): 0.13, Total Time (hrs): 0.7914
# ====> Epoch: 25027 Train ELBO: 207.1356 Val ELBO: 172.4300, Epoch Time (s): 0.15, Total Time (hrs): 0.7914
# ====> Epoch: 25028 Train ELBO: 207.1857 Val ELBO: 172.1762, Epoch Time (s): 0.13, Total Time (hrs): 0.7915
# ====> Epoch: 25029 Train ELBO: 207.2939 Val ELBO: 174.2883, Epoch Time (s): 0.14, Total Time (hrs): 0.7915
# ====> Epoch: 25030 Train ELBO: 207.4640 Val ELBO: 173.8217, Epoch Time (s): 0.14, Total Time (hrs): 0.7915
# ====> Epoch: 25031 Train ELBO: 205.1565 Val ELBO: 175.1965, Epoch Time (s): 0.19, Total Time (hrs): 0.7916
# ====> Epoch: 25032 Train ELBO: 203.7158 Val ELBO: 166.8108, Epoch Time (s): 0.14, Total Time (hrs): 0.7916
# ====> Epoch: 25033 Train ELBO: 202.1934 Val ELBO: 172.3887, Epoch Time (s): 0.15, Total Time (hrs): 0.7917
# ====> Epoch: 25034 Train ELBO: 203.1000 Val ELBO: 171.5883, Epoch Time (s): 0.16, Total Time (hrs): 0.7917
# ====> Epoch: 25035 Train ELBO: 205.3044 Val ELBO: 171.0623, Epoch Time (s): 0.19, Total Time (hrs): 0.7918
# ====> Epoch: 25036 Train ELBO: 206.3340 Val ELBO: 173.6435, Epoch Time (s): 0.10, Total Time (hrs): 0.7918
# ====> Epoch: 25037 Train ELBO: 207.3201 Val ELBO: 173.4137, Epoch Time (s): 0.12, Total Time (hrs): 0.7918
# ====> Epoch: 25038 Train ELBO: 206.8100 Val ELBO: 171.3305, Epoch Time (s): 0.10, Total Time (hrs): 0.7919
# ====> Epoch: 25039 Train ELBO: 204.5286 Val ELBO: 171.1228, Epoch Time (s): 0.12, Total Time (hrs): 0.7919
# ====> Epoch: 25040 Train ELBO: 204.9699 Val ELBO: 171.4746, Epoch Time (s): 0.09, Total Time (hrs): 0.7919
# ====> Epoch: 25041 Train ELBO: 205.1407 Val ELBO: 174.2257, Epoch Time (s): 0.09, Total Time (hrs): 0.7919
# ====> Epoch: 25042 Train ELBO: 203.8151 Val ELBO: 170.4727, Epoch Time (s): 0.10, Total Time (hrs): 0.7920
# ====> Epoch: 25043 Train ELBO: 204.8741 Val ELBO: 173.0566, Epoch Time (s): 0.09, Total Time (hrs): 0.7920
# ====> Epoch: 25044 Train ELBO: 205.0734 Val ELBO: 173.0264, Epoch Time (s): 0.09, Total Time (hrs): 0.7920
# ====> Epoch: 25045 Train ELBO: 204.8091 Val ELBO: 169.7732, Epoch Time (s): 0.10, Total Time (hrs): 0.7920
# ====> Epoch: 25046 Train ELBO: 204.0745 Val ELBO: 172.3951, Epoch Time (s): 0.09, Total Time (hrs): 0.7921
# ====> Epoch: 25047 Train ELBO: 203.6537 Val ELBO: 172.2061, Epoch Time (s): 0.10, Total Time (hrs): 0.7921
# ====> Epoch: 25048 Train ELBO: 203.0940 Val ELBO: 166.5171, Epoch Time (s): 0.10, Total Time (hrs): 0.7921
# ====> Epoch: 25049 Train ELBO: 202.1409 Val ELBO: 167.9799, Epoch Time (s): 0.09, Total Time (hrs): 0.7921
# ====> Epoch: 25050 Train ELBO: 199.4140 Val ELBO: 167.9394, Epoch Time (s): 0.12, Total Time (hrs): 0.7922
# ====> Epoch: 25051 Train ELBO: 201.2121 Val ELBO: 169.8656, Epoch Time (s): 0.10, Total Time (hrs): 0.7922
# ====> Epoch: 25052 Train ELBO: 203.6556 Val ELBO: 168.3723, Epoch Time (s): 0.09, Total Time (hrs): 0.7922
# ====> Epoch: 25053 Train ELBO: 203.6360 Val ELBO: 173.4841, Epoch Time (s): 0.10, Total Time (hrs): 0.7923
# ====> Epoch: 25054 Train ELBO: 205.9310 Val ELBO: 173.0558, Epoch Time (s): 0.10, Total Time (hrs): 0.7923
# ====> Epoch: 25055 Train ELBO: 204.4464 Val ELBO: 172.2421, Epoch Time (s): 0.09, Total Time (hrs): 0.7923
# ====> Epoch: 25056 Train ELBO: 204.7670 Val ELBO: 172.6653, Epoch Time (s): 0.10, Total Time (hrs): 0.7923
# ====> Epoch: 25057 Train ELBO: 203.8568 Val ELBO: 173.2663, Epoch Time (s): 0.09, Total Time (hrs): 0.7924
# ====> Epoch: 25058 Train ELBO: 202.2645 Val ELBO: 170.7885, Epoch Time (s): 0.10, Total Time (hrs): 0.7924
# ====> Epoch: 25059 Train ELBO: 200.7484 Val ELBO: 169.1888, Epoch Time (s): 0.10, Total Time (hrs): 0.7924
# ====> Epoch: 25060 Train ELBO: 200.0779 Val ELBO: 173.9170, Epoch Time (s): 0.10, Total Time (hrs): 0.7925
# ====> Epoch: 25061 Train ELBO: 201.6154 Val ELBO: 171.9831, Epoch Time (s): 0.09, Total Time (hrs): 0.7925
# ====> Epoch: 25062 Train ELBO: 204.4830 Val ELBO: 173.6390, Epoch Time (s): 0.10, Total Time (hrs): 0.7925
# ====> Epoch: 25063 Train ELBO: 204.4093 Val ELBO: 173.0667, Epoch Time (s): 0.09, Total Time (hrs): 0.7925
# ====> Epoch: 25064 Train ELBO: 204.3772 Val ELBO: 172.3791, Epoch Time (s): 0.09, Total Time (hrs): 0.7926
# ====> Epoch: 25065 Train ELBO: 204.5366 Val ELBO: 172.2560, Epoch Time (s): 0.10, Total Time (hrs): 0.7926
# ====> Epoch: 25066 Train ELBO: 202.1877 Val ELBO: 172.1976, Epoch Time (s): 0.10, Total Time (hrs): 0.7926
# ====> Epoch: 25067 Train ELBO: 201.0597 Val ELBO: 172.3928, Epoch Time (s): 0.09, Total Time (hrs): 0.7926
# ====> Epoch: 25068 Train ELBO: 202.0254 Val ELBO: 169.0701, Epoch Time (s): 0.10, Total Time (hrs): 0.7927
# ====> Epoch: 25069 Train ELBO: 200.0256 Val ELBO: 168.3129, Epoch Time (s): 0.09, Total Time (hrs): 0.7927
# ====> Epoch: 25070 Train ELBO: 202.5140 Val ELBO: 165.8151, Epoch Time (s): 0.09, Total Time (hrs): 0.7927
# ====> Epoch: 25071 Train ELBO: 199.2941 Val ELBO: 169.1403, Epoch Time (s): 0.12, Total Time (hrs): 0.7927
# ====> Epoch: 25072 Train ELBO: 198.1000 Val ELBO: 166.2134, Epoch Time (s): 0.09, Total Time (hrs): 0.7928
# ====> Epoch: 25073 Train ELBO: 201.3266 Val ELBO: 167.2868, Epoch Time (s): 0.09, Total Time (hrs): 0.7928
# ====> Epoch: 25074 Train ELBO: 203.1845 Val ELBO: 170.9428, Epoch Time (s): 0.10, Total Time (hrs): 0.7928
# ====> Epoch: 25075 Train ELBO: 202.4761 Val ELBO: 169.9813, Epoch Time (s): 0.09, Total Time (hrs): 0.7928
# ====> Epoch: 25076 Train ELBO: 202.8037 Val ELBO: 166.5878, Epoch Time (s): 0.09, Total Time (hrs): 0.7929
# ====> Epoch: 25077 Train ELBO: 201.6658 Val ELBO: 171.8301, Epoch Time (s): 0.09, Total Time (hrs): 0.7929
# ====> Epoch: 25078 Train ELBO: 196.5018 Val ELBO: 163.2359, Epoch Time (s): 0.09, Total Time (hrs): 0.7929
# ====> Epoch: 25079 Train ELBO: 195.6090 Val ELBO: 164.2050, Epoch Time (s): 0.09, Total Time (hrs): 0.7930
# ====> Epoch: 25080 Train ELBO: 193.7104 Val ELBO: 166.6229, Epoch Time (s): 0.10, Total Time (hrs): 0.7930
# ====> Epoch: 25081 Train ELBO: 191.5816 Val ELBO: 164.1208, Epoch Time (s): 0.09, Total Time (hrs): 0.7930
# ====> Epoch: 25082 Train ELBO: 186.8290 Val ELBO: 150.3213, Epoch Time (s): 0.11, Total Time (hrs): 0.7930
# ====> Epoch: 25083 Train ELBO: 190.1201 Val ELBO: 159.8028, Epoch Time (s): 0.10, Total Time (hrs): 0.7931
# ====> Epoch: 25084 Train ELBO: 196.0747 Val ELBO: 168.9708, Epoch Time (s): 0.09, Total Time (hrs): 0.7931
# ====> Epoch: 25085 Train ELBO: 199.1272 Val ELBO: 161.3136, Epoch Time (s): 0.09, Total Time (hrs): 0.7931
# ====> Epoch: 25086 Train ELBO: 200.9077 Val ELBO: 174.4553, Epoch Time (s): 0.10, Total Time (hrs): 0.7931
# ====> Epoch: 25087 Train ELBO: 202.3750 Val ELBO: 167.1617, Epoch Time (s): 0.09, Total Time (hrs): 0.7932
# ====> Epoch: 25088 Train ELBO: 202.1182 Val ELBO: 169.2672, Epoch Time (s): 0.09, Total Time (hrs): 0.7932
# ====> Epoch: 25089 Train ELBO: 199.6612 Val ELBO: 169.8639, Epoch Time (s): 0.10, Total Time (hrs): 0.7932
# ====> Epoch: 25090 Train ELBO: 198.8559 Val ELBO: 170.0661, Epoch Time (s): 0.09, Total Time (hrs): 0.7932
# ====> Epoch: 25091 Train ELBO: 198.6653 Val ELBO: 163.6294, Epoch Time (s): 0.09, Total Time (hrs): 0.7933
# ====> Epoch: 25092 Train ELBO: 198.4970 Val ELBO: 166.8515, Epoch Time (s): 0.09, Total Time (hrs): 0.7933
# ====> Epoch: 25093 Train ELBO: 200.2080 Val ELBO: 169.8500, Epoch Time (s): 0.11, Total Time (hrs): 0.7933
# ====> Epoch: 25094 Train ELBO: 202.6043 Val ELBO: 167.4874, Epoch Time (s): 0.09, Total Time (hrs): 0.7933
# ====> Epoch: 25095 Train ELBO: 201.6945 Val ELBO: 159.4171, Epoch Time (s): 0.10, Total Time (hrs): 0.7934
# ====> Epoch: 25096 Train ELBO: 186.7135 Val ELBO: 148.3672, Epoch Time (s): 0.09, Total Time (hrs): 0.7934
# ====> Epoch: 25097 Train ELBO: 161.9311 Val ELBO: 141.2158, Epoch Time (s): 0.15, Total Time (hrs): 0.7934
# ====> Epoch: 25098 Train ELBO: 166.7226 Val ELBO: 150.5701, Epoch Time (s): 0.09, Total Time (hrs): 0.7935
# ====> Epoch: 25099 Train ELBO: 178.0622 Val ELBO: 155.3586, Epoch Time (s): 0.09, Total Time (hrs): 0.7935
# ====> Epoch: 25100 Train ELBO: 177.1708 Val ELBO: 152.2075, Epoch Time (s): 0.10, Total Time (hrs): 0.7935
# ====> Epoch: 25101 Train ELBO: 182.0496 Val ELBO: 165.8342, Epoch Time (s): 0.09, Total Time (hrs): 0.7935
# ====> Epoch: 25102 Train ELBO: 180.6441 Val ELBO: 154.9956, Epoch Time (s): 0.09, Total Time (hrs): 0.7936
# ====> Epoch: 25103 Train ELBO: 176.2371 Val ELBO: 152.6649, Epoch Time (s): 0.10, Total Time (hrs): 0.7936
# ====> Epoch: 25104 Train ELBO: 181.4508 Val ELBO: 162.1738, Epoch Time (s): 0.11, Total Time (hrs): 0.7936
# ====> Epoch: 25105 Train ELBO: 193.7212 Val ELBO: 166.5335, Epoch Time (s): 0.09, Total Time (hrs): 0.7937
# ====> Epoch: 25106 Train ELBO: 194.0396 Val ELBO: 159.4684, Epoch Time (s): 0.10, Total Time (hrs): 0.7937
# ====> Epoch: 25107 Train ELBO: 195.4320 Val ELBO: 165.6708, Epoch Time (s): 0.09, Total Time (hrs): 0.7937
# ====> Epoch: 25108 Train ELBO: 197.4848 Val ELBO: 157.0142, Epoch Time (s): 0.09, Total Time (hrs): 0.7937
# ====> Epoch: 25109 Train ELBO: 196.4495 Val ELBO: 163.8997, Epoch Time (s): 0.11, Total Time (hrs): 0.7938
# ====> Epoch: 25110 Train ELBO: 196.3985 Val ELBO: 164.9127, Epoch Time (s): 0.09, Total Time (hrs): 0.7938
# ====> Epoch: 25111 Train ELBO: 192.6509 Val ELBO: 164.0215, Epoch Time (s): 0.09, Total Time (hrs): 0.7938
# ====> Epoch: 25112 Train ELBO: 193.0370 Val ELBO: 160.3133, Epoch Time (s): 0.10, Total Time (hrs): 0.7938
# ====> Epoch: 25113 Train ELBO: 194.3414 Val ELBO: 164.9489, Epoch Time (s): 0.09, Total Time (hrs): 0.7939
# ====> Epoch: 25114 Train ELBO: 196.3600 Val ELBO: 164.9904, Epoch Time (s): 0.11, Total Time (hrs): 0.7939
# ====> Epoch: 25115 Train ELBO: 195.4853 Val ELBO: 164.3393, Epoch Time (s): 0.10, Total Time (hrs): 0.7939
# ====> Epoch: 25116 Train ELBO: 197.6278 Val ELBO: 170.7017, Epoch Time (s): 0.09, Total Time (hrs): 0.7939
# ====> Epoch: 25117 Train ELBO: 201.6108 Val ELBO: 172.3693, Epoch Time (s): 0.09, Total Time (hrs): 0.7940
# ====> Epoch: 25118 Train ELBO: 201.1641 Val ELBO: 167.9464, Epoch Time (s): 0.10, Total Time (hrs): 0.7940
# ====> Epoch: 25119 Train ELBO: 202.9515 Val ELBO: 173.8222, Epoch Time (s): 0.09, Total Time (hrs): 0.7940
# ====> Epoch: 25120 Train ELBO: 203.3575 Val ELBO: 168.2327, Epoch Time (s): 0.10, Total Time (hrs): 0.7940
# ====> Epoch: 25121 Train ELBO: 202.6842 Val ELBO: 173.6122, Epoch Time (s): 0.11, Total Time (hrs): 0.7941
# ====> Epoch: 25122 Train ELBO: 202.4141 Val ELBO: 172.4944, Epoch Time (s): 0.10, Total Time (hrs): 0.7941
# ====> Epoch: 25123 Train ELBO: 203.0541 Val ELBO: 169.5075, Epoch Time (s): 0.09, Total Time (hrs): 0.7941
# ====> Epoch: 25124 Train ELBO: 201.9964 Val ELBO: 174.5089, Epoch Time (s): 0.09, Total Time (hrs): 0.7942
# ====> Epoch: 25125 Train ELBO: 203.7402 Val ELBO: 172.3973, Epoch Time (s): 0.10, Total Time (hrs): 0.7942
# ====> Epoch: 25126 Train ELBO: 204.1961 Val ELBO: 171.6297, Epoch Time (s): 0.09, Total Time (hrs): 0.7942
# ====> Epoch: 25127 Train ELBO: 204.5928 Val ELBO: 168.2237, Epoch Time (s): 0.10, Total Time (hrs): 0.7942
# ====> Epoch: 25128 Train ELBO: 200.8323 Val ELBO: 171.7184, Epoch Time (s): 0.10, Total Time (hrs): 0.7943
# ====> Epoch: 25129 Train ELBO: 198.5872 Val ELBO: 173.3868, Epoch Time (s): 0.09, Total Time (hrs): 0.7943
# ====> Epoch: 25130 Train ELBO: 197.7527 Val ELBO: 158.9175, Epoch Time (s): 0.10, Total Time (hrs): 0.7943
# ====> Epoch: 25131 Train ELBO: 198.9924 Val ELBO: 166.6323, Epoch Time (s): 0.09, Total Time (hrs): 0.7943
# ====> Epoch: 25132 Train ELBO: 201.2204 Val ELBO: 168.9460, Epoch Time (s): 0.09, Total Time (hrs): 0.7944
# ====> Epoch: 25133 Train ELBO: 199.8321 Val ELBO: 167.8565, Epoch Time (s): 0.09, Total Time (hrs): 0.7944
# ====> Epoch: 25134 Train ELBO: 200.8469 Val ELBO: 169.6203, Epoch Time (s): 0.09, Total Time (hrs): 0.7944
# ====> Epoch: 25135 Train ELBO: 199.0814 Val ELBO: 164.5011, Epoch Time (s): 0.09, Total Time (hrs): 0.7944
# ====> Epoch: 25136 Train ELBO: 197.9434 Val ELBO: 164.5866, Epoch Time (s): 0.11, Total Time (hrs): 0.7945
# ====> Epoch: 25137 Train ELBO: 198.5956 Val ELBO: 166.8702, Epoch Time (s): 0.09, Total Time (hrs): 0.7945
# ====> Epoch: 25138 Train ELBO: 201.2753 Val ELBO: 171.8311, Epoch Time (s): 0.08, Total Time (hrs): 0.7945
# ====> Epoch: 25139 Train ELBO: 203.0083 Val ELBO: 171.9798, Epoch Time (s): 0.10, Total Time (hrs): 0.7945
# ====> Epoch: 25140 Train ELBO: 204.9564 Val ELBO: 174.2115, Epoch Time (s): 0.12, Total Time (hrs): 0.7946
# ====> Epoch: 25141 Train ELBO: 204.7112 Val ELBO: 171.6463, Epoch Time (s): 0.13, Total Time (hrs): 0.7946
# ====> Epoch: 25142 Train ELBO: 206.1874 Val ELBO: 172.2138, Epoch Time (s): 0.13, Total Time (hrs): 0.7947
# ====> Epoch: 25143 Train ELBO: 206.8427 Val ELBO: 176.0721, Epoch Time (s): 0.13, Total Time (hrs): 0.7947
# ====> Epoch: 25144 Train ELBO: 208.0324 Val ELBO: 174.6521, Epoch Time (s): 0.12, Total Time (hrs): 0.7947
# ====> Epoch: 25145 Train ELBO: 207.4093 Val ELBO: 173.7225, Epoch Time (s): 0.15, Total Time (hrs): 0.7948
# ====> Epoch: 25146 Train ELBO: 206.5598 Val ELBO: 175.9199, Epoch Time (s): 0.12, Total Time (hrs): 0.7948
# ====> Epoch: 25147 Train ELBO: 206.5300 Val ELBO: 171.8004, Epoch Time (s): 0.13, Total Time (hrs): 0.7948
# ====> Epoch: 25148 Train ELBO: 207.3757 Val ELBO: 172.9607, Epoch Time (s): 0.12, Total Time (hrs): 0.7949
# ====> Epoch: 25149 Train ELBO: 205.0032 Val ELBO: 171.5703, Epoch Time (s): 0.15, Total Time (hrs): 0.7949
# ====> Epoch: 25150 Train ELBO: 203.8008 Val ELBO: 171.5860, Epoch Time (s): 0.13, Total Time (hrs): 0.7950
# ====> Epoch: 25151 Train ELBO: 203.9942 Val ELBO: 168.3105, Epoch Time (s): 0.14, Total Time (hrs): 0.7950
# ====> Epoch: 25152 Train ELBO: 205.6410 Val ELBO: 174.4385, Epoch Time (s): 0.13, Total Time (hrs): 0.7950
# ====> Epoch: 25153 Train ELBO: 201.5192 Val ELBO: 173.5435, Epoch Time (s): 0.13, Total Time (hrs): 0.7951
# ====> Epoch: 25154 Train ELBO: 200.4383 Val ELBO: 165.9293, Epoch Time (s): 0.13, Total Time (hrs): 0.7951
# ====> Epoch: 25155 Train ELBO: 200.4611 Val ELBO: 171.8997, Epoch Time (s): 0.14, Total Time (hrs): 0.7951
# ====> Epoch: 25156 Train ELBO: 201.5639 Val ELBO: 166.8527, Epoch Time (s): 0.13, Total Time (hrs): 0.7952
# ====> Epoch: 25157 Train ELBO: 202.9288 Val ELBO: 170.9054, Epoch Time (s): 0.13, Total Time (hrs): 0.7952
# ====> Epoch: 25158 Train ELBO: 203.3403 Val ELBO: 165.8810, Epoch Time (s): 0.12, Total Time (hrs): 0.7952
# ====> Epoch: 25159 Train ELBO: 202.2248 Val ELBO: 168.5619, Epoch Time (s): 0.13, Total Time (hrs): 0.7953
# ====> Epoch: 25160 Train ELBO: 201.7589 Val ELBO: 171.7944, Epoch Time (s): 0.12, Total Time (hrs): 0.7953
# ====> Epoch: 25161 Train ELBO: 203.7867 Val ELBO: 166.2071, Epoch Time (s): 0.15, Total Time (hrs): 0.7953
# ====> Epoch: 25162 Train ELBO: 203.2687 Val ELBO: 173.2597, Epoch Time (s): 0.14, Total Time (hrs): 0.7954
# ====> Epoch: 25163 Train ELBO: 204.2450 Val ELBO: 171.2975, Epoch Time (s): 0.14, Total Time (hrs): 0.7954
# ====> Epoch: 25164 Train ELBO: 204.3492 Val ELBO: 170.4355, Epoch Time (s): 0.14, Total Time (hrs): 0.7955
# ====> Epoch: 25165 Train ELBO: 197.8293 Val ELBO: 169.4311, Epoch Time (s): 0.16, Total Time (hrs): 0.7955
# ====> Epoch: 25166 Train ELBO: 194.6255 Val ELBO: 161.0049, Epoch Time (s): 0.14, Total Time (hrs): 0.7956
# ====> Epoch: 25167 Train ELBO: 185.8439 Val ELBO: 166.0358, Epoch Time (s): 0.09, Total Time (hrs): 0.7956
# ====> Epoch: 25168 Train ELBO: 181.1590 Val ELBO: 162.4895, Epoch Time (s): 0.09, Total Time (hrs): 0.7956
# ====> Epoch: 25169 Train ELBO: 177.0372 Val ELBO: 126.3070, Epoch Time (s): 0.09, Total Time (hrs): 0.7956
# ====> Epoch: 25170 Train ELBO: 164.3612 Val ELBO: 140.7209, Epoch Time (s): 0.11, Total Time (hrs): 0.7957
# ====> Epoch: 25171 Train ELBO: 176.3792 Val ELBO: 161.3849, Epoch Time (s): 0.10, Total Time (hrs): 0.7957
# ====> Epoch: 25172 Train ELBO: 184.7712 Val ELBO: 158.1997, Epoch Time (s): 0.09, Total Time (hrs): 0.7957
# ====> Epoch: 25173 Train ELBO: 178.6299 Val ELBO: 154.7981, Epoch Time (s): 0.10, Total Time (hrs): 0.7957
# ====> Epoch: 25174 Train ELBO: 179.3471 Val ELBO: 165.4072, Epoch Time (s): 0.09, Total Time (hrs): 0.7958
# ====> Epoch: 25175 Train ELBO: 179.4399 Val ELBO: 147.0684, Epoch Time (s): 0.08, Total Time (hrs): 0.7958
# ====> Epoch: 25176 Train ELBO: 177.6424 Val ELBO: 160.1183, Epoch Time (s): 0.09, Total Time (hrs): 0.7958
# ====> Epoch: 25177 Train ELBO: 189.3005 Val ELBO: 162.5448, Epoch Time (s): 0.09, Total Time (hrs): 0.7958
# ====> Epoch: 25178 Train ELBO: 196.0045 Val ELBO: 165.1148, Epoch Time (s): 0.08, Total Time (hrs): 0.7959
# ====> Epoch: 25179 Train ELBO: 196.3658 Val ELBO: 168.3767, Epoch Time (s): 0.10, Total Time (hrs): 0.7959
# ====> Epoch: 25180 Train ELBO: 198.2250 Val ELBO: 167.7829, Epoch Time (s): 0.09, Total Time (hrs): 0.7959
# ====> Epoch: 25181 Train ELBO: 196.2964 Val ELBO: 167.1649, Epoch Time (s): 0.09, Total Time (hrs): 0.7959
# ====> Epoch: 25182 Train ELBO: 193.6027 Val ELBO: 166.7214, Epoch Time (s): 0.11, Total Time (hrs): 0.7960
# ====> Epoch: 25183 Train ELBO: 191.1611 Val ELBO: 157.2913, Epoch Time (s): 0.09, Total Time (hrs): 0.7960
# ====> Epoch: 25184 Train ELBO: 188.0922 Val ELBO: 165.8235, Epoch Time (s): 0.09, Total Time (hrs): 0.7960
# ====> Epoch: 25185 Train ELBO: 192.5845 Val ELBO: 151.0710, Epoch Time (s): 0.09, Total Time (hrs): 0.7960
# ====> Epoch: 25186 Train ELBO: 191.2618 Val ELBO: 164.0560, Epoch Time (s): 0.09, Total Time (hrs): 0.7961
# ====> Epoch: 25187 Train ELBO: 193.2519 Val ELBO: 167.1653, Epoch Time (s): 0.09, Total Time (hrs): 0.7961
# ====> Epoch: 25188 Train ELBO: 190.5900 Val ELBO: 155.1433, Epoch Time (s): 0.10, Total Time (hrs): 0.7961
# ====> Epoch: 25189 Train ELBO: 191.3845 Val ELBO: 160.7268, Epoch Time (s): 0.09, Total Time (hrs): 0.7961
# ====> Epoch: 25190 Train ELBO: 187.9867 Val ELBO: 164.3853, Epoch Time (s): 0.09, Total Time (hrs): 0.7962
# ====> Epoch: 25191 Train ELBO: 182.3483 Val ELBO: 166.4060, Epoch Time (s): 0.10, Total Time (hrs): 0.7962
# ====> Epoch: 25192 Train ELBO: 191.2223 Val ELBO: 162.7713, Epoch Time (s): 0.09, Total Time (hrs): 0.7962
# ====> Epoch: 25193 Train ELBO: 198.0906 Val ELBO: 169.3824, Epoch Time (s): 0.10, Total Time (hrs): 0.7962
# ====> Epoch: 25194 Train ELBO: 198.2556 Val ELBO: 169.1956, Epoch Time (s): 0.09, Total Time (hrs): 0.7963
# ====> Epoch: 25195 Train ELBO: 199.8173 Val ELBO: 163.8318, Epoch Time (s): 0.09, Total Time (hrs): 0.7963
# ====> Epoch: 25196 Train ELBO: 202.0430 Val ELBO: 175.1671, Epoch Time (s): 0.08, Total Time (hrs): 0.7963
# ====> Epoch: 25197 Train ELBO: 205.0084 Val ELBO: 171.5374, Epoch Time (s): 0.09, Total Time (hrs): 0.7963
# ====> Epoch: 25198 Train ELBO: 204.8453 Val ELBO: 172.2180, Epoch Time (s): 0.09, Total Time (hrs): 0.7964
# ====> Epoch: 25199 Train ELBO: 204.5279 Val ELBO: 171.3062, Epoch Time (s): 0.09, Total Time (hrs): 0.7964
# ====> Epoch: 25200 Train ELBO: 206.4516 Val ELBO: 172.2430, Epoch Time (s): 0.09, Total Time (hrs): 0.7964
# ====> Epoch: 25201 Train ELBO: 206.3467 Val ELBO: 173.6483, Epoch Time (s): 0.09, Total Time (hrs): 0.7964
# ====> Epoch: 25202 Train ELBO: 204.3237 Val ELBO: 172.7741, Epoch Time (s): 0.09, Total Time (hrs): 0.7965
# ====> Epoch: 25203 Train ELBO: 200.5668 Val ELBO: 166.1773, Epoch Time (s): 0.10, Total Time (hrs): 0.7965
# ====> Epoch: 25204 Train ELBO: 201.5102 Val ELBO: 170.1817, Epoch Time (s): 0.09, Total Time (hrs): 0.7965
# ====> Epoch: 25205 Train ELBO: 201.8316 Val ELBO: 168.6916, Epoch Time (s): 0.10, Total Time (hrs): 0.7965
# ====> Epoch: 25206 Train ELBO: 200.2377 Val ELBO: 169.3902, Epoch Time (s): 0.11, Total Time (hrs): 0.7966
# ====> Epoch: 25207 Train ELBO: 197.6084 Val ELBO: 169.8796, Epoch Time (s): 0.09, Total Time (hrs): 0.7966
# ====> Epoch: 25208 Train ELBO: 198.3364 Val ELBO: 168.3897, Epoch Time (s): 0.09, Total Time (hrs): 0.7966
# ====> Epoch: 25209 Train ELBO: 200.3014 Val ELBO: 171.9178, Epoch Time (s): 0.09, Total Time (hrs): 0.7967
# ====> Epoch: 25210 Train ELBO: 203.6038 Val ELBO: 171.3278, Epoch Time (s): 0.08, Total Time (hrs): 0.7967
# ====> Epoch: 25211 Train ELBO: 204.9655 Val ELBO: 173.1281, Epoch Time (s): 0.08, Total Time (hrs): 0.7967
# ====> Epoch: 25212 Train ELBO: 204.7642 Val ELBO: 172.6434, Epoch Time (s): 0.10, Total Time (hrs): 0.7967
# ====> Epoch: 25213 Train ELBO: 205.2992 Val ELBO: 174.0087, Epoch Time (s): 0.09, Total Time (hrs): 0.7968
# ====> Epoch: 25214 Train ELBO: 204.5157 Val ELBO: 170.5180, Epoch Time (s): 0.09, Total Time (hrs): 0.7968
# ====> Epoch: 25215 Train ELBO: 203.5594 Val ELBO: 171.9209, Epoch Time (s): 0.09, Total Time (hrs): 0.7968
# ====> Epoch: 25216 Train ELBO: 202.9237 Val ELBO: 167.4552, Epoch Time (s): 0.10, Total Time (hrs): 0.7968
# ====> Epoch: 25217 Train ELBO: 202.9553 Val ELBO: 169.3639, Epoch Time (s): 0.09, Total Time (hrs): 0.7969
# ====> Epoch: 25218 Train ELBO: 201.6338 Val ELBO: 168.0965, Epoch Time (s): 0.09, Total Time (hrs): 0.7969
# ====> Epoch: 25219 Train ELBO: 201.1633 Val ELBO: 171.3922, Epoch Time (s): 0.09, Total Time (hrs): 0.7969
# ====> Epoch: 25220 Train ELBO: 200.9233 Val ELBO: 167.5349, Epoch Time (s): 0.09, Total Time (hrs): 0.7969
# ====> Epoch: 25221 Train ELBO: 199.1632 Val ELBO: 166.3972, Epoch Time (s): 0.09, Total Time (hrs): 0.7970
# ====> Epoch: 25222 Train ELBO: 198.5913 Val ELBO: 171.7403, Epoch Time (s): 0.08, Total Time (hrs): 0.7970
# ====> Epoch: 25223 Train ELBO: 199.4688 Val ELBO: 168.5600, Epoch Time (s): 0.08, Total Time (hrs): 0.7970
# ====> Epoch: 25224 Train ELBO: 194.5515 Val ELBO: 169.2087, Epoch Time (s): 0.09, Total Time (hrs): 0.7970
# ====> Epoch: 25225 Train ELBO: 197.6708 Val ELBO: 168.6275, Epoch Time (s): 0.09, Total Time (hrs): 0.7971
# ====> Epoch: 25226 Train ELBO: 193.6679 Val ELBO: 162.6419, Epoch Time (s): 0.09, Total Time (hrs): 0.7971
# ====> Epoch: 25227 Train ELBO: 192.9901 Val ELBO: 156.0478, Epoch Time (s): 0.11, Total Time (hrs): 0.7971
# ====> Epoch: 25228 Train ELBO: 194.3644 Val ELBO: 162.4768, Epoch Time (s): 0.09, Total Time (hrs): 0.7971
# ====> Epoch: 25229 Train ELBO: 194.3492 Val ELBO: 156.3756, Epoch Time (s): 0.08, Total Time (hrs): 0.7972
# ====> Epoch: 25230 Train ELBO: 174.4340 Val ELBO: 157.4572, Epoch Time (s): 0.09, Total Time (hrs): 0.7972
# ====> Epoch: 25231 Train ELBO: 154.4408 Val ELBO: 150.9363, Epoch Time (s): 0.09, Total Time (hrs): 0.7972
# ====> Epoch: 25232 Train ELBO: 145.4260 Val ELBO: 125.6158, Epoch Time (s): 0.08, Total Time (hrs): 0.7972
# ====> Epoch: 25233 Train ELBO: 161.6860 Val ELBO: 144.0000, Epoch Time (s): 0.09, Total Time (hrs): 0.7973
# ====> Epoch: 25234 Train ELBO: 178.8363 Val ELBO: 156.9282, Epoch Time (s): 0.09, Total Time (hrs): 0.7973
# ====> Epoch: 25235 Train ELBO: 183.2052 Val ELBO: 161.4418, Epoch Time (s): 0.09, Total Time (hrs): 0.7973
# ====> Epoch: 25236 Train ELBO: 191.5030 Val ELBO: 164.0775, Epoch Time (s): 0.10, Total Time (hrs): 0.7973
# ====> Epoch: 25237 Train ELBO: 190.8462 Val ELBO: 164.2618, Epoch Time (s): 0.09, Total Time (hrs): 0.7974
# ====> Epoch: 25238 Train ELBO: 191.5731 Val ELBO: 165.4303, Epoch Time (s): 0.09, Total Time (hrs): 0.7974
# ====> Epoch: 25239 Train ELBO: 195.1357 Val ELBO: 159.1945, Epoch Time (s): 0.12, Total Time (hrs): 0.7974
# ====> Epoch: 25240 Train ELBO: 140.3372 Val ELBO: 111.5243, Epoch Time (s): 0.09, Total Time (hrs): 0.7974
# ====> Epoch: 25241 Train ELBO: 118.3255 Val ELBO: 102.1468, Epoch Time (s): 0.09, Total Time (hrs): 0.7975
# ====> Epoch: 25242 Train ELBO: 148.1583 Val ELBO: 141.8259, Epoch Time (s): 0.10, Total Time (hrs): 0.7975
# ====> Epoch: 25243 Train ELBO: 152.1079 Val ELBO: 141.3594, Epoch Time (s): 0.09, Total Time (hrs): 0.7975
# ====> Epoch: 25244 Train ELBO: 163.9548 Val ELBO: 128.7356, Epoch Time (s): 0.09, Total Time (hrs): 0.7975
# ====> Epoch: 25245 Train ELBO: 171.0433 Val ELBO: 135.0098, Epoch Time (s): 0.10, Total Time (hrs): 0.7976
# ====> Epoch: 25246 Train ELBO: 186.7912 Val ELBO: 164.0865, Epoch Time (s): 0.09, Total Time (hrs): 0.7976
# ====> Epoch: 25247 Train ELBO: 190.2520 Val ELBO: 141.8917, Epoch Time (s): 0.09, Total Time (hrs): 0.7976
# ====> Epoch: 25248 Train ELBO: 183.7502 Val ELBO: 151.8012, Epoch Time (s): 0.09, Total Time (hrs): 0.7976
# ====> Epoch: 25249 Train ELBO: 191.3773 Val ELBO: 168.4884, Epoch Time (s): 0.09, Total Time (hrs): 0.7977
# ====> Epoch: 25250 Train ELBO: 201.3575 Val ELBO: 169.0318, Epoch Time (s): 0.11, Total Time (hrs): 0.7977
# ====> Epoch: 25251 Train ELBO: 201.1851 Val ELBO: 170.5051, Epoch Time (s): 0.09, Total Time (hrs): 0.7977
# ====> Epoch: 25252 Train ELBO: 202.7367 Val ELBO: 167.0925, Epoch Time (s): 0.09, Total Time (hrs): 0.7977
# ====> Epoch: 25253 Train ELBO: 200.6279 Val ELBO: 166.4635, Epoch Time (s): 0.09, Total Time (hrs): 0.7978
# ====> Epoch: 25254 Train ELBO: 202.8368 Val ELBO: 172.9346, Epoch Time (s): 0.10, Total Time (hrs): 0.7978
# ====> Epoch: 25255 Train ELBO: 205.3379 Val ELBO: 175.2461, Epoch Time (s): 0.09, Total Time (hrs): 0.7978
# ====> Epoch: 25256 Train ELBO: 205.8787 Val ELBO: 174.0556, Epoch Time (s): 0.09, Total Time (hrs): 0.7978
# ====> Epoch: 25257 Train ELBO: 206.9827 Val ELBO: 175.2003, Epoch Time (s): 0.10, Total Time (hrs): 0.7979
# ====> Epoch: 25258 Train ELBO: 205.8205 Val ELBO: 172.7957, Epoch Time (s): 0.10, Total Time (hrs): 0.7979
# ====> Epoch: 25259 Train ELBO: 205.6281 Val ELBO: 169.3953, Epoch Time (s): 0.09, Total Time (hrs): 0.7979
# ====> Epoch: 25260 Train ELBO: 204.8135 Val ELBO: 173.2074, Epoch Time (s): 0.10, Total Time (hrs): 0.7980
# ====> Epoch: 25261 Train ELBO: 205.6003 Val ELBO: 173.2767, Epoch Time (s): 0.11, Total Time (hrs): 0.7980
# ====> Epoch: 25262 Train ELBO: 206.6293 Val ELBO: 175.1620, Epoch Time (s): 0.09, Total Time (hrs): 0.7980
# ====> Epoch: 25263 Train ELBO: 206.9322 Val ELBO: 173.6860, Epoch Time (s): 0.10, Total Time (hrs): 0.7980
# ====> Epoch: 25264 Train ELBO: 207.7211 Val ELBO: 171.3372, Epoch Time (s): 0.09, Total Time (hrs): 0.7981
# ====> Epoch: 25265 Train ELBO: 207.8534 Val ELBO: 174.0235, Epoch Time (s): 0.09, Total Time (hrs): 0.7981
# ====> Epoch: 25266 Train ELBO: 207.6924 Val ELBO: 172.3346, Epoch Time (s): 0.10, Total Time (hrs): 0.7981
# ====> Epoch: 25267 Train ELBO: 207.0518 Val ELBO: 173.1037, Epoch Time (s): 0.09, Total Time (hrs): 0.7981
# ====> Epoch: 25268 Train ELBO: 206.1940 Val ELBO: 173.5132, Epoch Time (s): 0.09, Total Time (hrs): 0.7982
# ====> Epoch: 25269 Train ELBO: 207.1188 Val ELBO: 170.8076, Epoch Time (s): 0.09, Total Time (hrs): 0.7982
# ====> Epoch: 25270 Train ELBO: 205.1679 Val ELBO: 171.7172, Epoch Time (s): 0.09, Total Time (hrs): 0.7982
# ====> Epoch: 25271 Train ELBO: 205.2705 Val ELBO: 171.8527, Epoch Time (s): 0.09, Total Time (hrs): 0.7982
# ====> Epoch: 25272 Train ELBO: 204.5573 Val ELBO: 173.2496, Epoch Time (s): 0.12, Total Time (hrs): 0.7983
# ====> Epoch: 25273 Train ELBO: 205.7584 Val ELBO: 175.9743, Epoch Time (s): 0.09, Total Time (hrs): 0.7983
# ====> Epoch: 25274 Train ELBO: 206.4495 Val ELBO: 171.2673, Epoch Time (s): 0.09, Total Time (hrs): 0.7983
# ====> Epoch: 25275 Train ELBO: 207.0879 Val ELBO: 175.1749, Epoch Time (s): 0.14, Total Time (hrs): 0.7984
# ====> Epoch: 25276 Train ELBO: 207.2725 Val ELBO: 173.5517, Epoch Time (s): 0.13, Total Time (hrs): 0.7984
# ====> Epoch: 25277 Train ELBO: 207.5082 Val ELBO: 174.2230, Epoch Time (s): 0.15, Total Time (hrs): 0.7984
# ====> Epoch: 25278 Train ELBO: 206.1388 Val ELBO: 170.9979, Epoch Time (s): 0.13, Total Time (hrs): 0.7985
# ====> Epoch: 25279 Train ELBO: 206.1888 Val ELBO: 173.9954, Epoch Time (s): 0.15, Total Time (hrs): 0.7985
# ====> Epoch: 25280 Train ELBO: 206.0215 Val ELBO: 172.1848, Epoch Time (s): 0.14, Total Time (hrs): 0.7986
# ====> Epoch: 25281 Train ELBO: 206.4430 Val ELBO: 173.7624, Epoch Time (s): 0.14, Total Time (hrs): 0.7986
# ====> Epoch: 25282 Train ELBO: 206.8804 Val ELBO: 175.2233, Epoch Time (s): 0.13, Total Time (hrs): 0.7986
# ====> Epoch: 25283 Train ELBO: 207.3286 Val ELBO: 173.3875, Epoch Time (s): 0.14, Total Time (hrs): 0.7987
# ====> Epoch: 25284 Train ELBO: 206.1592 Val ELBO: 172.4853, Epoch Time (s): 0.15, Total Time (hrs): 0.7987
# ====> Epoch: 25285 Train ELBO: 205.4237 Val ELBO: 171.2500, Epoch Time (s): 0.16, Total Time (hrs): 0.7988
# ====> Epoch: 25286 Train ELBO: 206.8259 Val ELBO: 174.3705, Epoch Time (s): 0.13, Total Time (hrs): 0.7988
# ====> Epoch: 25287 Train ELBO: 206.4362 Val ELBO: 175.2029, Epoch Time (s): 0.13, Total Time (hrs): 0.7988
# ====> Epoch: 25288 Train ELBO: 203.7372 Val ELBO: 173.6493, Epoch Time (s): 0.15, Total Time (hrs): 0.7989
# ====> Epoch: 25289 Train ELBO: 203.3774 Val ELBO: 170.7605, Epoch Time (s): 0.13, Total Time (hrs): 0.7989
# ====> Epoch: 25290 Train ELBO: 203.9522 Val ELBO: 167.6422, Epoch Time (s): 0.13, Total Time (hrs): 0.7989
# ====> Epoch: 25291 Train ELBO: 199.5180 Val ELBO: 172.5885, Epoch Time (s): 0.14, Total Time (hrs): 0.7990
# ====> Epoch: 25292 Train ELBO: 197.6260 Val ELBO: 158.4939, Epoch Time (s): 0.13, Total Time (hrs): 0.7990
# ====> Epoch: 25293 Train ELBO: 197.3875 Val ELBO: 168.5038, Epoch Time (s): 0.13, Total Time (hrs): 0.7991
# ====> Epoch: 25294 Train ELBO: 201.9442 Val ELBO: 170.1818, Epoch Time (s): 0.13, Total Time (hrs): 0.7991
# ====> Epoch: 25295 Train ELBO: 202.2838 Val ELBO: 166.9652, Epoch Time (s): 0.13, Total Time (hrs): 0.7991
# ====> Epoch: 25296 Train ELBO: 203.3157 Val ELBO: 174.0600, Epoch Time (s): 0.15, Total Time (hrs): 0.7992
# ====> Epoch: 25297 Train ELBO: 202.5982 Val ELBO: 172.4479, Epoch Time (s): 0.14, Total Time (hrs): 0.7992
# ====> Epoch: 25298 Train ELBO: 204.9009 Val ELBO: 171.2167, Epoch Time (s): 0.14, Total Time (hrs): 0.7993
# ====> Epoch: 25299 Train ELBO: 206.0871 Val ELBO: 171.2769, Epoch Time (s): 0.16, Total Time (hrs): 0.7993
# ====> Epoch: 25300 Train ELBO: 207.4265 Val ELBO: 172.7289, Epoch Time (s): 0.15, Total Time (hrs): 0.7993
# ====> Epoch: 25301 Train ELBO: 207.9854 Val ELBO: 174.9125, Epoch Time (s): 0.13, Total Time (hrs): 0.7994
# ====> Epoch: 25302 Train ELBO: 207.3185 Val ELBO: 173.4510, Epoch Time (s): 0.10, Total Time (hrs): 0.7994
# ====> Epoch: 25303 Train ELBO: 205.7595 Val ELBO: 170.0684, Epoch Time (s): 0.09, Total Time (hrs): 0.7994
# ====> Epoch: 25304 Train ELBO: 204.4947 Val ELBO: 173.7837, Epoch Time (s): 0.11, Total Time (hrs): 0.7995
# ====> Epoch: 25305 Train ELBO: 205.4434 Val ELBO: 173.0767, Epoch Time (s): 0.09, Total Time (hrs): 0.7995
# ====> Epoch: 25306 Train ELBO: 206.2968 Val ELBO: 172.9249, Epoch Time (s): 0.09, Total Time (hrs): 0.7995
# ====> Epoch: 25307 Train ELBO: 205.6920 Val ELBO: 173.8491, Epoch Time (s): 0.09, Total Time (hrs): 0.7995
# ====> Epoch: 25308 Train ELBO: 204.3450 Val ELBO: 171.5086, Epoch Time (s): 0.09, Total Time (hrs): 0.7996
# ====> Epoch: 25309 Train ELBO: 204.4502 Val ELBO: 175.0847, Epoch Time (s): 0.09, Total Time (hrs): 0.7996
# ====> Epoch: 25310 Train ELBO: 205.5877 Val ELBO: 172.6451, Epoch Time (s): 0.10, Total Time (hrs): 0.7996
# ====> Epoch: 25311 Train ELBO: 206.6168 Val ELBO: 170.5835, Epoch Time (s): 0.09, Total Time (hrs): 0.7996
# ====> Epoch: 25312 Train ELBO: 205.7640 Val ELBO: 175.0448, Epoch Time (s): 0.09, Total Time (hrs): 0.7997
# ====> Epoch: 25313 Train ELBO: 207.0791 Val ELBO: 173.6143, Epoch Time (s): 0.09, Total Time (hrs): 0.7997
# ====> Epoch: 25314 Train ELBO: 206.0701 Val ELBO: 173.3206, Epoch Time (s): 0.09, Total Time (hrs): 0.7997
# ====> Epoch: 25315 Train ELBO: 205.6181 Val ELBO: 171.1153, Epoch Time (s): 0.10, Total Time (hrs): 0.7997
# ====> Epoch: 25316 Train ELBO: 202.8520 Val ELBO: 167.9732, Epoch Time (s): 0.10, Total Time (hrs): 0.7998
# ====> Epoch: 25317 Train ELBO: 203.5080 Val ELBO: 169.5720, Epoch Time (s): 0.09, Total Time (hrs): 0.7998
# ====> Epoch: 25318 Train ELBO: 204.3612 Val ELBO: 172.9992, Epoch Time (s): 0.09, Total Time (hrs): 0.7998
# ====> Epoch: 25319 Train ELBO: 205.6961 Val ELBO: 173.9731, Epoch Time (s): 0.10, Total Time (hrs): 0.7998
# ====> Epoch: 25320 Train ELBO: 206.9123 Val ELBO: 172.3420, Epoch Time (s): 0.09, Total Time (hrs): 0.7999
# ====> Epoch: 25321 Train ELBO: 201.5828 Val ELBO: 170.8399, Epoch Time (s): 0.09, Total Time (hrs): 0.7999
# ====> Epoch: 25322 Train ELBO: 203.2103 Val ELBO: 170.0504, Epoch Time (s): 0.10, Total Time (hrs): 0.7999
# ====> Epoch: 25323 Train ELBO: 201.9164 Val ELBO: 170.1892, Epoch Time (s): 0.08, Total Time (hrs): 0.7999
# ====> Epoch: 25324 Train ELBO: 201.2942 Val ELBO: 166.2652, Epoch Time (s): 0.09, Total Time (hrs): 0.8000
# ====> Epoch: 25325 Train ELBO: 202.4982 Val ELBO: 172.5182, Epoch Time (s): 0.10, Total Time (hrs): 0.8000
# ====> Epoch: 25326 Train ELBO: 205.2456 Val ELBO: 171.5019, Epoch Time (s): 0.09, Total Time (hrs): 0.8000
# ====> Epoch: 25327 Train ELBO: 202.5770 Val ELBO: 169.5598, Epoch Time (s): 0.10, Total Time (hrs): 0.8001
# ====> Epoch: 25328 Train ELBO: 205.1866 Val ELBO: 171.7240, Epoch Time (s): 0.09, Total Time (hrs): 0.8001
# ====> Epoch: 25329 Train ELBO: 205.1112 Val ELBO: 173.3997, Epoch Time (s): 0.09, Total Time (hrs): 0.8001
# ====> Epoch: 25330 Train ELBO: 204.5929 Val ELBO: 171.1353, Epoch Time (s): 0.09, Total Time (hrs): 0.8001
# ====> Epoch: 25331 Train ELBO: 204.1538 Val ELBO: 172.6247, Epoch Time (s): 0.09, Total Time (hrs): 0.8002
# ====> Epoch: 25332 Train ELBO: 204.0767 Val ELBO: 171.8644, Epoch Time (s): 0.09, Total Time (hrs): 0.8002
# ====> Epoch: 25333 Train ELBO: 204.3136 Val ELBO: 168.8916, Epoch Time (s): 0.09, Total Time (hrs): 0.8002
# ====> Epoch: 25334 Train ELBO: 200.9399 Val ELBO: 171.5134, Epoch Time (s): 0.09, Total Time (hrs): 0.8002
# ====> Epoch: 25335 Train ELBO: 202.7846 Val ELBO: 171.9498, Epoch Time (s): 0.09, Total Time (hrs): 0.8003
# ====> Epoch: 25336 Train ELBO: 202.3655 Val ELBO: 172.8720, Epoch Time (s): 0.09, Total Time (hrs): 0.8003
# ====> Epoch: 25337 Train ELBO: 202.7544 Val ELBO: 159.9922, Epoch Time (s): 0.10, Total Time (hrs): 0.8003
# ====> Epoch: 25338 Train ELBO: 201.9699 Val ELBO: 173.3810, Epoch Time (s): 0.10, Total Time (hrs): 0.8003
# ====> Epoch: 25339 Train ELBO: 204.8257 Val ELBO: 174.1046, Epoch Time (s): 0.08, Total Time (hrs): 0.8004
# ====> Epoch: 25340 Train ELBO: 204.7437 Val ELBO: 170.3609, Epoch Time (s): 0.10, Total Time (hrs): 0.8004
# ====> Epoch: 25341 Train ELBO: 201.7602 Val ELBO: 168.7898, Epoch Time (s): 0.09, Total Time (hrs): 0.8004
# ====> Epoch: 25342 Train ELBO: 199.5925 Val ELBO: 165.9527, Epoch Time (s): 0.09, Total Time (hrs): 0.8004
# ====> Epoch: 25343 Train ELBO: 200.0310 Val ELBO: 171.7534, Epoch Time (s): 0.10, Total Time (hrs): 0.8005
# ====> Epoch: 25344 Train ELBO: 190.6438 Val ELBO: 170.2802, Epoch Time (s): 0.09, Total Time (hrs): 0.8005
# ====> Epoch: 25345 Train ELBO: 186.3923 Val ELBO: 145.2459, Epoch Time (s): 0.09, Total Time (hrs): 0.8005
# ====> Epoch: 25346 Train ELBO: 186.2292 Val ELBO: 169.8954, Epoch Time (s): 0.10, Total Time (hrs): 0.8005
# ====> Epoch: 25347 Train ELBO: 194.7173 Val ELBO: 165.7141, Epoch Time (s): 0.09, Total Time (hrs): 0.8006
# ====> Epoch: 25348 Train ELBO: 194.7460 Val ELBO: 163.1362, Epoch Time (s): 0.09, Total Time (hrs): 0.8006
# ====> Epoch: 25349 Train ELBO: 193.1098 Val ELBO: 166.4425, Epoch Time (s): 0.11, Total Time (hrs): 0.8006
# ====> Epoch: 25350 Train ELBO: 188.1386 Val ELBO: 167.3869, Epoch Time (s): 0.09, Total Time (hrs): 0.8006
# ====> Epoch: 25351 Train ELBO: 194.4240 Val ELBO: 166.4305, Epoch Time (s): 0.09, Total Time (hrs): 0.8007
# ====> Epoch: 25352 Train ELBO: 193.1406 Val ELBO: 165.6654, Epoch Time (s): 0.10, Total Time (hrs): 0.8007
# ====> Epoch: 25353 Train ELBO: 190.9822 Val ELBO: 159.7440, Epoch Time (s): 0.09, Total Time (hrs): 0.8007
# ====> Epoch: 25354 Train ELBO: 190.8282 Val ELBO: 161.9377, Epoch Time (s): 0.09, Total Time (hrs): 0.8007
# ====> Epoch: 25355 Train ELBO: 194.9429 Val ELBO: 170.1247, Epoch Time (s): 0.10, Total Time (hrs): 0.8008
# ====> Epoch: 25356 Train ELBO: 196.7351 Val ELBO: 163.9682, Epoch Time (s): 0.09, Total Time (hrs): 0.8008
# ====> Epoch: 25357 Train ELBO: 191.4592 Val ELBO: 166.7122, Epoch Time (s): 0.09, Total Time (hrs): 0.8008
# ====> Epoch: 25358 Train ELBO: 194.4331 Val ELBO: 165.9543, Epoch Time (s): 0.09, Total Time (hrs): 0.8008
# ====> Epoch: 25359 Train ELBO: 198.0242 Val ELBO: 170.2828, Epoch Time (s): 0.09, Total Time (hrs): 0.8009
# ====> Epoch: 25360 Train ELBO: 199.1959 Val ELBO: 162.3469, Epoch Time (s): 0.09, Total Time (hrs): 0.8009
# ====> Epoch: 25361 Train ELBO: 192.3304 Val ELBO: 165.3922, Epoch Time (s): 0.11, Total Time (hrs): 0.8009
# ====> Epoch: 25362 Train ELBO: 181.1145 Val ELBO: 159.7225, Epoch Time (s): 0.09, Total Time (hrs): 0.8009
# ====> Epoch: 25363 Train ELBO: 188.3397 Val ELBO: 163.8505, Epoch Time (s): 0.09, Total Time (hrs): 0.8010
# ====> Epoch: 25364 Train ELBO: 186.6086 Val ELBO: 165.0445, Epoch Time (s): 0.09, Total Time (hrs): 0.8010
# ====> Epoch: 25365 Train ELBO: 178.4598 Val ELBO: 152.0145, Epoch Time (s): 0.09, Total Time (hrs): 0.8010
# ====> Epoch: 25366 Train ELBO: 181.0664 Val ELBO: 160.6927, Epoch Time (s): 0.09, Total Time (hrs): 0.8010
# ====> Epoch: 25367 Train ELBO: 192.4498 Val ELBO: 158.5049, Epoch Time (s): 0.09, Total Time (hrs): 0.8011
# ====> Epoch: 25368 Train ELBO: 191.8332 Val ELBO: 165.1636, Epoch Time (s): 0.09, Total Time (hrs): 0.8011
# ====> Epoch: 25369 Train ELBO: 198.4982 Val ELBO: 173.8966, Epoch Time (s): 0.09, Total Time (hrs): 0.8011
# ====> Epoch: 25370 Train ELBO: 201.3866 Val ELBO: 173.1017, Epoch Time (s): 0.10, Total Time (hrs): 0.8011
# ====> Epoch: 25371 Train ELBO: 201.7911 Val ELBO: 173.5037, Epoch Time (s): 0.09, Total Time (hrs): 0.8012
# ====> Epoch: 25372 Train ELBO: 203.0419 Val ELBO: 172.5103, Epoch Time (s): 0.10, Total Time (hrs): 0.8012
# ====> Epoch: 25373 Train ELBO: 202.6174 Val ELBO: 170.7702, Epoch Time (s): 0.10, Total Time (hrs): 0.8012
# ====> Epoch: 25374 Train ELBO: 201.7789 Val ELBO: 170.6248, Epoch Time (s): 0.09, Total Time (hrs): 0.8013
# ====> Epoch: 25375 Train ELBO: 202.6828 Val ELBO: 165.5637, Epoch Time (s): 0.09, Total Time (hrs): 0.8013
# ====> Epoch: 25376 Train ELBO: 202.2451 Val ELBO: 171.3576, Epoch Time (s): 0.10, Total Time (hrs): 0.8013
# ====> Epoch: 25377 Train ELBO: 203.7388 Val ELBO: 172.2498, Epoch Time (s): 0.09, Total Time (hrs): 0.8013
# ====> Epoch: 25378 Train ELBO: 205.6426 Val ELBO: 172.8106, Epoch Time (s): 0.08, Total Time (hrs): 0.8014
# ====> Epoch: 25379 Train ELBO: 205.9785 Val ELBO: 174.2525, Epoch Time (s): 0.09, Total Time (hrs): 0.8014
# ====> Epoch: 25380 Train ELBO: 206.0822 Val ELBO: 169.5155, Epoch Time (s): 0.09, Total Time (hrs): 0.8014
# ====> Epoch: 25381 Train ELBO: 199.5737 Val ELBO: 163.1917, Epoch Time (s): 0.09, Total Time (hrs): 0.8014
# ====> Epoch: 25382 Train ELBO: 199.6507 Val ELBO: 170.0741, Epoch Time (s): 0.10, Total Time (hrs): 0.8015
# ====> Epoch: 25383 Train ELBO: 201.8881 Val ELBO: 169.5101, Epoch Time (s): 0.10, Total Time (hrs): 0.8015
# ====> Epoch: 25384 Train ELBO: 191.8763 Val ELBO: 157.7693, Epoch Time (s): 0.09, Total Time (hrs): 0.8015
# ====> Epoch: 25385 Train ELBO: 183.9196 Val ELBO: 159.3616, Epoch Time (s): 0.09, Total Time (hrs): 0.8015
# ====> Epoch: 25386 Train ELBO: 181.2788 Val ELBO: 158.9214, Epoch Time (s): 0.09, Total Time (hrs): 0.8016
# ====> Epoch: 25387 Train ELBO: 170.6825 Val ELBO: 144.0705, Epoch Time (s): 0.09, Total Time (hrs): 0.8016
# ====> Epoch: 25388 Train ELBO: 171.8248 Val ELBO: 164.9175, Epoch Time (s): 0.10, Total Time (hrs): 0.8016
# ====> Epoch: 25389 Train ELBO: 182.6921 Val ELBO: 158.1487, Epoch Time (s): 0.08, Total Time (hrs): 0.8016
# ====> Epoch: 25390 Train ELBO: 187.0877 Val ELBO: 161.0934, Epoch Time (s): 0.09, Total Time (hrs): 0.8017
# ====> Epoch: 25391 Train ELBO: 178.4226 Val ELBO: 143.0378, Epoch Time (s): 0.10, Total Time (hrs): 0.8017
# ====> Epoch: 25392 Train ELBO: 172.3717 Val ELBO: 148.0132, Epoch Time (s): 0.09, Total Time (hrs): 0.8017
# ====> Epoch: 25393 Train ELBO: 179.8599 Val ELBO: 158.6678, Epoch Time (s): 0.08, Total Time (hrs): 0.8017
# ====> Epoch: 25394 Train ELBO: 167.6509 Val ELBO: 135.1121, Epoch Time (s): 0.11, Total Time (hrs): 0.8018
# ====> Epoch: 25395 Train ELBO: 174.0179 Val ELBO: 137.7310, Epoch Time (s): 0.12, Total Time (hrs): 0.8018
# ====> Epoch: 25396 Train ELBO: 177.2175 Val ELBO: 149.1696, Epoch Time (s): 0.09, Total Time (hrs): 0.8018
# ====> Epoch: 25397 Train ELBO: 168.8364 Val ELBO: 148.6600, Epoch Time (s): 0.10, Total Time (hrs): 0.8018
# ====> Epoch: 25398 Train ELBO: 177.4168 Val ELBO: 143.7405, Epoch Time (s): 0.09, Total Time (hrs): 0.8019
# ====> Epoch: 25399 Train ELBO: 188.2713 Val ELBO: 166.5296, Epoch Time (s): 0.09, Total Time (hrs): 0.8019
# ====> Epoch: 25400 Train ELBO: 193.0796 Val ELBO: 161.2517, Epoch Time (s): 0.09, Total Time (hrs): 0.8019
# ====> Epoch: 25401 Train ELBO: 190.7062 Val ELBO: 163.5892, Epoch Time (s): 0.09, Total Time (hrs): 0.8019
# ====> Epoch: 25402 Train ELBO: 191.5613 Val ELBO: 172.5686, Epoch Time (s): 0.09, Total Time (hrs): 0.8020
# ====> Epoch: 25403 Train ELBO: 197.8392 Val ELBO: 164.2837, Epoch Time (s): 0.09, Total Time (hrs): 0.8020
# ====> Epoch: 25404 Train ELBO: 198.5840 Val ELBO: 167.3038, Epoch Time (s): 0.08, Total Time (hrs): 0.8020
# ====> Epoch: 25405 Train ELBO: 196.0842 Val ELBO: 168.1146, Epoch Time (s): 0.11, Total Time (hrs): 0.8021
# ====> Epoch: 25406 Train ELBO: 200.2424 Val ELBO: 173.1341, Epoch Time (s): 0.09, Total Time (hrs): 0.8021
# ====> Epoch: 25407 Train ELBO: 202.4221 Val ELBO: 172.7729, Epoch Time (s): 0.09, Total Time (hrs): 0.8021
# ====> Epoch: 25408 Train ELBO: 201.4940 Val ELBO: 168.2412, Epoch Time (s): 0.09, Total Time (hrs): 0.8021
# ====> Epoch: 25409 Train ELBO: 202.6206 Val ELBO: 175.3312, Epoch Time (s): 0.11, Total Time (hrs): 0.8022
# ====> Epoch: 25410 Train ELBO: 202.5070 Val ELBO: 170.4346, Epoch Time (s): 0.15, Total Time (hrs): 0.8022
# ====> Epoch: 25411 Train ELBO: 201.6609 Val ELBO: 168.0229, Epoch Time (s): 0.14, Total Time (hrs): 0.8022
# ====> Epoch: 25412 Train ELBO: 200.1232 Val ELBO: 170.1896, Epoch Time (s): 0.14, Total Time (hrs): 0.8023
# ====> Epoch: 25413 Train ELBO: 187.2941 Val ELBO: 154.6924, Epoch Time (s): 0.13, Total Time (hrs): 0.8023
# ====> Epoch: 25414 Train ELBO: 177.3491 Val ELBO: 156.7869, Epoch Time (s): 0.15, Total Time (hrs): 0.8024
# ====> Epoch: 25415 Train ELBO: 163.0737 Val ELBO: 156.9743, Epoch Time (s): 0.13, Total Time (hrs): 0.8024
# ====> Epoch: 25416 Train ELBO: 164.3921 Val ELBO: 137.1025, Epoch Time (s): 0.14, Total Time (hrs): 0.8024
# ====> Epoch: 25417 Train ELBO: 163.0900 Val ELBO: 134.3670, Epoch Time (s): 0.12, Total Time (hrs): 0.8025
# ====> Epoch: 25418 Train ELBO: 159.1033 Val ELBO: 144.6169, Epoch Time (s): 0.14, Total Time (hrs): 0.8025
# ====> Epoch: 25419 Train ELBO: 176.2499 Val ELBO: 159.3639, Epoch Time (s): 0.13, Total Time (hrs): 0.8025
# ====> Epoch: 25420 Train ELBO: 175.8758 Val ELBO: 161.1149, Epoch Time (s): 0.14, Total Time (hrs): 0.8026
# ====> Epoch: 25421 Train ELBO: 182.1060 Val ELBO: 162.4016, Epoch Time (s): 0.13, Total Time (hrs): 0.8026
# ====> Epoch: 25422 Train ELBO: 193.6714 Val ELBO: 162.3615, Epoch Time (s): 0.14, Total Time (hrs): 0.8027
# ====> Epoch: 25423 Train ELBO: 198.1439 Val ELBO: 172.4174, Epoch Time (s): 0.13, Total Time (hrs): 0.8027
# ====> Epoch: 25424 Train ELBO: 200.9988 Val ELBO: 167.1184, Epoch Time (s): 0.14, Total Time (hrs): 0.8027
# ====> Epoch: 25425 Train ELBO: 199.2029 Val ELBO: 170.3853, Epoch Time (s): 0.13, Total Time (hrs): 0.8028
# ====> Epoch: 25426 Train ELBO: 202.2722 Val ELBO: 175.0377, Epoch Time (s): 0.13, Total Time (hrs): 0.8028
# ====> Epoch: 25427 Train ELBO: 203.1525 Val ELBO: 172.6946, Epoch Time (s): 0.12, Total Time (hrs): 0.8028
# ====> Epoch: 25428 Train ELBO: 203.0672 Val ELBO: 170.4895, Epoch Time (s): 0.14, Total Time (hrs): 0.8029
# ====> Epoch: 25429 Train ELBO: 204.8577 Val ELBO: 173.2212, Epoch Time (s): 0.13, Total Time (hrs): 0.8029
# ====> Epoch: 25430 Train ELBO: 203.4895 Val ELBO: 166.2507, Epoch Time (s): 0.16, Total Time (hrs): 0.8030
# ====> Epoch: 25431 Train ELBO: 201.9593 Val ELBO: 167.7894, Epoch Time (s): 0.13, Total Time (hrs): 0.8030
# ====> Epoch: 25432 Train ELBO: 201.0053 Val ELBO: 169.5287, Epoch Time (s): 0.15, Total Time (hrs): 0.8030
# ====> Epoch: 25433 Train ELBO: 199.5072 Val ELBO: 166.7437, Epoch Time (s): 0.14, Total Time (hrs): 0.8031
# ====> Epoch: 25434 Train ELBO: 198.1935 Val ELBO: 168.2867, Epoch Time (s): 0.16, Total Time (hrs): 0.8031
# ====> Epoch: 25435 Train ELBO: 201.2185 Val ELBO: 170.2631, Epoch Time (s): 0.14, Total Time (hrs): 0.8032
# ====> Epoch: 25436 Train ELBO: 201.1453 Val ELBO: 166.6013, Epoch Time (s): 0.09, Total Time (hrs): 0.8032
# ====> Epoch: 25437 Train ELBO: 201.0239 Val ELBO: 171.3241, Epoch Time (s): 0.08, Total Time (hrs): 0.8032
# ====> Epoch: 25438 Train ELBO: 202.6748 Val ELBO: 173.4455, Epoch Time (s): 0.08, Total Time (hrs): 0.8032
# ====> Epoch: 25439 Train ELBO: 202.2621 Val ELBO: 169.8592, Epoch Time (s): 0.11, Total Time (hrs): 0.8033
# ====> Epoch: 25440 Train ELBO: 202.6664 Val ELBO: 172.8047, Epoch Time (s): 0.09, Total Time (hrs): 0.8033
# ====> Epoch: 25441 Train ELBO: 203.1437 Val ELBO: 170.1556, Epoch Time (s): 0.09, Total Time (hrs): 0.8033
# ====> Epoch: 25442 Train ELBO: 202.7577 Val ELBO: 171.6833, Epoch Time (s): 0.09, Total Time (hrs): 0.8033
# ====> Epoch: 25443 Train ELBO: 203.4982 Val ELBO: 171.5209, Epoch Time (s): 0.09, Total Time (hrs): 0.8034
# ====> Epoch: 25444 Train ELBO: 206.3493 Val ELBO: 173.9271, Epoch Time (s): 0.09, Total Time (hrs): 0.8034
# ====> Epoch: 25445 Train ELBO: 206.9936 Val ELBO: 175.0506, Epoch Time (s): 0.09, Total Time (hrs): 0.8034
# ====> Epoch: 25446 Train ELBO: 207.5545 Val ELBO: 173.4253, Epoch Time (s): 0.09, Total Time (hrs): 0.8034
# ====> Epoch: 25447 Train ELBO: 207.4734 Val ELBO: 174.2199, Epoch Time (s): 0.08, Total Time (hrs): 0.8035
# ====> Epoch: 25448 Train ELBO: 205.7981 Val ELBO: 172.5725, Epoch Time (s): 0.09, Total Time (hrs): 0.8035
# ...
# ====> Epoch: 29851 Train ELBO: 185.1164 Val ELBO: 165.6336, Epoch Time (s): 0.09, Total Time (hrs): 0.9456
# ====> Epoch: 29852 Train ELBO: 180.0535 Val ELBO: 147.8619, Epoch Time (s): 0.14, Total Time (hrs): 0.9456
# ====> Epoch: 29853 Train ELBO: 170.1242 Val ELBO: 153.7654, Epoch Time (s): 0.14, Total Time (hrs): 0.9457
# ====> Epoch: 29854 Train ELBO: 180.6324 Val ELBO: 159.2426, Epoch Time (s): 0.15, Total Time (hrs): 0.9457
# ====> Epoch: 29855 Train ELBO: 193.3156 Val ELBO: 166.8418, Epoch Time (s): 0.12, Total Time (hrs): 0.9457
# ====> Epoch: 29856 Train ELBO: 197.5270 Val ELBO: 167.9440, Epoch Time (s): 0.13, Total Time (hrs): 0.9458
# ====> Epoch: 29857 Train ELBO: 199.2846 Val ELBO: 164.1129, Epoch Time (s): 0.13, Total Time (hrs): 0.9458
# ====> Epoch: 29858 Train ELBO: 193.0886 Val ELBO: 160.6420, Epoch Time (s): 0.12, Total Time (hrs): 0.9458
# ====> Epoch: 29859 Train ELBO: 195.0466 Val ELBO: 168.1580, Epoch Time (s): 0.13, Total Time (hrs): 0.9459
# ====> Epoch: 29860 Train ELBO: 199.3625 Val ELBO: 165.2528, Epoch Time (s): 0.12, Total Time (hrs): 0.9459
# ====> Epoch: 29861 Train ELBO: 197.3545 Val ELBO: 162.3196, Epoch Time (s): 0.15, Total Time (hrs): 0.9459
# ====> Epoch: 29862 Train ELBO: 196.1801 Val ELBO: 171.5315, Epoch Time (s): 0.15, Total Time (hrs): 0.9460
# ====> Epoch: 29863 Train ELBO: 196.5685 Val ELBO: 167.8520, Epoch Time (s): 0.13, Total Time (hrs): 0.9460
# ====> Epoch: 29864 Train ELBO: 200.7275 Val ELBO: 171.4637, Epoch Time (s): 0.12, Total Time (hrs): 0.9461
# ====> Epoch: 29865 Train ELBO: 200.2766 Val ELBO: 170.7718, Epoch Time (s): 0.14, Total Time (hrs): 0.9461
# ====> Epoch: 29866 Train ELBO: 199.5756 Val ELBO: 160.5412, Epoch Time (s): 0.12, Total Time (hrs): 0.9461
# ====> Epoch: 29867 Train ELBO: 201.3980 Val ELBO: 175.1949, Epoch Time (s): 0.13, Total Time (hrs): 0.9462
# ====> Epoch: 29868 Train ELBO: 206.1677 Val ELBO: 173.0807, Epoch Time (s): 0.12, Total Time (hrs): 0.9462
# ====> Epoch: 29869 Train ELBO: 204.8213 Val ELBO: 174.1413, Epoch Time (s): 0.13, Total Time (hrs): 0.9462
# ====> Epoch: 29870 Train ELBO: 201.5095 Val ELBO: 171.9192, Epoch Time (s): 0.13, Total Time (hrs): 0.9463
# ====> Epoch: 29871 Train ELBO: 202.7488 Val ELBO: 169.6128, Epoch Time (s): 0.13, Total Time (hrs): 0.9463
# ====> Epoch: 29872 Train ELBO: 205.2370 Val ELBO: 172.8450, Epoch Time (s): 0.12, Total Time (hrs): 0.9463
# ====> Epoch: 29873 Train ELBO: 203.1996 Val ELBO: 170.9956, Epoch Time (s): 0.14, Total Time (hrs): 0.9464
# ====> Epoch: 29874 Train ELBO: 201.8885 Val ELBO: 171.6123, Epoch Time (s): 0.13, Total Time (hrs): 0.9464
# ====> Epoch: 29875 Train ELBO: 201.8200 Val ELBO: 167.9381, Epoch Time (s): 0.15, Total Time (hrs): 0.9465
# ====> Epoch: 29876 Train ELBO: 196.0244 Val ELBO: 167.9321, Epoch Time (s): 0.14, Total Time (hrs): 0.9465
# ====> Epoch: 29877 Train ELBO: 201.1954 Val ELBO: 170.5154, Epoch Time (s): 0.15, Total Time (hrs): 0.9465
# ====> Epoch: 29878 Train ELBO: 202.7290 Val ELBO: 168.7797, Epoch Time (s): 0.14, Total Time (hrs): 0.9466
# ====> Epoch: 29879 Train ELBO: 202.1275 Val ELBO: 171.4954, Epoch Time (s): 0.09, Total Time (hrs): 0.9466
# ====> Epoch: 29880 Train ELBO: 201.4603 Val ELBO: 167.9534, Epoch Time (s): 0.08, Total Time (hrs): 0.9466
# ====> Epoch: 29881 Train ELBO: 201.1784 Val ELBO: 170.0489, Epoch Time (s): 0.09, Total Time (hrs): 0.9466
# ====> Epoch: 29882 Train ELBO: 203.7314 Val ELBO: 174.1174, Epoch Time (s): 0.09, Total Time (hrs): 0.9467
# ====> Epoch: 29883 Train ELBO: 205.1224 Val ELBO: 174.0758, Epoch Time (s): 0.08, Total Time (hrs): 0.9467
# ====> Epoch: 29884 Train ELBO: 206.1578 Val ELBO: 173.5469, Epoch Time (s): 0.08, Total Time (hrs): 0.9467
# ====> Epoch: 29885 Train ELBO: 203.9366 Val ELBO: 170.1741, Epoch Time (s): 0.09, Total Time (hrs): 0.9467
# ====> Epoch: 29886 Train ELBO: 207.2248 Val ELBO: 174.5087, Epoch Time (s): 0.09, Total Time (hrs): 0.9468
# ====> Epoch: 29887 Train ELBO: 206.4962 Val ELBO: 173.2863, Epoch Time (s): 0.08, Total Time (hrs): 0.9468
# ====> Epoch: 29888 Train ELBO: 206.5358 Val ELBO: 172.7182, Epoch Time (s): 0.09, Total Time (hrs): 0.9468
# ====> Epoch: 29889 Train ELBO: 207.6243 Val ELBO: 173.1319, Epoch Time (s): 0.09, Total Time (hrs): 0.9468
# ====> Epoch: 29890 Train ELBO: 205.6037 Val ELBO: 171.6772, Epoch Time (s): 0.10, Total Time (hrs): 0.9469
# ====> Epoch: 29891 Train ELBO: 203.5829 Val ELBO: 169.7887, Epoch Time (s): 0.09, Total Time (hrs): 0.9469
# ====> Epoch: 29892 Train ELBO: 196.9658 Val ELBO: 163.6794, Epoch Time (s): 0.09, Total Time (hrs): 0.9469
# ====> Epoch: 29893 Train ELBO: 196.2745 Val ELBO: 170.0748, Epoch Time (s): 0.09, Total Time (hrs): 0.9469
# ====> Epoch: 29894 Train ELBO: 204.1894 Val ELBO: 172.1110, Epoch Time (s): 0.09, Total Time (hrs): 0.9470
# ====> Epoch: 29895 Train ELBO: 203.5792 Val ELBO: 168.4131, Epoch Time (s): 0.08, Total Time (hrs): 0.9470
# ====> Epoch: 29896 Train ELBO: 202.9937 Val ELBO: 171.9823, Epoch Time (s): 0.09, Total Time (hrs): 0.9470
# ====> Epoch: 29897 Train ELBO: 198.8655 Val ELBO: 168.6056, Epoch Time (s): 0.10, Total Time (hrs): 0.9470
# ====> Epoch: 29898 Train ELBO: 203.8895 Val ELBO: 171.8764, Epoch Time (s): 0.08, Total Time (hrs): 0.9471
# ====> Epoch: 29899 Train ELBO: 203.7063 Val ELBO: 168.8656, Epoch Time (s): 0.09, Total Time (hrs): 0.9471
# ====> Epoch: 29900 Train ELBO: 205.4946 Val ELBO: 171.8426, Epoch Time (s): 0.09, Total Time (hrs): 0.9471
# ====> Epoch: 29901 Train ELBO: 206.2397 Val ELBO: 174.0770, Epoch Time (s): 0.10, Total Time (hrs): 0.9471
# ====> Epoch: 29902 Train ELBO: 206.7440 Val ELBO: 172.6814, Epoch Time (s): 0.08, Total Time (hrs): 0.9472
# ====> Epoch: 29903 Train ELBO: 206.9059 Val ELBO: 173.2694, Epoch Time (s): 0.10, Total Time (hrs): 0.9472
# ====> Epoch: 29904 Train ELBO: 206.4432 Val ELBO: 173.2155, Epoch Time (s): 0.08, Total Time (hrs): 0.9472
# ====> Epoch: 29905 Train ELBO: 207.6459 Val ELBO: 173.3624, Epoch Time (s): 0.08, Total Time (hrs): 0.9472
# ====> Epoch: 29906 Train ELBO: 206.9061 Val ELBO: 171.2308, Epoch Time (s): 0.09, Total Time (hrs): 0.9473
# ====> Epoch: 29907 Train ELBO: 205.2306 Val ELBO: 171.1736, Epoch Time (s): 0.08, Total Time (hrs): 0.9473
# ====> Epoch: 29908 Train ELBO: 204.0789 Val ELBO: 172.6531, Epoch Time (s): 0.09, Total Time (hrs): 0.9473
# ====> Epoch: 29909 Train ELBO: 203.6318 Val ELBO: 170.9868, Epoch Time (s): 0.10, Total Time (hrs): 0.9473
# ====> Epoch: 29910 Train ELBO: 200.9806 Val ELBO: 165.7095, Epoch Time (s): 0.08, Total Time (hrs): 0.9474
# ====> Epoch: 29911 Train ELBO: 196.3273 Val ELBO: 166.2432, Epoch Time (s): 0.09, Total Time (hrs): 0.9474
# ====> Epoch: 29912 Train ELBO: 200.0620 Val ELBO: 170.8485, Epoch Time (s): 0.09, Total Time (hrs): 0.9474
# ====> Epoch: 29913 Train ELBO: 204.7309 Val ELBO: 170.5134, Epoch Time (s): 0.10, Total Time (hrs): 0.9474
# ====> Epoch: 29914 Train ELBO: 205.0990 Val ELBO: 172.3440, Epoch Time (s): 0.09, Total Time (hrs): 0.9475
# ====> Epoch: 29915 Train ELBO: 205.4685 Val ELBO: 171.7462, Epoch Time (s): 0.10, Total Time (hrs): 0.9475
# ====> Epoch: 29916 Train ELBO: 205.1668 Val ELBO: 174.4663, Epoch Time (s): 0.08, Total Time (hrs): 0.9475
# ====> Epoch: 29917 Train ELBO: 205.8829 Val ELBO: 171.1800, Epoch Time (s): 0.08, Total Time (hrs): 0.9475
# ====> Epoch: 29918 Train ELBO: 204.0751 Val ELBO: 168.0171, Epoch Time (s): 0.10, Total Time (hrs): 0.9476
# ====> Epoch: 29919 Train ELBO: 201.7176 Val ELBO: 173.3455, Epoch Time (s): 0.10, Total Time (hrs): 0.9476
# ====> Epoch: 29920 Train ELBO: 204.9070 Val ELBO: 171.7884, Epoch Time (s): 0.09, Total Time (hrs): 0.9476
# ====> Epoch: 29921 Train ELBO: 204.4827 Val ELBO: 174.8566, Epoch Time (s): 0.10, Total Time (hrs): 0.9476
# ====> Epoch: 29922 Train ELBO: 205.6274 Val ELBO: 172.2575, Epoch Time (s): 0.09, Total Time (hrs): 0.9477
# ====> Epoch: 29923 Train ELBO: 205.7909 Val ELBO: 173.4670, Epoch Time (s): 0.08, Total Time (hrs): 0.9477
# ====> Epoch: 29924 Train ELBO: 202.7498 Val ELBO: 168.1943, Epoch Time (s): 0.10, Total Time (hrs): 0.9477
# ====> Epoch: 29925 Train ELBO: 193.5324 Val ELBO: 158.5337, Epoch Time (s): 0.08, Total Time (hrs): 0.9477
# ====> Epoch: 29926 Train ELBO: 181.3949 Val ELBO: 150.0001, Epoch Time (s): 0.09, Total Time (hrs): 0.9478
# ====> Epoch: 29927 Train ELBO: 181.5612 Val ELBO: 160.8390, Epoch Time (s): 0.09, Total Time (hrs): 0.9478
# ====> Epoch: 29928 Train ELBO: 183.0214 Val ELBO: 152.8925, Epoch Time (s): 0.08, Total Time (hrs): 0.9478
# ====> Epoch: 29929 Train ELBO: 183.8001 Val ELBO: 163.7700, Epoch Time (s): 0.08, Total Time (hrs): 0.9478
# ====> Epoch: 29930 Train ELBO: 192.6027 Val ELBO: 155.3062, Epoch Time (s): 0.10, Total Time (hrs): 0.9479
# ====> Epoch: 29931 Train ELBO: 176.4405 Val ELBO: 110.7493, Epoch Time (s): 0.08, Total Time (hrs): 0.9479
# ====> Epoch: 29932 Train ELBO: 163.4367 Val ELBO: 144.6454, Epoch Time (s): 0.09, Total Time (hrs): 0.9479
# ====> Epoch: 29933 Train ELBO: 163.3702 Val ELBO: 128.6609, Epoch Time (s): 0.09, Total Time (hrs): 0.9479
# ====> Epoch: 29934 Train ELBO: 161.4516 Val ELBO: 142.9556, Epoch Time (s): 0.08, Total Time (hrs): 0.9480
# ====> Epoch: 29935 Train ELBO: 167.0663 Val ELBO: 136.8875, Epoch Time (s): 0.08, Total Time (hrs): 0.9480
# ====> Epoch: 29936 Train ELBO: 179.7826 Val ELBO: 158.9272, Epoch Time (s): 0.11, Total Time (hrs): 0.9480
# ====> Epoch: 29937 Train ELBO: 179.1364 Val ELBO: 142.5166, Epoch Time (s): 0.09, Total Time (hrs): 0.9480
# ====> Epoch: 29938 Train ELBO: 181.1132 Val ELBO: 157.6321, Epoch Time (s): 0.08, Total Time (hrs): 0.9481
# ====> Epoch: 29939 Train ELBO: 177.5129 Val ELBO: 156.2965, Epoch Time (s): 0.09, Total Time (hrs): 0.9481
# ====> Epoch: 29940 Train ELBO: 175.6254 Val ELBO: 158.0207, Epoch Time (s): 0.08, Total Time (hrs): 0.9481
# ====> Epoch: 29941 Train ELBO: 181.8247 Val ELBO: 165.6560, Epoch Time (s): 0.08, Total Time (hrs): 0.9481
# ====> Epoch: 29942 Train ELBO: 187.0247 Val ELBO: 164.3441, Epoch Time (s): 0.09, Total Time (hrs): 0.9482
# ====> Epoch: 29943 Train ELBO: 179.5213 Val ELBO: 150.2717, Epoch Time (s): 0.08, Total Time (hrs): 0.9482
# ====> Epoch: 29944 Train ELBO: 182.6183 Val ELBO: 138.5567, Epoch Time (s): 0.08, Total Time (hrs): 0.9482
# ====> Epoch: 29945 Train ELBO: 176.6418 Val ELBO: 162.5381, Epoch Time (s): 0.09, Total Time (hrs): 0.9482
# ====> Epoch: 29946 Train ELBO: 177.1299 Val ELBO: 147.5951, Epoch Time (s): 0.08, Total Time (hrs): 0.9483
# ====> Epoch: 29947 Train ELBO: 181.8604 Val ELBO: 159.1169, Epoch Time (s): 0.08, Total Time (hrs): 0.9483
# ====> Epoch: 29948 Train ELBO: 189.8286 Val ELBO: 170.0914, Epoch Time (s): 0.11, Total Time (hrs): 0.9483
# ====> Epoch: 29949 Train ELBO: 199.1451 Val ELBO: 170.8225, Epoch Time (s): 0.09, Total Time (hrs): 0.9483
# ====> Epoch: 29950 Train ELBO: 202.1118 Val ELBO: 172.3772, Epoch Time (s): 0.08, Total Time (hrs): 0.9484
# ====> Epoch: 29951 Train ELBO: 203.3647 Val ELBO: 169.0517, Epoch Time (s): 0.09, Total Time (hrs): 0.9484
# ====> Epoch: 29952 Train ELBO: 201.7505 Val ELBO: 171.7003, Epoch Time (s): 0.09, Total Time (hrs): 0.9484
# ====> Epoch: 29953 Train ELBO: 198.9541 Val ELBO: 166.4464, Epoch Time (s): 0.09, Total Time (hrs): 0.9484
# ====> Epoch: 29954 Train ELBO: 200.2796 Val ELBO: 170.7275, Epoch Time (s): 0.09, Total Time (hrs): 0.9485
# ====> Epoch: 29955 Train ELBO: 198.5707 Val ELBO: 172.3528, Epoch Time (s): 0.08, Total Time (hrs): 0.9485
# ====> Epoch: 29956 Train ELBO: 198.8305 Val ELBO: 156.6855, Epoch Time (s): 0.08, Total Time (hrs): 0.9485
# ====> Epoch: 29957 Train ELBO: 194.7910 Val ELBO: 168.8738, Epoch Time (s): 0.09, Total Time (hrs): 0.9485
# ====> Epoch: 29958 Train ELBO: 197.2050 Val ELBO: 168.0740, Epoch Time (s): 0.08, Total Time (hrs): 0.9486
# ====> Epoch: 29959 Train ELBO: 189.0633 Val ELBO: 165.8598, Epoch Time (s): 0.08, Total Time (hrs): 0.9486
# ====> Epoch: 29960 Train ELBO: 195.8485 Val ELBO: 164.0985, Epoch Time (s): 0.11, Total Time (hrs): 0.9486
# ====> Epoch: 29961 Train ELBO: 197.5044 Val ELBO: 172.3082, Epoch Time (s): 0.08, Total Time (hrs): 0.9486
# ====> Epoch: 29962 Train ELBO: 203.2827 Val ELBO: 170.9807, Epoch Time (s): 0.08, Total Time (hrs): 0.9487
# ====> Epoch: 29963 Train ELBO: 203.0933 Val ELBO: 171.0649, Epoch Time (s): 0.09, Total Time (hrs): 0.9487
# ====> Epoch: 29964 Train ELBO: 201.1002 Val ELBO: 167.4214, Epoch Time (s): 0.09, Total Time (hrs): 0.9487
# ====> Epoch: 29965 Train ELBO: 204.4953 Val ELBO: 172.7602, Epoch Time (s): 0.09, Total Time (hrs): 0.9487
# ====> Epoch: 29966 Train ELBO: 205.1631 Val ELBO: 173.5655, Epoch Time (s): 0.09, Total Time (hrs): 0.9488
# ====> Epoch: 29967 Train ELBO: 206.4496 Val ELBO: 175.3126, Epoch Time (s): 0.08, Total Time (hrs): 0.9488
# ====> Epoch: 29968 Train ELBO: 207.1472 Val ELBO: 175.0458, Epoch Time (s): 0.08, Total Time (hrs): 0.9488
# ====> Epoch: 29969 Train ELBO: 208.0954 Val ELBO: 174.9938, Epoch Time (s): 0.09, Total Time (hrs): 0.9488
# ====> Epoch: 29970 Train ELBO: 207.3101 Val ELBO: 172.4206, Epoch Time (s): 0.08, Total Time (hrs): 0.9488
# ====> Epoch: 29971 Train ELBO: 206.7997 Val ELBO: 172.1361, Epoch Time (s): 0.09, Total Time (hrs): 0.9489
# ====> Epoch: 29972 Train ELBO: 205.2866 Val ELBO: 173.8920, Epoch Time (s): 0.10, Total Time (hrs): 0.9489
# ====> Epoch: 29973 Train ELBO: 207.8544 Val ELBO: 174.3540, Epoch Time (s): 0.08, Total Time (hrs): 0.9489
# ====> Epoch: 29974 Train ELBO: 209.2873 Val ELBO: 175.7092, Epoch Time (s): 0.08, Total Time (hrs): 0.9489
# ====> Epoch: 29975 Train ELBO: 208.0072 Val ELBO: 174.8574, Epoch Time (s): 0.10, Total Time (hrs): 0.9490
# ====> Epoch: 29976 Train ELBO: 207.7336 Val ELBO: 173.2064, Epoch Time (s): 0.09, Total Time (hrs): 0.9490
# ====> Epoch: 29977 Train ELBO: 207.0498 Val ELBO: 172.4688, Epoch Time (s): 0.09, Total Time (hrs): 0.9490
# ====> Epoch: 29978 Train ELBO: 206.0331 Val ELBO: 172.8064, Epoch Time (s): 0.09, Total Time (hrs): 0.9491
# ====> Epoch: 29979 Train ELBO: 204.9124 Val ELBO: 168.6877, Epoch Time (s): 0.09, Total Time (hrs): 0.9491
# ====> Epoch: 29980 Train ELBO: 204.2498 Val ELBO: 173.2968, Epoch Time (s): 0.09, Total Time (hrs): 0.9491
# ====> Epoch: 29981 Train ELBO: 203.5698 Val ELBO: 172.3174, Epoch Time (s): 0.09, Total Time (hrs): 0.9491
# ====> Epoch: 29982 Train ELBO: 204.3764 Val ELBO: 169.3600, Epoch Time (s): 0.09, Total Time (hrs): 0.9491
# ====> Epoch: 29983 Train ELBO: 205.2954 Val ELBO: 172.6453, Epoch Time (s): 0.10, Total Time (hrs): 0.9492
# ====> Epoch: 29984 Train ELBO: 203.6638 Val ELBO: 171.9237, Epoch Time (s): 0.09, Total Time (hrs): 0.9492
# ====> Epoch: 29985 Train ELBO: 204.4594 Val ELBO: 167.2257, Epoch Time (s): 0.09, Total Time (hrs): 0.9492
# ====> Epoch: 29986 Train ELBO: 200.2086 Val ELBO: 172.0518, Epoch Time (s): 0.09, Total Time (hrs): 0.9492
# ====> Epoch: 29987 Train ELBO: 202.7757 Val ELBO: 169.8864, Epoch Time (s): 0.09, Total Time (hrs): 0.9493
# ====> Epoch: 29988 Train ELBO: 201.0788 Val ELBO: 167.6973, Epoch Time (s): 0.09, Total Time (hrs): 0.9493
# ====> Epoch: 29989 Train ELBO: 196.9983 Val ELBO: 170.8443, Epoch Time (s): 0.08, Total Time (hrs): 0.9493
# ====> Epoch: 29990 Train ELBO: 203.2777 Val ELBO: 171.0961, Epoch Time (s): 0.09, Total Time (hrs): 0.9493
# ====> Epoch: 29991 Train ELBO: 204.1774 Val ELBO: 174.9480, Epoch Time (s): 0.13, Total Time (hrs): 0.9494
# ====> Epoch: 29992 Train ELBO: 203.9658 Val ELBO: 169.7007, Epoch Time (s): 0.13, Total Time (hrs): 0.9494
# ====> Epoch: 29993 Train ELBO: 205.9682 Val ELBO: 174.5493, Epoch Time (s): 0.14, Total Time (hrs): 0.9495
# ====> Epoch: 29994 Train ELBO: 207.4979 Val ELBO: 174.2792, Epoch Time (s): 0.14, Total Time (hrs): 0.9495
# ====> Epoch: 29995 Train ELBO: 207.8618 Val ELBO: 175.8962, Epoch Time (s): 0.12, Total Time (hrs): 0.9495
# ====> Epoch: 29996 Train ELBO: 207.7004 Val ELBO: 172.9839, Epoch Time (s): 0.13, Total Time (hrs): 0.9496
# ====> Epoch: 29997 Train ELBO: 208.0296 Val ELBO: 174.2436, Epoch Time (s): 0.12, Total Time (hrs): 0.9496
# ====> Epoch: 29998 Train ELBO: 208.1827 Val ELBO: 174.3336, Epoch Time (s): 0.13, Total Time (hrs): 0.9496
# ====> Epoch: 29999 Train ELBO: 207.5410 Val ELBO: 172.8611, Epoch Time (s): 0.12, Total Time (hrs): 0.9497
# Training took  0:56:58.824595

# %% [markdown]
# # Load and Plot Results

# %%
if loadFlag:
  path = dirname
  epoch = n_epochs - 1
params = {}
encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd1, hd2]).to("cuda")
decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd2, hd1], decoder_var=decoder_var).to("cuda")

# Use if you need to load in the data
if loadFlag:
  suffix = postfix
  encoder.load_state_dict(torch.load(os.path.join(path, f'encoder_{suffix}.pt'),map_location=torch.device('cpu')))
  decoder.load_state_dict(torch.load(os.path.join(path, f'decoder_{suffix}.pt'),map_location=torch.device('cpu')))
  logsigmasq = torch.load(os.path.join(path, f'gmm_params_logsigmasq_{suffix}.pt'),map_location=torch.device('cpu'))
  mu = torch.load(os.path.join(path, f'gmm_params_mu_{suffix}.pt'),map_location=torch.device('cpu'))
  pi = torch.load(os.path.join(path, f'gmm_params_pi_{suffix}.pt'),map_location=torch.device('cpu'))

encoder_list = [encoder]
decoder_list = [decoder]

device = next(encoder.parameters()).device
# Load in training history metrics
pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


text_labels = [f'Cluster {i}' for i in range((n_clusters))]
label_colors = [f'C{i+1}' for i in range((n_clusters))]
data_colors = label_colors

# Plot training history
# Plot the training and validation loss vs. epoch number
plt.figure(figsize=(4, 4))
const = min(min(train_loss), min(val_loss))
# const = min(10, const)
train_loss_adjusted = train_loss
val_loss_adjusted = val_loss
plt.plot(train_loss_adjusted.cpu(), label='Training')
plt.plot(val_loss_adjusted.cpu(), label='Validation')
plt.xlabel("Number of Epochs")
plt.ylabel("Negative Loss")
# plt.title("Negative Loss")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()


 # Plot each term of the training loss and validation loss
plt.figure(figsize=(4.5, 4))
labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
for ii in range(4):
  # print(train_elbo_terms.cpu()[ii, :epoch])
  # print(len(train_elbo_terms.cpu()[ii, :epoch]))
  train_loss_adjusted = train_elbo_terms[:, ii]
  val_loss_adjusted = val_elbo_terms[:, ii]
  plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
  plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
plt.xlabel("number of epochs")
plt.ylabel("loss")
plt.title("Negative Loss Terms")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()


 # Plot the sum of each term of the training loss and validation loss
plt.figure(figsize=(4.5, 4))
  # print(train_elbo_terms.cpu()[ii, :epoch])
  # print(len(train_elbo_terms.cpu()[ii, :epoch]))
train_loss_adjusted = train_elbo_terms.sum(axis=1)
val_loss_adjusted = val_elbo_terms.sum(axis=1)
plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
plt.xlabel("number of epochs")
plt.ylabel("loss")
plt.title("Sum of ELBO Terms")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Plot the training and validation mse vs. epoch number
plt.figure(figsize=(4.5, 4))
plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
plt.xlabel("number of epochs")
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Plot the history of pi
plt.figure(figsize=(4, 4))
for i in range(K):
    plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
plt.xlabel("Number of Epochs")
plt.ylabel("Predicted Cluster Probability")
plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Load best model saved
params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

encoder.eval()
decoder.eval()

# run one last EM step and plot training data in latent space
for encoder in encoder_list:
    encoder.eval()

with torch.no_grad():
    means = []
    samples = []
    labels = []
    params['hist_weights'] = torch.zeros((K, 1))
    params['hist_mu_c'] = torch.zeros((K, latent_dim))
    params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
    for batch in train_loader:
        batch_x, batch_label = batch
        x_list = [batch_x]
        mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
        sigma = torch.exp(0.5 * logsigmasq)
        eps = Normal(0, 1).sample(mu.shape)
        z = mu + eps * sigma
        with torch.no_grad():
            gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
        params['mu_c'] = mu_c
        params['logsigmasq_c'] = logsigmasq_c

        means.append(mu)
        samples.append(z)
        labels.append(batch_label)

means = torch.vstack(means).cpu()
samples = torch.vstack(samples).cpu()
labels = torch.hstack(labels).cpu()


savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

# plot test data in latent space
with torch.no_grad():
    test_means = []
    test_labels = []
    for batch in test_loader:
        batch_x, batch_label = batch
        x_list = [batch_x]
        mean, _ = encoder_step(x_list, encoder_list, decoder_list)
        test_means.append(mean)
        test_labels.append(batch_label)

test_means = torch.vstack(test_means).cpu()
test_labels = torch.hstack(test_labels).cpu()


savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

# plot decoding results from cluster means # todo: expand this function for multi-modal data
fig, ax = plt.subplots(figsize=(4.5, 4))
for i in range(K):
    # with torch.no_grad:
    x_mean = decoder.forward(params['mu_c'][i])[0]
    ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
ax.legend()
plt.title("Decoded Means")
fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
# plt.close()

# plot samples from generative model
n_gen = n_train
cluster_probs = params['pi_c'].cpu().detach().numpy()
fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_gen):
    c = np.random.choice(K, p=cluster_probs)
    # print(c)
    mu_c = params['mu_c'][c].cpu().clone().detach()
    sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
    z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
    # print(z)
    mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
    sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
    sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
    ax.plot(sample_x.cpu().detach().numpy())
plt.title("Generated Samples")
fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
# plt.close()

np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
      train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
      pi_history=pi_history.cpu().detach().numpy(),
      cluster_probs=params['pi_c'].cpu().detach().numpy(),
      cluster_means=params['mu_c'].cpu().detach().numpy(),
      cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


print("Training data size", n_train)
print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
print("Cluster 1 probability:", cluster_probs.min().item())
# Out:
# Training data size 1024
# Fraction of downward curves: 0.91796875
# Cluster 1 probability: 0.06073112040758133
