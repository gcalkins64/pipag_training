# %% [markdown]
# # Imports

# %% [markdown]
# TO RUN:
# - Make sure to select Runtime>Change Runtime Type>T4 GPU to use cuda
# - Install pytorch_lightning
# - clone in repo to read in common files

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2025.3.2)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (24.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pytorch_lightning) (4.13.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics>=0.7.0->pytorch_lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.10)
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 35.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 104.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.6 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 61.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, pytorch_lightning
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-utilities-0.14.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch_lightning-2.5.1.post0 torchmetrics-1.7.1

# %%
import os
import random
import numpy as np
import torch
from pytorch_lightning import seed_everything

SEED = 42
seed_everything(SEED, workers=True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch.optim as optim
from torch.distributions import Normal
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pathlib
from torch.utils.data import DataLoader
from pytorch_lightning import LightningDataModule
import seaborn as sns
import json
from tqdm.notebook import tqdm_notebook
from time import time
import datetime
import pickle
import matplotlib.lines as mlines
import sys
from sklearn.decomposition import PCA
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 42

# %%
# !git clone https://gcalkins64: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@github.com/gcalkins64/pipag_training.git
# !cd pipag_training && git pull
sys.path.append('/content/pipag_training')
# Out:
# fatal: destination path 'pipag_training' already exists and is not an empty directory.
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gmvae_common import *

# %% [markdown]
# # Check Devices

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set default tensor type to CUDA tensors
torch.set_default_tensor_type(torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor)
print(device)
# Out:
# cuda
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py:1236: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)

# %% [markdown]
# # Settings

# %%
n_train = 1024
n_val = 128
n_test = 128
# For testing small batches of data
# n_train = 400
# n_val = 50
# n_test = 50
hd1 = 32
hd2 = 16
latent_dim = 5
n_clusters = 4
lr = 1e-3
n_epochs = 30_000 # 30_000
batch_size = 128
em_reg = 1e-6
decoder_var = 1e-5

plot_interval = 500
dpi = 300

K = n_clusters
Z = latent_dim
D = 1  #num_modalities
downsampleNum = 64

loadFlag = False  # True to load in old case, False to run a new case

# %% [markdown]
# # Set Up Data Loader

# %%
from datetime import datetime
timestr = datetime.strftime(datetime.now(), "%Y%m%d_%H%M%S")

# %%
if loadFlag:  # Load in old data
  dirname = os.path.join("drive", "MyDrive", "JP_gmvae_data", 'gmvae_em_aerocapture_energy_20250429_155508_5_4')
else:  # generate new data
  dirname = os.path.join("drive", "MyDrive", "JP_gmvae_data", "gmvae_em_aerocapture_energy_"+timestr+"_"+str(latent_dim)+"_"+str(n_clusters))
  os.makedirs(dirname, exist_ok=True)
print("Filepath directory: " + dirname)

if loadFlag:  # load old data
  postfix = '_42_1024_128_128_32_16_5_4_0.001000_128_0.001000_0.000010_1000.000000_'
else:  # Generate new suffix
  postfix = '_{0:d}_{1:d}_{2:d}_{3:d}_{4:d}_{5:d}_{6:d}_{7:d}_{8:f}_{9:d}_{10:f}_{11:f}_{12:f}_'.format(
          SEED, n_train, n_val, n_test, hd1, hd2, latent_dim, n_clusters, lr, batch_size, em_reg * 1e3, decoder_var, n_epochs)
print("Filepath postfix: " + postfix)
# Out:
# Filepath directory: drive/MyDrive/JP_gmvae_data/gmvae_em_aerocapture_energy_20250429_155508_5_4
# Filepath postfix: _42_1024_128_128_32_16_5_4_0.001000_128_0.001000_0.000010_1000.000000_

# %%
data = 'UOP_inc_lit_disps_5000_data_energy_scaled_downsampled_'
# data = 'UOP_near_crash_5000_data_energy_scaled_downsampled_'
# data = 'UOP_near_crash_steeper_5000_data_energy_scaled_downsampled_'
data_dir = os.path.join("drive", "MyDrive", "JP_gmvae_data", f"{data}.json")

data_module = AerocaptureDataModuleCUDA(data_dir=data_dir, n_train=n_train, n_val=n_val, n_test=n_test,
                                  train_batch=batch_size, val_batch=batch_size, test_batch=batch_size,
                                  num_workers=0)

data_module.setup("fit")

train_loader = data_module.train_dataloader()
val_loader = data_module.val_dataloader()
test_loader = data_module.test_dataloader()
data_dim = len(train_loader.dataset[0][0])
text_labels = ['capture', 'escape', 'impact']
label_colors = ['C2', 'C3', 'C4']

num_train_batches = len(train_loader)

ts_plot = np.linspace(0,450,64)
seabornSettings()
fig, ax = plt.subplots(figsize=(4, 4))
for j in range(n_train):
    ax.plot(ts_plot, train_loader.dataset[j][0].cpu(), color=label_colors[train_loader.dataset[j][1].cpu()], alpha=0.75)

eline = mlines.Line2D([], [], color='C2', label='Escape')
cline = mlines.Line2D([], [], color='C3', label='Capture')
iline = mlines.Line2D([], [], color='C4', label='Impact')
plt.legend(handles=[eline, cline, iline])
plt.hlines(0, 0, ts_plot[-1], colors='r', linestyles='dashed')
plt.xlabel("Time [s]")
plt.ylabel("Nondimensionalized Energy")
plt.title("Training Data")
plt.tight_layout()
fig.savefig(os.path.join(dirname, 'train_data'+postfix+'.png'), dpi=dpi)

fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_val):
    ax.plot(ts_plot, val_loader.dataset[j][0].cpu(), color=label_colors[val_loader.dataset[j][1].cpu()])
plt.title("Validation Data")
fig.savefig(os.path.join(dirname, 'val_data'+postfix+'.png'), dpi=dpi)

fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_test):
    ax.plot(ts_plot, test_loader.dataset[j][0].cpu(), color=label_colors[test_loader.dataset[j][1].cpu()])
plt.title("Test Data")
fig.savefig(os.path.join(dirname, 'test_data'+postfix+'.png'), dpi=dpi)
# Out:
# Loading File...
# ...File Loaded
# [912, 204, 2253, 2006, 1828, 1143, 839, 4467, 712, 4837, 3456, 260, 244, 767, 1791, 1905, 4139, 4931, 217, 4597, 1628, 4464, 3436, 1805, 3679, 4827, 2278, 53, 1307, 3462, 2787, 2276, 1273, 1763, 2757, 837, 759, 3112, 792, 2940, 2817, 4945, 2166, 355, 3763, 4392, 1022, 3100, 645, 4522, 2401, 2962, 4729, 1575, 569, 375, 1866, 2370, 653, 1907, 827, 3113, 2277, 3714, 2988, 1332, 3032, 2910, 1716, 2187, 584, 4990, 1401, 4375, 2005, 1338, 3786, 3108, 2211, 4562, 1799, 2656, 458, 1876, 262, 2584, 3286, 2193, 542, 1728, 4646, 2577, 1741, 4089, 3241, 3758, 1170, 2169, 2020, 4598, 4415, 2152, 4788, 3509, 4780, 3271, 2965, 1796, 1133, 4174, 4042, 744, 385, 898, 1252, 1310, 3458, 4885, 520, 3152, 3126, 4881, 3834, 4334, 2059, 4532, 94, 938, 4398, 2185, 2786, 913, 2404, 3561, 1295, 3716, 26, 2157, 4100, 1463, 4158, 871, 2444, 4988, 1629, 3063, 1323, 4418, 4344, 4, 4906, 2655, 4002, 159, 916, 2973, 2519, 1961, 474, 1973, 4647, 701, 3981, 566, 4363, 1030, 1051, 3893, 4503, 1352, 2171, 4322, 4969, 3466, 1735, 4417, 1647, 2553, 3268, 3059, 3588, 4239, 3698, 991, 2030, 1840, 524, 2769, 172, 4819, 4537, 1885, 4820, 1804, 58, 581, 482, 1875, 552, 257, 2706, 580, 4211, 1949, 2281, 3976, 1755, 1083, 4677, 4720, 3872, 1990, 3874, 3334, 1559, 772, 794, 3531, 2902, 3469, 3367, 3825, 443, 806, 496, 3298, 2779, 895, 2036, 1569, 1558, 4393, 3675, 1148, 1503, 3789, 2046, 617, 3630, 4508, 802, 414, 4428, 120, 764, 1936, 1362, 3329, 3978, 3943, 1751, 3285, 480, 1348, 3104, 17, 3198, 2172, 3727, 2336, 3465, 4552, 3986, 1268, 1555, 2430, 1783, 479, 4744, 4441, 499, 2569, 468, 410, 4785, 3905, 4119, 4350, 1289, 465, 4160, 656, 1522, 561, 4874, 556, 1926, 3307, 982, 4666, 2016, 4742, 4870, 325, 671, 3434, 4781, 4630, 4282, 2591, 2136, 1673, 2573, 1955, 2175, 3242, 1072, 2457, 3745, 2590, 594, 76, 3754, 4612, 819, 600, 4404, 1746, 4144, 1085, 2859, 563, 2001, 3027, 2334, 1292, 3589, 4450, 2478, 4333, 64, 4543, 2452, 848, 1100, 945, 876, 2231, 2308, 4954, 1725, 2808, 1667, 2162, 4140, 2057, 416, 756, 2266, 361, 29, 2732, 1071, 2145, 3619, 4519, 3503, 4594, 79, 616, 1221, 4469, 295, 3024, 4771, 4526, 1213, 3520, 1044, 342, 2525, 2987, 326, 2931, 1720, 2044, 842, 2897, 4586, 1266, 1939, 1331, 1450, 3377, 203, 1469, 2721, 3372, 2032, 1304, 885, 3133, 317, 3855, 1822, 1634, 3770, 2864, 2500, 1864, 1826, 193, 1582, 3264, 2689, 2282, 568, 2286, 2876, 4173, 3274, 2712, 226, 944, 2139, 1462, 4756, 2174, 313, 888, 4887, 3559, 2831, 3574, 4966, 4189, 947, 3155, 4723, 1557, 2086, 363, 3572, 13, 4259, 4410, 1614, 2983, 3533, 573, 2704, 2571, 1020, 2460, 4154, 2533, 3345, 2672, 3296, 2422, 4541, 1042, 1571, 3444, 3105, 1425, 4662, 2465, 3326, 4488, 3, 2489, 2350, 1721, 3521, 4751, 2639, 3809, 3622, 1750, 4187, 3876, 1390, 694, 2324, 4222, 2745, 765, 1924, 2542, 1631, 1207, 200, 378, 3892, 596, 3730, 3395, 4715, 1592, 3145, 4049, 3273, 1998, 1208, 45, 873, 3482, 1792, 1440, 4243, 3805, 411, 4566, 2041, 994, 3739, 1092, 3806, 4351, 4578, 4877, 2599, 3625, 4135, 3495, 3652, 1303, 3888, 3686, 2123, 2025, 2271, 4270, 3969, 1959, 2249, 3603, 634, 2340, 1920, 2225, 2751, 2619, 4424, 660, 1235, 1894, 3137, 1251, 1752, 526, 3398, 3339, 2710, 4445, 3816, 3406, 510, 1694, 3441, 3190, 4784, 160, 4716, 3116, 3907, 48, 2881, 2446, 3194, 3432, 4409, 4473, 4941, 1806, 3999, 1797, 2235, 3570, 237, 3185, 2753, 3312, 3828, 1045, 220, 3227, 4848, 4623, 222, 687, 3511, 1111, 3782, 1488, 2131, 2681, 1733, 3724, 2677, 2764, 2279, 3453, 2066, 670, 3852, 158, 426, 2866, 1836, 562, 329, 254, 1633, 166, 1248, 1954, 1034, 3879, 937, 4620, 1785, 2099, 3021, 1374, 4963, 4974, 1341, 2548, 4740, 210, 2555, 3074, 3249, 1624, 622, 4850, 1989, 834, 2470, 4918, 4636, 336, 2844, 4364, 3035, 564, 2795, 103, 4015, 864, 3551, 2967, 3766, 1253, 3567, 1442, 4274, 2212, 4408, 3960, 3808, 3568, 4853, 2198, 2640, 2011, 709, 2284, 3692, 1997, 4668, 2755, 235, 2662, 1489, 3994, 1737, 2906, 2116, 2788, 2290, 4883, 2263, 4553, 83, 4232, 1565, 1977, 4548, 1968, 3900, 4020, 3671, 141, 762, 2410, 1815, 1993, 2508, 4764, 3023,  ...
#   0%|          | 0/1280 [00:00<?, ?it/s]

# %% [markdown]
# # Run GMVAE

# %%
# initialize latent GMM model parameters
params = {}
pi_variables = torch.zeros(K).clone().detach().requires_grad_(True)
params['pi_c'] = torch.ones(K) / K
params['mu_c'] = torch.rand((K, Z)) * 2.0 - 1.0
params['logsigmasq_c'] = torch.zeros((K, Z))


text_labels = [f'Cluster {i}' for i in range((n_clusters))]
label_colors = [f'C{i+1}' for i in range((n_clusters))]

# initialize neural networks
encoder_list = []
decoder_list = []
trainable_parameters = []
trainable_parameters.append(pi_variables)

for _ in range(D):
    encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd1, hd2])
    decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd2, hd1], decoder_var=decoder_var)
    encoder_list.append(encoder)
    decoder_list.append(decoder)
    trainable_parameters += list(encoder.parameters()) + list(decoder.parameters())

optimizer = optim.Adam(trainable_parameters, lr=lr)

# training

import time
ts = time.time()
tic = time.perf_counter()

train_loss = torch.zeros(n_epochs)
train_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
val_elbo_terms = torch.zeros((n_epochs, 4)) # 4 ELBO terms
val_loss = torch.zeros(n_epochs)
pi_history = torch.zeros((n_epochs, K))
train_mse_history = torch.zeros(n_epochs)
val_mse_history = torch.zeros(n_epochs)
min_val_loss = torch.inf
seabornSettings()

for epoch in range(n_epochs):
    ti = time.time()
    for encoder in encoder_list:
        encoder.train()
    for decoder in decoder_list:
        decoder.train()

    train_elbo = 0
    train_mse = 0
    train_elbo_term = np.zeros(4)
    params['hist_weights'] = torch.zeros((K, 1))
    params['hist_mu_c'] = torch.zeros((K, latent_dim))
    params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))

    for (batch_idx, batch) in enumerate(train_loader):
        batch_x, _ = batch
        x_list = [batch_x]  # assume D=2 and each modality has data_dim
        optimizer.zero_grad()
        pi_c = torch.exp(pi_variables) / torch.sum(torch.exp(pi_variables))
        params['pi_c'] = pi_c

        mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
        sigma = torch.exp(0.5 * logsigmasq)
        eps = Normal(0, 1).sample(mu.shape)
        z = mu + eps * sigma

        with torch.no_grad():
            gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
        params['mu_c'] = mu_c
        params['logsigmasq_c'] = logsigmasq_c

        elbo, sse, elbo_terms = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
        train_elbo += elbo.item()
        train_elbo_term += elbo_terms
        train_mse += sse.item()
        loss = - elbo / batch_x.shape[0]
        loss.backward()
        optimizer.step()

    for encoder in encoder_list:
        encoder.eval()
    for decoder in decoder_list:
        decoder.eval()

    if epoch % plot_interval == 0 or epoch == n_epochs:
        # Plot the first two dimensions of the latents
        with torch.no_grad():
            means = []
            samples = []
            labels = []
            for batch in train_loader:
                batch_x, batch_label = batch
                x_list = [batch_x]
                mean, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
                sigma = torch.exp(0.5 * logsigmasq)
                eps = Normal(0, 1).sample(mean.shape)
                z = mean + eps * sigma
                means.append(mean)
                samples.append(z)
                labels.append(batch_label)

        means = torch.vstack(means).cpu()
        samples = torch.vstack(samples).cpu()
        labels = torch.hstack(labels).cpu()

        savepath = os.path.join(dirname, "latent_samples_epoch_" + str(epoch) + postfix)
        plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)

        savepath = os.path.join(dirname, "latent_means_epoch_" + str(epoch) + postfix)
        plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, label_colors, epoch, dpi=dpi)


        # plot samples from generative model
        n_gen = n_train
        cluster_probs = params['pi_c'].cpu().detach().numpy() #
        fig, ax = plt.subplots(figsize=(4.5, 4))
        for j in range(n_gen):
            c = np.random.choice(K, p=cluster_probs)
            mu_c = params['mu_c'][c].clone().detach()
            sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).clone().detach()
            z = Normal(0, 1).sample(mu_c.shape) * sigma_c + mu_c
            mu_x = decoder.forward(z)[0]
            ax.plot(mu_x.cpu().detach().numpy())
        fig.savefig(os.path.join(dirname, "generate_samples_" + str(epoch) + postfix+ '.png'), dpi=dpi)
        plt.close()


    val_elbo = 0
    val_mse = 0
    val_elbo_term = np.zeros(4)
    with torch.no_grad():
        for (batch_idx, batch) in enumerate(val_loader):
            batch_x, _ = batch
            x_list = [batch_x]
            mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
            sigma = torch.exp(0.5 * logsigmasq)
            eps = Normal(0, 1).sample(mu.shape)
            z = mu + eps * sigma
            with torch.no_grad():
                gamma_c, _, _ = em_step(z, mu, logsigmasq, params, em_reg)
            elbo, sse, elbo_items = decoder_step(x_list, z, encoder_list, decoder_list, params, mu, logsigmasq, gamma_c)
            val_elbo += elbo.item()
            val_mse += sse.item()
            val_elbo_term += elbo_items

    train_elbo /= len(train_loader.dataset)
    train_elbo_term = torch.tensor(train_elbo_term) / len(train_loader.dataset)
    val_elbo /= len(val_loader.dataset)
    val_elbo_term = torch.tensor(val_elbo_term) / len(val_loader.dataset)
    train_mse /= len(train_loader.dataset)
    val_mse /= len(val_loader.dataset)

    tf = time.time()
    toc = time.perf_counter()
    print('====> Epoch: {} Train ELBO: {:.4f} Val ELBO: {:.4f}, Epoch Time (s): {:.2f}, Total Time (hrs): {:.4f}'.format(epoch, train_elbo, val_elbo, tf-ti, (toc-tic)/60/60))

    train_loss[epoch] = - train_elbo
    val_loss[epoch] = - val_elbo
    train_elbo_terms[epoch,:] = - train_elbo_term
    val_elbo_terms[epoch,:] = - val_elbo_term
    pi_history[epoch] = params['pi_c']
    train_mse_history[epoch] = train_mse
    val_mse_history[epoch] = val_mse

    if - val_elbo < min_val_loss:
        min_val_loss = - val_elbo
        torch.save(params['pi_c'], os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
        torch.save(params['mu_c'], os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
        torch.save(params['logsigmasq_c'], os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
        torch.save(encoder.state_dict(), os.path.join(dirname, 'encoder'+ postfix + '.pt'))
        torch.save(decoder.state_dict(), os.path.join(dirname, 'decoder'+ postfix + '.pt'))

    if epoch % plot_interval == 0 or epoch == n_epochs:
      # Plot the training and validation loss vs. epoch number
      plt.figure(figsize=(4.5, 4))
      # const = min(min(train_loss), min(val_loss))
      train_loss_adjusted = train_loss
      val_loss_adjusted = val_loss
      plt.plot(train_loss_adjusted.cpu()[:epoch], label='train')
      # print(train_loss_adjusted.cpu()[:epoch])
      plt.plot(val_loss_adjusted.cpu()[:epoch], label='val')
      plt.yscale('symlog')
      plt.xlabel("number of epochs")
      plt.ylabel("loss")
      plt.title("Negative Loss")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot each term of the training loss and validation loss
      plt.figure(figsize=(4.5, 4))
      labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
      for ii in range(4):
        train_loss_adjusted = train_elbo_terms[:epoch, ii]
        val_loss_adjusted = val_elbo_terms[:epoch, ii]
        plt.plot(train_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Train")
        plt.plot(val_loss_adjusted.cpu()[:epoch], label=f"{labels[ii]}: Val", linestyle='--')
      plt.xlabel("number of epochs")
      plt.yscale('symlog')
      plt.ylabel("loss")
      plt.title("Negative Loss Terms")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot the training and validation mse vs. epoch number
      plt.figure(figsize=(4.5, 4))
      plt.semilogy(train_mse_history.cpu().detach().numpy()[:epoch], label='train')
      plt.semilogy(val_mse_history.cpu().detach().numpy()[:epoch], label='val')
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()

      # Plot the history of pi
      plt.figure(figsize=(4.5, 4))
      for i in range(K):
          plt.plot(pi_history[:, i].cpu().detach().numpy()[:epoch], label=r'$\pi$' + str(i+1))
      plt.xlabel("number of epochs")
      plt.legend()
      plt.tight_layout()
      plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
      plt.close()


te = time.time()
import datetime
duration = datetime.timedelta(seconds=te - ts)
print("Training took ", duration)

# Save off pi_history, train_loss, val_loss, train_mse_history, val_mse_history
torch.save(pi_history, os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
torch.save(train_loss, os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
torch.save(val_loss, os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
torch.save(train_elbo_terms, os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
torch.save(val_elbo_terms, os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
torch.save(train_mse_history, os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
torch.save(val_mse_history, os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))
# Out:
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 25001 Train ELBO: 260.6587 Val ELBO: 252.9004, Epoch Time (s): 0.11, Total Time (hrs): 0.6917
# ====> Epoch: 25002 Train ELBO: 260.9017 Val ELBO: 254.3586, Epoch Time (s): 0.11, Total Time (hrs): 0.6917
# ====> Epoch: 25003 Train ELBO: 262.1507 Val ELBO: 254.4561, Epoch Time (s): 0.12, Total Time (hrs): 0.6917
# ====> Epoch: 25004 Train ELBO: 261.3888 Val ELBO: 250.3545, Epoch Time (s): 0.11, Total Time (hrs): 0.6917
# ====> Epoch: 25005 Train ELBO: 257.1229 Val ELBO: 255.7154, Epoch Time (s): 0.11, Total Time (hrs): 0.6918
# ====> Epoch: 25006 Train ELBO: 258.9290 Val ELBO: 257.0175, Epoch Time (s): 0.13, Total Time (hrs): 0.6918
# ====> Epoch: 25007 Train ELBO: 261.1384 Val ELBO: 255.3255, Epoch Time (s): 0.12, Total Time (hrs): 0.6918
# ====> Epoch: 25008 Train ELBO: 262.8078 Val ELBO: 257.7075, Epoch Time (s): 0.11, Total Time (hrs): 0.6919
# ====> Epoch: 25009 Train ELBO: 263.6521 Val ELBO: 258.9523, Epoch Time (s): 0.12, Total Time (hrs): 0.6919
# ====> Epoch: 25010 Train ELBO: 262.6782 Val ELBO: 255.7436, Epoch Time (s): 0.11, Total Time (hrs): 0.6919
# ====> Epoch: 25011 Train ELBO: 262.5978 Val ELBO: 256.8926, Epoch Time (s): 0.12, Total Time (hrs): 0.6920
# ====> Epoch: 25012 Train ELBO: 263.0642 Val ELBO: 255.9995, Epoch Time (s): 0.11, Total Time (hrs): 0.6920
# ====> Epoch: 25013 Train ELBO: 261.9808 Val ELBO: 256.0420, Epoch Time (s): 0.12, Total Time (hrs): 0.6920
# ====> Epoch: 25014 Train ELBO: 260.8750 Val ELBO: 249.9304, Epoch Time (s): 0.11, Total Time (hrs): 0.6921
# ====> Epoch: 25015 Train ELBO: 260.1814 Val ELBO: 257.5938, Epoch Time (s): 0.14, Total Time (hrs): 0.6921
# ====> Epoch: 25016 Train ELBO: 262.6012 Val ELBO: 257.9523, Epoch Time (s): 0.12, Total Time (hrs): 0.6921
# ====> Epoch: 25017 Train ELBO: 262.8510 Val ELBO: 255.8288, Epoch Time (s): 0.13, Total Time (hrs): 0.6922
# ====> Epoch: 25018 Train ELBO: 262.6749 Val ELBO: 257.2597, Epoch Time (s): 0.11, Total Time (hrs): 0.6922
# ====> Epoch: 25019 Train ELBO: 262.7614 Val ELBO: 257.0170, Epoch Time (s): 0.12, Total Time (hrs): 0.6922
# ====> Epoch: 25020 Train ELBO: 261.6819 Val ELBO: 253.0560, Epoch Time (s): 0.12, Total Time (hrs): 0.6923
# ====> Epoch: 25021 Train ELBO: 256.4069 Val ELBO: 250.1013, Epoch Time (s): 0.12, Total Time (hrs): 0.6923
# ====> Epoch: 25022 Train ELBO: 259.6303 Val ELBO: 254.3744, Epoch Time (s): 0.12, Total Time (hrs): 0.6923
# ====> Epoch: 25023 Train ELBO: 256.9752 Val ELBO: 247.3374, Epoch Time (s): 0.09, Total Time (hrs): 0.6924
# ====> Epoch: 25024 Train ELBO: 256.3948 Val ELBO: 245.0961, Epoch Time (s): 0.09, Total Time (hrs): 0.6924
# ====> Epoch: 25025 Train ELBO: 257.0580 Val ELBO: 253.5353, Epoch Time (s): 0.08, Total Time (hrs): 0.6924
# ====> Epoch: 25026 Train ELBO: 261.7469 Val ELBO: 257.2425, Epoch Time (s): 0.08, Total Time (hrs): 0.6924
# ====> Epoch: 25027 Train ELBO: 262.9999 Val ELBO: 255.0865, Epoch Time (s): 0.07, Total Time (hrs): 0.6925
# ====> Epoch: 25028 Train ELBO: 262.4230 Val ELBO: 255.7264, Epoch Time (s): 0.08, Total Time (hrs): 0.6925
# ====> Epoch: 25029 Train ELBO: 261.5131 Val ELBO: 251.8512, Epoch Time (s): 0.08, Total Time (hrs): 0.6925
# ====> Epoch: 25030 Train ELBO: 260.9590 Val ELBO: 257.0148, Epoch Time (s): 0.08, Total Time (hrs): 0.6925
# ====> Epoch: 25031 Train ELBO: 261.6112 Val ELBO: 256.0286, Epoch Time (s): 0.08, Total Time (hrs): 0.6925
# ====> Epoch: 25032 Train ELBO: 262.2005 Val ELBO: 257.7178, Epoch Time (s): 0.08, Total Time (hrs): 0.6926
# ====> Epoch: 25033 Train ELBO: 262.3501 Val ELBO: 254.4456, Epoch Time (s): 0.07, Total Time (hrs): 0.6926
# ====> Epoch: 25034 Train ELBO: 262.6418 Val ELBO: 255.8013, Epoch Time (s): 0.08, Total Time (hrs): 0.6926
# ====> Epoch: 25035 Train ELBO: 262.5787 Val ELBO: 257.4627, Epoch Time (s): 0.08, Total Time (hrs): 0.6926
# ====> Epoch: 25036 Train ELBO: 263.9094 Val ELBO: 255.2461, Epoch Time (s): 0.08, Total Time (hrs): 0.6927
# ====> Epoch: 25037 Train ELBO: 262.8791 Val ELBO: 256.7217, Epoch Time (s): 0.09, Total Time (hrs): 0.6927
# ====> Epoch: 25038 Train ELBO: 261.8332 Val ELBO: 251.8220, Epoch Time (s): 0.08, Total Time (hrs): 0.6927
# ====> Epoch: 25039 Train ELBO: 259.9516 Val ELBO: 256.8787, Epoch Time (s): 0.07, Total Time (hrs): 0.6927
# ====> Epoch: 25040 Train ELBO: 260.1659 Val ELBO: 255.1551, Epoch Time (s): 0.07, Total Time (hrs): 0.6927
# ====> Epoch: 25041 Train ELBO: 262.2889 Val ELBO: 256.1395, Epoch Time (s): 0.08, Total Time (hrs): 0.6928
# ====> Epoch: 25042 Train ELBO: 262.1641 Val ELBO: 257.1637, Epoch Time (s): 0.08, Total Time (hrs): 0.6928
# ====> Epoch: 25043 Train ELBO: 262.0082 Val ELBO: 255.3869, Epoch Time (s): 0.08, Total Time (hrs): 0.6928
# ====> Epoch: 25044 Train ELBO: 259.7848 Val ELBO: 246.4665, Epoch Time (s): 0.08, Total Time (hrs): 0.6928
# ====> Epoch: 25045 Train ELBO: 252.4772 Val ELBO: 229.4519, Epoch Time (s): 0.07, Total Time (hrs): 0.6929
# ====> Epoch: 25046 Train ELBO: 247.1933 Val ELBO: 241.2909, Epoch Time (s): 0.07, Total Time (hrs): 0.6929
# ====> Epoch: 25047 Train ELBO: 251.2750 Val ELBO: 254.3775, Epoch Time (s): 0.08, Total Time (hrs): 0.6929
# ====> Epoch: 25048 Train ELBO: 259.9547 Val ELBO: 253.1292, Epoch Time (s): 0.08, Total Time (hrs): 0.6929
# ====> Epoch: 25049 Train ELBO: 261.8119 Val ELBO: 257.3568, Epoch Time (s): 0.08, Total Time (hrs): 0.6929
# ====> Epoch: 25050 Train ELBO: 262.9854 Val ELBO: 258.8429, Epoch Time (s): 0.10, Total Time (hrs): 0.6930
# ====> Epoch: 25051 Train ELBO: 263.6079 Val ELBO: 258.4641, Epoch Time (s): 0.08, Total Time (hrs): 0.6930
# ====> Epoch: 25052 Train ELBO: 263.8735 Val ELBO: 259.3230, Epoch Time (s): 0.07, Total Time (hrs): 0.6930
# ====> Epoch: 25053 Train ELBO: 264.3906 Val ELBO: 258.3473, Epoch Time (s): 0.08, Total Time (hrs): 0.6930
# ====> Epoch: 25054 Train ELBO: 263.8427 Val ELBO: 258.5719, Epoch Time (s): 0.08, Total Time (hrs): 0.6931
# ====> Epoch: 25055 Train ELBO: 263.4183 Val ELBO: 256.7416, Epoch Time (s): 0.08, Total Time (hrs): 0.6931
# ====> Epoch: 25056 Train ELBO: 262.9337 Val ELBO: 256.9271, Epoch Time (s): 0.08, Total Time (hrs): 0.6931
# ====> Epoch: 25057 Train ELBO: 262.7280 Val ELBO: 256.8156, Epoch Time (s): 0.08, Total Time (hrs): 0.6931
# ====> Epoch: 25058 Train ELBO: 262.1471 Val ELBO: 257.7844, Epoch Time (s): 0.07, Total Time (hrs): 0.6931
# ====> Epoch: 25059 Train ELBO: 261.1006 Val ELBO: 248.3344, Epoch Time (s): 0.08, Total Time (hrs): 0.6932
# ====> Epoch: 25060 Train ELBO: 259.6559 Val ELBO: 254.1641, Epoch Time (s): 0.08, Total Time (hrs): 0.6932
# ====> Epoch: 25061 Train ELBO: 262.2168 Val ELBO: 257.3539, Epoch Time (s): 0.08, Total Time (hrs): 0.6932
# ====> Epoch: 25062 Train ELBO: 261.0409 Val ELBO: 254.3813, Epoch Time (s): 0.08, Total Time (hrs): 0.6932
# ====> Epoch: 25063 Train ELBO: 261.9809 Val ELBO: 252.2578, Epoch Time (s): 0.09, Total Time (hrs): 0.6933
# ====> Epoch: 25064 Train ELBO: 261.9814 Val ELBO: 254.5099, Epoch Time (s): 0.07, Total Time (hrs): 0.6933
# ====> Epoch: 25065 Train ELBO: 262.2649 Val ELBO: 257.6402, Epoch Time (s): 0.08, Total Time (hrs): 0.6933
# ====> Epoch: 25066 Train ELBO: 263.6102 Val ELBO: 258.3714, Epoch Time (s): 0.07, Total Time (hrs): 0.6933
# ====> Epoch: 25067 Train ELBO: 263.3893 Val ELBO: 255.8487, Epoch Time (s): 0.08, Total Time (hrs): 0.6933
# ====> Epoch: 25068 Train ELBO: 263.2388 Val ELBO: 255.9640, Epoch Time (s): 0.08, Total Time (hrs): 0.6934
# ====> Epoch: 25069 Train ELBO: 262.4797 Val ELBO: 257.3546, Epoch Time (s): 0.08, Total Time (hrs): 0.6934
# ====> Epoch: 25070 Train ELBO: 262.3655 Val ELBO: 253.9711, Epoch Time (s): 0.08, Total Time (hrs): 0.6934
# ====> Epoch: 25071 Train ELBO: 261.7993 Val ELBO: 255.1087, Epoch Time (s): 0.08, Total Time (hrs): 0.6934
# ====> Epoch: 25072 Train ELBO: 262.1093 Val ELBO: 256.8040, Epoch Time (s): 0.07, Total Time (hrs): 0.6934
# ====> Epoch: 25073 Train ELBO: 262.5603 Val ELBO: 257.4842, Epoch Time (s): 0.08, Total Time (hrs): 0.6935
# ====> Epoch: 25074 Train ELBO: 262.3351 Val ELBO: 255.0855, Epoch Time (s): 0.08, Total Time (hrs): 0.6935
# ====> Epoch: 25075 Train ELBO: 263.1763 Val ELBO: 256.1339, Epoch Time (s): 0.07, Total Time (hrs): 0.6935
# ====> Epoch: 25076 Train ELBO: 262.9406 Val ELBO: 257.3382, Epoch Time (s): 0.09, Total Time (hrs): 0.6935
# ====> Epoch: 25077 Train ELBO: 263.5955 Val ELBO: 256.8703, Epoch Time (s): 0.08, Total Time (hrs): 0.6936
# ====> Epoch: 25078 Train ELBO: 263.1385 Val ELBO: 255.8032, Epoch Time (s): 0.08, Total Time (hrs): 0.6936
# ====> Epoch: 25079 Train ELBO: 262.3855 Val ELBO: 255.1001, Epoch Time (s): 0.08, Total Time (hrs): 0.6936
# ====> Epoch: 25080 Train ELBO: 263.3011 Val ELBO: 257.1193, Epoch Time (s): 0.09, Total Time (hrs): 0.6936
# ====> Epoch: 25081 Train ELBO: 264.2353 Val ELBO: 258.5791, Epoch Time (s): 0.08, Total Time (hrs): 0.6937
# ====> Epoch: 25082 Train ELBO: 264.6385 Val ELBO: 258.7202, Epoch Time (s): 0.07, Total Time (hrs): 0.6937
# ====> Epoch: 25083 Train ELBO: 263.8660 Val ELBO: 257.0549, Epoch Time (s): 0.08, Total Time (hrs): 0.6937
# ====> Epoch: 25084 Train ELBO: 261.3381 Val ELBO: 256.2217, Epoch Time (s): 0.07, Total Time (hrs): 0.6937
# ====> Epoch: 25085 Train ELBO: 261.9687 Val ELBO: 247.8450, Epoch Time (s): 0.07, Total Time (hrs): 0.6937
# ====> Epoch: 25086 Train ELBO: 259.7763 Val ELBO: 256.4380, Epoch Time (s): 0.08, Total Time (hrs): 0.6938
# ====> Epoch: 25087 Train ELBO: 261.6933 Val ELBO: 256.8543, Epoch Time (s): 0.08, Total Time (hrs): 0.6938
# ====> Epoch: 25088 Train ELBO: 264.0553 Val ELBO: 257.8401, Epoch Time (s): 0.07, Total Time (hrs): 0.6938
# ====> Epoch: 25089 Train ELBO: 264.2329 Val ELBO: 255.7614, Epoch Time (s): 0.09, Total Time (hrs): 0.6938
# ====> Epoch: 25090 Train ELBO: 262.7589 Val ELBO: 252.8041, Epoch Time (s): 0.07, Total Time (hrs): 0.6939
# ====> Epoch: 25091 Train ELBO: 261.4904 Val ELBO: 258.3440, Epoch Time (s): 0.07, Total Time (hrs): 0.6939
# ====> Epoch: 25092 Train ELBO: 261.7188 Val ELBO: 254.9591, Epoch Time (s): 0.08, Total Time (hrs): 0.6939
# ====> Epoch: 25093 Train ELBO: 262.1178 Val ELBO: 254.1480, Epoch Time (s): 0.07, Total Time (hrs): 0.6939
# ====> Epoch: 25094 Train ELBO: 260.2810 Val ELBO: 256.6503, Epoch Time (s): 0.07, Total Time (hrs): 0.6939
# ====> Epoch: 25095 Train ELBO: 261.1436 Val ELBO: 255.5847, Epoch Time (s): 0.08, Total Time (hrs): 0.6940
# ====> Epoch: 25096 Train ELBO: 261.5427 Val ELBO: 255.6842, Epoch Time (s): 0.08, Total Time (hrs): 0.6940
# ====> Epoch: 25097 Train ELBO: 258.7113 Val ELBO: 251.5304, Epoch Time (s): 0.07, Total Time (hrs): 0.6940
# ====> Epoch: 25098 Train ELBO: 261.0397 Val ELBO: 254.3734, Epoch Time (s): 0.08, Total Time (hrs): 0.6940
# ====> Epoch: 25099 Train ELBO: 258.7752 Val ELBO: 251.3241, Epoch Time (s): 0.08, Total Time (hrs): 0.6940
# ====> Epoch: 25100 Train ELBO: 256.3264 Val ELBO: 254.6957, Epoch Time (s): 0.08, Total Time (hrs): 0.6941
# ====> Epoch: 25101 Train ELBO: 256.7856 Val ELBO: 256.4164, Epoch Time (s): 0.08, Total Time (hrs): 0.6941
# ====> Epoch: 25102 Train ELBO: 261.9269 Val ELBO: 255.5609, Epoch Time (s): 0.09, Total Time (hrs): 0.6941
# ====> Epoch: 25103 Train ELBO: 262.0556 Val ELBO: 256.0522, Epoch Time (s): 0.08, Total Time (hrs): 0.6941
# ====> Epoch: 25104 Train ELBO: 262.2020 Val ELBO: 253.6726, Epoch Time (s): 0.08, Total Time (hrs): 0.6942
# ====> Epoch: 25105 Train ELBO: 261.4085 Val ELBO: 253.3206, Epoch Time (s): 0.08, Total Time (hrs): 0.6942
# ====> Epoch: 25106 Train ELBO: 261.0908 Val ELBO: 253.0228, Epoch Time (s): 0.08, Total Time (hrs): 0.6942
# ====> Epoch: 25107 Train ELBO: 260.2338 Val ELBO: 253.5889, Epoch Time (s): 0.08, Total Time (hrs): 0.6942
# ====> Epoch: 25108 Train ELBO: 261.6442 Val ELBO: 256.3217, Epoch Time (s): 0.08, Total Time (hrs): 0.6942
# ====> Epoch: 25109 Train ELBO: 262.8778 Val ELBO: 257.3922, Epoch Time (s): 0.07, Total Time (hrs): 0.6943
# ====> Epoch: 25110 Train ELBO: 263.0751 Val ELBO: 257.6609, Epoch Time (s): 0.08, Total Time (hrs): 0.6943
# ====> Epoch: 25111 Train ELBO: 263.0714 Val ELBO: 253.3461, Epoch Time (s): 0.08, Total Time (hrs): 0.6943
# ====> Epoch: 25112 Train ELBO: 263.3453 Val ELBO: 258.0449, Epoch Time (s): 0.08, Total Time (hrs): 0.6943
# ====> Epoch: 25113 Train ELBO: 263.0749 Val ELBO: 255.1891, Epoch Time (s): 0.08, Total Time (hrs): 0.6944
# ====> Epoch: 25114 Train ELBO: 262.7379 Val ELBO: 257.3566, Epoch Time (s): 0.08, Total Time (hrs): 0.6944
# ====> Epoch: 25115 Train ELBO: 262.0733 Val ELBO: 256.5445, Epoch Time (s): 0.09, Total Time (hrs): 0.6944
# ====> Epoch: 25116 Train ELBO: 263.2651 Val ELBO: 256.5966, Epoch Time (s): 0.08, Total Time (hrs): 0.6944
# ====> Epoch: 25117 Train ELBO: 262.7527 Val ELBO: 257.4459, Epoch Time (s): 0.08, Total Time (hrs): 0.6944
# ====> Epoch: 25118 Train ELBO: 262.5375 Val ELBO: 256.9460, Epoch Time (s): 0.08, Total Time (hrs): 0.6945
# ====> Epoch: 25119 Train ELBO: 263.5980 Val ELBO: 254.5924, Epoch Time (s): 0.08, Total Time (hrs): 0.6945
# ====> Epoch: 25120 Train ELBO: 262.6551 Val ELBO: 256.6761, Epoch Time (s): 0.08, Total Time (hrs): 0.6945
# ====> Epoch: 25121 Train ELBO: 263.2025 Val ELBO: 256.6633, Epoch Time (s): 0.08, Total Time (hrs): 0.6945
# ====> Epoch: 25122 Train ELBO: 262.9718 Val ELBO: 257.4215, Epoch Time (s): 0.08, Total Time (hrs): 0.6946
# ====> Epoch: 25123 Train ELBO: 262.9877 Val ELBO: 255.4987, Epoch Time (s): 0.08, Total Time (hrs): 0.6946
# ====> Epoch: 25124 Train ELBO: 262.6215 Val ELBO: 255.7756, Epoch Time (s): 0.08, Total Time (hrs): 0.6946
# ====> Epoch: 25125 Train ELBO: 260.9138 Val ELBO: 255.7896, Epoch Time (s): 0.08, Total Time (hrs): 0.6946
# ====> Epoch: 25126 Train ELBO: 262.4618 Val ELBO: 254.3546, Epoch Time (s): 0.08, Total Time (hrs): 0.6946
# ====> Epoch: 25127 Train ELBO: 261.9579 Val ELBO: 258.3942, Epoch Time (s): 0.08, Total Time (hrs): 0.6947
# ====> Epoch: 25128 Train ELBO: 261.9158 Val ELBO: 256.8913, Epoch Time (s): 0.10, Total Time (hrs): 0.6947
# ====> Epoch: 25129 Train ELBO: 261.7360 Val ELBO: 256.5186, Epoch Time (s): 0.07, Total Time (hrs): 0.6947
# ====> Epoch: 25130 Train ELBO: 262.3955 Val ELBO: 256.0762, Epoch Time (s): 0.07, Total Time (hrs): 0.6947
# ====> Epoch: 25131 Train ELBO: 262.3932 Val ELBO: 255.4341, Epoch Time (s): 0.08, Total Time (hrs): 0.6948
# ====> Epoch: 25132 Train ELBO: 256.5839 Val ELBO: 251.1599, Epoch Time (s): 0.07, Total Time (hrs): 0.6948
# ====> Epoch: 25133 Train ELBO: 251.9860 Val ELBO: 250.0367, Epoch Time (s): 0.08, Total Time (hrs): 0.6948
# ====> Epoch: 25134 Train ELBO: 250.4270 Val ELBO: 249.6637, Epoch Time (s): 0.08, Total Time (hrs): 0.6948
# ====> Epoch: 25135 Train ELBO: 249.0849 Val ELBO: 250.7629, Epoch Time (s): 0.08, Total Time (hrs): 0.6948
# ====> Epoch: 25136 Train ELBO: 257.4824 Val ELBO: 250.9764, Epoch Time (s): 0.09, Total Time (hrs): 0.6949
# ====> Epoch: 25137 Train ELBO: 258.9221 Val ELBO: 253.8035, Epoch Time (s): 0.09, Total Time (hrs): 0.6949
# ====> Epoch: 25138 Train ELBO: 260.8628 Val ELBO: 253.2097, Epoch Time (s): 0.07, Total Time (hrs): 0.6949
# ====> Epoch: 25139 Train ELBO: 260.0765 Val ELBO: 250.2250, Epoch Time (s): 0.08, Total Time (hrs): 0.6949
# ====> Epoch: 25140 Train ELBO: 258.7378 Val ELBO: 251.4016, Epoch Time (s): 0.08, Total Time (hrs): 0.6950
# ====> Epoch: 25141 Train ELBO: 261.0860 Val ELBO: 254.9185, Epoch Time (s): 0.09, Total Time (hrs): 0.6950
# ====> Epoch: 25142 Train ELBO: 259.6068 Val ELBO: 251.7165, Epoch Time (s): 0.08, Total Time (hrs): 0.6950
# ====> Epoch: 25143 Train ELBO: 259.1108 Val ELBO: 256.4219, Epoch Time (s): 0.08, Total Time (hrs): 0.6950
# ====> Epoch: 25144 Train ELBO: 258.6558 Val ELBO: 244.5328, Epoch Time (s): 0.08, Total Time (hrs): 0.6950
# ====> Epoch: 25145 Train ELBO: 257.6995 Val ELBO: 252.8026, Epoch Time (s): 0.08, Total Time (hrs): 0.6951
# ====> Epoch: 25146 Train ELBO: 258.0696 Val ELBO: 255.3813, Epoch Time (s): 0.08, Total Time (hrs): 0.6951
# ====> Epoch: 25147 Train ELBO: 260.5424 Val ELBO: 255.5773, Epoch Time (s): 0.07, Total Time (hrs): 0.6951
# ====> Epoch: 25148 Train ELBO: 262.0386 Val ELBO: 254.9422, Epoch Time (s): 0.09, Total Time (hrs): 0.6951
# ====> Epoch: 25149 Train ELBO: 261.8328 Val ELBO: 255.4802, Epoch Time (s): 0.13, Total Time (hrs): 0.6952
# ====> Epoch: 25150 Train ELBO: 261.6799 Val ELBO: 255.0016, Epoch Time (s): 0.11, Total Time (hrs): 0.6952
# ====> Epoch: 25151 Train ELBO: 261.0770 Val ELBO: 254.8598, Epoch Time (s): 0.12, Total Time (hrs): 0.6952
# ====> Epoch: 25152 Train ELBO: 260.8760 Val ELBO: 256.1277, Epoch Time (s): 0.12, Total Time (hrs): 0.6953
# ====> Epoch: 25153 Train ELBO: 261.4799 Val ELBO: 254.1776, Epoch Time (s): 0.11, Total Time (hrs): 0.6953
# ====> Epoch: 25154 Train ELBO: 261.9103 Val ELBO: 258.7147, Epoch Time (s): 0.11, Total Time (hrs): 0.6953
# ====> Epoch: 25155 Train ELBO: 260.9192 Val ELBO: 249.2336, Epoch Time (s): 0.11, Total Time (hrs): 0.6954
# ====> Epoch: 25156 Train ELBO: 253.6739 Val ELBO: 242.9006, Epoch Time (s): 0.11, Total Time (hrs): 0.6954
# ====> Epoch: 25157 Train ELBO: 252.3458 Val ELBO: 240.7698, Epoch Time (s): 0.11, Total Time (hrs): 0.6954
# ====> Epoch: 25158 Train ELBO: 249.2521 Val ELBO: 245.4093, Epoch Time (s): 0.11, Total Time (hrs): 0.6954
# ====> Epoch: 25159 Train ELBO: 249.7951 Val ELBO: 246.0139, Epoch Time (s): 0.11, Total Time (hrs): 0.6955
# ====> Epoch: 25160 Train ELBO: 251.8554 Val ELBO: 250.1870, Epoch Time (s): 0.11, Total Time (hrs): 0.6955
# ====> Epoch: 25161 Train ELBO: 257.2532 Val ELBO: 256.1569, Epoch Time (s): 0.12, Total Time (hrs): 0.6955
# ====> Epoch: 25162 Train ELBO: 260.4593 Val ELBO: 250.7701, Epoch Time (s): 0.11, Total Time (hrs): 0.6956
# ====> Epoch: 25163 Train ELBO: 258.8997 Val ELBO: 256.0195, Epoch Time (s): 0.12, Total Time (hrs): 0.6956
# ====> Epoch: 25164 Train ELBO: 261.4891 Val ELBO: 257.2684, Epoch Time (s): 0.11, Total Time (hrs): 0.6956
# ====> Epoch: 25165 Train ELBO: 262.0210 Val ELBO: 256.5372, Epoch Time (s): 0.11, Total Time (hrs): 0.6957
# ====> Epoch: 25166 Train ELBO: 262.8305 Val ELBO: 256.8877, Epoch Time (s): 0.11, Total Time (hrs): 0.6957
# ====> Epoch: 25167 Train ELBO: 263.3307 Val ELBO: 256.2131, Epoch Time (s): 0.11, Total Time (hrs): 0.6957
# ====> Epoch: 25168 Train ELBO: 260.6845 Val ELBO: 256.0204, Epoch Time (s): 0.12, Total Time (hrs): 0.6958
# ====> Epoch: 25169 Train ELBO: 261.2485 Val ELBO: 253.1994, Epoch Time (s): 0.12, Total Time (hrs): 0.6958
# ====> Epoch: 25170 Train ELBO: 262.0798 Val ELBO: 255.2968, Epoch Time (s): 0.13, Total Time (hrs): 0.6958
# ====> Epoch: 25171 Train ELBO: 261.7716 Val ELBO: 256.6624, Epoch Time (s): 0.14, Total Time (hrs): 0.6959
# ====> Epoch: 25172 Train ELBO: 262.1461 Val ELBO: 256.1396, Epoch Time (s): 0.12, Total Time (hrs): 0.6959
# ====> Epoch: 25173 Train ELBO: 262.5898 Val ELBO: 254.0089, Epoch Time (s): 0.12, Total Time (hrs): 0.6959
# ====> Epoch: 25174 Train ELBO: 262.4526 Val ELBO: 258.0675, Epoch Time (s): 0.13, Total Time (hrs): 0.6960
# ====> Epoch: 25175 Train ELBO: 263.5754 Val ELBO: 258.1667, Epoch Time (s): 0.12, Total Time (hrs): 0.6960
# ====> Epoch: 25176 Train ELBO: 263.4859 Val ELBO: 253.9959, Epoch Time (s): 0.08, Total Time (hrs): 0.6960
# ====> Epoch: 25177 Train ELBO: 263.1959 Val ELBO: 258.2982, Epoch Time (s): 0.08, Total Time (hrs): 0.6961
# ====> Epoch: 25178 Train ELBO: 263.9283 Val ELBO: 258.0266, Epoch Time (s): 0.08, Total Time (hrs): 0.6961
# ====> Epoch: 25179 Train ELBO: 262.2669 Val ELBO: 255.8365, Epoch Time (s): 0.07, Total Time (hrs): 0.6961
# ====> Epoch: 25180 Train ELBO: 261.0957 Val ELBO: 257.4526, Epoch Time (s): 0.08, Total Time (hrs): 0.6961
# ====> Epoch: 25181 Train ELBO: 260.7087 Val ELBO: 255.0863, Epoch Time (s): 0.10, Total Time (hrs): 0.6961
# ====> Epoch: 25182 Train ELBO: 262.0482 Val ELBO: 256.9760, Epoch Time (s): 0.08, Total Time (hrs): 0.6962
# ====> Epoch: 25183 Train ELBO: 262.7077 Val ELBO: 256.6457, Epoch Time (s): 0.08, Total Time (hrs): 0.6962
# ====> Epoch: 25184 Train ELBO: 263.1398 Val ELBO: 258.5768, Epoch Time (s): 0.08, Total Time (hrs): 0.6962
# ====> Epoch: 25185 Train ELBO: 263.8878 Val ELBO: 257.5997, Epoch Time (s): 0.07, Total Time (hrs): 0.6962
# ====> Epoch: 25186 Train ELBO: 263.5934 Val ELBO: 257.0292, Epoch Time (s): 0.08, Total Time (hrs): 0.6963
# ====> Epoch: 25187 Train ELBO: 263.3552 Val ELBO: 256.4213, Epoch Time (s): 0.08, Total Time (hrs): 0.6963
# ====> Epoch: 25188 Train ELBO: 262.8684 Val ELBO: 257.7667, Epoch Time (s): 0.08, Total Time (hrs): 0.6963
# ====> Epoch: 25189 Train ELBO: 262.9464 Val ELBO: 256.4255, Epoch Time (s): 0.08, Total Time (hrs): 0.6963
# ====> Epoch: 25190 Train ELBO: 262.1425 Val ELBO: 255.0888, Epoch Time (s): 0.08, Total Time (hrs): 0.6963
# ====> Epoch: 25191 Train ELBO: 261.0340 Val ELBO: 258.3463, Epoch Time (s): 0.07, Total Time (hrs): 0.6964
# ====> Epoch: 25192 Train ELBO: 260.3400 Val ELBO: 255.5237, Epoch Time (s): 0.08, Total Time (hrs): 0.6964
# ====> Epoch: 25193 Train ELBO: 260.6175 Val ELBO: 249.8140, Epoch Time (s): 0.08, Total Time (hrs): 0.6964
# ====> Epoch: 25194 Train ELBO: 259.5603 Val ELBO: 249.5656, Epoch Time (s): 0.09, Total Time (hrs): 0.6964
# ====> Epoch: 25195 Train ELBO: 261.5643 Val ELBO: 258.7521, Epoch Time (s): 0.08, Total Time (hrs): 0.6964
# ====> Epoch: 25196 Train ELBO: 263.3714 Val ELBO: 257.8223, Epoch Time (s): 0.08, Total Time (hrs): 0.6965
# ====> Epoch: 25197 Train ELBO: 263.6540 Val ELBO: 258.2906, Epoch Time (s): 0.07, Total Time (hrs): 0.6965
# ====> Epoch: 25198 Train ELBO: 263.8859 Val ELBO: 259.4406, Epoch Time (s): 0.08, Total Time (hrs): 0.6965
# ====> Epoch: 25199 Train ELBO: 263.9277 Val ELBO: 257.8366, Epoch Time (s): 0.08, Total Time (hrs): 0.6965
# ====> Epoch: 25200 Train ELBO: 264.3060 Val ELBO: 256.7709, Epoch Time (s): 0.08, Total Time (hrs): 0.6966
# ====> Epoch: 25201 Train ELBO: 262.1344 Val ELBO: 255.8920, Epoch Time (s): 0.07, Total Time (hrs): 0.6966
# ====> Epoch: 25202 Train ELBO: 259.7481 Val ELBO: 253.3852, Epoch Time (s): 0.08, Total Time (hrs): 0.6966
# ====> Epoch: 25203 Train ELBO: 262.4777 Val ELBO: 256.5084, Epoch Time (s): 0.08, Total Time (hrs): 0.6966
# ====> Epoch: 25204 Train ELBO: 263.5733 Val ELBO: 257.5644, Epoch Time (s): 0.07, Total Time (hrs): 0.6966
# ====> Epoch: 25205 Train ELBO: 263.6459 Val ELBO: 256.3501, Epoch Time (s): 0.08, Total Time (hrs): 0.6967
# ====> Epoch: 25206 Train ELBO: 262.7569 Val ELBO: 257.5143, Epoch Time (s): 0.07, Total Time (hrs): 0.6967
# ====> Epoch: 25207 Train ELBO: 263.8792 Val ELBO: 255.2614, Epoch Time (s): 0.09, Total Time (hrs): 0.6967
# ====> Epoch: 25208 Train ELBO: 262.8722 Val ELBO: 252.9923, Epoch Time (s): 0.08, Total Time (hrs): 0.6967
# ====> Epoch: 25209 Train ELBO: 258.9399 Val ELBO: 251.9637, Epoch Time (s): 0.07, Total Time (hrs): 0.6968
# ====> Epoch: 25210 Train ELBO: 260.1711 Val ELBO: 251.9490, Epoch Time (s): 0.07, Total Time (hrs): 0.6968
# ====> Epoch: 25211 Train ELBO: 259.3381 Val ELBO: 252.5988, Epoch Time (s): 0.08, Total Time (hrs): 0.6968
# ====> Epoch: 25212 Train ELBO: 260.5949 Val ELBO: 252.4744, Epoch Time (s): 0.08, Total Time (hrs): 0.6968
# ====> Epoch: 25213 Train ELBO: 259.1299 Val ELBO: 254.5563, Epoch Time (s): 0.07, Total Time (hrs): 0.6968
# ====> Epoch: 25214 Train ELBO: 259.9043 Val ELBO: 255.2362, Epoch Time (s): 0.08, Total Time (hrs): 0.6969
# ====> Epoch: 25215 Train ELBO: 262.0916 Val ELBO: 257.4396, Epoch Time (s): 0.07, Total Time (hrs): 0.6969
# ====> Epoch: 25216 Train ELBO: 262.4654 Val ELBO: 255.6086, Epoch Time (s): 0.08, Total Time (hrs): 0.6969
# ====> Epoch: 25217 Train ELBO: 255.8525 Val ELBO: 234.7039, Epoch Time (s): 0.11, Total Time (hrs): 0.6969
# ====> Epoch: 25218 Train ELBO: 254.1459 Val ELBO: 237.3171, Epoch Time (s): 0.08, Total Time (hrs): 0.6970
# ====> Epoch: 25219 Train ELBO: 250.4230 Val ELBO: 231.6335, Epoch Time (s): 0.08, Total Time (hrs): 0.6970
# ====> Epoch: 25220 Train ELBO: 249.1429 Val ELBO: 241.2621, Epoch Time (s): 0.10, Total Time (hrs): 0.6970
# ====> Epoch: 25221 Train ELBO: 244.4939 Val ELBO: 222.7179, Epoch Time (s): 0.07, Total Time (hrs): 0.6970
# ====> Epoch: 25222 Train ELBO: 249.6003 Val ELBO: 244.8959, Epoch Time (s): 0.08, Total Time (hrs): 0.6970
# ====> Epoch: 25223 Train ELBO: 258.0582 Val ELBO: 253.4554, Epoch Time (s): 0.08, Total Time (hrs): 0.6971
# ====> Epoch: 25224 Train ELBO: 261.3764 Val ELBO: 253.9625, Epoch Time (s): 0.08, Total Time (hrs): 0.6971
# ====> Epoch: 25225 Train ELBO: 262.5111 Val ELBO: 256.7464, Epoch Time (s): 0.07, Total Time (hrs): 0.6971
# ====> Epoch: 25226 Train ELBO: 263.3622 Val ELBO: 257.3807, Epoch Time (s): 0.08, Total Time (hrs): 0.6971
# ====> Epoch: 25227 Train ELBO: 263.1438 Val ELBO: 255.5115, Epoch Time (s): 0.08, Total Time (hrs): 0.6972
# ====> Epoch: 25228 Train ELBO: 263.7527 Val ELBO: 256.6385, Epoch Time (s): 0.08, Total Time (hrs): 0.6972
# ====> Epoch: 25229 Train ELBO: 263.8764 Val ELBO: 256.3789, Epoch Time (s): 0.08, Total Time (hrs): 0.6972
# ====> Epoch: 25230 Train ELBO: 262.3898 Val ELBO: 254.2051, Epoch Time (s): 0.08, Total Time (hrs): 0.6972
# ====> Epoch: 25231 Train ELBO: 261.9039 Val ELBO: 256.9212, Epoch Time (s): 0.08, Total Time (hrs): 0.6972
# ====> Epoch: 25232 Train ELBO: 263.0296 Val ELBO: 256.3208, Epoch Time (s): 0.08, Total Time (hrs): 0.6973
# ====> Epoch: 25233 Train ELBO: 263.0413 Val ELBO: 256.0117, Epoch Time (s): 0.09, Total Time (hrs): 0.6973
# ====> Epoch: 25234 Train ELBO: 262.7617 Val ELBO: 254.0328, Epoch Time (s): 0.07, Total Time (hrs): 0.6973
# ====> Epoch: 25235 Train ELBO: 261.9000 Val ELBO: 256.1112, Epoch Time (s): 0.08, Total Time (hrs): 0.6973
# ====> Epoch: 25236 Train ELBO: 261.6573 Val ELBO: 253.5552, Epoch Time (s): 0.08, Total Time (hrs): 0.6974
# ====> Epoch: 25237 Train ELBO: 261.4843 Val ELBO: 255.7931, Epoch Time (s): 0.08, Total Time (hrs): 0.6974
# ====> Epoch: 25238 Train ELBO: 262.3487 Val ELBO: 255.3696, Epoch Time (s): 0.08, Total Time (hrs): 0.6974
# ====> Epoch: 25239 Train ELBO: 263.4194 Val ELBO: 258.5067, Epoch Time (s): 0.08, Total Time (hrs): 0.6974
# ====> Epoch: 25240 Train ELBO: 264.0943 Val ELBO: 258.4391, Epoch Time (s): 0.07, Total Time (hrs): 0.6974
# ====> Epoch: 25241 Train ELBO: 264.0414 Val ELBO: 258.0741, Epoch Time (s): 0.08, Total Time (hrs): 0.6975
# ====> Epoch: 25242 Train ELBO: 263.5151 Val ELBO: 256.6502, Epoch Time (s): 0.07, Total Time (hrs): 0.6975
# ====> Epoch: 25243 Train ELBO: 263.7530 Val ELBO: 256.9763, Epoch Time (s): 0.08, Total Time (hrs): 0.6975
# ====> Epoch: 25244 Train ELBO: 261.9877 Val ELBO: 257.8410, Epoch Time (s): 0.08, Total Time (hrs): 0.6975
# ====> Epoch: 25245 Train ELBO: 262.2035 Val ELBO: 256.4384, Epoch Time (s): 0.08, Total Time (hrs): 0.6975
# ====> Epoch: 25246 Train ELBO: 261.3837 Val ELBO: 255.7086, Epoch Time (s): 0.08, Total Time (hrs): 0.6976
# ====> Epoch: 25247 Train ELBO: 262.3945 Val ELBO: 254.7619, Epoch Time (s): 0.10, Total Time (hrs): 0.6976
# ====> Epoch: 25248 Train ELBO: 258.8224 Val ELBO: 257.2734, Epoch Time (s): 0.07, Total Time (hrs): 0.6976
# ====> Epoch: 25249 Train ELBO: 258.5819 Val ELBO: 253.3921, Epoch Time (s): 0.08, Total Time (hrs): 0.6976
# ====> Epoch: 25250 Train ELBO: 258.7032 Val ELBO: 255.7120, Epoch Time (s): 0.08, Total Time (hrs): 0.6977
# ====> Epoch: 25251 Train ELBO: 258.6861 Val ELBO: 249.9337, Epoch Time (s): 0.08, Total Time (hrs): 0.6977
# ====> Epoch: 25252 Train ELBO: 256.7812 Val ELBO: 255.2379, Epoch Time (s): 0.07, Total Time (hrs): 0.6977
# ====> Epoch: 25253 Train ELBO: 258.9889 Val ELBO: 254.3011, Epoch Time (s): 0.08, Total Time (hrs): 0.6977
# ====> Epoch: 25254 Train ELBO: 260.2068 Val ELBO: 254.9335, Epoch Time (s): 0.07, Total Time (hrs): 0.6977
# ====> Epoch: 25255 Train ELBO: 263.2065 Val ELBO: 255.5325, Epoch Time (s): 0.08, Total Time (hrs): 0.6978
# ====> Epoch: 25256 Train ELBO: 262.8734 Val ELBO: 256.4125, Epoch Time (s): 0.08, Total Time (hrs): 0.6978
# ====> Epoch: 25257 Train ELBO: 263.2597 Val ELBO: 257.6343, Epoch Time (s): 0.08, Total Time (hrs): 0.6978
# ====> Epoch: 25258 Train ELBO: 263.2735 Val ELBO: 257.0603, Epoch Time (s): 0.07, Total Time (hrs): 0.6978
# ====> Epoch: 25259 Train ELBO: 263.5193 Val ELBO: 254.5107, Epoch Time (s): 0.08, Total Time (hrs): 0.6979
# ====> Epoch: 25260 Train ELBO: 259.5331 Val ELBO: 256.0275, Epoch Time (s): 0.09, Total Time (hrs): 0.6979
# ====> Epoch: 25261 Train ELBO: 258.9195 Val ELBO: 254.2194, Epoch Time (s): 0.07, Total Time (hrs): 0.6979
# ====> Epoch: 25262 Train ELBO: 259.8660 Val ELBO: 256.0732, Epoch Time (s): 0.09, Total Time (hrs): 0.6979
# ====> Epoch: 25263 Train ELBO: 260.9802 Val ELBO: 256.3842, Epoch Time (s): 0.07, Total Time (hrs): 0.6979
# ====> Epoch: 25264 Train ELBO: 262.2530 Val ELBO: 253.3580, Epoch Time (s): 0.08, Total Time (hrs): 0.6980
# ====> Epoch: 25265 Train ELBO: 260.2210 Val ELBO: 256.5178, Epoch Time (s): 0.08, Total Time (hrs): 0.6980
# ====> Epoch: 25266 Train ELBO: 261.6022 Val ELBO: 256.0489, Epoch Time (s): 0.08, Total Time (hrs): 0.6980
# ====> Epoch: 25267 Train ELBO: 262.7750 Val ELBO: 257.9383, Epoch Time (s): 0.07, Total Time (hrs): 0.6980
# ====> Epoch: 25268 Train ELBO: 264.2359 Val ELBO: 257.9546, Epoch Time (s): 0.08, Total Time (hrs): 0.6981
# ====> Epoch: 25269 Train ELBO: 264.1453 Val ELBO: 257.2672, Epoch Time (s): 0.08, Total Time (hrs): 0.6981
# ====> Epoch: 25270 Train ELBO: 263.8954 Val ELBO: 256.6208, Epoch Time (s): 0.07, Total Time (hrs): 0.6981
# ====> Epoch: 25271 Train ELBO: 263.1494 Val ELBO: 256.3013, Epoch Time (s): 0.08, Total Time (hrs): 0.6981
# ====> Epoch: 25272 Train ELBO: 262.7416 Val ELBO: 257.2028, Epoch Time (s): 0.08, Total Time (hrs): 0.6981
# ====> Epoch: 25273 Train ELBO: 263.2368 Val ELBO: 256.9001, Epoch Time (s): 0.08, Total Time (hrs): 0.6982
# ====> Epoch: 25274 Train ELBO: 262.4924 Val ELBO: 256.1213, Epoch Time (s): 0.08, Total Time (hrs): 0.6982
# ====> Epoch: 25275 Train ELBO: 262.8596 Val ELBO: 255.5773, Epoch Time (s): 0.08, Total Time (hrs): 0.6982
# ====> Epoch: 25276 Train ELBO: 262.8276 Val ELBO: 252.3572, Epoch Time (s): 0.08, Total Time (hrs): 0.6982
# ====> Epoch: 25277 Train ELBO: 256.7527 Val ELBO: 252.2515, Epoch Time (s): 0.08, Total Time (hrs): 0.6983
# ====> Epoch: 25278 Train ELBO: 260.8867 Val ELBO: 254.5021, Epoch Time (s): 0.07, Total Time (hrs): 0.6983
# ====> Epoch: 25279 Train ELBO: 258.5464 Val ELBO: 229.2756, Epoch Time (s): 0.08, Total Time (hrs): 0.6983
# ====> Epoch: 25280 Train ELBO: 253.4027 Val ELBO: 254.9111, Epoch Time (s): 0.08, Total Time (hrs): 0.6983
# ====> Epoch: 25281 Train ELBO: 261.6121 Val ELBO: 251.6266, Epoch Time (s): 0.08, Total Time (hrs): 0.6983
# ====> Epoch: 25282 Train ELBO: 261.5476 Val ELBO: 257.4622, Epoch Time (s): 0.07, Total Time (hrs): 0.6984
# ====> Epoch: 25283 Train ELBO: 261.9147 Val ELBO: 257.5940, Epoch Time (s): 0.08, Total Time (hrs): 0.6984
# ====> Epoch: 25284 Train ELBO: 263.3003 Val ELBO: 257.4654, Epoch Time (s): 0.07, Total Time (hrs): 0.6984
# ====> Epoch: 25285 Train ELBO: 262.9179 Val ELBO: 256.9817, Epoch Time (s): 0.07, Total Time (hrs): 0.6984
# ====> Epoch: 25286 Train ELBO: 263.1839 Val ELBO: 257.8006, Epoch Time (s): 0.10, Total Time (hrs): 0.6985
# ====> Epoch: 25287 Train ELBO: 263.8061 Val ELBO: 257.5609, Epoch Time (s): 0.08, Total Time (hrs): 0.6985
# ====> Epoch: 25288 Train ELBO: 264.1417 Val ELBO: 257.0034, Epoch Time (s): 0.07, Total Time (hrs): 0.6985
# ====> Epoch: 25289 Train ELBO: 263.6469 Val ELBO: 257.9930, Epoch Time (s): 0.08, Total Time (hrs): 0.6985
# ====> Epoch: 25290 Train ELBO: 262.6693 Val ELBO: 257.3386, Epoch Time (s): 0.08, Total Time (hrs): 0.6985
# ====> Epoch: 25291 Train ELBO: 262.8780 Val ELBO: 258.6151, Epoch Time (s): 0.08, Total Time (hrs): 0.6986
# ====> Epoch: 25292 Train ELBO: 262.3749 Val ELBO: 256.4349, Epoch Time (s): 0.08, Total Time (hrs): 0.6986
# ====> Epoch: 25293 Train ELBO: 262.0530 Val ELBO: 254.3886, Epoch Time (s): 0.08, Total Time (hrs): 0.6986
# ====> Epoch: 25294 Train ELBO: 260.9918 Val ELBO: 256.8055, Epoch Time (s): 0.08, Total Time (hrs): 0.6986
# ====> Epoch: 25295 Train ELBO: 261.8808 Val ELBO: 255.3914, Epoch Time (s): 0.08, Total Time (hrs): 0.6986
# ====> Epoch: 25296 Train ELBO: 263.2602 Val ELBO: 259.0409, Epoch Time (s): 0.07, Total Time (hrs): 0.6987
# ====> Epoch: 25297 Train ELBO: 264.3967 Val ELBO: 255.7449, Epoch Time (s): 0.08, Total Time (hrs): 0.6987
# ====> Epoch: 25298 Train ELBO: 263.0720 Val ELBO: 258.4484, Epoch Time (s): 0.09, Total Time (hrs): 0.6987
# ====> Epoch: 25299 Train ELBO: 262.7091 Val ELBO: 257.0748, Epoch Time (s): 0.09, Total Time (hrs): 0.6987
# ====> Epoch: 25300 Train ELBO: 262.2111 Val ELBO: 255.8682, Epoch Time (s): 0.08, Total Time (hrs): 0.6988
# ====> Epoch: 25301 Train ELBO: 262.6135 Val ELBO: 257.9655, Epoch Time (s): 0.08, Total Time (hrs): 0.6988
# ====> Epoch: 25302 Train ELBO: 263.5554 Val ELBO: 259.2154, Epoch Time (s): 0.12, Total Time (hrs): 0.6988
# ====> Epoch: 25303 Train ELBO: 262.6398 Val ELBO: 257.6904, Epoch Time (s): 0.12, Total Time (hrs): 0.6989
# ====> Epoch: 25304 Train ELBO: 263.0261 Val ELBO: 256.6166, Epoch Time (s): 0.11, Total Time (hrs): 0.6989
# ====> Epoch: 25305 Train ELBO: 261.9369 Val ELBO: 256.6691, Epoch Time (s): 0.11, Total Time (hrs): 0.6989
# ====> Epoch: 25306 Train ELBO: 261.0735 Val ELBO: 254.7785, Epoch Time (s): 0.11, Total Time (hrs): 0.6989
# ====> Epoch: 25307 Train ELBO: 261.4135 Val ELBO: 256.6435, Epoch Time (s): 0.12, Total Time (hrs): 0.6990
# ====> Epoch: 25308 Train ELBO: 263.3546 Val ELBO: 257.5307, Epoch Time (s): 0.11, Total Time (hrs): 0.6990
# ====> Epoch: 25309 Train ELBO: 262.8339 Val ELBO: 256.7921, Epoch Time (s): 0.12, Total Time (hrs): 0.6990
# ====> Epoch: 25310 Train ELBO: 261.2330 Val ELBO: 250.3180, Epoch Time (s): 0.10, Total Time (hrs): 0.6991
# ====> Epoch: 25311 Train ELBO: 260.9943 Val ELBO: 252.4183, Epoch Time (s): 0.12, Total Time (hrs): 0.6991
# ====> Epoch: 25312 Train ELBO: 258.5006 Val ELBO: 246.9340, Epoch Time (s): 0.11, Total Time (hrs): 0.6991
# ====> Epoch: 25313 Train ELBO: 259.5074 Val ELBO: 248.8499, Epoch Time (s): 0.11, Total Time (hrs): 0.6992
# ====> Epoch: 25314 Train ELBO: 259.9975 Val ELBO: 246.8641, Epoch Time (s): 0.11, Total Time (hrs): 0.6992
# ====> Epoch: 25315 Train ELBO: 259.0841 Val ELBO: 250.7224, Epoch Time (s): 0.11, Total Time (hrs): 0.6992
# ====> Epoch: 25316 Train ELBO: 258.7815 Val ELBO: 256.7452, Epoch Time (s): 0.11, Total Time (hrs): 0.6993
# ====> Epoch: 25317 Train ELBO: 260.3151 Val ELBO: 258.8845, Epoch Time (s): 0.12, Total Time (hrs): 0.6993
# ====> Epoch: 25318 Train ELBO: 262.9462 Val ELBO: 257.2823, Epoch Time (s): 0.12, Total Time (hrs): 0.6993
# ====> Epoch: 25319 Train ELBO: 263.2285 Val ELBO: 255.9032, Epoch Time (s): 0.12, Total Time (hrs): 0.6994
# ====> Epoch: 25320 Train ELBO: 263.8050 Val ELBO: 256.7390, Epoch Time (s): 0.10, Total Time (hrs): 0.6994
# ====> Epoch: 25321 Train ELBO: 263.8106 Val ELBO: 258.7181, Epoch Time (s): 0.13, Total Time (hrs): 0.6994
# ====> Epoch: 25322 Train ELBO: 263.8344 Val ELBO: 255.3394, Epoch Time (s): 0.12, Total Time (hrs): 0.6995
# ====> Epoch: 25323 Train ELBO: 262.5135 Val ELBO: 256.4930, Epoch Time (s): 0.13, Total Time (hrs): 0.6995
# ====> Epoch: 25324 Train ELBO: 262.5839 Val ELBO: 258.1519, Epoch Time (s): 0.11, Total Time (hrs): 0.6995
# ====> Epoch: 25325 Train ELBO: 263.7214 Val ELBO: 257.2896, Epoch Time (s): 0.12, Total Time (hrs): 0.6996
# ====> Epoch: 25326 Train ELBO: 263.1244 Val ELBO: 257.2619, Epoch Time (s): 0.12, Total Time (hrs): 0.6996
# ====> Epoch: 25327 Train ELBO: 262.0972 Val ELBO: 254.4779, Epoch Time (s): 0.15, Total Time (hrs): 0.6996
# ====> Epoch: 25328 Train ELBO: 259.8069 Val ELBO: 254.8258, Epoch Time (s): 0.10, Total Time (hrs): 0.6997
# ====> Epoch: 25329 Train ELBO: 260.9253 Val ELBO: 248.4937, Epoch Time (s): 0.08, Total Time (hrs): 0.6997
# ====> Epoch: 25330 Train ELBO: 258.2149 Val ELBO: 257.5175, Epoch Time (s): 0.08, Total Time (hrs): 0.6997
# ====> Epoch: 25331 Train ELBO: 258.6947 Val ELBO: 256.4840, Epoch Time (s): 0.08, Total Time (hrs): 0.6997
# ====> Epoch: 25332 Train ELBO: 259.3722 Val ELBO: 256.1073, Epoch Time (s): 0.07, Total Time (hrs): 0.6997
# ====> Epoch: 25333 Train ELBO: 261.5181 Val ELBO: 254.2856, Epoch Time (s): 0.08, Total Time (hrs): 0.6998
# ====> Epoch: 25334 Train ELBO: 259.7673 Val ELBO: 254.5245, Epoch Time (s): 0.08, Total Time (hrs): 0.6998
# ====> Epoch: 25335 Train ELBO: 260.9384 Val ELBO: 254.2255, Epoch Time (s): 0.08, Total Time (hrs): 0.6998
# ====> Epoch: 25336 Train ELBO: 262.3831 Val ELBO: 258.2189, Epoch Time (s): 0.08, Total Time (hrs): 0.6998
# ====> Epoch: 25337 Train ELBO: 262.5661 Val ELBO: 254.6667, Epoch Time (s): 0.08, Total Time (hrs): 0.6999
# ====> Epoch: 25338 Train ELBO: 261.3464 Val ELBO: 254.2523, Epoch Time (s): 0.08, Total Time (hrs): 0.6999
# ====> Epoch: 25339 Train ELBO: 262.1402 Val ELBO: 256.2002, Epoch Time (s): 0.09, Total Time (hrs): 0.6999
# ====> Epoch: 25340 Train ELBO: 263.4327 Val ELBO: 258.6476, Epoch Time (s): 0.08, Total Time (hrs): 0.6999
# ====> Epoch: 25341 Train ELBO: 263.4520 Val ELBO: 250.4327, Epoch Time (s): 0.07, Total Time (hrs): 0.7000
# ====> Epoch: 25342 Train ELBO: 261.0527 Val ELBO: 256.6799, Epoch Time (s): 0.08, Total Time (hrs): 0.7000
# ====> Epoch: 25343 Train ELBO: 263.0716 Val ELBO: 255.0893, Epoch Time (s): 0.07, Total Time (hrs): 0.7000
# ====> Epoch: 25344 Train ELBO: 261.3702 Val ELBO: 252.9529, Epoch Time (s): 0.07, Total Time (hrs): 0.7000
# ====> Epoch: 25345 Train ELBO: 261.8702 Val ELBO: 256.9980, Epoch Time (s): 0.08, Total Time (hrs): 0.7000
# ====> Epoch: 25346 Train ELBO: 262.4435 Val ELBO: 254.6284, Epoch Time (s): 0.08, Total Time (hrs): 0.7001
# ====> Epoch: 25347 Train ELBO: 262.6516 Val ELBO: 254.7463, Epoch Time (s): 0.08, Total Time (hrs): 0.7001
# ====> Epoch: 25348 Train ELBO: 263.2103 Val ELBO: 255.8627, Epoch Time (s): 0.08, Total Time (hrs): 0.7001
# ====> Epoch: 25349 Train ELBO: 262.7845 Val ELBO: 255.9428, Epoch Time (s): 0.08, Total Time (hrs): 0.7001
# ====> Epoch: 25350 Train ELBO: 261.5107 Val ELBO: 254.3379, Epoch Time (s): 0.08, Total Time (hrs): 0.7001
# ====> Epoch: 25351 Train ELBO: 260.9770 Val ELBO: 250.7600, Epoch Time (s): 0.08, Total Time (hrs): 0.7002
# ====> Epoch: 25352 Train ELBO: 249.0630 Val ELBO: 235.2113, Epoch Time (s): 0.08, Total Time (hrs): 0.7002
# ====> Epoch: 25353 Train ELBO: 254.6097 Val ELBO: 249.4373, Epoch Time (s): 0.08, Total Time (hrs): 0.7002
# ====> Epoch: 25354 Train ELBO: 258.6090 Val ELBO: 251.7322, Epoch Time (s): 0.08, Total Time (hrs): 0.7002
# ====> Epoch: 25355 Train ELBO: 256.6702 Val ELBO: 257.8491, Epoch Time (s): 0.08, Total Time (hrs): 0.7003
# ====> Epoch: 25356 Train ELBO: 259.7685 Val ELBO: 256.1984, Epoch Time (s): 0.08, Total Time (hrs): 0.7003
# ====> Epoch: 25357 Train ELBO: 261.3032 Val ELBO: 254.7120, Epoch Time (s): 0.08, Total Time (hrs): 0.7003
# ====> Epoch: 25358 Train ELBO: 261.0723 Val ELBO: 254.4695, Epoch Time (s): 0.08, Total Time (hrs): 0.7003
# ====> Epoch: 25359 Train ELBO: 262.1982 Val ELBO: 254.9518, Epoch Time (s): 0.08, Total Time (hrs): 0.7003
# ====> Epoch: 25360 Train ELBO: 262.3675 Val ELBO: 254.7494, Epoch Time (s): 0.08, Total Time (hrs): 0.7004
# ====> Epoch: 25361 Train ELBO: 263.1475 Val ELBO: 257.3072, Epoch Time (s): 0.07, Total Time (hrs): 0.7004
# ====> Epoch: 25362 Train ELBO: 262.9980 Val ELBO: 251.1070, Epoch Time (s): 0.08, Total Time (hrs): 0.7004
# ====> Epoch: 25363 Train ELBO: 261.5258 Val ELBO: 257.9132, Epoch Time (s): 0.09, Total Time (hrs): 0.7004
# ====> Epoch: 25364 Train ELBO: 263.0512 Val ELBO: 256.6897, Epoch Time (s): 0.08, Total Time (hrs): 0.7005
# ====> Epoch: 25365 Train ELBO: 262.5332 Val ELBO: 256.4229, Epoch Time (s): 0.08, Total Time (hrs): 0.7005
# ====> Epoch: 25366 Train ELBO: 261.7634 Val ELBO: 257.3854, Epoch Time (s): 0.09, Total Time (hrs): 0.7005
# ====> Epoch: 25367 Train ELBO: 262.4109 Val ELBO: 255.2147, Epoch Time (s): 0.08, Total Time (hrs): 0.7005
# ====> Epoch: 25368 Train ELBO: 260.2896 Val ELBO: 254.6831, Epoch Time (s): 0.07, Total Time (hrs): 0.7005
# ====> Epoch: 25369 Train ELBO: 260.1305 Val ELBO: 256.0326, Epoch Time (s): 0.08, Total Time (hrs): 0.7006
# ====> Epoch: 25370 Train ELBO: 253.3644 Val ELBO: 239.5722, Epoch Time (s): 0.07, Total Time (hrs): 0.7006
# ====> Epoch: 25371 Train ELBO: 246.9799 Val ELBO: 230.1782, Epoch Time (s): 0.08, Total Time (hrs): 0.7006
# ====> Epoch: 25372 Train ELBO: 246.2225 Val ELBO: 251.4521, Epoch Time (s): 0.08, Total Time (hrs): 0.7006
# ====> Epoch: 25373 Train ELBO: 252.4708 Val ELBO: 250.1942, Epoch Time (s): 0.07, Total Time (hrs): 0.7007
# ====> Epoch: 25374 Train ELBO: 254.0522 Val ELBO: 248.4009, Epoch Time (s): 0.07, Total Time (hrs): 0.7007
# ====> Epoch: 25375 Train ELBO: 256.4362 Val ELBO: 248.8141, Epoch Time (s): 0.09, Total Time (hrs): 0.7007
# ====> Epoch: 25376 Train ELBO: 256.8450 Val ELBO: 252.0574, Epoch Time (s): 0.07, Total Time (hrs): 0.7007
# ====> Epoch: 25377 Train ELBO: 258.3970 Val ELBO: 253.9220, Epoch Time (s): 0.08, Total Time (hrs): 0.7007
# ====> Epoch: 25378 Train ELBO: 256.0374 Val ELBO: 246.4139, Epoch Time (s): 0.09, Total Time (hrs): 0.7008
# ====> Epoch: 25379 Train ELBO: 259.1370 Val ELBO: 254.0415, Epoch Time (s): 0.08, Total Time (hrs): 0.7008
# ====> Epoch: 25380 Train ELBO: 255.3689 Val ELBO: 223.1263, Epoch Time (s): 0.08, Total Time (hrs): 0.7008
# ====> Epoch: 25381 Train ELBO: 246.9802 Val ELBO: 248.2124, Epoch Time (s): 0.08, Total Time (hrs): 0.7008
# ====> Epoch: 25382 Train ELBO: 258.5867 Val ELBO: 249.5429, Epoch Time (s): 0.07, Total Time (hrs): 0.7009
# ====> Epoch: 25383 Train ELBO: 258.8698 Val ELBO: 253.5316, Epoch Time (s): 0.07, Total Time (hrs): 0.7009
# ====> Epoch: 25384 Train ELBO: 257.0251 Val ELBO: 252.8158, Epoch Time (s): 0.08, Total Time (hrs): 0.7009
# ====> Epoch: 25385 Train ELBO: 256.4422 Val ELBO: 247.5647, Epoch Time (s): 0.08, Total Time (hrs): 0.7009
# ====> Epoch: 25386 Train ELBO: 259.4438 Val ELBO: 253.0102, Epoch Time (s): 0.08, Total Time (hrs): 0.7009
# ====> Epoch: 25387 Train ELBO: 262.5144 Val ELBO: 255.2045, Epoch Time (s): 0.08, Total Time (hrs): 0.7010
# ====> Epoch: 25388 Train ELBO: 263.1624 Val ELBO: 256.5544, Epoch Time (s): 0.08, Total Time (hrs): 0.7010
# ====> Epoch: 25389 Train ELBO: 262.1590 Val ELBO: 254.0957, Epoch Time (s): 0.08, Total Time (hrs): 0.7010
# ====> Epoch: 25390 Train ELBO: 260.6464 Val ELBO: 252.9273, Epoch Time (s): 0.08, Total Time (hrs): 0.7010
# ====> Epoch: 25391 Train ELBO: 260.4323 Val ELBO: 247.4475, Epoch Time (s): 0.08, Total Time (hrs): 0.7011
# ====> Epoch: 25392 Train ELBO: 261.0637 Val ELBO: 256.1028, Epoch Time (s): 0.08, Total Time (hrs): 0.7011
# ====> Epoch: 25393 Train ELBO: 262.2032 Val ELBO: 255.1160, Epoch Time (s): 0.08, Total Time (hrs): 0.7011
# ====> Epoch: 25394 Train ELBO: 260.2930 Val ELBO: 252.8898, Epoch Time (s): 0.08, Total Time (hrs): 0.7011
# ====> Epoch: 25395 Train ELBO: 260.4651 Val ELBO: 248.8067, Epoch Time (s): 0.08, Total Time (hrs): 0.7011
# ====> Epoch: 25396 Train ELBO: 259.1101 Val ELBO: 251.0217, Epoch Time (s): 0.08, Total Time (hrs): 0.7012
# ====> Epoch: 25397 Train ELBO: 260.6242 Val ELBO: 253.3958, Epoch Time (s): 0.07, Total Time (hrs): 0.7012
# ====> Epoch: 25398 Train ELBO: 261.5317 Val ELBO: 255.2786, Epoch Time (s): 0.07, Total Time (hrs): 0.7012
# ====> Epoch: 25399 Train ELBO: 262.3907 Val ELBO: 257.0798, Epoch Time (s): 0.08, Total Time (hrs): 0.7012
# ====> Epoch: 25400 Train ELBO: 262.3703 Val ELBO: 254.9822, Epoch Time (s): 0.08, Total Time (hrs): 0.7012
# ====> Epoch: 25401 Train ELBO: 261.5617 Val ELBO: 256.3079, Epoch Time (s): 0.08, Total Time (hrs): 0.7013
# ====> Epoch: 25402 Train ELBO: 262.7202 Val ELBO: 255.7825, Epoch Time (s): 0.08, Total Time (hrs): 0.7013
# ====> Epoch: 25403 Train ELBO: 263.2197 Val ELBO: 253.6933, Epoch Time (s): 0.07, Total Time (hrs): 0.7013
# ====> Epoch: 25404 Train ELBO: 262.9451 Val ELBO: 256.1266, Epoch Time (s): 0.07, Total Time (hrs): 0.7013
# ====> Epoch: 25405 Train ELBO: 262.3938 Val ELBO: 255.6026, Epoch Time (s): 0.10, Total Time (hrs): 0.7014
# ====> Epoch: 25406 Train ELBO: 262.3190 Val ELBO: 257.0070, Epoch Time (s): 0.08, Total Time (hrs): 0.7014
# ====> Epoch: 25407 Train ELBO: 262.0741 Val ELBO: 256.4270, Epoch Time (s): 0.08, Total Time (hrs): 0.7014
# ====> Epoch: 25408 Train ELBO: 261.7845 Val ELBO: 258.0064, Epoch Time (s): 0.08, Total Time (hrs): 0.7014
# ====> Epoch: 25409 Train ELBO: 261.6249 Val ELBO: 256.5969, Epoch Time (s): 0.07, Total Time (hrs): 0.7014
# ====> Epoch: 25410 Train ELBO: 263.3976 Val ELBO: 257.3904, Epoch Time (s): 0.07, Total Time (hrs): 0.7015
# ====> Epoch: 25411 Train ELBO: 263.4558 Val ELBO: 258.0057, Epoch Time (s): 0.08, Total Time (hrs): 0.7015
# ====> Epoch: 25412 Train ELBO: 263.1158 Val ELBO: 257.8404, Epoch Time (s): 0.07, Total Time (hrs): 0.7015
# ====> Epoch: 25413 Train ELBO: 259.8105 Val ELBO: 252.1855, Epoch Time (s): 0.08, Total Time (hrs): 0.7015
# ====> Epoch: 25414 Train ELBO: 258.3624 Val ELBO: 255.2871, Epoch Time (s): 0.08, Total Time (hrs): 0.7016
# ====> Epoch: 25415 Train ELBO: 262.4901 Val ELBO: 256.2683, Epoch Time (s): 0.08, Total Time (hrs): 0.7016
# ====> Epoch: 25416 Train ELBO: 261.8443 Val ELBO: 256.3412, Epoch Time (s): 0.07, Total Time (hrs): 0.7016
# ====> Epoch: 25417 Train ELBO: 261.0465 Val ELBO: 253.2634, Epoch Time (s): 0.08, Total Time (hrs): 0.7016
# ====> Epoch: 25418 Train ELBO: 261.0646 Val ELBO: 256.0768, Epoch Time (s): 0.09, Total Time (hrs): 0.7016
# ====> Epoch: 25419 Train ELBO: 261.8591 Val ELBO: 256.7786, Epoch Time (s): 0.08, Total Time (hrs): 0.7017
# ====> Epoch: 25420 Train ELBO: 259.2231 Val ELBO: 255.3109, Epoch Time (s): 0.08, Total Time (hrs): 0.7017
# ====> Epoch: 25421 Train ELBO: 254.5089 Val ELBO: 249.7528, Epoch Time (s): 0.07, Total Time (hrs): 0.7017
# ====> Epoch: 25422 Train ELBO: 253.4326 Val ELBO: 252.4786, Epoch Time (s): 0.08, Total Time (hrs): 0.7017
# ====> Epoch: 25423 Train ELBO: 254.6948 Val ELBO: 243.8233, Epoch Time (s): 0.08, Total Time (hrs): 0.7018
# ====> Epoch: 25424 Train ELBO: 257.2157 Val ELBO: 253.0775, Epoch Time (s): 0.07, Total Time (hrs): 0.7018
# ====> Epoch: 25425 Train ELBO: 258.5164 Val ELBO: 251.8803, Epoch Time (s): 0.07, Total Time (hrs): 0.7018
# ====> Epoch: 25426 Train ELBO: 256.8675 Val ELBO: 246.9510, Epoch Time (s): 0.09, Total Time (hrs): 0.7018
# ====> Epoch: 25427 Train ELBO: 256.0490 Val ELBO: 257.8785, Epoch Time (s): 0.07, Total Time (hrs): 0.7018
# ====> Epoch: 25428 Train ELBO: 257.3286 Val ELBO: 249.7822, Epoch Time (s): 0.08, Total Time (hrs): 0.7019
# ====> Epoch: 25429 Train ELBO: 260.2084 Val ELBO: 256.9417, Epoch Time (s): 0.08, Total Time (hrs): 0.7019
# ====> Epoch: 25430 Train ELBO: 260.8245 Val ELBO: 251.0500, Epoch Time (s): 0.07, Total Time (hrs): 0.7019
# ====> Epoch: 25431 Train ELBO: 261.4375 Val ELBO: 255.4379, Epoch Time (s): 0.09, Total Time (hrs): 0.7019
# ====> Epoch: 25432 Train ELBO: 261.9204 Val ELBO: 254.4102, Epoch Time (s): 0.08, Total Time (hrs): 0.7020
# ====> Epoch: 25433 Train ELBO: 261.4596 Val ELBO: 253.7935, Epoch Time (s): 0.08, Total Time (hrs): 0.7020
# ====> Epoch: 25434 Train ELBO: 261.4140 Val ELBO: 256.5799, Epoch Time (s): 0.08, Total Time (hrs): 0.7020
# ====> Epoch: 25435 Train ELBO: 262.2533 Val ELBO: 254.9245, Epoch Time (s): 0.08, Total Time (hrs): 0.7020
# ====> Epoch: 25436 Train ELBO: 261.5753 Val ELBO: 254.7890, Epoch Time (s): 0.08, Total Time (hrs): 0.7020
# ====> Epoch: 25437 Train ELBO: 261.3583 Val ELBO: 252.9716, Epoch Time (s): 0.07, Total Time (hrs): 0.7021
# ====> Epoch: 25438 Train ELBO: 261.9203 Val ELBO: 256.3973, Epoch Time (s): 0.08, Total Time (hrs): 0.7021
# ====> Epoch: 25439 Train ELBO: 263.5742 Val ELBO: 257.1299, Epoch Time (s): 0.08, Total Time (hrs): 0.7021
# ====> Epoch: 25440 Train ELBO: 261.8805 Val ELBO: 257.5981, Epoch Time (s): 0.08, Total Time (hrs): 0.7021
# ====> Epoch: 25441 Train ELBO: 262.9590 Val ELBO: 257.2190, Epoch Time (s): 0.08, Total Time (hrs): 0.7022
# ====> Epoch: 25442 Train ELBO: 262.9648 Val ELBO: 255.8628, Epoch Time (s): 0.07, Total Time (hrs): 0.7022
# ====> Epoch: 25443 Train ELBO: 261.7369 Val ELBO: 255.0586, Epoch Time (s): 0.08, Total Time (hrs): 0.7022
# ====> Epoch: 25444 Train ELBO: 261.8813 Val ELBO: 257.0645, Epoch Time (s): 0.10, Total Time (hrs): 0.7022
# ====> Epoch: 25445 Train ELBO: 259.3154 Val ELBO: 247.3725, Epoch Time (s): 0.08, Total Time (hrs): 0.7022
# ====> Epoch: 25446 Train ELBO: 249.7929 Val ELBO: 213.9991, Epoch Time (s): 0.07, Total Time (hrs): 0.7023
# ====> Epoch: 25447 Train ELBO: 239.7761 Val ELBO: 255.9908, Epoch Time (s): 0.08, Total Time (hrs): 0.7023
# ====> Epoch: 25448 Train ELBO: 254.1672 Val ELBO: 243.8298, Epoch Time (s): 0.07, Total Time (hrs): 0.7023
# ...
# ====> Epoch: 29851 Train ELBO: 264.6698 Val ELBO: 258.3652, Epoch Time (s): 0.09, Total Time (hrs): 0.8253
# ====> Epoch: 29852 Train ELBO: 265.4163 Val ELBO: 259.6525, Epoch Time (s): 0.08, Total Time (hrs): 0.8254
# ====> Epoch: 29853 Train ELBO: 265.6659 Val ELBO: 258.8981, Epoch Time (s): 0.08, Total Time (hrs): 0.8254
# ====> Epoch: 29854 Train ELBO: 264.5269 Val ELBO: 258.3586, Epoch Time (s): 0.08, Total Time (hrs): 0.8254
# ====> Epoch: 29855 Train ELBO: 264.3421 Val ELBO: 258.3238, Epoch Time (s): 0.08, Total Time (hrs): 0.8254
# ====> Epoch: 29856 Train ELBO: 263.4192 Val ELBO: 258.4846, Epoch Time (s): 0.08, Total Time (hrs): 0.8254
# ====> Epoch: 29857 Train ELBO: 264.3749 Val ELBO: 255.6839, Epoch Time (s): 0.08, Total Time (hrs): 0.8255
# ====> Epoch: 29858 Train ELBO: 264.7819 Val ELBO: 258.0406, Epoch Time (s): 0.07, Total Time (hrs): 0.8255
# ====> Epoch: 29859 Train ELBO: 264.7905 Val ELBO: 257.8271, Epoch Time (s): 0.08, Total Time (hrs): 0.8255
# ====> Epoch: 29860 Train ELBO: 263.7565 Val ELBO: 259.4661, Epoch Time (s): 0.08, Total Time (hrs): 0.8255
# ====> Epoch: 29861 Train ELBO: 264.1647 Val ELBO: 258.5977, Epoch Time (s): 0.08, Total Time (hrs): 0.8256
# ====> Epoch: 29862 Train ELBO: 261.5682 Val ELBO: 249.0814, Epoch Time (s): 0.08, Total Time (hrs): 0.8256
# ====> Epoch: 29863 Train ELBO: 259.2323 Val ELBO: 250.9474, Epoch Time (s): 0.07, Total Time (hrs): 0.8256
# ====> Epoch: 29864 Train ELBO: 260.7087 Val ELBO: 256.2794, Epoch Time (s): 0.08, Total Time (hrs): 0.8256
# ====> Epoch: 29865 Train ELBO: 263.2118 Val ELBO: 259.3143, Epoch Time (s): 0.08, Total Time (hrs): 0.8256
# ====> Epoch: 29866 Train ELBO: 265.0493 Val ELBO: 258.4211, Epoch Time (s): 0.07, Total Time (hrs): 0.8257
# ====> Epoch: 29867 Train ELBO: 263.6000 Val ELBO: 257.5480, Epoch Time (s): 0.08, Total Time (hrs): 0.8257
# ====> Epoch: 29868 Train ELBO: 261.0095 Val ELBO: 258.3990, Epoch Time (s): 0.08, Total Time (hrs): 0.8257
# ====> Epoch: 29869 Train ELBO: 261.4132 Val ELBO: 255.3064, Epoch Time (s): 0.07, Total Time (hrs): 0.8257
# ====> Epoch: 29870 Train ELBO: 263.1353 Val ELBO: 256.5359, Epoch Time (s): 0.07, Total Time (hrs): 0.8257
# ====> Epoch: 29871 Train ELBO: 263.3183 Val ELBO: 257.1640, Epoch Time (s): 0.08, Total Time (hrs): 0.8258
# ====> Epoch: 29872 Train ELBO: 263.6734 Val ELBO: 257.4150, Epoch Time (s): 0.07, Total Time (hrs): 0.8258
# ====> Epoch: 29873 Train ELBO: 264.2678 Val ELBO: 258.1213, Epoch Time (s): 0.08, Total Time (hrs): 0.8258
# ====> Epoch: 29874 Train ELBO: 264.1934 Val ELBO: 257.8665, Epoch Time (s): 0.08, Total Time (hrs): 0.8258
# ====> Epoch: 29875 Train ELBO: 263.9215 Val ELBO: 257.2997, Epoch Time (s): 0.07, Total Time (hrs): 0.8259
# ====> Epoch: 29876 Train ELBO: 262.4211 Val ELBO: 256.2550, Epoch Time (s): 0.08, Total Time (hrs): 0.8259
# ====> Epoch: 29877 Train ELBO: 259.6073 Val ELBO: 256.3099, Epoch Time (s): 0.08, Total Time (hrs): 0.8259
# ====> Epoch: 29878 Train ELBO: 263.5558 Val ELBO: 255.3962, Epoch Time (s): 0.09, Total Time (hrs): 0.8259
# ====> Epoch: 29879 Train ELBO: 263.7082 Val ELBO: 257.6347, Epoch Time (s): 0.08, Total Time (hrs): 0.8259
# ====> Epoch: 29880 Train ELBO: 264.6522 Val ELBO: 258.3382, Epoch Time (s): 0.08, Total Time (hrs): 0.8260
# ====> Epoch: 29881 Train ELBO: 263.5286 Val ELBO: 257.2228, Epoch Time (s): 0.08, Total Time (hrs): 0.8260
# ====> Epoch: 29882 Train ELBO: 262.0870 Val ELBO: 256.5630, Epoch Time (s): 0.08, Total Time (hrs): 0.8260
# ====> Epoch: 29883 Train ELBO: 261.8393 Val ELBO: 255.1245, Epoch Time (s): 0.08, Total Time (hrs): 0.8260
# ====> Epoch: 29884 Train ELBO: 259.1364 Val ELBO: 256.9913, Epoch Time (s): 0.07, Total Time (hrs): 0.8261
# ====> Epoch: 29885 Train ELBO: 263.4957 Val ELBO: 255.3360, Epoch Time (s): 0.08, Total Time (hrs): 0.8261
# ====> Epoch: 29886 Train ELBO: 263.7060 Val ELBO: 256.4206, Epoch Time (s): 0.08, Total Time (hrs): 0.8261
# ====> Epoch: 29887 Train ELBO: 263.2345 Val ELBO: 255.8266, Epoch Time (s): 0.08, Total Time (hrs): 0.8261
# ====> Epoch: 29888 Train ELBO: 262.9822 Val ELBO: 252.3061, Epoch Time (s): 0.07, Total Time (hrs): 0.8261
# ====> Epoch: 29889 Train ELBO: 263.0443 Val ELBO: 254.6711, Epoch Time (s): 0.08, Total Time (hrs): 0.8262
# ====> Epoch: 29890 Train ELBO: 263.2502 Val ELBO: 256.0663, Epoch Time (s): 0.08, Total Time (hrs): 0.8262
# ====> Epoch: 29891 Train ELBO: 260.4185 Val ELBO: 252.5493, Epoch Time (s): 0.09, Total Time (hrs): 0.8262
# ====> Epoch: 29892 Train ELBO: 255.4880 Val ELBO: 246.6166, Epoch Time (s): 0.08, Total Time (hrs): 0.8262
# ====> Epoch: 29893 Train ELBO: 255.1723 Val ELBO: 245.9049, Epoch Time (s): 0.08, Total Time (hrs): 0.8263
# ====> Epoch: 29894 Train ELBO: 253.4021 Val ELBO: 241.4075, Epoch Time (s): 0.07, Total Time (hrs): 0.8263
# ====> Epoch: 29895 Train ELBO: 257.9090 Val ELBO: 256.3761, Epoch Time (s): 0.08, Total Time (hrs): 0.8263
# ====> Epoch: 29896 Train ELBO: 260.8432 Val ELBO: 256.9268, Epoch Time (s): 0.08, Total Time (hrs): 0.8263
# ====> Epoch: 29897 Train ELBO: 262.4765 Val ELBO: 257.4029, Epoch Time (s): 0.07, Total Time (hrs): 0.8263
# ====> Epoch: 29898 Train ELBO: 264.3001 Val ELBO: 257.4687, Epoch Time (s): 0.08, Total Time (hrs): 0.8264
# ====> Epoch: 29899 Train ELBO: 263.8005 Val ELBO: 256.3622, Epoch Time (s): 0.08, Total Time (hrs): 0.8264
# ====> Epoch: 29900 Train ELBO: 263.7324 Val ELBO: 257.6128, Epoch Time (s): 0.07, Total Time (hrs): 0.8264
# ====> Epoch: 29901 Train ELBO: 262.7307 Val ELBO: 258.9449, Epoch Time (s): 0.08, Total Time (hrs): 0.8264
# ====> Epoch: 29902 Train ELBO: 260.7036 Val ELBO: 255.5218, Epoch Time (s): 0.08, Total Time (hrs): 0.8264
# ====> Epoch: 29903 Train ELBO: 261.0113 Val ELBO: 254.2525, Epoch Time (s): 0.08, Total Time (hrs): 0.8265
# ====> Epoch: 29904 Train ELBO: 259.3884 Val ELBO: 258.1384, Epoch Time (s): 0.10, Total Time (hrs): 0.8265
# ====> Epoch: 29905 Train ELBO: 262.6782 Val ELBO: 257.2666, Epoch Time (s): 0.08, Total Time (hrs): 0.8265
# ====> Epoch: 29906 Train ELBO: 261.8574 Val ELBO: 252.8118, Epoch Time (s): 0.11, Total Time (hrs): 0.8265
# ====> Epoch: 29907 Train ELBO: 260.1271 Val ELBO: 253.0822, Epoch Time (s): 0.12, Total Time (hrs): 0.8266
# ====> Epoch: 29908 Train ELBO: 262.4674 Val ELBO: 252.1736, Epoch Time (s): 0.11, Total Time (hrs): 0.8266
# ====> Epoch: 29909 Train ELBO: 260.5178 Val ELBO: 250.9807, Epoch Time (s): 0.12, Total Time (hrs): 0.8266
# ====> Epoch: 29910 Train ELBO: 261.3200 Val ELBO: 254.9888, Epoch Time (s): 0.11, Total Time (hrs): 0.8267
# ====> Epoch: 29911 Train ELBO: 260.8466 Val ELBO: 254.6461, Epoch Time (s): 0.12, Total Time (hrs): 0.8267
# ====> Epoch: 29912 Train ELBO: 262.4068 Val ELBO: 256.6241, Epoch Time (s): 0.11, Total Time (hrs): 0.8267
# ====> Epoch: 29913 Train ELBO: 264.7127 Val ELBO: 257.2381, Epoch Time (s): 0.12, Total Time (hrs): 0.8268
# ====> Epoch: 29914 Train ELBO: 264.6939 Val ELBO: 258.2151, Epoch Time (s): 0.11, Total Time (hrs): 0.8268
# ====> Epoch: 29915 Train ELBO: 264.7777 Val ELBO: 256.7618, Epoch Time (s): 0.11, Total Time (hrs): 0.8268
# ====> Epoch: 29916 Train ELBO: 264.3397 Val ELBO: 253.3425, Epoch Time (s): 0.11, Total Time (hrs): 0.8269
# ====> Epoch: 29917 Train ELBO: 259.5915 Val ELBO: 250.2684, Epoch Time (s): 0.11, Total Time (hrs): 0.8269
# ====> Epoch: 29918 Train ELBO: 256.9292 Val ELBO: 217.4749, Epoch Time (s): 0.11, Total Time (hrs): 0.8269
# ====> Epoch: 29919 Train ELBO: 244.4365 Val ELBO: 228.6416, Epoch Time (s): 0.12, Total Time (hrs): 0.8270
# ====> Epoch: 29920 Train ELBO: 249.6218 Val ELBO: 258.0029, Epoch Time (s): 0.11, Total Time (hrs): 0.8270
# ====> Epoch: 29921 Train ELBO: 255.2322 Val ELBO: 229.8277, Epoch Time (s): 0.11, Total Time (hrs): 0.8270
# ====> Epoch: 29922 Train ELBO: 250.6457 Val ELBO: 251.0406, Epoch Time (s): 0.11, Total Time (hrs): 0.8271
# ====> Epoch: 29923 Train ELBO: 256.2346 Val ELBO: 245.9046, Epoch Time (s): 0.13, Total Time (hrs): 0.8271
# ====> Epoch: 29924 Train ELBO: 255.3547 Val ELBO: 250.4060, Epoch Time (s): 0.10, Total Time (hrs): 0.8271
# ====> Epoch: 29925 Train ELBO: 260.1954 Val ELBO: 256.1183, Epoch Time (s): 0.11, Total Time (hrs): 0.8271
# ====> Epoch: 29926 Train ELBO: 262.3741 Val ELBO: 256.3313, Epoch Time (s): 0.12, Total Time (hrs): 0.8272
# ====> Epoch: 29927 Train ELBO: 263.6210 Val ELBO: 254.7331, Epoch Time (s): 0.13, Total Time (hrs): 0.8272
# ====> Epoch: 29928 Train ELBO: 262.6966 Val ELBO: 256.0762, Epoch Time (s): 0.11, Total Time (hrs): 0.8273
# ====> Epoch: 29929 Train ELBO: 261.1250 Val ELBO: 256.1350, Epoch Time (s): 0.12, Total Time (hrs): 0.8273
# ====> Epoch: 29930 Train ELBO: 262.7426 Val ELBO: 258.9137, Epoch Time (s): 0.12, Total Time (hrs): 0.8273
# ====> Epoch: 29931 Train ELBO: 264.7239 Val ELBO: 259.1485, Epoch Time (s): 0.13, Total Time (hrs): 0.8274
# ====> Epoch: 29932 Train ELBO: 264.9260 Val ELBO: 258.9580, Epoch Time (s): 0.14, Total Time (hrs): 0.8274
# ====> Epoch: 29933 Train ELBO: 264.1878 Val ELBO: 256.8505, Epoch Time (s): 0.09, Total Time (hrs): 0.8274
# ====> Epoch: 29934 Train ELBO: 263.4836 Val ELBO: 258.4442, Epoch Time (s): 0.07, Total Time (hrs): 0.8274
# ====> Epoch: 29935 Train ELBO: 264.9944 Val ELBO: 259.0054, Epoch Time (s): 0.07, Total Time (hrs): 0.8275
# ====> Epoch: 29936 Train ELBO: 264.7691 Val ELBO: 258.0781, Epoch Time (s): 0.08, Total Time (hrs): 0.8275
# ====> Epoch: 29937 Train ELBO: 264.7958 Val ELBO: 258.1349, Epoch Time (s): 0.08, Total Time (hrs): 0.8275
# ====> Epoch: 29938 Train ELBO: 263.0768 Val ELBO: 254.8563, Epoch Time (s): 0.08, Total Time (hrs): 0.8275
# ====> Epoch: 29939 Train ELBO: 262.4026 Val ELBO: 252.6860, Epoch Time (s): 0.08, Total Time (hrs): 0.8275
# ====> Epoch: 29940 Train ELBO: 261.2272 Val ELBO: 255.0655, Epoch Time (s): 0.08, Total Time (hrs): 0.8276
# ====> Epoch: 29941 Train ELBO: 260.4921 Val ELBO: 254.6693, Epoch Time (s): 0.08, Total Time (hrs): 0.8276
# ====> Epoch: 29942 Train ELBO: 260.7525 Val ELBO: 256.2202, Epoch Time (s): 0.08, Total Time (hrs): 0.8276
# ====> Epoch: 29943 Train ELBO: 262.4871 Val ELBO: 258.8782, Epoch Time (s): 0.08, Total Time (hrs): 0.8276
# ====> Epoch: 29944 Train ELBO: 263.8033 Val ELBO: 256.3842, Epoch Time (s): 0.09, Total Time (hrs): 0.8277
# ====> Epoch: 29945 Train ELBO: 263.6316 Val ELBO: 257.6757, Epoch Time (s): 0.08, Total Time (hrs): 0.8277
# ====> Epoch: 29946 Train ELBO: 264.3598 Val ELBO: 259.2369, Epoch Time (s): 0.07, Total Time (hrs): 0.8277
# ====> Epoch: 29947 Train ELBO: 264.9680 Val ELBO: 258.6094, Epoch Time (s): 0.07, Total Time (hrs): 0.8277
# ====> Epoch: 29948 Train ELBO: 265.2251 Val ELBO: 258.8532, Epoch Time (s): 0.08, Total Time (hrs): 0.8277
# ====> Epoch: 29949 Train ELBO: 264.9293 Val ELBO: 260.0679, Epoch Time (s): 0.08, Total Time (hrs): 0.8278
# ====> Epoch: 29950 Train ELBO: 265.0354 Val ELBO: 258.0331, Epoch Time (s): 0.08, Total Time (hrs): 0.8278
# ====> Epoch: 29951 Train ELBO: 264.3233 Val ELBO: 258.2709, Epoch Time (s): 0.08, Total Time (hrs): 0.8278
# ====> Epoch: 29952 Train ELBO: 264.8683 Val ELBO: 255.8500, Epoch Time (s): 0.08, Total Time (hrs): 0.8278
# ====> Epoch: 29953 Train ELBO: 263.9795 Val ELBO: 253.3331, Epoch Time (s): 0.07, Total Time (hrs): 0.8279
# ====> Epoch: 29954 Train ELBO: 263.1573 Val ELBO: 257.6754, Epoch Time (s): 0.08, Total Time (hrs): 0.8279
# ====> Epoch: 29955 Train ELBO: 262.8274 Val ELBO: 254.4327, Epoch Time (s): 0.07, Total Time (hrs): 0.8279
# ====> Epoch: 29956 Train ELBO: 262.6327 Val ELBO: 257.7055, Epoch Time (s): 0.08, Total Time (hrs): 0.8279
# ====> Epoch: 29957 Train ELBO: 262.9295 Val ELBO: 255.1767, Epoch Time (s): 0.10, Total Time (hrs): 0.8279
# ====> Epoch: 29958 Train ELBO: 261.2599 Val ELBO: 253.6349, Epoch Time (s): 0.08, Total Time (hrs): 0.8280
# ====> Epoch: 29959 Train ELBO: 261.0911 Val ELBO: 250.9776, Epoch Time (s): 0.08, Total Time (hrs): 0.8280
# ====> Epoch: 29960 Train ELBO: 260.2245 Val ELBO: 254.2339, Epoch Time (s): 0.08, Total Time (hrs): 0.8280
# ====> Epoch: 29961 Train ELBO: 262.2152 Val ELBO: 258.0916, Epoch Time (s): 0.08, Total Time (hrs): 0.8280
# ====> Epoch: 29962 Train ELBO: 262.6546 Val ELBO: 258.6899, Epoch Time (s): 0.08, Total Time (hrs): 0.8281
# ====> Epoch: 29963 Train ELBO: 264.0897 Val ELBO: 257.3698, Epoch Time (s): 0.08, Total Time (hrs): 0.8281
# ====> Epoch: 29964 Train ELBO: 264.2434 Val ELBO: 257.6533, Epoch Time (s): 0.07, Total Time (hrs): 0.8281
# ====> Epoch: 29965 Train ELBO: 264.5710 Val ELBO: 256.3614, Epoch Time (s): 0.08, Total Time (hrs): 0.8281
# ====> Epoch: 29966 Train ELBO: 264.2366 Val ELBO: 256.1334, Epoch Time (s): 0.08, Total Time (hrs): 0.8281
# ====> Epoch: 29967 Train ELBO: 262.4907 Val ELBO: 255.2366, Epoch Time (s): 0.08, Total Time (hrs): 0.8282
# ====> Epoch: 29968 Train ELBO: 262.0418 Val ELBO: 259.2639, Epoch Time (s): 0.08, Total Time (hrs): 0.8282
# ====> Epoch: 29969 Train ELBO: 265.0545 Val ELBO: 258.9552, Epoch Time (s): 0.08, Total Time (hrs): 0.8282
# ====> Epoch: 29970 Train ELBO: 264.6152 Val ELBO: 251.5507, Epoch Time (s): 0.09, Total Time (hrs): 0.8282
# ====> Epoch: 29971 Train ELBO: 258.6407 Val ELBO: 243.1583, Epoch Time (s): 0.08, Total Time (hrs): 0.8283
# ====> Epoch: 29972 Train ELBO: 258.5096 Val ELBO: 255.8361, Epoch Time (s): 0.08, Total Time (hrs): 0.8283
# ====> Epoch: 29973 Train ELBO: 262.9497 Val ELBO: 257.6015, Epoch Time (s): 0.07, Total Time (hrs): 0.8283
# ====> Epoch: 29974 Train ELBO: 259.7058 Val ELBO: 249.9413, Epoch Time (s): 0.07, Total Time (hrs): 0.8283
# ====> Epoch: 29975 Train ELBO: 254.1481 Val ELBO: 240.0422, Epoch Time (s): 0.08, Total Time (hrs): 0.8283
# ====> Epoch: 29976 Train ELBO: 252.4276 Val ELBO: 255.3695, Epoch Time (s): 0.08, Total Time (hrs): 0.8284
# ====> Epoch: 29977 Train ELBO: 261.7613 Val ELBO: 254.4476, Epoch Time (s): 0.07, Total Time (hrs): 0.8284
# ====> Epoch: 29978 Train ELBO: 263.0035 Val ELBO: 259.3134, Epoch Time (s): 0.08, Total Time (hrs): 0.8284
# ====> Epoch: 29979 Train ELBO: 264.6910 Val ELBO: 258.8947, Epoch Time (s): 0.08, Total Time (hrs): 0.8284
# ====> Epoch: 29980 Train ELBO: 262.2840 Val ELBO: 252.5406, Epoch Time (s): 0.09, Total Time (hrs): 0.8285
# ====> Epoch: 29981 Train ELBO: 259.8285 Val ELBO: 255.1677, Epoch Time (s): 0.10, Total Time (hrs): 0.8285
# ====> Epoch: 29982 Train ELBO: 261.0175 Val ELBO: 254.6789, Epoch Time (s): 0.07, Total Time (hrs): 0.8285
# ====> Epoch: 29983 Train ELBO: 260.3250 Val ELBO: 254.4897, Epoch Time (s): 0.09, Total Time (hrs): 0.8285
# ====> Epoch: 29984 Train ELBO: 259.1607 Val ELBO: 253.8050, Epoch Time (s): 0.08, Total Time (hrs): 0.8285
# ====> Epoch: 29985 Train ELBO: 261.1870 Val ELBO: 258.4540, Epoch Time (s): 0.07, Total Time (hrs): 0.8286
# ====> Epoch: 29986 Train ELBO: 264.9690 Val ELBO: 259.0479, Epoch Time (s): 0.07, Total Time (hrs): 0.8286
# ====> Epoch: 29987 Train ELBO: 265.0283 Val ELBO: 258.1959, Epoch Time (s): 0.08, Total Time (hrs): 0.8286
# ====> Epoch: 29988 Train ELBO: 264.4866 Val ELBO: 258.9676, Epoch Time (s): 0.08, Total Time (hrs): 0.8286
# ====> Epoch: 29989 Train ELBO: 264.0185 Val ELBO: 258.0270, Epoch Time (s): 0.07, Total Time (hrs): 0.8287
# ====> Epoch: 29990 Train ELBO: 264.2559 Val ELBO: 257.7340, Epoch Time (s): 0.08, Total Time (hrs): 0.8287
# ====> Epoch: 29991 Train ELBO: 264.1427 Val ELBO: 255.8043, Epoch Time (s): 0.07, Total Time (hrs): 0.8287
# ====> Epoch: 29992 Train ELBO: 262.8307 Val ELBO: 252.8749, Epoch Time (s): 0.08, Total Time (hrs): 0.8287
# ====> Epoch: 29993 Train ELBO: 259.5158 Val ELBO: 253.4761, Epoch Time (s): 0.08, Total Time (hrs): 0.8287
# ====> Epoch: 29994 Train ELBO: 260.8505 Val ELBO: 254.7826, Epoch Time (s): 0.08, Total Time (hrs): 0.8288
# ====> Epoch: 29995 Train ELBO: 264.2449 Val ELBO: 258.6657, Epoch Time (s): 0.07, Total Time (hrs): 0.8288
# ====> Epoch: 29996 Train ELBO: 264.6004 Val ELBO: 257.9089, Epoch Time (s): 0.09, Total Time (hrs): 0.8288
# ====> Epoch: 29997 Train ELBO: 264.9114 Val ELBO: 259.7630, Epoch Time (s): 0.08, Total Time (hrs): 0.8288
# ====> Epoch: 29998 Train ELBO: 265.1072 Val ELBO: 258.5871, Epoch Time (s): 0.08, Total Time (hrs): 0.8288
# ====> Epoch: 29999 Train ELBO: 264.2982 Val ELBO: 252.6152, Epoch Time (s): 0.08, Total Time (hrs): 0.8289
# Training took  0:49:43.939548

# %% [markdown]
# # Load and Plot Results

# %%
if loadFlag:
  path = dirname
  epoch = n_epochs - 1
params = {}
encoder = Encoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd1, hd2]).to("cuda")
decoder = Decoder(data_dim=data_dim, latent_dim=latent_dim, hidden_dims=[hd2, hd1], decoder_var=decoder_var).to("cuda")

# Use if you need to load in the data
if loadFlag:
  suffix = postfix
  encoder.load_state_dict(torch.load(os.path.join(path, f'encoder_{suffix}.pt'),map_location=torch.device('cpu')))
  decoder.load_state_dict(torch.load(os.path.join(path, f'decoder_{suffix}.pt'),map_location=torch.device('cpu')))
  logsigmasq = torch.load(os.path.join(path, f'gmm_params_logsigmasq_{suffix}.pt'),map_location=torch.device('cpu'))
  mu = torch.load(os.path.join(path, f'gmm_params_mu_{suffix}.pt'),map_location=torch.device('cpu'))
  pi = torch.load(os.path.join(path, f'gmm_params_pi_{suffix}.pt'),map_location=torch.device('cpu'))

encoder_list = [encoder]
decoder_list = [decoder]

device = next(encoder.parameters()).device
# Load in training history metrics
pi_history = torch.load(os.path.join(dirname, 'pi_history'+ postfix + '.pt'))
train_loss = torch.load(os.path.join(dirname, 'train_loss'+ postfix + '.pt'))
val_loss = torch.load(os.path.join(dirname, 'val_loss'+ postfix + '.pt'))
train_elbo_terms = torch.load(os.path.join(dirname, 'train_elbo_terms'+ postfix + '.pt'))
val_elbo_terms = torch.load(os.path.join(dirname, 'val_elbo_terms'+ postfix + '.pt'))
train_mse_history = torch.load(os.path.join(dirname, 'train_mse_history'+ postfix + '.pt'))
val_mse_history = torch.load(os.path.join(dirname, 'val_mse_history'+ postfix + '.pt'))


text_labels = [f'Cluster {i}' for i in range((n_clusters))]
label_colors = [f'C{i+1}' for i in range((n_clusters))]
data_colors = label_colors

# Plot training history
# Plot the training and validation loss vs. epoch number
plt.figure(figsize=(4, 4))
const = min(min(train_loss), min(val_loss))
# const = min(10, const)
train_loss_adjusted = train_loss
val_loss_adjusted = val_loss
plt.plot(train_loss_adjusted.cpu(), label='Training')
plt.plot(val_loss_adjusted.cpu(), label='Validation')
plt.xlabel("Number of Epochs")
plt.ylabel("Negative Loss")
# plt.title("Negative Loss")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()


 # Plot each term of the training loss and validation loss
plt.figure(figsize=(4.5, 4))
labels = ["Reconstruction", "GMM Reg", "Prob Reg", "Encoder Var"]
for ii in range(4):
  # print(train_elbo_terms.cpu()[ii, :epoch])
  # print(len(train_elbo_terms.cpu()[ii, :epoch]))
  train_loss_adjusted = train_elbo_terms[:, ii]
  val_loss_adjusted = val_elbo_terms[:, ii]
  plt.plot(train_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Train")
  plt.plot(val_loss_adjusted.cpu()[:], label=f"{labels[ii]}: Val", linestyle='--')
plt.xlabel("number of epochs")
plt.ylabel("loss")
plt.title("Negative Loss Terms")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_terms_'+ str(epoch)+postfix+'.png'), dpi=dpi)
plt.close()


 # Plot the sum of each term of the training loss and validation loss
plt.figure(figsize=(4.5, 4))
  # print(train_elbo_terms.cpu()[ii, :epoch])
  # print(len(train_elbo_terms.cpu()[ii, :epoch]))
train_loss_adjusted = train_elbo_terms.sum(axis=1)
val_loss_adjusted = val_elbo_terms.sum(axis=1)
plt.plot(train_loss_adjusted.cpu()[:], label=f"Train")
plt.plot(val_loss_adjusted.cpu()[:], label=f"Val", linestyle='--')
plt.xlabel("number of epochs")
plt.ylabel("loss")
plt.title("Sum of ELBO Terms")
plt.yscale('symlog')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'elbo_terms_sum_'+ str(epoch)+postfix+'.png'), dpi=dpi)
plt.close()

# Plot the training and validation mse vs. epoch number
plt.figure(figsize=(4.5, 4))
plt.semilogy(train_mse_history.cpu().detach().numpy(), label='train')
plt.semilogy(val_mse_history.cpu().detach().numpy(), label='val')
plt.xlabel("number of epochs")
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'reconst_mse_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Plot the history of pi
plt.figure(figsize=(4, 4))
for i in range(K):
    plt.plot(pi_history[:, i].cpu().detach().numpy(), label=text_labels[i]+r' $\pi$', color=label_colors[i])
plt.xlabel("Number of Epochs")
plt.ylabel("Predicted Cluster Probability")
plt.axhline(y=0.05, color='C1', linestyle='--', label='True Escape Probability')
plt.axhline(y=0.95, color='C3', linestyle='--', label='True Capture Probability')
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(dirname, 'pi_'+ str(epoch)+postfix+'.png'), dpi=dpi)
# plt.close()

# Load best model saved
params['pi_c'] = torch.load(os.path.join(dirname, 'gmm_params_pi'+ postfix + '.pt'))
params['mu_c'] = torch.load(os.path.join(dirname, 'gmm_params_mu'+ postfix + '.pt'))
params['logsigmasq_c'] = torch.load(os.path.join(dirname, 'gmm_params_logsigmasq'+ postfix + '.pt'))
encoder.load_state_dict(torch.load(os.path.join(dirname, 'encoder'+ postfix + '.pt')))
decoder.load_state_dict(torch.load(os.path.join(dirname, 'decoder'+ postfix + '.pt')))

encoder.eval()
decoder.eval()

# run one last EM step and plot training data in latent space
for encoder in encoder_list:
    encoder.eval()

with torch.no_grad():
    means = []
    samples = []
    labels = []
    params['hist_weights'] = torch.zeros((K, 1))
    params['hist_mu_c'] = torch.zeros((K, latent_dim))
    params['hist_logsigmasq_c'] = torch.zeros((K, latent_dim))
    for batch in train_loader:
        batch_x, batch_label = batch
        x_list = [batch_x]
        mu, logsigmasq = encoder_step(x_list, encoder_list, decoder_list)
        sigma = torch.exp(0.5 * logsigmasq)
        eps = Normal(0, 1).sample(mu.shape)
        z = mu + eps * sigma
        with torch.no_grad():
            gamma_c, mu_c, logsigmasq_c = em_step(z, mu, logsigmasq, params, em_reg, update_by_batch=True)
        params['mu_c'] = mu_c
        params['logsigmasq_c'] = logsigmasq_c

        means.append(mu)
        samples.append(z)
        labels.append(batch_label)

means = torch.vstack(means).cpu()
samples = torch.vstack(samples).cpu()
labels = torch.hstack(labels).cpu()


savepath = os.path.join(dirname, "BEST_latent_samples"+postfix)
plot_latent_space_with_clusters(samples, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

savepath = os.path.join(dirname, "BEST_latent_means"+postfix)
plot_latent_space_with_clusters(means, labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

# plot test data in latent space
with torch.no_grad():
    test_means = []
    test_labels = []
    for batch in test_loader:
        batch_x, batch_label = batch
        x_list = [batch_x]
        mean, _ = encoder_step(x_list, encoder_list, decoder_list)
        test_means.append(mean)
        test_labels.append(batch_label)

test_means = torch.vstack(test_means).cpu()
test_labels = torch.hstack(test_labels).cpu()


savepath = os.path.join(dirname, "BEST_test_latent_samples"+postfix)
plot_latent_space_with_clusters(test_means, test_labels, K, mu_c.cpu(), logsigmasq_c.cpu(), savepath, text_labels, label_colors, data_colors, dpi=dpi)

# plot decoding results from cluster means # todo: expand this function for multi-modal data
fig, ax = plt.subplots(figsize=(4.5, 4))
for i in range(K):
    # with torch.no_grad:
    x_mean = decoder.forward(params['mu_c'][i])[0]
    ax.plot(x_mean.cpu().detach().numpy(), label="decoded $\mu$"+str(i+1))
ax.legend()
plt.title("Decoded Means")
fig.savefig(os.path.join(dirname, "BEST_decoded_means"+postfix+'.png'), dpi=dpi)
# plt.close()

# plot samples from generative model
n_gen = n_train
cluster_probs = params['pi_c'].cpu().detach().numpy()
fig, ax = plt.subplots(figsize=(4.5, 4))
for j in range(n_gen):
    c = np.random.choice(K, p=cluster_probs)
    # print(c)
    mu_c = params['mu_c'][c].cpu().clone().detach()
    sigma_c = torch.exp(0.5 * params['logsigmasq_c'][c]).cpu().clone().detach()
    z = Normal(0, 1).sample(mu_c.shape).cpu().clone().detach() * sigma_c + mu_c
    # print(z)
    mu_x = decoder.forward(z.cuda())[0].cpu().clone().detach()
    sigma_x = torch.exp(0.5 * decoder.forward(z.cuda())[1])
    sample_x = Normal(0, 1).sample(mu_x.shape).cpu().clone().detach() * sigma_x.cpu().clone().detach() + mu_x
    ax.plot(sample_x.cpu().detach().numpy())
plt.title("Generated Samples")
fig.savefig(os.path.join(dirname, "BEST_generate_samples"+postfix+'.png'), dpi=dpi)
# plt.close()

np.savez(dirname + postfix, train_loss=train_loss.cpu().detach().numpy(), val_loss=val_loss.cpu().detach().numpy(),
      train_mse=train_mse_history.cpu().detach().numpy(), val_mse=val_mse_history.cpu().detach().numpy(),
      pi_history=pi_history.cpu().detach().numpy(),
      cluster_probs=params['pi_c'].cpu().detach().numpy(),
      cluster_means=params['mu_c'].cpu().detach().numpy(),
      cluster_vars=torch.exp(params['logsigmasq_c']).cpu().detach().numpy())


print("Training data size", n_train)
print("Fraction of downward curves:", (torch.sum(labels == 0) / n_train).item())
print("Cluster 1 probability:", cluster_probs.min().item())
# Out:
# Training data size 1024
# Fraction of downward curves: 0.8583984375
# Cluster 1 probability: 0.06394635885953903
# Error: 0.19335364114046094
